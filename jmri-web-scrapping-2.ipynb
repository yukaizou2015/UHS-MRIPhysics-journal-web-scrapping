# %% [markdown]
# # Web Scraping using Python

# %% [markdown]
# ## Target Journal: JMRI
# - https://onlinelibrary.wiley.com/toc/15222586/2022/55/1
# - https://onlinelibrary.wiley.com/toc/15222586/2021/54/6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#To easily display the plots, make sure to include the line %matplotlib inline as shown below.
# %matplotlib inline

import urllib
import requests
import lxml

#To perform web scraping, you should also import the libraries shown below. 
#The urllib.request module is used to open URLs. 
#The Beautiful Soup package is used to extract data from html files. 
#The Beautiful Soup library's name is bs4 which stands for Beautiful Soup, version 4.
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ## First, save as a local html file
#  - See: https://zetcode.com/python/beautifulsoup/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# JMRI Vol 54 No 1
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_Vol 54, No 1.html'
# JMRI Vol 54 No 2
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 54, No 2.html'
# JMRI Vol 54 No 3
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 54, No 3.html'
# Vol 54 No 4
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 54, No 4.html'
# Vol 54 No 5
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 54, No 5.html'
# Vol 54 No 6
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 54, No 6.html'
# Vol 55 No 1
URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 55, No 1.html'

with open(URL, 'r') as f:

    contents = f.read()

    soup = BeautifulSoup(contents, 'lxml')

# %% [markdown]
# Find the corresponding index, and identify the title info

# %%
def safeOpenParsePage(targetUrl):
    try:
        # tmpurl = urlopen(Request(targetUrl, headers={'User-Agent': 'Chrome/92.0.4515.107'}))
        tmpurl = open(targetUrl, 'r')
        tmpR = tmpurl.read()
        # tmpSoup = BeautifulSoup(tmpR, 'html.parser')
        tmpSoup = BeautifulSoup(tmpR, 'lxml')
        return tmpSoup
    except urllib.error.HTTPError as e:
        print(e)
        return None

soupJMRI = safeOpenParsePage(URL)
if soupJMRI is not None:
      print(soupJMRI.prettify())
# Out:
# <!DOCTYPE html>
# <html class="pb-page" data-request-id="cf15f650-9dbd-40f2-bc22-1827e3d04b82" lang="en">
#  <head data-pb-dropzone="head">
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content=";journal:journal:15222586;issue:issue:doi\:10.1002/jmri.v55.1;ctype:string:Journal Content;website:website:pericles;page:string:Table of Contents;requestedJournal:journal:15222586;wgroup:string:Publication Websites;pageGroup:string:Publication Pages" name="pbContext"/>
#   <script type="text/javascript">
#    var $DoubleClickZone = "j-magres-imaging_jmri";var $DoubleClickSite =  "wly.radiol.imag_000105";
#   </script>
#   <script id="analyticDigitalData">
#    digitalData = {"site":{"ip":"152.78.0.24","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2021-12-24"},"identities":[{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"ReferrerUser","uuid":"5a2c1d70-1255-4a45-95f3-a3aa3a2771fb"},{"type":"InstitutionUser","uuid":"58cbd8e6-3c5d-4fc0-ac26-57c4792d2c4b","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALWB000204"}]},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"SmartGroupUser","uuid":"cb1790a9-a0b9-40b3-915d-806df593aeeb"},{"type":"ReferrerUser","uuid":"6401b279-b825-4f41-a389-04e29feb967f"},{"type":"InstitutionUser","uuid":"bfa4ccf8-8126-488a-b090-da278aa7b4d9","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOG00017"}]},{"type":"BasicGroup","uuid":"6a17ff38-0daf-4f0a-b4eb-b42c69d5c12f","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000007783"}]},{"type":"BasicGroup","uuid":"9cb21bff-5e36-40b2-9183-08a76524dc18","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL57933332"}]},{"type":"InstitutionUser","uuid":"a7606ea9-e934-4307-a3d4-c30ec2175d59","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOB00014"}]},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"RegionUser","uuid":"3147507a-46c1-4f33-a077-4feac12c6b71"},{"type":"SmartGroupUser","uuid":"1a6297fb-6679-4882-a4c2-fdd124624edf"},{"type":"SmartGroupUser","uuid":"77da7ca2-c9f3-4f94-9737-922e1d15b7d9"},{"type":"SmartGroupUser","uuid":"8032f17e-5050-4fb4-9c40-e1f6875d5c2b"},{"type":"BasicGroup","uuid":"2f6750d5-f13f-4356-939b-048ac1423e64"},{"type":"SmartGroupUser","uuid":"a4187e00-f28e-4754-9a0f-1eb306fb0679"},{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"BasicGroup","uuid":"32489ba7-57d6-43ed-b717-a0de5ed5ca0e"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"InstitutionUser","uuid":"1b19994e-f6cd-4a6e-b151-a166eb757a02","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALEM00084"}]},{"type":"InstitutionUser","uuid":"838af7aa-2073-4eca-9e95-df167c7953bb","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"SOUTHA450S"}]},{"type":"InstitutionUser","uuid":"a454dd84-0b2c-4d7b-804b-20fd42da68c7","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"P#JISC"}]},{"type":"BasicGroup","uuid":"8b5697d0-0580-43b3-83ea-a258c8085ad5","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004148"}]},{"type":"InstitutionUser","uuid":"2196ade6-df1b-4d0d-b877-7d8cca58ee79","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"PARENTNESLI"}]},{"type":"BasicGroup","uuid":"8d568359-32d1-4757-be79-b72d00d11429"},{"type":"BasicGroup","uuid":"a9298b81-eb3e-4dfb-82a5-86f98d156f4d","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004150"}]},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"InstitutionUser","uuid":"c2c7b09d-2b4d-4ce1-b401-b744073e0ebc","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000165532"}]},{"type":"BasicGroup","uuid":"f0737c70-8d27-48b0-8b44-af576d0063e8","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000068532"}]},{"type":"SmartGroupUser","uuid":"261f34be-39f9-4f9e-8feb-500f73213904"},{"type":"InstitutionUser","uuid":"ca0c2bfa-0ec9-4312-aa4b-4c51702429d4","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL0000647"}]},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"20d013f5-e22b-4df0-ba93-d6d925db9e32"},{"type":"RegionUser","uuid":"82409588-c43f-4337-a6a8-3272d1b7e20e"},{"type":"SmartGroupUser","uuid":"055a2bdd-861f-4fa7-bd49-9773db7e0e3e"},{"type":"SmartGroupUser","uuid" ...
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="noarchive" name="robots"/>
#   <meta content=" Journal of Magnetic Resonance Imaging: Vol 55, No 1" property="og:title"/>
#   <meta content="Journal" property="og:type"/>
#   <meta content="https://onlinelibrary.wiley.com/toc/15222586/2022/55/1" property="og:url"/>
#   <meta content="https://onlinelibrary.wiley.com/cover/15222586/55/1" property="og:image"/>
#   <meta content="Wiley Online Library" property="og:site_name"/>
#   <meta content="Click on the title to browse this issue" property="og:description"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="app-id=673861322" name="apple-itunes-app"/>
#   <link as="script" href="https://cmp.osano.com/AzZdRbSORDOOzF9W/67a788d8-9344-4c9b-a3c2-89b5073ee231/osano.js" rel="preload"/>
#   <script src="https://cmp.osano.com/AzZdRbSORDOOzF9W/67a788d8-9344-4c9b-a3c2-89b5073ee231/osano.js">
#   </script>
#   <meta content="10.1002/jmri.v55.1" name="citation_doi"/>
#   <meta content="10.1002/jmri.v55.1" name="dc.identifier"/>
#   <title>
#    Journal of Magnetic Resonance Imaging: Vol 55, No 1
#   </title>
#   <link href="/wro/kugu~article-metrics-phase3.css" rel="stylesheet" type="text/css"/>
#   <link href="/wro/kugu~product.css" rel="stylesheet" type="text/css"/>
#   <link as="font" crossorigin="anonymous" href="/products/acropolis/pericles/releasedAssets/fonts/icomoon/icomoon.woff?65fa26f6e223b24e76d9" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/products/acropolis/pericles/releasedAssets/fonts/open-sans/open-sans-v15-latin-regular.woff2?65fa26f6e223b24e76d9" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="/products/acropolis/pericles/releasedAssets/fonts/source-serif-pro/source-serif-pro-v5-latin-regular.woff2?65fa26f6e223b24e76d9" rel="preload" type="font/woff2"/>
#   <link href="/products/acropolis/pericles/releasedAssets/css/build-65fa26f6e223b24e76d9.css" rel="stylesheet"/>
#   <link href="/products/acropolis/pericles/releasedAssets/css/print-65fa26f6e223b24e76d9.css" media="print" rel="stylesheet"/>
#   <script async="" src="/pb-assets/catchpoint-1549680351760.js">
#   </script>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/pb-assets/hub-assets/pericles/hub-1628068886633.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/iucr-1510734465460.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/readcube-1510565373110.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/dr-overrides-1611780866727.css" rel="stylesheet" type="text/css"/>
#   <!-- link rel="stylesheet" type="text/css" href="/pb-assets/css/temporary-1525702334993.css" -->
#   <style>
#    /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#   </style>
#   <!-- The Adobe DTM script. Must come after the digitalData object -->
#   <script src="//assets.adobedtm.com/6e626c9ec247e474f6b98eb15a79a185cf7e26a5/satelliteLib-c1ac050bbdc647f13a62578e71f0d817f8a6cbb5.js">
#   </script>
#   <!-- Google Search Console verification -->
#   <meta content="ffz4i4DxIJCdGpRXe0XN6KG6o4FYI-nnFW9I_dg8piM" name="google-site-verification"/>
#   <!-- KRUX Implementation-->
#   <script class="kxct" data-id="JMOONjNh" data-timing="async" data-version="1.9" type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#   </script>
#   <!-- KRUX Implementation cont'd -->
#   <script type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#   </script>
#   <!-- Grapeshot Implementation -->
#   <script>
#    var gs_channels = 'default';
#   </script>
#   <script async="" src="//wiley.grapeshot.co.uk/main/channels.cgi?url=https://onlinelibrary.wiley.com/toc/15222586/2022/55/1">
#   </script>
#   <!-- DoubleClick Implementation -->
#   <script type="text/javascript">
#    var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#   </script>
#   <script>
#    var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#   </script>
#   <script>
#    googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/jmri.v55.1')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#   </script>
#   <script src="//validate.onecount.net/js/all.min.js#cff4b10c3a3d5cc9bbb7e2b9292cc66eae1deafa">
#   </script>
#   <script>
#    try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#   </script>
#   <script data-cf-beacon='{"rayId":"65604cf31ed0e4d9","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.1","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script data-cf-beacon='{"rayId":"65cb04cf2c4898e7","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script async="" src="/cdn-cgi/bm/cv/669835187/api.js">
#   </script>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#   </script>
#   <script data-cf-beacon='{"rayId":"65d1a8e0c92cd32a","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <link href="https://onlinelibrary.wiley.com/toc/15222586/2022/55/1" rel="canonical"/>
#   <!-- Get whether TNSI is in live or test mode -->
#   <!-- Get the configured TNSI Javascript version number -->
#   <!-- Get the configured TNSI MerchantID -->
#   <!-- Add "TEST" to beginning of merchant ID when running in test mode -->
#   <!-- loading Javascript for using the persistence Service -->
#   <script src="//unpkg.com/@theidentityselector/thiss-ds">
#   </script>
#   <script type="text/javascript">
#    function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf('?') !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId, entityTitle) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId, entityTitle: entityTitle, eventGroupKey: '54ea5850-c31b-456c-a70d-421995c7244b'}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID, ssoInstitution.entity.title)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#   </script>
#   <script type="text/javascript">
#    (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaasnb9hO7BTq4Wwu9P3x';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#   </script>
#   <script>
#    var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Journal of Magnetic Resonance Imaging: Vol 55, No 1";
#   </script>
#  </head>
#  <body class="pb-ui">
#   <div class="skip-links">
#    <ul class="rlist">
#     <li>
#      <a href="#main-content" tabindex="1">
#       Skip to Main Content
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div data-ng-non-bindable="" id="pb-page-content">
#    <div data-pb-dropzone="main" data-pb-dropzone-name="Main">
#     <div class="pageHeader" data-widget-def="pageHeader" data-widget-id="62175478-b98a-43d5-90f2-1f2045ac1a7e">
#      <header class="page-header">
#       <div data-pb-dropzone="main">
#        <div class="admin-message" data-widget-def="ux3-layout-widget" data-widget-id="bb5b5e2c-d3d6-4015-b586-eeade38f59d4">
#         <div class="container">
#          <div class="row">
#           <div>
#            <div class="pb-ad">
#             <div style="background=blue;">
#              <div class="container">
#               <p style="text-align: center;">
#                <b>
#                 Working off-campus?
#                </b>
#                Learn about our
#                <a href="/action/clickThrough?id=101169&amp;url=https%3A%2F%2Fonlinelibrary.wiley.com%2Fresearchers%2Fread%2Faccess-options&amp;loc=%2Ftoc%2F15222586%2F2022%2F55%2F1&amp;pubId=76272116&amp;placeholderId=1029&amp;productId=1011" tabindex="2" target="_blank">
#                 <font color="white">
#                  <u>
#                   remote access options
#                  </u>
#                 </font>
#                </a>
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="container">
#         <div class="row">
#          <div class="contents col-md-12">
#           <div class="institution-wrapper-mobile hidden-lg hidden-md padded-content" data-widget-def="UX3InstitutionBanner" data-widget-id="4d1f2e23-571a-4b27-8ab7-e7cd8ca15964">
#            <div class="institution">
#             <div class="institution-box no-image">
#              <div class="institution-info-wrapper">
#               <span class="institution__name">
#                University of Southampton
#               </span>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="pull-left">
#            <div class="logo-container hidden-xs hidden-sm hidden-md" data-widget-def="ux3-general-image" data-widget-id="ff262197-0fb8-4973-aaa2-2fceba4b5a61">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mainLogo" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#             </a>
#            </div>
#            <div class="logo-container-mobile hidden-lg hidden-md hidden-sm" data-widget-def="ux3-general-image" data-widget-id="6b601b23-7301-47c8-8889-242d041241c4">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mobileLogo" src="/pb-assets/hub-assets/pericles/mobilehublogo-1518781861020.png"/>
#             </a>
#            </div>
#            <div class="institution-wrapper hidden-xs hidden-sm hidden-md institution--block" data-widget-def="UX3InstitutionBanner" data-widget-id="14d0e2f8-27d3-42d0-a477-72015e14e818">
#             <div class="institution">
#              <div class="institution-box no-image">
#               <div class="institution-info-wrapper">
#                <span class="institution__name">
#                 University of Southampton
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="header-quicksearch" data-widget-def="UX3QuickSearchWidget" data-widget-id="48175bb0-0f70-46e6-bb89-7e2781fdb8e4">
#             <div class="quick-search-wrapper">
#              <a aria-label="Search" class="quick-search__item" href="#" title="search">
#               <i aria-hidden="true" class="icon-search">
#               </i>
#               <span class="quick-search__item__arrow">
#               </span>
#              </a>
#              <div class="quick-search quickSearchFormContainer" data-linkto-page="true">
#               <div class="main-search-field-wrapper">
#                <div class="tab clearfix">
#                 <input class="fakeQSInput quickSearchFilter" placeholder="Search" tabindex="13" type="search" value=""/>
#                 <label class="sr-only" for="search-within">
#                  Search within
#                 </label>
#                 <select class="search-within" id="search-within" name="search-within" tabindex="10">
#                  <option data-url="thisCategory" data-value="15222586" value="#pane-67065c09-4a88-49cd-934c-ac707951d35c0">
#                   This Journal
#                  </option>
#                  <option data-url="https://onlinelibrary.wiley.com" value="#pane-67065c09-4a88-49cd-934c-ac707951d35c1">
#                   Anywhere
#                  </option>
#                 </select>
#                 <ul class="rlist tab__content" role="tablist">
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c0-con" class="tab__pane quick-search-pane__anywhere active" id="pane-67065c09-4a88-49cd-934c-ac707951d35c0" role="tab">
#                   <form action="/action/doSearch" method="get" name="thisJournalQuickSearch" title="Quick Search">
#                    <div class="input-group option-0">
#                     <label class="hiddenLabel" for="searchField0">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField0" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <input name="SeriesKey" type="hidden" value="15222586"/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222586" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222586#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c1-con" class="tab__pane quick-search-pane__anywhere" id="pane-67065c09-4a88-49cd-934c-ac707951d35c1" role="tab">
#                   <form action="https://onlinelibrary.wiley.com/action/doSearch" method="get" name="defaultQuickSearch" title="Quick Search">
#                    <div class="input-group option-1">
#                     <label class="hiddenLabel" for="searchField1">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField1" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="cart-indicator__wrapper" data-widget-def="ux3-layout-widget" data-widget-id="5ef13ed1-f4ac-4b62-a426-07ec9576a586">
#             <div class="pull-left">
#              <div class="cart-indicator__wrapper" data-widget-def="eCommerceCartIndicatorWidget" data-widget-id="4a9f7c04-a273-4a25-91fb-8e7bd9970288">
#               <div class="eCommerceCartIndicatorWidget">
#               </div>
#              </div>
#             </div>
#             <div class="pull-right">
#              <div class="login-bar-container" data-widget-def="literatumNavigationLoginBar" data-widget-id="d384ca92-7137-45d6-b3c2-78c9c0a98c2b">
#               <div class="loginBar login-open">
#                <a aria-label="Log in or Register" class="show-login" href="/action/showLogin?uri=%2Ftoc%2F15222586%2F2022%2F55%2F1&amp;aria-label=Log+in+or+Register" role="button" uri="/toc/15222586/2022/55/1">
#                 <span class="icon-profile_empty">
#                 </span>
#                 <span class="sign-in-label">
#                  Login / Register
#                 </span>
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </header>
#     </div>
#     <h1 class="hidden">
#      Journal list menu
#     </h1>
#     <div class="pages-nav--sticky pages-nav hidden-lg fixed-element">
#      <div class="pages-nav--res">
#       <div class="container">
#        <ul class="rlist--inline pull-left">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="journal-list" href="#">
#           <i aria-hidden="true" class="icon-toc">
#           </i>
#           <span>
#            Journal
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="journal-list" id="journal-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-1, #menu-item-undefined-2, #menu-item-main-menu-1-1, #menu-item-main-menu-1-2, #menu-item--1, #menu-item--2, .journal-featured" data-toggle="transplant" data-transplant="self">
#           </div>
#           <!-- PERICLES-7683
#               <a href="#" title="More from this journal" class="dropdown__toggle"><span>More from this journal</span></a>
#
#                 <div data-target=".journal-resources" data-remove="false" data-toggle="transplant" data-direction="from" data-transplant="self" class="transplant showit"></div>
# -->
#          </div>
#         </li>
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="articles-list" href="#">
#           <i class="article-img-icon">
#            <img src="/pb-assets/hub-assets/pericles/articles_1-1499257321163.png"/>
#           </i>
#           <span>
#            Articles
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="articles-list" id="articles-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-3, #menu-item-undefined-4, #menu-item-main-menu-1-3, #menu-item-main-menu-1-4, #menu-item--3" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#        <ul class="rlist--inline pull-right">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="actions-list" href="#">
#           <span>
#            Actions
#           </span>
#           <i aria-hidden="true" class="icon-chevron-down">
#           </i>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="actions-list" id="actions-list">
#           <h2 class="side-section-header hiddenLabel--lg">
#            Tools
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target=".journal-actions-container li:nth-child(1), .journal-actions-container li:nth-child(2), .journal-actions-container li:nth-child(3), .journal-actions-container li:nth-child(4), .journal-actions-container li:nth-child(5), #subscribeLink" data-toggle="transplant" data-transplant="self">
#           </div>
#           <h2 class="side-section-header hiddenLabel--lg">
#            Follow journal
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#alert-link, #facebook-link, #twitter-link, #linkedin-link, #most-recent-link, #most-read-link, #most-cited-link" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="pageBody body-text" data-widget-def="pageBody" data-widget-id="72100436-7a82-49fc-933b-c6c9d8c42914">
#      <main id="main-content" tabindex="-1">
#       <!--begin pagefulltext-->
#       <div class="page-body pagefulltext">
#        <div data-pb-dropzone="main">
#         <div class="js--fixed-switch" data-widget-def="ux3-layout-widget" data-widget-id="6da55ccb-5daf-4c91-b961-05eee9e6f293">
#          <div>
#           <div class="secondary-bg-color banner-wrapper" data-widget-def="literatumAd" data-widget-id="0220a30b-90c0-4b51-8637-141edf12f86a">
#            <div class="pb-ad">
#             <aside role="complementary">
#              <div class="advert advert-leaderboard" id="advert-leaderboard">
#               <script>
#                googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#               </script>
#               <!-- No JavaScript support is a call to an image -->
#               <noscript>
#                <a href="/action/clickThrough?id=1013&amp;url=https%3A%2F%2Fpubads.g.doubleclick.net%2Fgampad%2Fjump%3Fiu%3D%24googlePublisherCategory%26amp%3Bsz%3D728x90%26amp%3Btile%3D1%26amp%3Bc%3D%24random&amp;loc=%2Ftoc%2F15222586%2F2022%2F55%2F1&amp;pubId=76272116&amp;placeholderId=1015&amp;productId=101018" target="_blank">
#                 <img src="https://pubads.g.doubleclick.net/gampad/ad?iu=$googlePublisherCategory&amp;sz=728x90&amp;tile=1&amp;c=$random"/>
#                </a>
#               </noscript>
#              </div>
#             </aside>
#            </div>
#           </div>
#           <style type="text/css">
#            li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#           </style>
#           <section class="journal-page-header card" data-widget-def="ux3-layout-widget" data-widget-id="9e8ee65a-2e18-4c00-9474-5ac10e16ecfe">
#            <div class="container">
#             <div class="row">
#              <div class="journal-info-container col-md-8">
#               <a href="/journal/15222586" title="Journal of Magnetic Resonance Imaging homepage">
#                <h1 id="journal-banner-text" style="margin: 0; font-size: 0">
#                 Journal of Magnetic Resonance Imaging
#                </h1>
#                <img alt="Journal of Magnetic Resonance Imaging" class="journal-banner-image" id="journal-banner-image" src="/pb-assets/journal-banners/15222586-1590394653627.jpg" style="margin-bottom: 15px; display: none"/>
#               </a>
#               <script>
#                var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222586-1590394653627.jpg";
#               </script>
#              </div>
#              <div class="hidden-xs hidden-sm hidden-md col-md-4">
#              </div>
#             </div>
#            </div>
#           </section>
#           <div class="stickybar pages-nav hidden-xs hidden-sm hidden-md scrollable-element" data-widget-def="menuWidget" data-widget-id="998218b4-f988-4a0c-8c4f-b2d3875e1770">
#            <div class="stickybar__wrapper">
#             <div class="main-nav">
#              <a data-toggle="nav" href="#undefined" title="menu drawer">
#               <i aria-hidden="true" class="icon-menu2">
#               </i>
#               <i aria-hidden="true" class="icon-close_thin">
#               </i>
#              </a>
#              <nav aria-label="Journal navigation" class="drawer__nav container gutterless hidden-sm hidden-xs" data-ctrl-res="never" role="navigation">
#               <h2 class="is-accessible">
#                Navigation Bar
#               </h2>
#               <section>
#                <h3 class="is-accessible">
#                 Menu
#                </h3>
#                <a class="menu-header hidden-md hidden-lg" href="/">
#                 Home
#                </a>
#                <ul class="menubar rlist--inline" id="menubar" role="menubar">
#                 <li class="menu-item" data-menu-label="Home" id="menu-item-undefined-0" role="presentation">
#                  <a class="sub-menu-item" href="/journal/15222586" role="menuitem" tabindex="0">
#                   <span>
#                    Home
#                   </span>
#                  </a>
#                 </li>
#                 <li class="dropdown menu-parent" data-menu-label="About" id="menu-item-undefined-1" role="presentation">
#                  <a aria-expanded="false" aria-haspopup="true" class="dropdown__toggle" data-target="About-1-dropdown" data-toggle="dropdown" href="#" id="About-1" role="menuitem" tabindex="-1">
#                   <span>
#                    About
#                   </span>
#                   <i aria-hidden="true" class="icon-arrow_r pull-right hidden-md hidden-lg">
#                   </i>
#                   <i aria-hidden="true" class="icon-section_arrow_d pull-right hidden-sm hidden-xs">
#                   </i>
#                  </a>
#                  <ul aria-labelledby="About-1" class="rlist dropdown__menu" id="About-1-dropdown" role="menu">
#                   <li class="menu-item" data-menu-label="Overview" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222586/homepage/productinformation.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Overview
#                     </span>
# ...
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://www.wiley.com/privacy">
#                 Privacy Policy
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/terms-and-conditions">
#                 Terms of Use
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/cookies">
#                 Cookies
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/accessibility">
#                 Accessibility
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/publishing-policies">
#                 Publishing Policies
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Help &amp; Support
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://hub.wiley.com/community/support/onlinelibrary">
#                 Contact Us
#                </a>
#               </li>
#               <li>
#                <a href="https://www.wiley.com/customer-success/wiley-online-library-training-hub">
#                 Training and Support
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/dmca-notification-policy">
#                 DMCA &amp; Reporting Piracy
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Opportunities
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://onlinelibrary.wiley.com/agents">
#                 Subscription Agents
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/advertisers">
#                 Advertisers &amp; Corporate Partners
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Connect with Wiley
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://www.wiley.com/network">
#                 The Wiley Network
#                </a>
#               </li>
#               <li>
#                <a href="https://newsroom.wiley.com/">
#                 Wiley Press Room
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="copyright-container" data-widget-def="ux3-layout-widget" data-widget-id="86584e25-e4db-4118-9550-9b4f5341a4ac">
#          <div class="container">
#           <div class="row">
#            <div class=" col-md-12">
#             <div class="copyright" data-widget-def="UX3HTMLWidget" data-widget-id="bfbf6c5d-a650-4662-828f-5275fada9120">
#              <div class="copyright pull-left">
#               Copyright © 1999-2021
#               <a href="https://www.wiley.com">
#                John Wiley &amp; Sons, Inc
#               </a>
#               . All rights reserved
#              </div>
#             </div>
#             <div class="footer-logo pull-right">
#              <a aria-label="Wiley" href="https://www.wiley.com" title="Wiley Home Page">
#               <img alt="Wiley Home Page" src="/pb-assets/tmp-images/footer-logo-wiley-1510029248417.png"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#     <div aria-labelledby="loginPopupHead" class="popup login-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="Cancel Login" class="close" href="#" role="button">
#        <i aria-hidden="true" class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#       </div>
#       <div class="modal__body">
#        <div class="ssoLogin">
#        </div>
#        <h2 id="loginPopupHead">
#         Log in to Wiley Online Library
#        </h2>
#        <div class="login-form">
#         <form action="/action/doLogin?societyURLCode=" class="bordered" method="post">
#          <input name="id" type="hidden" value="67065c09-4a88-49cd-934c-ac707951d35c"/>
#          <input name="popup" type="hidden" value="true"/>
#          <input name="loginUri" type="hidden" value="/toc/15222586/2022/55/1"/>
#          <input name="redirectUri" type="hidden" value="/toc/15222586/2022/55/1"/>
#          <input name="loginUri" type="hidden" value="/toc/15222586/2022/55/1"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="username">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="login" id="username" name="login" placeholder="Enter your email" required="true" size="15" spellcheck="false" type="text" value=""/>
#           <div class="actions">
#           </div>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="password">
#             Password
#            </label>
#           </div>
#           <input autocapitalize="off" autocomplete="off" autocorrect="off" class="password" id="password" name="password" placeholder="Enter your password" required="true" spellcheck="false" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="actions">
#           <a class="link show-request-reset-password" href="/action/requestResetPassword">
#            Forgot password?
#           </a>
#          </div>
#          <div class="loginExtraBeans-dropZone" data-pb-dropzone="loginExtraBeans">
#          </div>
#          <div class="align-end">
#           <span class="submit ">
#            <input class="button btn submit primary no-margin-bottom accessSubmit" name="submitButton" type="submit" value="Log In"/>
#           </span>
#          </div>
#         </form>
#         <div class="societySpecificInstructions">
#         </div>
#        </div>
#        <div class="login-container clearfix form-btn">
#         <a class="linkBtn float-left" href="/action/registration">
#          NEW USER
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#         <a class="linkBtn float-right instituation-login" href="/action/ssostart?redirectUri=%2Ftoc%2F15222586%2F2022%2F55%2F1">
#          INSTITUTIONAL LOGIN
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="changePasswordPopupHead" class="popup change-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close cancel" href="#" role="button">
#        <i class="icon-close_thin">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="changePasswordPopupHead">
#         Change Password
#        </h2>
#       </div>
#       <div class="modal__body">
#        <div class="form">
#         <form action="/action/changePassword" method="post">
#          <div class="message error">
#          </div>
#          <input name="submit" type="hidden" value="submit"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-old">
#             Old Password
#            </label>
#           </div>
#           <input autocomplete="off" class="old" id="a589574e-bb98-4c6e-8fed-67365ff05357-old" name="old" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-new">
#             New Password
#            </label>
#           </div>
#           <input autocomplete="off" class="pass-hint new" id="a589574e-bb98-4c6e-8fed-67365ff05357-new" name="new" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#           <div class="password-strength-indicator" data-max="32" data-min="10" data-strength="3">
#            <span class="text too-short">
#             Too Short
#            </span>
#            <span class="text weak">
#             Weak
#            </span>
#            <span class="text medium">
#             Medium
#            </span>
#            <span class="text strong">
#             Strong
#            </span>
#            <span class="text very-strong">
#             Very Strong
#            </span>
#            <span class="text too-long">
#             Too Long
#            </span>
#           </div>
#          </div>
#          <input class="button primary submit" disabled="disabled" type="submit" value="Submit"/>
#         </form>
#         <a class="fakeFormLastElement" href="#">
#         </a>
#        </div>
#        <div class="success-template hidden">
#         <h2>
#          Password Changed Successfully
#         </h2>
#         <p>
#          Your password has been changed
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="createAccountPopupHead" class="popup registration-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close" href="#" role="button">
#        <i class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="logoDropZone" data-pb-dropzone="logoDropZone">
#        </div>
#        <h2 id="createAccountPopupHead">
#         Create a new account
#        </h2>
#       </div>
#       <div class="modal__body">
#        <form action="/action/registration" class="registration-form" method="post">
#         <input name="redirectUri" type="hidden" value="/toc/15222586/2022/55/1"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="4e647394-f751-4441-baa4-df426bca4b6e.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="4e647394-f751-4441-baa4-df426bca4b6e.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="submit">
#          <input class="button submit primary" type="submit" value="Register"/>
#         </div>
#        </form>
#        <div class="center">
#         <a class="show-login" href="/action/showLogin">
#          Returning user
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="resetPasswordPopupHead" class="popup top-drawer request-reset-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <div class="modal__header">
#        <a aria-label="close dialog" class="cancel close" href="#" role="button">
#         <i class="icon-close_thin">
#         </i>
#        </a>
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="resetPasswordPopupHead">
#         Forgot your password?
#        </h2>
#        <p class="sub">
#         Enter your email address below.
#        </p>
#       </div>
#       <div class="modal__body">
#        <div class="error">
#        </div>
#        <form action="/action/requestResetPassword" class="request-reset-password-form" method="post">
#         <input name="requestResetPassword" type="hidden" value="true"/>
#         <div class="input-group">
#          <div class="input-group">
#           <div class="label">
#            <label for="email">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="email" id="email" name="email" placeholder="Enter your email" size="15" spellcheck="false" type="text" value=""/>
#          </div>
#         </div>
#         <div class="password-recaptcha-ajax">
#         </div>
#         <div class="form-btn">
#          <input class="button btn primary submit" disabled="disabled" name="submit" type="submit" value="RESET PASSWORD"/>
#         </div>
#        </form>
#        <div class="message error">
#        </div>
#        <div class="success-template hidden">
#         <p>
#          Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div>
#      <div class="pb-dropzone" data-pb-dropzone="col-0" title="col-0">
#      </div>
#     </div>
#     <div aria-labelledby="requestUsernamePopupHead" class="popup top-drawer request-username-drawer username-popup hidden" role="dialog" tabindex="-1">
#      <a aria-label="close dialog" class="close" href="#" role="button">
#       <i class="icon-close_thin">
#       </i>
#      </a>
#      <div class="content">
#       <h2 id="requestUsernamePopupHead">
#        Request Username
#       </h2>
#       <div class="form">
#        <p>
#         Can't sign in? Forgot your username?
#        </p>
#        <p class="sub">
#         Enter your email address below and we will send you your username
#        </p>
#        <div class="message error">
#        </div>
#        <form action="/action/requestUsername" method="post">
#         <input name="requestUsername" type="hidden" value="requestUsername"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="username-recaptcha-ajax">
#         </div>
#         <input class="button primary submit" disabled="disabled" name="submit" type="submit" value="Submit"/>
#         <div class="center">
#          <a class="cancel" href="#">
#           Close
#          </a>
#         </div>
#        </form>
#       </div>
#       <div class="success-template hidden note">
#        <p>
#         If the address matches an existing account you will receive an email with instructions to retrieve your username
#        </p>
#       </div>
#      </div>
#     </div>
#     <!-- Belongs at the bottom of the page -->
#     <script type="text/javascript">
#      if(window._satellite) {
# _satellite.pageBottom();
# }
#     </script>
#    </div>
#   </div>
#   <script src="/wro/kugu~article-metrics-phase2.js" type="text/javascript">
#   </script>
#   <script src="/products/acropolis/pericles/releasedAssets/js/build.lazyload.bundle-d86f0dc0b2a236cbd960.js">
#   </script>
#   <script src="/products/acropolis/pericles/releasedAssets/js/main.bundle-746913b324d43c03ed0f.js">
#   </script>
#   <script src="/wro/kugu~product.js" type="text/javascript">
#   </script>
#   <script>
#    var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"6c2994288ad874d5","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194">
#   </script>
#  </body>
# </html>

# %%
# Get the title
title = soupJMRI.title
print(title)
# Out:
# <title> Journal of Magnetic Resonance Imaging: Vol 55, No 1</title>

# %%
# Print out the text
text = soupJMRI.get_text()
print(soup.text)

# Another way to extract text
# str(all_links[103]).split("<h2>")[1].replace("</h2></a>", "")
# Out:
# var $DoubleClickZone = "j-magres-imaging_jmri";var $DoubleClickSite =  "wly.radiol.imag_000105";digitalData = {"site":{"ip":"152.78.0.24","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2021-12-24"},"identities":[{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"ReferrerUser","uuid":"5a2c1d70-1255-4a45-95f3-a3aa3a2771fb"},{"type":"InstitutionUser","uuid":"58cbd8e6-3c5d-4fc0-ac26-57c4792d2c4b","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALWB000204"}]},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"SmartGroupUser","uuid":"cb1790a9-a0b9-40b3-915d-806df593aeeb"},{"type":"ReferrerUser","uuid":"6401b279-b825-4f41-a389-04e29feb967f"},{"type":"InstitutionUser","uuid":"bfa4ccf8-8126-488a-b090-da278aa7b4d9","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOG00017"}]},{"type":"BasicGroup","uuid":"6a17ff38-0daf-4f0a-b4eb-b42c69d5c12f","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000007783"}]},{"type":"BasicGroup","uuid":"9cb21bff-5e36-40b2-9183-08a76524dc18","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL57933332"}]},{"type":"InstitutionUser","uuid":"a7606ea9-e934-4307-a3d4-c30ec2175d59","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOB00014"}]},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"RegionUser","uuid":"3147507a-46c1-4f33-a077-4feac12c6b71"},{"type":"SmartGroupUser","uuid":"1a6297fb-6679-4882-a4c2-fdd124624edf"},{"type":"SmartGroupUser","uuid":"77da7ca2-c9f3-4f94-9737-922e1d15b7d9"},{"type":"SmartGroupUser","uuid":"8032f17e-5050-4fb4-9c40-e1f6875d5c2b"},{"type":"BasicGroup","uuid":"2f6750d5-f13f-4356-939b-048ac1423e64"},{"type":"SmartGroupUser","uuid":"a4187e00-f28e-4754-9a0f-1eb306fb0679"},{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"BasicGroup","uuid":"32489ba7-57d6-43ed-b717-a0de5ed5ca0e"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"InstitutionUser","uuid":"1b19994e-f6cd-4a6e-b151-a166eb757a02","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALEM00084"}]},{"type":"InstitutionUser","uuid":"838af7aa-2073-4eca-9e95-df167c7953bb","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"SOUTHA450S"}]},{"type":"InstitutionUser","uuid":"a454dd84-0b2c-4d7b-804b-20fd42da68c7","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"P#JISC"}]},{"type":"BasicGroup","uuid":"8b5697d0-0580-43b3-83ea-a258c8085ad5","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004148"}]},{"type":"InstitutionUser","uuid":"2196ade6-df1b-4d0d-b877-7d8cca58ee79","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"PARENTNESLI"}]},{"type":"BasicGroup","uuid":"8d568359-32d1-4757-be79-b72d00d11429"},{"type":"BasicGroup","uuid":"a9298b81-eb3e-4dfb-82a5-86f98d156f4d","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004150"}]},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"InstitutionUser","uuid":"c2c7b09d-2b4d-4ce1-b401-b744073e0ebc","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000165532"}]},{"type":"BasicGroup","uuid":"f0737c70-8d27-48b0-8b44-af576d0063e8","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000068532"}]},{"type":"SmartGroupUser","uuid":"261f34be-39f9-4f9e-8feb-500f73213904"},{"type":"InstitutionUser","uuid":"ca0c2bfa-0ec9-4312-aa4b-4c51702429d4","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL0000647"}]},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"20d013f5-e22b-4df0-ba93-d6d925db9e32"},{"type":"RegionUser","uuid":"82409588-c43f-4337-a6a8-3272d1b7e20e"},{"type":"S ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Journal of Magnetic Resonance Imaging: Vol 55, No 1
#
#
#
#
#
#
#
#
#
#
#
#
# /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#
#
#
#
#
#
#
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#
#
#
# 	var gs_channels = 'default';
#
#
#
#
# 	var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#
#
# 	var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#
#
# 	googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/jmri.v55.1')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#
#
#
# 	try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#
#
#
# (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#
#
#
#
#
#
#
#
#
#         function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf('?') !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId, entityTitle) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId, entityTitle: entityTitle, eventGroupKey: '54ea5850-c31b-456c-a70d-421995c7244b'}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID, ssoInstitution.entity.title)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#
#
#
#         (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaasnb9hO7BTq4Wwu9P3x';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#
#
#     var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Journal of Magnetic Resonance Imaging: Vol 55, No 1";
#
#
#
#
# Skip to Main Content
#
#
#
#
#
#
#
#
#
#
#
#
# Working off-campus? Learn about our remote access options
#
#
#
#
#
#
#
# University of Southampton
#
#
#
#
#
#
#
#
#
# University of Southampton
#
#
#
# Search withinThis JournalAnywhereSearch term  Advanced Search  Citation SearchSearch term  Advanced Search  Citation Search
#
#
#
#
#
#
#
#
#
#
#
#
# Login / Register
#
#
#
#
#
#
#
#
#
#
#  Journal list menu
#
#
#
#
# Journal
#
#
#
#
#
# Articles
#
#
#
#
#
#
# Actions
#
# Tools
#
# Follow journal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
# li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#
#
#
# Journal of Magnetic Resonance Imaging
#
#
#
# var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222586-1590394653627.jpg";
#
#
#
#
# Navigation BarMenuHomeHomeAboutOverviewContactEditorial BoardOA AdvantagesAdvertisePermissionsContributeAuthor GuidelinesOpen AccessSubmit a Manuscript For Referees BrowseAccepted ArticlesEarly ViewCurrent IssueAll IssuesCover GalleryVirtual Issues
#
#
# Follow journal
#
# Alert
#
#
#
#
#
# RSS Feeds
#
#
# Most recent (RSS)
#
# Most cited (RSS)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# IssueVolume 55,  Issue 1Pages: spcone, 1-312January 2022
#
# Previous Issue
#
#
#
# GO TO SECTION
#
#
#
#
#
#
#
#
# Export Citation(s)
# Export CitationsFormatPlain TextRIS (ProCite, Reference Manager)EndNoteBibTexMedlarsRefWorksType of importCitation file or direct importIndirect import or copy/pasteCancelNext< Go backCitation HelpExport
#
#
# Cover Image
#
# Full Access
#
#
# full
#
# Four-Dimensional flow Magnetic Resonance Imaging for Assessment of Pediatric Coarctation of the Aorta
#
#  Lajja Desai MD,
#  Heather Stefek MD,
#  Haben Berhane MA,
#  Joshua Robinson MD,
#  Cynthia Rigsby MD,
#  Michael Markl PhD,
#
#
# Pages: spcone
# First Published: 15 December 2021
#
#
#
# 4D Pathline Images Comparing Flow Patterns and Maximum Intensity Projections (MIPS) of Aortic Peak Systolic Velocities in the Ascending Aorta (AAO), Transverse Arch (ARCH), and Descending Aorta (DAO) by Desai et al. (200-208)
#
#
#
#
#
#
# AbstractPDFRequest permissions
#
#
#
#
# Issue Information
#
# Free Access
#
#
# free
#
# Issue Information
# Pages: 1-10
# First Published: 15 December 2021
#
#
#
# First PagePDFRequest permissions
#
#
#
#
# JMRI-ISMRM Recommendation
#
# Full Access
#
#
# full
#
# Histological Validation of MRI: A Review of Challenges in Registration of Imaging and Whole-Mount Histopathology
#
#  Wadha Alyami MSc,
#  Andre Kyme PhD,
#  Roger Bourne PhD,
#
#
# Pages: 11-22
# First Published: 31 October 2020
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Review Articles
#
# Full Access
#
#
# full
#
# VI-RADS for Bladder Cancer: Current Applications and Future Developments
#
#  Valeria Panebianco MD,
#  Martina Pecoraro MD,
#  Francesco Del Giudice MD,
#  Mitsuru Takeuchi PhD,
#  Valdair F. Muglia PhD,
#  Emanuele Messina MD,
#  Stefano Cipollari MD,
#  Gianluca Giannarini MD,
#  Carlo Catalano MD,
#  Yoshifumi Narumi PhD,
#
#
# Pages: 23-36
# First Published: 17 September 2020
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Primary Site Identification of Soft-Tissue Mass: Things to Know in MRI Assessment
#
#  Takatoshi Aoki MD, PhD,
#  Akitaka Fujisaki MD, PhD,
#  Takashi Terasawa MD, PhD,
#  Yoshiko Hayashida MD, PhD,
#  Yo Todoroki MD,
#  Natsumi Hirano MD,
#  Masanori Hisaoka MD, PhD,
#  Akinori Sakai MD, PhD,
#  Yukunori Korogi MD, PhD,
#
#
# Pages: 37-47
# First Published: 18 September 2020
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Machine Learning in Meningioma MRI: Past to Present. A Narrative Review
#
#  Eleftherios Neromyliotis MD, PhD,
#  Theodosis Kalamatianos PhD,
#  Athanasios Paschalis MD,
#  Spyridon Komaitis MD, MSc,
#  Konstantinos N. Fountas MD, PhD,
#  Eftychia Z. Kapsalaki MD, PhD,
#  George Stranjalis MD, PhD,
#  Ioannis Tsougos PhD,
#
#
# Pages: 48-60
# First Published: 02 October 2020
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Black-Blood Contrast in Cardiovascular MRI
#
#  Markus Henningsson PhD,
#  Shaihan Malik PhD,
#  Rene Botnar PhD,
#  Daniel Castellanos MD,
#  Tarique Hussain MD,
#  Tim Leiner MD, PhD,
#
#
# Pages: 61-80
# First Published: 19 October 2020
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Real-Time Magnetic Resonance Imaging
#
#  Krishna S. Nayak PhD,
#  Yongwan Lim PhD,
#  Adrienne E. Campbell-Washburn PhD,
#  Jennifer Steeden PhD,
#
#
# Pages: 81-99
# First Published: 09 December 2020
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Abdomen
#
# Full Access
#
#
# full
#
# Integrative Machine Learning Prediction of Prostate Biopsy Results From Negative Multiparametric MRI
#
#  Haoxin Zheng MS,
#  Qi Miao MD,
#  Yongkai Liu MS,
#  Steven S. Raman MD,
#  Fabien Scalzo PhD,
#  Kyunghyun Sung PhD,
#
#
# Pages: 100-110
# First Published: 23 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# MRI-Based Quantitative R2* Mapping at 3 Tesla Reflects Hepatic Iron Overload and Pathogenesis in Nonalcoholic Fatty Liver Disease Patients
#
#  Kento Imajo MD, PhD,
#  Takaomi Kessoku MD, PhD,
#  Yasushi Honda MD, PhD,
#  Sho Hasegawa MD, PhD,
#  Wataru Tomeno MD, PhD,
#  Yuji Ogawa MD, PhD,
#  Utaroh Motosugi MD, PhD,
#  Yusuke Saigusa MD, PhD,
#  Masato Yoneda MD, PhD,
#  Hiroyuki Kirikoshi MD, PhD,
#  Shoji Yamanaka MD, PhD,
#  Daisuke Utsunomiya MD, PhD,
#  Satoru Saito MD, PhD,
#  Atsushi Nakajima MD, PhD,
#
#
# Pages: 111-125
# First Published: 28 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Multi-shot Diffusion-Weighted MRI With Multiplexed Sensitivity Encoding (MUSE) in the Assessment of Active Inflammation in Crohn's Disease
#
#  Hing-Chiu Chang PhD,
#  Guangtao Chen MS,
#  Hsiao-Wen Chung PhD,
#  Philip Yuguang Wu MD,
#  Liyuan Liang BS,
#  Chun-Jung Juan MD, PhD,
#  Yi-Jui Liu PhD,
#  Man-Lap Donald Tse MD,
#  Arren Chan MBBS,
#  Sailong Zhang MS,
#  Keith Wan-Hang Chiu MD,
#
#
# Pages: 126-137
# First Published: 25 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Multi-Shot Diffusion-Weighted Imaging With Multiplexed Sensitivity Encoding (MUSE) in the Assessment of Active Inflammation in Crohn's Disease”
#
#  Mathilde Vermersch,
#  Mustapha Azahaf MD, PhD,
#  Olivier Ernst MD, PhD,
#
#
# Pages: 138-139
# First Published: 19 June 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Neuro
#
# Open Access
#
#
# oa
#
# Longitudinal Sodium MRI of Multiple Sclerosis Lesions: Is there Added Value of Sodium Inversion Recovery MRI
#
#  Angelika B. Mennecke MS,
#  Armin M. Nagel PhD,
#  Konstantin Huhn MD,
#  Ralf A. Linker MD,
#  Manuel Schmidt MD,
#  Veit Rothhammer MD,
#  Tobias Wilferth MS,
#  Peter Linz PhD,
#  Julius Wegmann MS,
#  Felix Eisenhut MD,
#  Tobias Engelhorn MD,
#  Arnd Doerfler MD, PhD,
#
#
# Pages: 140-151
# First Published: 14 July 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Longitudinal Sodium MRI of Multiple Sclerosis Lesions: Is There Added Value of Sodium Inversion Recovery MRI?”
#
#  Tomohisa Okada MD, PhD,
#  Thai Akasaka MD, PhD,
#
#
# Pages: 152-153
# First Published: 29 July 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Neuro
#
# Open Access
#
#
# oa
#
# Unraveling the MRI-Based Microstructural Signatures Behind Primary Progressive and Relapsing–Remitting Multiple Sclerosis Phenotypes
#
#  Ilaria Boscolo Galazzo PhD,
#  Lorenza Brusini PhD,
#  Muge Akinci MSc,
#  Federica Cruciani MSc,
#  Marco Pitteri PhD,
#  Stefano Ziccardi PhD,
#  Albulena Bajrami MD,
#  Marco Castellaro PhD,
#  Ahmed M.A. Salih MSc,
#  Francesca B. Pizzini MD, PhD,
#  Jorge Jovicich PhD,
#  Massimiliano Calabrese MD, PhD,
#  Gloria Menegaz PhD,
#
#
# Pages: 154-163
# First Published: 30 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Unraveling the MRI-Based Microstructural Signatures Behind Primary Progressive and Relapsing-Remitting Multiple Sclerosis Phenotypes”
#
#  Bramsh Qamar Chandio MS, PhD Candidate,
#
#
# Pages: 164-165
# First Published: 23 July 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Neuro
#
# Full Access
#
#
# full
#
# Improved Brain MR Imaging from a Compact, Lightweight 3T Scanner with High-Performance Gradients
#
#  Emanuele Camerucci MD,
#  Norbert G. Campeau MD,
#  Joshua D. Trzasko PhD,
#  Erin M. Gray MS, MHA,
#  Matt A. Bernstein PhD,
#  Petrice M. Cogswell MD, PhD,
#  Yunhong Shu PhD,
#  Thomas K. Foo PhD,
#  John Huston III MD,
#
#
# Pages: 166-175
# First Published: 28 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Improved Brain MR Imaging from a Compact, Lightweight 3 Tesla Scanner With High Performance Gradients”
#
#  Gergely Orsi PhD,
#
#
# Pages: 176-177
# First Published: 11 July 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Neuro
#
# Full Access
#
#
# full
#
# Arterial Transit Time-Based Multidelay Combination Strategy Improves Arterial Spin Labeling Cerebral Blood Flow Measurement Accuracy in Severe Steno-Occlusive Diseases
#
#  Shiori Amemiya MD, PhD,
#  Yusuke Watanabe MD, PhD,
#  Naoyuki Takei MS,
#  Tsuyoshi Ueyama MS,
#  Satoru Miyawaki MD, PhD,
#  Satoshi Koizumi MD, PhD,
#  Seiji Kato MS,
#  Hidemasa Takao MD, PhD,
#  Osamu Abe MD, PhD,
#  Nobuhito Saito MD, PhD,
#
#
# Pages: 178-187
# First Published: 15 July 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Arterial Transit Time–Based Multidelay Combination Strategy Improves Arterial Spin Labeling MRI Cerebral Blood Flow Measurement Accuracy in Severe Steno-Occlusive Diseases”
#
#  Nobuyuki Kosaka MD, PhD,
#  Hirohiko Kimura MD, PhD,
#
#
# Pages: 188-189
# First Published: 25 August 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Cardiac
#
# Open Access
#
#
# oa
#
# Histopathological Validation of Dark-Blood Late Gadolinium Enhancement MRI Without Additional Magnetization Preparation
#
#  Robert J. Holtackers MSc,
#  Suzanne Gommers MD,
#  Luuk I.B. Heckman MD,
#  Caroline M. Van De Heyning MD, PhD,
#  Amedeo Chiribiri MD, PhD,
#  Frits W. Prinzen PhD,
#
#
# Pages: 190-197
# First Published: 24 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Histopathological Validation of Dark-Blood Late Gadolinium Enhancement Cardiovascular Magnetic Resonance Without Additional Magnetization Preparation”
#
#  Patrick Krumm MD,
#  Simon Greulich MD,
#  Konstantin Nikolaou MD,
#
#
# Pages: 198-199
# First Published: 27 July 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Cardiac
#
# Full Access
#
#
# full
#
# Four-Dimensional flow Magnetic Resonance Imaging for Assessment of Pediatric Coarctation of the Aorta
#
#  Lajja Desai MD,
#  Heather Stefek MD,
#  Haben Berhane MA,
#  Joshua Robinson MD,
#  Cynthia Rigsby MD,
#  Michael Markl PhD,
#
#
# Pages: 200-208
# First Published: 26 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “4D flow MRI for Assessment of Pediatric Coarctation of the Aorta”
#
#  Amir Awwad MRCS, FRCR,
#
#
# Pages: 209-210
# First Published: 06 July 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Cardiac
#
# Open Access
#
#
# oa
#
# Traveling Volunteers: A Multi-Vendor, Multi-Center Study on Reproducibility and Comparability of 4D Flow Derived Aortic Hemodynamics in Cardiovascular Magnetic Resonance
#
#  Aylin Demir MD,
#  Stephanie Wiesemann MD,
#  Jennifer Erley MD,
#  Sebastian Schmitter PhD,
#  Ralf Felix Trauzeddel MD,
#  Burkert Pieske MD,
#  Jochen Hansmann MD,
#  Sebastian Kelle MD,
#  Jeanette Schulz-Menger MD,
#
#
# Pages: 211-222
# First Published: 25 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Open Access
#
#
# oa
#
# Editorial for “Traveling Volunteers – A Multi-Vendor, Multi-Center Study on Reproducibility and Comparability of 4D Flow Derived Aortic Hemodynamics in Cardiovascular Magnetic Resonance”
#
#  Marko Boban MD, PhD, MBA,
#
#
# Pages: 223-224
# First Published: 22 June 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Musculoskeletal
#
# Full Access
#
#
# full
#
# DWI and IVIM Imaging in a Murine Model of Rhabdomyosarcoma: Correlations with Quantitative Histopathologic Features
#
#  Shaobo Fang MD,
#  Yanyu Yang MD,
#  Bo Chen MD,
#  Zhenzhen Yin MD,
#  Yajie Liu MS,
#  Juan Tao PhD,
#  Yu Zhang PhD,
#  Yuan Yuan MD,
#  Qi Wang PhD,
#  Shaowu Wang PhD,
#
#
# Pages: 225-233
# First Published: 08 July 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Cartilage Matrix Changes in Hindfoot Joints in Chronic Ankle Instability Patients After Anatomic Repair Using T2-Mapping: Initial Experience With 3-Year Follow-Up
#
#  Hongyue Tao MD,
#  Yuyang Zhang MD,
#  Yiwen Hu MD,
#  Qianru Li MD,
#  Yinghui Hua PhD,
#  Rong Lu MD,
#  Yuxie Xie MD,
#  Xiangwen Li MD,
#  Bo Zhang MD,
#  Shuang Chen PhD,
#
#
# Pages: 234-243
# First Published: 30 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Cartilage Matrix Changes in Hindfoot Joints in Chronic Ankle Instability Patients After Anatomic Repair Using T2-Mapping: Initial Experience With 3-Year Follow-Up”
#
#  Andrew J. Wheaton PhD,
#
#
# Pages: 244-245
# First Published: 28 July 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Vascular
#
# Full Access
#
#
# full
#
# Quiescent-Interval Slice-Selective MRA Accurately Estimates Intravascular Stent Dimensions Prior to Intervention in Patients With Peripheral Artery Disease
#
#  Josua A. Decker MD,
#  Andreas M. Fischer MD,
#  U. Joseph Schoepf MD,
#  Fei Xiong MS,
#  Thomas M. Todoran MD,
#  Jonathan Aldinger MS,
#  Lauren Ellis BS,
#  Robert R. Edelman MD,
#  Ioannis Koktzoglou PhD,
#  Tilman Emrich MD,
#  Akos Varga-Szemes MD, PhD,
#
#
# Pages: 246-254
# First Published: 29 July 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Pelvis
#
# Full Access
#
#
# full
#
# Diffusion MRI Based Myometrium Tractography for Detection of Placenta Accreta Spectrum Disorder
#
#  Guohui Yan MD,
#  Yuhao Liao MD,
#  Kui Li MD,
#  Xiaodan Zhang MD,
#  Weizeng Zheng MD,
#  Yi Zhang MD,
#  Yu Zou MD,
#  Danqing Chen PhD,
#  Dan Wu PhD,
#
#
# Pages: 255-264
# First Published: 21 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Utility of Quantitative T2-Mapping Compared to Conventional and Advanced Diffusion Weighted Imaging Techniques for Multiparametric Prostate MRI in Men with Hip Prosthesis
#
#  Paul Sathiadoss MD,
#  Nicola Schieda MD,
#  Mohammad Haroon MD,
#  Heba Osman MD,
#  Sumaya Alrasheed MD,
#  Trevor A. Flood MD,
#  Gerd Melkus PhD,
#
#
# Pages: 265-274
# First Published: 05 July 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Preliminary Exploration of the Application of Vesical Imaging-Reporting and Data System (VI-RADS) in Post-treatment Patients With Bladder Cancer: A Prospective Single-Center Study
#
#  Bohong Cao BS,
#  Qing Li BS,
#  Peirong Xu BS,
#  Weijie Chen BS,
#  Xiaoyi Hu MD,
#  Chenchen Dai BS,
#  Yingchan Shan BS,
#  Yuqin Ding PhD, MD,
#  Wei Mao MD,
#  Kai Liu BS,
#  Pu-Yeh Wu,
#  Weiling Sun BS,
#  Shengxiang Rao PhD, MD,
#  Mengsu Zeng PhD, MD,
#  Shuai Jiang PhD, MD,
#  Jianjun Zhou PhD, MD,
#
#
# Pages: 275-286
# First Published: 28 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Preliminary Exploration of the Application of Vesical Imaging-Reporting and Data System (VI-RADS) in Post-Treatment Patients with Bladder Cancer: A Prospective Single-Center Study”
#
#  Sara Lewis MD,
#  Matthew Galsky MD,
#
#
# Pages: 287-288
# First Published: 19 July 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Technical
#
# Full Access
#
#
# full
#
# Abdominal T2-Weighted Imaging and T2 Mapping Using a Variable Flip Angle Radial Turbo Spin-Echo Technique
#
#  Mahesh B. Keerthivasan PhD,
#  Jean-Philippe Galons PhD,
#  Kevin Johnson BA,
#  Lavanya Umapathy MS,
#  Diego R. Martin MD, PhD,
#  Ali Bilgin PhD,
#  Maria I. Altbach PhD,
#
#
# Pages: 289-300
# First Published: 13 July 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Application of Multiparametric Magnetic Resonance Imaging to Monitor the Early Antitumor Effect of CuS@GOD Nanoparticles in a 4 T1 Breast Cancer Xenograft Model
#
#  Yao-Jiang Ye MS,
#  Xiu-Jie Huang PhD,
#  Bi-Chong Luo MS,
#  Xiao-Ying Wang PhD,
#  Xiang-Ran Cai MD,
#
#
# Pages: 301-310
# First Published: 24 August 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Application of Multiparametric Magnetic Resonance Imaging to Monitor the Early Antitumor Effect of CuS@GOD Nanoparticles in a 4T1 Breast Cancer Xenograft Model”
#
#  Oscar Jalnefjord PhD,
#
#
# Pages: 311-312
# First Published: 27 July 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
# Tools
#
# Submit an Article
# Browse free sample issue
# Get content alerts
#
#
#
#
#
# Subscribe to this journal
#
#
#
#
#
#
#
#                 More from this journal
#
# Professional OpportunitiesISMRM Journal AppsW.S. Moore Award Winning ArticlesOther ResourcesFull Issue PDFs
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-rail-1' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			googletag.cmd.push 		( function () {
# 				googletag.display 	( 'advert-rail-2' );
# 			});
#
#
#
#
#
#
#
#
#
#
#
#
#                 Related Title
#
# IssueVolume 87, Issue 2Pages: C1, 551-1092February 2022
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     .footer-links {
#         text-align: center;
#     }
#     .footer-links h3 {
#         font-weight: 300;
#     }
#     .footer-links a {
#         font-weight: 600;
#     }
#     @media (min-width: 992px) {
#         .footer-links {
#             text-align: left;
#         }
#     }
#
#
#
#                 Additional links
#
#
#
# About Wiley Online Library
#
# Privacy Policy
# Terms of Use
# Cookies
# Accessibility
# Publishing Policies
#
#
#
#
# Help & Support
#
# Contact Us
# Training and Support
# DMCA & Reporting Piracy
#
#
#
#
# Opportunities
#
# Subscription Agents
# Advertisers & Corporate Partners
#
#
#
#
# Connect with Wiley
#
# The Wiley Network
# Wiley Press Room
#
#
#
#
#
#
#
# Copyright © 1999-2021 John Wiley & Sons, Inc. All rights reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Log in to Wiley Online Library
#
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Password
#
#
#
#
#
#
#                                 Forgot password?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         NEW USER >
#
#
#
#                             INSTITUTIONAL LOGIN >
#
#
#
#
#
#
#
#
#
#
#
#
# Change Password
#
#
#
#
#
#
#
# Old Password
#
#
#
#
#
#
# New Password
#
#
#
#
# Too Short
# Weak
# Medium
# Strong
# Very Strong
# Too Long
#
#
#
#
#
#
# Password Changed Successfully
# Your password has been changed
#
#
#
#
#
#
#
#
#
#
# Create a new account
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#                     Returning user
#
#
#
#
#
#
#
#
#
#
#
#
# Forgot your password?
# Enter your email address below.
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#
# Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#
#
#
#
#
#
#
#
# Request Username
#
# Can't sign in? Forgot your username?
# Enter your email address below and we will send you your username
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Close
#
#
#
# If the address matches an existing account you will receive an email with instructions to retrieve your username
#
#
#
#
#
# if(window._satellite) {
# _satellite.pageBottom();
# }
#
#
#
#
#
#
# var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();

# %%
all_links = soupJMRI.find_all('a')

# %% [markdown]
# ### Explore Category

# %%
# h3 class corresponds to editorial

all_h3 = soupJMRI.find_all("h3")

i = 0
for h3 in all_h3:
  # print(h3)
  print(h3.get_text())
  i += 1
print(i)
# Out:
# Menu
# Format
# Type of import
# Cover Image
# Issue Information
# JMRI-ISMRM Recommendation
# Review Articles
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# About Wiley Online Library
# Help & Support
# Opportunities
# Connect with Wiley
# 33

# %% [markdown]
# ### Explore Original Research Subcategory

# %%
# h4 class corresponds to category

all_h4 = soupJMRI.find_all("h4")

i = 0
for h4 in all_h4:
  # print(h4)
  print(h4.get_text())
  i += 1
print(i)
# Out:
# Abdomen
# Neuro
# Neuro
# Neuro
# Neuro
# Cardiac
# Cardiac
# Cardiac
# Musculoskeletal
# Vascular
# Pelvis
# Technical
# 12

# %%
all_h2 = soupJMRI.find_all("h2")

i = 0
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 3:
    print(h2.get_text())
    i += 1
print(i)

# str_h2 = str(all_h2)

# links = soupJMRI.find_all("a")
# str_links = str(links)
# print(str_h2)

# cleantext = BeautifulSoup(str_h2, "lxml").get_text()
# cleantext = BeautifulSoup(str_links, "lxml").get_text()
# print(cleantext)
# Out:
# Four-Dimensional flow Magnetic Resonance Imaging for Assessment of Pediatric Coarctation of the Aorta
# Histological Validation of MRI: A Review of Challenges in Registration of Imaging and Whole-Mount Histopathology
# VI-RADS for Bladder Cancer: Current Applications and Future Developments
# Primary Site Identification of Soft-Tissue Mass: Things to Know in MRI Assessment
# Machine Learning in Meningioma MRI: Past to Present. A Narrative Review
# Black-Blood Contrast in Cardiovascular MRI
# Real-Time Magnetic Resonance Imaging
# Integrative Machine Learning Prediction of Prostate Biopsy Results From Negative Multiparametric MRI
# MRI-Based Quantitative R2* Mapping at 3 Tesla Reflects Hepatic Iron Overload and Pathogenesis in Nonalcoholic Fatty Liver Disease Patients
# Multi-shot Diffusion-Weighted MRI With Multiplexed Sensitivity Encoding (MUSE) in the Assessment of Active Inflammation in Crohn's Disease
# Editorial for “Multi-Shot Diffusion-Weighted Imaging With Multiplexed Sensitivity Encoding (MUSE) in the Assessment of Active Inflammation in Crohn's Disease”
# Longitudinal Sodium MRI of Multiple Sclerosis Lesions: Is there Added Value of Sodium Inversion Recovery MRI
# Editorial for “Longitudinal Sodium MRI of Multiple Sclerosis Lesions: Is There Added Value of Sodium Inversion Recovery MRI?”
# Unraveling the MRI-Based Microstructural Signatures Behind Primary Progressive and Relapsing–Remitting Multiple Sclerosis Phenotypes
# Editorial for “Unraveling the MRI-Based Microstructural Signatures Behind Primary Progressive and Relapsing-Remitting Multiple Sclerosis Phenotypes”
# Improved Brain MR Imaging from a Compact, Lightweight 3T Scanner with High-Performance Gradients
# Editorial for “Improved Brain MR Imaging from a Compact, Lightweight 3 Tesla Scanner With High Performance Gradients”
# Arterial Transit Time-Based Multidelay Combination Strategy Improves Arterial Spin Labeling Cerebral Blood Flow Measurement Accuracy in Severe Steno-Occlusive Diseases
# Editorial for “Arterial Transit Time–Based Multidelay Combination Strategy Improves Arterial Spin Labeling MRI Cerebral Blood Flow Measurement Accuracy in Severe Steno-Occlusive Diseases”
# Histopathological Validation of Dark-Blood Late Gadolinium Enhancement MRI Without Additional Magnetization Preparation
# Editorial for “Histopathological Validation of Dark-Blood Late Gadolinium Enhancement Cardiovascular Magnetic Resonance Without Additional Magnetization Preparation”
# Four-Dimensional flow Magnetic Resonance Imaging for Assessment of Pediatric Coarctation of the Aorta
# Editorial for “4D flow MRI for Assessment of Pediatric Coarctation of the Aorta”
# Traveling Volunteers: A Multi-Vendor, Multi-Center Study on Reproducibility and Comparability of 4D Flow Derived Aortic Hemodynamics in Cardiovascular Magnetic Resonance
# Editorial for “Traveling Volunteers – A Multi-Vendor, Multi-Center Study on Reproducibility and Comparability of 4D Flow Derived Aortic Hemodynamics in Cardiovascular Magnetic Resonance”
# DWI and IVIM Imaging in a Murine Model of Rhabdomyosarcoma: Correlations with Quantitative Histopathologic Features
# Cartilage Matrix Changes in Hindfoot Joints in Chronic Ankle Instability Patients After Anatomic Repair Using T2-Mapping: Initial Experience With 3-Year Follow-Up
# Editorial for “Cartilage Matrix Changes in Hindfoot Joints in Chronic Ankle Instability Patients After Anatomic Repair Using T2-Mapping: Initial Experience With 3-Year Follow-Up”
# Quiescent-Interval Slice-Selective MRA Accurately Estimates Intravascular Stent Dimensions Prior to Intervention in Patients With Peripheral Artery Disease
# Diffusion MRI Based Myometrium Tractography for Detection of Placenta Accreta Spectrum Disorder
# Utility of Quantitative T2-Mapping Compared to Conventional and Advanced Diffusion Weighted Imaging Techniques for Multiparametric Prostate MRI in Men with Hip Prosthesis
# Preliminary Exploration of the Application of Vesical Imaging-Reporting and Data System (VI-RADS) in Post-treatment Patients With Bladder Cancer: A Prospective Single-Center Study
# Editorial for “Preliminary Exploration of the Application of Vesical Imaging-Reporting and Data System (VI-RADS) in Post-Treatment Patients with Bladder Cancer: A Prospective Single-Center Study”
# Abdominal T2-Weighted Imaging and T2 Mapping Using a Variable Flip Angle Radial Turbo Spin-Echo Technique
# Application of Multiparametric Magnetic Resonance Imaging to Monitor the Early Antitumor Effect of CuS@GOD Nanoparticles in a 4 T1 Breast Cancer Xenograft Model
# Editorial for “Application of Multiparametric Magnetic Resonance Imaging to Monitor the Early Antitumor Effect of CuS@GOD Nanoparticles in a 4T1 Breast Cancer Xenograft Model”
#
#                 More from this journal
#
# Log in to Wiley Online Library
# Create a new account
# 39

# %% [markdown]
# ## Next, clean up the title list

# %%
list_h2 = []
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 3:
    cells = h2.get_text()
    list_h2.append(cells)

# Delete the last element: "Log in to Wiley Online Library"
list_h2.pop()

# Insert "Issue Information" as the 2nd element
list_h2.insert(1, "Issue Information")

# JMRI Vol 54 No 2
# list_h2.append("Erratum")

# JMRI Vol 54 No 3
# list_h2.insert(2, "Commentary")
# list_h2.append("Condensation Artifact")
# list_h2.append("Reviewer Acknowledgements")

# JMRI Vol 54 No 6
# list_h2.insert(2, "ISMRM Young Investigator Award Winners")

# JMRI Vol 55 No 1 Pop out a few more
list_h2 = list_h2[:-2]

for l in list_h2:
  print(l)
print(len(list_h2))
# Out:
# Four-Dimensional flow Magnetic Resonance Imaging for Assessment of Pediatric Coarctation of the Aorta
# Issue Information
# Histological Validation of MRI: A Review of Challenges in Registration of Imaging and Whole-Mount Histopathology
# VI-RADS for Bladder Cancer: Current Applications and Future Developments
# Primary Site Identification of Soft-Tissue Mass: Things to Know in MRI Assessment
# Machine Learning in Meningioma MRI: Past to Present. A Narrative Review
# Black-Blood Contrast in Cardiovascular MRI
# Real-Time Magnetic Resonance Imaging
# Integrative Machine Learning Prediction of Prostate Biopsy Results From Negative Multiparametric MRI
# MRI-Based Quantitative R2* Mapping at 3 Tesla Reflects Hepatic Iron Overload and Pathogenesis in Nonalcoholic Fatty Liver Disease Patients
# Multi-shot Diffusion-Weighted MRI With Multiplexed Sensitivity Encoding (MUSE) in the Assessment of Active Inflammation in Crohn's Disease
# Editorial for “Multi-Shot Diffusion-Weighted Imaging With Multiplexed Sensitivity Encoding (MUSE) in the Assessment of Active Inflammation in Crohn's Disease”
# Longitudinal Sodium MRI of Multiple Sclerosis Lesions: Is there Added Value of Sodium Inversion Recovery MRI
# Editorial for “Longitudinal Sodium MRI of Multiple Sclerosis Lesions: Is There Added Value of Sodium Inversion Recovery MRI?”
# Unraveling the MRI-Based Microstructural Signatures Behind Primary Progressive and Relapsing–Remitting Multiple Sclerosis Phenotypes
# Editorial for “Unraveling the MRI-Based Microstructural Signatures Behind Primary Progressive and Relapsing-Remitting Multiple Sclerosis Phenotypes”
# Improved Brain MR Imaging from a Compact, Lightweight 3T Scanner with High-Performance Gradients
# Editorial for “Improved Brain MR Imaging from a Compact, Lightweight 3 Tesla Scanner With High Performance Gradients”
# Arterial Transit Time-Based Multidelay Combination Strategy Improves Arterial Spin Labeling Cerebral Blood Flow Measurement Accuracy in Severe Steno-Occlusive Diseases
# Editorial for “Arterial Transit Time–Based Multidelay Combination Strategy Improves Arterial Spin Labeling MRI Cerebral Blood Flow Measurement Accuracy in Severe Steno-Occlusive Diseases”
# Histopathological Validation of Dark-Blood Late Gadolinium Enhancement MRI Without Additional Magnetization Preparation
# Editorial for “Histopathological Validation of Dark-Blood Late Gadolinium Enhancement Cardiovascular Magnetic Resonance Without Additional Magnetization Preparation”
# Four-Dimensional flow Magnetic Resonance Imaging for Assessment of Pediatric Coarctation of the Aorta
# Editorial for “4D flow MRI for Assessment of Pediatric Coarctation of the Aorta”
# Traveling Volunteers: A Multi-Vendor, Multi-Center Study on Reproducibility and Comparability of 4D Flow Derived Aortic Hemodynamics in Cardiovascular Magnetic Resonance
# Editorial for “Traveling Volunteers – A Multi-Vendor, Multi-Center Study on Reproducibility and Comparability of 4D Flow Derived Aortic Hemodynamics in Cardiovascular Magnetic Resonance”
# DWI and IVIM Imaging in a Murine Model of Rhabdomyosarcoma: Correlations with Quantitative Histopathologic Features
# Cartilage Matrix Changes in Hindfoot Joints in Chronic Ankle Instability Patients After Anatomic Repair Using T2-Mapping: Initial Experience With 3-Year Follow-Up
# Editorial for “Cartilage Matrix Changes in Hindfoot Joints in Chronic Ankle Instability Patients After Anatomic Repair Using T2-Mapping: Initial Experience With 3-Year Follow-Up”
# Quiescent-Interval Slice-Selective MRA Accurately Estimates Intravascular Stent Dimensions Prior to Intervention in Patients With Peripheral Artery Disease
# Diffusion MRI Based Myometrium Tractography for Detection of Placenta Accreta Spectrum Disorder
# Utility of Quantitative T2-Mapping Compared to Conventional and Advanced Diffusion Weighted Imaging Techniques for Multiparametric Prostate MRI in Men with Hip Prosthesis
# Preliminary Exploration of the Application of Vesical Imaging-Reporting and Data System (VI-RADS) in Post-treatment Patients With Bladder Cancer: A Prospective Single-Center Study
# Editorial for “Preliminary Exploration of the Application of Vesical Imaging-Reporting and Data System (VI-RADS) in Post-Treatment Patients with Bladder Cancer: A Prospective Single-Center Study”
# Abdominal T2-Weighted Imaging and T2 Mapping Using a Variable Flip Angle Radial Turbo Spin-Echo Technique
# Application of Multiparametric Magnetic Resonance Imaging to Monitor the Early Antitumor Effect of CuS@GOD Nanoparticles in a 4 T1 Breast Cancer Xenograft Model
# Editorial for “Application of Multiparametric Magnetic Resonance Imaging to Monitor the Early Antitumor Effect of CuS@GOD Nanoparticles in a 4T1 Breast Cancer Xenograft Model”
# 37

# %% [markdown]
# ### Add dates first published

# %%
# li class: corresponds to "First Published"

all_li = soupJMRI.find_all("li")

# i = 0
# for li in all_li:
  # li_class = li.get_attribute_list("class")
  # print(li_class)
  # if li_class == ['ePubDate']:
    # print(li.get_text())
    # i += 1
  # print(li.get_text())
  # i += 1
# print(i)

list_date = []
for li in all_li:
  li_class = li.get_attribute_list("class")
  if li_class == ['ePubDate']:
    cells = li.get_text().split(': ')[1]
    list_date.append(cells)

for l in list_date:
  print(l)
print(len(list_date))
# Out:
# 15 December 2021
# 15 December 2021
# 31 October 2020
# 17 September 2020
# 18 September 2020
# 02 October 2020
# 19 October 2020
# 09 December 2020
# 23 June 2021
# 28 June 2021
# 25 June 2021
# 19 June 2021
# 14 July 2021
# 29 July 2021
# 30 June 2021
# 23 July 2021
# 28 June 2021
# 11 July 2021
# 15 July 2021
# 25 August 2021
# 24 June 2021
# 27 July 2021
# 26 June 2021
# 06 July 2021
# 25 June 2021
# 22 June 2021
# 08 July 2021
# 30 June 2021
# 28 July 2021
# 29 July 2021
# 21 June 2021
# 05 July 2021
# 28 June 2021
# 19 July 2021
# 13 July 2021
# 24 August 2021
# 27 July 2021
# 37

# %%
list_url = []
for link in all_links:
  if 'visitable' in str(link.get("class")): # and '/doi/' in link.get("href"):
    cells = link.get("href").replace('/doi', 'https://doi.org')
    list_url.append(cells)

for l in list_url:
  print(l)
print(len(list_url))
# Out:
# https://doi.org/10.1002/jmri.27704
# https://doi.org/10.1002/jmri.27705
# https://doi.org/10.1002/jmri.27409
# https://doi.org/10.1002/jmri.27361
# https://doi.org/10.1002/jmri.27368
# https://doi.org/10.1002/jmri.27378
# https://doi.org/10.1002/jmri.27399
# https://doi.org/10.1002/jmri.27411
# https://doi.org/10.1002/jmri.27793
# https://doi.org/10.1002/jmri.27810
# https://doi.org/10.1002/jmri.27801
# https://doi.org/10.1002/jmri.27795
# https://doi.org/10.1002/jmri.27832
# https://doi.org/10.1002/jmri.27872
# https://doi.org/10.1002/jmri.27806
# https://doi.org/10.1002/jmri.27862
# https://doi.org/10.1002/jmri.27812
# https://doi.org/10.1002/jmri.27831
# https://doi.org/10.1002/jmri.27823
# https://doi.org/10.1002/jmri.27901
# https://doi.org/10.1002/jmri.27805
# https://doi.org/10.1002/jmri.27855
# https://doi.org/10.1002/jmri.27802
# https://doi.org/10.1002/jmri.27798
# https://doi.org/10.1002/jmri.27804
# https://doi.org/10.1002/jmri.27800
# https://doi.org/10.1002/jmri.27828
# https://doi.org/10.1002/jmri.27809
# https://doi.org/10.1002/jmri.27835
# https://doi.org/10.1002/jmri.27864
# https://doi.org/10.1002/jmri.27794
# https://doi.org/10.1002/jmri.27803
# https://doi.org/10.1002/jmri.27807
# https://doi.org/10.1002/jmri.27843
# https://doi.org/10.1002/jmri.27825
# https://doi.org/10.1002/jmri.27867
# https://doi.org/10.1002/jmri.27868
# 37

# %%
# df = pd.DataFrame({'title':list_h2, 'url': list_url})
df = pd.DataFrame({'Journal': title, 
                   #'Category': list_category, 
                   'Title': list_h2, 
                   'First Published': list_date, 
                   'DOI': list_url})
df
# Out:
#                                               Journal  ...                                 DOI
# 0    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27704
# 1    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27705
# 2    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27409
# 3    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27361
# 4    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27368
# 5    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27378
# 6    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27399
# 7    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27411
# 8    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27793
# 9    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27810
# 10   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27801
# 11   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27795
# 12   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27832
# 13   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27872
# 14   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27806
# 15   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27862
# 16   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27812
# 17   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27831
# 18   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27823
# 19   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27901
# 20   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27805
# 21   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27855
# 22   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27802
# 23   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27798
# 24   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27804
# 25   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27800
# 26   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27828
# 27   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27809
# 28   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27835
# 29   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27864
# 30   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27794
# 31   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27803
# 32   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27807
# 33   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27843
# 34   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27825
# 35   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27867
# 36   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27868
#
# [37 rows x 4 columns]

# %% [markdown]
# ## Third, manually create the list of category based on Issue Information
#  - See [here](https://stackoverflow.com/questions/4654414/python-append-item-to-list-n-times) for extending elements in a list for X times

# %%
# list_category = ['Cover Image', 'Issue Information', 'Commentary']

### Vol 54 No 1 ###
# list_category.extend(['Review Articles'] * 3)
# list_category.extend(['Original Research: Head and Neck', 'Editorial'] * 2)
# list_category.extend(['Original Research: Pelvis'] * 1)
# list_category.extend(['Original Research: Abdomen'] * 1)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 2)
# list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 1)
# list_category.extend(['Original Research: Musculoskeletal'] * 1)
# list_category.extend(['Original Research: Vascular'] * 1)
# list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)
# list_category.extend(['Original Research: Neuro'] * 3)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 3)
# list_category.extend(['Original Research: Breast', 'Editorial'] * 1)
# list_category.extend(['Original Research: Pediatrics', 'Editorial'] * 1)
# list_category.extend(['Original Research: Cardiac'] * 2)
# list_category.extend(['Original Research: Cardiac', 'Editorial'] * 2)
# list_category.extend(['Original Research: Safety', 'Editorial'] * 1)
# list_category.extend(['Letter to the Editor'] * 1)

### Vol 54 No 2 ###
# list_category.extend(['CME Article'] * 1)
# list_category.extend(['Review Articles'] * 3)
# list_category.extend(['Original Research: Whole Body', 'Editorial'] * 1)
# list_category.extend(['Original Research: Cardiac'] * 4)
# list_category.extend(['Original Research: Pelvis', 'Editorial'] * 2)
# list_category.extend(['Original Research: Technical', 'Editorial'] * 1)
# list_category.extend(['Original Research: Musculoskeletal'] * 2)
# list_category.extend(['Original Research: Abdomen'] * 3)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 1)
# list_category.extend(['Original Research: Neuro'] * 2)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 4)
# list_category.extend(['Original Research: Thoracic', 'Editorial'] * 1)
# list_category.extend(['Original Research: Breast'] * 1)
# list_category.extend(['Original Research: Vascular'] * 1)
# list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)
# list_category.extend(['Original Research: Case Report'] * 1)
# list_category.extend(['Erratum'] * 1)

### Vol 54 No 3 ###
# list_category.extend(['Review Articles'] * 1)
# list_category.extend(['Original Research: Breast'] * 1)
# list_category.extend(['Original Research: Abdomen'] * 2)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 3)
# list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)
# list_category.extend(['Original Research: Cardiac'] * 2)
# list_category.extend(['Original Research: Cardiac', 'Editorial'] * 2)
# list_category.extend(['Original Research: Pediatrics', 'Editorial'] * 1)
# list_category.extend(['Original Research: Musculoskeletal'] * 1)
# list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 1)
# list_category.extend(['Original Research: Head and Neck'] * 1)
# list_category.extend(['Original Research: Neuro'] * 2)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 6)
# list_category.extend(['Original Research: Thoracic'] * 1)
# list_category.extend(['Original Research: Pelvis', 'Editorial'] * 2)
# list_category.extend(['Original Research: Technical'] * 1)
# list_category.extend(['Original Research: Technical', 'Editorial'] * 1)
# list_category.extend(['Case Report: Technical'] * 1)
# list_category.extend(['Reviewer Appreciation'] * 1)

### Vol 54 No 4 ###
# list_category = ['Cover Image', 'Issue Information']
# list_category.extend(['Review Articles'] * 1)
# list_category.extend(['Original Research: Neuro'] * 3)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 2)
# list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)
# list_category.extend(['Original Research: Pediatrics'] * 1)
# list_category.extend(['Original Research: Abdomen'] * 2)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 3)
# list_category.extend(['Original Research: Technical'] * 1)
# list_category.extend(['Original Research: Pelvis'] * 2)
# list_category.extend(['Original Research: Pelvis', 'Editorial'] * 1)
# list_category.extend(['Original Research: Cardiac'] * 1)
# list_category.extend(['Original Research: Cardiac', 'Editorial'] * 3)
# list_category.extend(['Original Research: Breast', 'Editorial'] * 1)
# list_category.extend(['Original Research: Musculoskeletal'] * 1)
# list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 2)
# list_category.extend(['Original Research: Head and Neck'] * 2)
# list_category.extend(['Original Research: Physics', 'Editorial'] * 1)
# list_category.extend(['Commentary'] * 1)
# list_category.extend(['Letter to the Editor'] * 1)

### Vol 54 No 5 ###
# list_category = ['Cover Image', 'Issue Information']
# list_category.extend(['Review Articles'] * 1)
# list_category.extend(['Original Research: Pediatrics'] * 1)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 4)
# list_category.extend(['Original Research: Pelvis'] * 1)
# list_category.extend(['Original Research: Pelvis', 'Editorial'] * 1)
# list_category.extend(['Original Research: Cardiac'] * 1)
# list_category.extend(['Original Research: Cardiac', 'Editorial'] * 2)
# list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)
# list_category.extend(['Original Research: Chest'] * 1)
# list_category.extend(['Original Research: Head and Neck'] * 1)
# list_category.extend(['Original Research: Head and Neck', 'Editorial'] * 1)
# list_category.extend(['Original Research: Thoracic'] * 1)
# list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 3)
# list_category.extend(['Original Research: Neuro'] * 2)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 4)
# list_category.extend(['Letter to the Editor'] * 1)

### Vol 54 No 6 ###
# list_category = ['Cover Image', 'Issue Information']
# list_category.extend(['Announcement'] * 1)
# list_category.extend(['CME Article: Neuro'] * 1)
# list_category.extend(['Original Research: Head and Neck', 'Editorial'] * 1)
# list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 2)
# list_category.extend(['Original Research: Cardiac'] * 1)
# list_category.extend(['Original Research: Cardiac', 'Editorial'] * 2)
# list_category.extend(['Original Research: Pediatrics', 'Editorial'] * 1)
# list_category.extend(['Original Research: Neuro'] * 2)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 5)
# list_category.extend(['Original Research: Abdomen'] * 2)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 3)
# list_category.extend(['Original Research: Technical', 'Editorial'] * 2)
# list_category.extend(['Original Research: Pelvis'] * 1)
# list_category.extend(['Original Research: Pelvis', 'Editorial'] * 1)
# list_category.extend(['Letter to the Editor'] * 1)

### Vol 55 No 1 ###
list_category = ['Cover Image', 'Issue Information']
list_category.extend(['JMRI-ISMRM Recommendation'] * 1)
list_category.extend(['Review Articles'] * 5)
list_category.extend(['Original Research: Abdomen'] * 2)
list_category.extend(['Original Research: Abdomen', 'Editorial'] * 1)
list_category.extend(['Original Research: Neuro', 'Editorial'] * 4)
list_category.extend(['Original Research: Cardiac', 'Editorial'] * 3)
list_category.extend(['Original Research: Musculoskeletal'] * 1)
list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 1)
list_category.extend(['Original Research: Vascular'] * 1)
list_category.extend(['Original Research: Pelvis'] * 2)
list_category.extend(['Original Research: Pelvis', 'Editorial'] * 1)
list_category.extend(['Original Research: Technical'] * 1)
list_category.extend(['Original Research: Technical', 'Editorial'] * 1)

i = 0
for l in list_category:
  print(l)
  i += 1
print(i)
# Out:
# Cover Image
# Issue Information
# JMRI-ISMRM Recommendation
# Review Articles
# Review Articles
# Review Articles
# Review Articles
# Review Articles
# Original Research: Abdomen
# Original Research: Abdomen
# Original Research: Abdomen
# Editorial
# Original Research: Neuro
# Editorial
# Original Research: Neuro
# Editorial
# Original Research: Neuro
# Editorial
# Original Research: Neuro
# Editorial
# Original Research: Cardiac
# Editorial
# Original Research: Cardiac
# Editorial
# Original Research: Cardiac
# Editorial
# Original Research: Musculoskeletal
# Original Research: Musculoskeletal
# Editorial
# Original Research: Vascular
# Original Research: Pelvis
# Original Research: Pelvis
# Original Research: Pelvis
# Editorial
# Original Research: Technical
# Original Research: Technical
# Editorial
# 37

# %%
df.insert(1, 'Category', list_category)
df
# Out:
#                                               Journal  ...                                 DOI
# 0    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27704
# 1    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27705
# 2    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27409
# 3    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27361
# 4    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27368
# 5    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27378
# 6    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27399
# 7    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27411
# 8    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27793
# 9    Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27810
# 10   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27801
# 11   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27795
# 12   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27832
# 13   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27872
# 14   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27806
# 15   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27862
# 16   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27812
# 17   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27831
# 18   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27823
# 19   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27901
# 20   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27805
# 21   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27855
# 22   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27802
# 23   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27798
# 24   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27804
# 25   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27800
# 26   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27828
# 27   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27809
# 28   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27835
# 29   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27864
# 30   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27794
# 31   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27803
# 32   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27807
# 33   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27843
# 34   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27825
# 35   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27867
# 36   Journal of Magnetic Resonance Imaging: Vol 55...  ...  https://doi.org/10.1002/jmri.27868
#
# [37 rows x 5 columns]

# %% [markdown]
# ## Save as csv

# %%
df.to_csv(path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri/jmri-vol-55-no-1.csv',
          #path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri/jmri-vol-54-no-6.csv',
          #path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-5.csv',
          #path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-4.csv',
          # path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-3.csv',
          # path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-2.csv',
          # path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-1.csv', 
          index=False)

# %% [markdown]
# ## Save as xlsx file
#  - See [here](https://xlsxwriter.readthedocs.io/working_with_pandas.html) for instruction

# %%
# !pip install xlsxwriter
import xlsxwriter

# (Comment out after saving first sheet) Create an ExcelWriter object
# writer = pd.ExcelWriter('/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-all-summary.xlsx', engine='xlsxwriter')

# %%
df.to_excel(excel_writer=writer,
            # sheet_name='jmri-vol-54-no-1',
            # sheet_name='jmri-vol-54-no-2',
            sheet_name='jmri-vol-54-no-3',
            index=False)

# %%
# (Uncomment at the end) Close the Pandas Excel writer and output the Excel file.
writer.save()
