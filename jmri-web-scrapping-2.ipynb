# %% [markdown]
# # Web Scraping using Python

# %% [markdown]
# ## Target Journal: JMRI
#
# Important volumes to include:
#  - Category
#  - Date first published
#
# Examples:
# - https://onlinelibrary.wiley.com/toc/15222586/2021/54/1
# - https://onlinelibrary.wiley.com/toc/15222586/2021/54/2
# - https://onlinelibrary.wiley.com/toc/15222586/2021/54/3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#To easily display the plots, make sure to include the line %matplotlib inline as shown below.
# %matplotlib inline

import urllib
import requests
import lxml

#To perform web scraping, you should also import the libraries shown below. 
#The urllib.request module is used to open URLs. 
#The Beautiful Soup package is used to extract data from html files. 
#The Beautiful Soup library's name is bs4 which stands for Beautiful Soup, version 4.
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ## Method 1 (default): First, save as a local html file
#  - See: https://zetcode.com/python/beautifulsoup/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# JMRI Vol 54 No 1
URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_Vol 54, No 1.html'
# JMRI Vol 54 No 2
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 54, No 2.html'
# Current: JMRI Vol 54 No 3
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 54, No 3.html'

with open(URL, 'r') as f:

    contents = f.read()

    soup = BeautifulSoup(contents, 'lxml')

# %% [markdown]
# Find the corresponding index, and identify the title info

# %%
def safeOpenParsePage(targetUrl):
    try:
        # tmpurl = urlopen(Request(targetUrl, headers={'User-Agent': 'Chrome/92.0.4515.107'}))
        tmpurl = open(targetUrl, 'r')
        tmpR = tmpurl.read()
        # tmpSoup = BeautifulSoup(tmpR, 'html.parser')
        tmpSoup = BeautifulSoup(tmpR, 'lxml')
        return tmpSoup
    except urllib.error.HTTPError as e:
        print(e)
        return None

soupJMRI = safeOpenParsePage(URL)
if soupJMRI is not None:
      print(soupJMRI.prettify())
# Out:
# <!DOCTYPE html>
# <html class="pb-page" data-request-id="037d99ac-cdd2-45fc-859a-57d62b6da74d" lang="en">
#  <head data-pb-dropzone="head">
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content=";issue:issue:doi\:10.1002/jmri.v54.1;journal:journal:15222586;ctype:string:Journal Content;website:website:pericles;page:string:Table of Contents;requestedJournal:journal:15222586;wgroup:string:Publication Websites;pageGroup:string:Publication Pages" name="pbContext"/>
#   <script type="text/javascript">
#    var $DoubleClickZone = "j-magres-imaging_jmri";var $DoubleClickSite =  "wly.radiol.imag_000105";
#   </script>
#   <script id="analyticDigitalData">
#    digitalData = {"site":{"ip":"152.78.0.24","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2021-08-05","server":"web117"},"identities":[{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"InstitutionUser","uuid":"58cbd8e6-3c5d-4fc0-ac26-57c4792d2c4b","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALWB000204"}]},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"InstitutionUser","uuid":"bfa4ccf8-8126-488a-b090-da278aa7b4d9","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOG00017"}]},{"type":"BasicGroup","uuid":"6a17ff38-0daf-4f0a-b4eb-b42c69d5c12f","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000007783"}]},{"type":"BasicGroup","uuid":"9cb21bff-5e36-40b2-9183-08a76524dc18","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL57933332"}]},{"type":"InstitutionUser","uuid":"a7606ea9-e934-4307-a3d4-c30ec2175d59","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOB00014"}]},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"RegionUser","uuid":"3147507a-46c1-4f33-a077-4feac12c6b71"},{"type":"SmartGroupUser","uuid":"77da7ca2-c9f3-4f94-9737-922e1d15b7d9"},{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"BasicGroup","uuid":"32489ba7-57d6-43ed-b717-a0de5ed5ca0e"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"InstitutionUser","uuid":"1b19994e-f6cd-4a6e-b151-a166eb757a02","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALEM00084"}]},{"type":"InstitutionUser","uuid":"838af7aa-2073-4eca-9e95-df167c7953bb","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"SOUTHA450S"}]},{"type":"InstitutionUser","uuid":"a454dd84-0b2c-4d7b-804b-20fd42da68c7","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"P#JISC"}]},{"type":"BasicGroup","uuid":"f6bf73a6-fd29-4303-8301-24bd8a179b03"},{"type":"BasicGroup","uuid":"8b5697d0-0580-43b3-83ea-a258c8085ad5","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004148"}]},{"type":"InstitutionUser","uuid":"2196ade6-df1b-4d0d-b877-7d8cca58ee79","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"PARENTNESLI"}]},{"type":"BasicGroup","uuid":"8d568359-32d1-4757-be79-b72d00d11429"},{"type":"InstitutionUser","uuid":"9b131268-5322-48d8-a32c-bf8de866dc72","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"OBTXTBULK"}]},{"type":"BasicGroup","uuid":"a9298b81-eb3e-4dfb-82a5-86f98d156f4d","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004150"}]},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"InstitutionUser","uuid":"c2c7b09d-2b4d-4ce1-b401-b744073e0ebc","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000165532"}]},{"type":"BasicGroup","uuid":"f0737c70-8d27-48b0-8b44-af576d0063e8","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000068532"}]},{"type":"SmartGroupUser","uuid":"261f34be-39f9-4f9e-8feb-500f73213904"},{"type":"InstitutionUser","uuid":"ca0c2bfa-0ec9-4312-aa4b-4c51702429d4","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL0000647"}]},{"type":"ReferrerUser","uuid":"b3da44b5-3aad-4291-8eca-73ea8ea97a07"},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"20d013f5-e22b-4df0-ba93-d6d925db9e32"},{"type":"RegionUser","uuid":"82409588-c43f-4337-a6a8-3272d1b7e20e"},{"type":"SmartGroupUser","uuid":"b2dbfe27-ecae-4bb6-bb0d-d75e5caa3762"},{"type":"BasicGroup","uuid":"bd2fcf7d-fa23-4396-9340-9ee81267838e"}],"publication":{"group":{"doi":"10.1002/jmri.v54.1","access":"full","volume":"54","issue":"1","coverDate":"2021-07-01","topics":[{"taxonomyUri":"global-s ...
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="noarchive" name="robots"/>
#   <meta name="pb-robots-disabled"/>
#   <meta content=" Journal of Magnetic Resonance Imaging: Vol 54, No 1" property="og:title"/>
#   <meta content="Journal" property="og:type"/>
#   <meta content="https://onlinelibrary.wiley.com/toc/15222586/2021/54/1" property="og:url"/>
#   <meta content="https://onlinelibrary.wiley.com/cover/15222586/54/1" property="og:image"/>
#   <meta content="Wiley Online Library" property="og:site_name"/>
#   <meta content="Click on the title to browse this issue" property="og:description"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="app-id=673861322" name="apple-itunes-app"/>
#   <meta content="10.1002/jmri.v54.1" name="citation_doi"/>
#   <meta content="10.1002/jmri.v54.1" name="dc.identifier"/>
#   <title>
#    Journal of Magnetic Resonance Imaging: Vol 54, No 1
#   </title>
#   <link href="/wro/kbrm~product.css" rel="stylesheet" type="text/css"/>
#   <style>
#    @font-face {
#     font-family: 'Open Sans Subset';
#     font-display: swap;
#     src: local('Muli Regular'), local('Muli-Regular'),
#     url(data:application/font-woff;charset=utf-8;base64,...) format('woff');
# }
#   </style>
#   <link href="/products/pericles/releasedAssets/css/build-7197e5046da8bff2894b.css" rel="stylesheet"/>
#   <link href="/products/pericles/releasedAssets/css/print-7197e5046da8bff2894b.css" media="print" rel="stylesheet"/>
#   <script async="" src="/pb-assets/catchpoint-1549680351760.js">
#   </script>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/pb-assets/hub-assets/pericles/hub-1628068886633.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/iucr-1510734465460.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/readcube-1510565373110.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/dr-overrides-1611780866727.css" rel="stylesheet" type="text/css"/>
#   <!-- link rel="stylesheet" type="text/css" href="/pb-assets/css/temporary-1525702334993.css" -->
#   <style>
#    /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#   </style>
#   <!-- The Adobe DTM script. Must come after the digitalData object -->
#   <script src="//assets.adobedtm.com/6e626c9ec247e474f6b98eb15a79a185cf7e26a5/satelliteLib-c1ac050bbdc647f13a62578e71f0d817f8a6cbb5.js">
#   </script>
#   <!-- Google Search Console verification -->
#   <meta content="ffz4i4DxIJCdGpRXe0XN6KG6o4FYI-nnFW9I_dg8piM" name="google-site-verification"/>
#   <!-- KRUX Implementation-->
#   <script class="kxct" data-id="JMOONjNh" data-timing="async" data-version="1.9" type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#   </script>
#   <!-- KRUX Implementation cont'd -->
#   <script type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#   </script>
#   <!-- Grapeshot Implementation -->
#   <script>
#    var gs_channels = 'default';
#   </script>
#   <script async="" src="//wiley.grapeshot.co.uk/main/channels.cgi?url=https://onlinelibrary.wiley.com/toc/15222586/2021/54/1">
#   </script>
#   <!-- DoubleClick Implementation -->
#   <script type="text/javascript">
#    var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#   </script>
#   <script>
#    var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#   </script>
#   <script>
#    googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/jmri.v54.1')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#   </script>
#   <script src="//validate.onecount.net/js/all.min.js#cff4b10c3a3d5cc9bbb7e2b9292cc66eae1deafa">
#   </script>
#   <script>
#    try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#   </script>
#   <script data-cf-beacon='{"rayId":"65604cf31ed0e4d9","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.1","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script data-cf-beacon='{"rayId":"65cb04cf2c4898e7","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script async="" src="/cdn-cgi/bm/cv/669835187/api.js">
#   </script>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#   </script>
#   <script data-cf-beacon='{"rayId":"65d1a8e0c92cd32a","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <!-- Get whether TNSI is in live or test mode -->
#   <!-- Get the configured TNSI Javascript version number -->
#   <!-- Get the configured TNSI MerchantID -->
#   <!-- Add "TEST" to beginning of merchant ID when running in test mode -->
#   <!-- loading Javascript for using the persistence Service -->
#   <script src="//unpkg.com/@theidentityselector/thiss-ds">
#   </script>
#   <script type="text/javascript">
#    function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf('?') !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#   </script>
#   <script type="text/javascript">
#    (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaaT8V5l-ZVYFarDpNsSx';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#   </script>
#   <script>
#    var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Journal of Magnetic Resonance Imaging: Vol 54, No 1";
#   </script>
#  </head>
#  <body class="pb-ui">
#   <div class="skip-links">
#    <ul class="rlist">
#     <li>
#      <a href="#main-content" tabindex="1">
#       Skip to Main Content
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div data-ng-non-bindable="" id="pb-page-content">
#    <div data-pb-dropzone="main" data-pb-dropzone-name="Main">
#     <div class="pageHeader" data-widget-def="pageHeader" data-widget-id="62175478-b98a-43d5-90f2-1f2045ac1a7e">
#      <header class="page-header">
#       <div data-pb-dropzone="main">
#        <div class="admin-message" data-widget-def="ux3-layout-widget" data-widget-id="bb5b5e2c-d3d6-4015-b586-eeade38f59d4">
#         <div class="container">
#          <div class="row">
#           <div>
#            <div class="pb-ad">
#             <div style="background=blue;">
#              <div class="container">
#               <p style="text-align: center;">
#                <b>
#                 Working off-campus?
#                </b>
#                Learn about our
#                <a href="/action/clickThrough?id=101169&amp;url=https%3A%2F%2Fonlinelibrary.wiley.com%2Fresearchers%2Fread%2Faccess-options&amp;loc=%2Ftoc%2F15222586%2F2021%2F54%2F1&amp;pubId=75078625&amp;placeholderId=1029&amp;productId=1011" tabindex="2" target="_blank">
#                 <font color="white">
#                  <u>
#                   remote access options
#                  </u>
#                 </font>
#                </a>
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="container">
#         <div class="row">
#          <div class="contents col-md-12">
#           <div class="institution-wrapper-mobile hidden-lg hidden-md padded-content" data-widget-def="UX3InstitutionBanner" data-widget-id="4d1f2e23-571a-4b27-8ab7-e7cd8ca15964">
#            <div class="institution">
#             <div class="institution-box no-image">
#              <div class="institution-info-wrapper">
#               <span class="institution__name">
#                University of Southampton
#               </span>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="pull-left">
#            <div class="logo-container hidden-xs hidden-sm hidden-md" data-widget-def="ux3-general-image" data-widget-id="ff262197-0fb8-4973-aaa2-2fceba4b5a61">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mainLogo" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#             </a>
#            </div>
#            <div class="logo-container-mobile hidden-lg hidden-md hidden-sm" data-widget-def="ux3-general-image" data-widget-id="6b601b23-7301-47c8-8889-242d041241c4">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mobileLogo" src="/pb-assets/hub-assets/pericles/mobilehublogo-1518781861020.png"/>
#             </a>
#            </div>
#            <div class="institution-wrapper hidden-xs hidden-sm hidden-md institution--block" data-widget-def="UX3InstitutionBanner" data-widget-id="14d0e2f8-27d3-42d0-a477-72015e14e818">
#             <div class="institution">
#              <div class="institution-box no-image">
#               <div class="institution-info-wrapper">
#                <span class="institution__name">
#                 University of Southampton
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="header-quicksearch" data-widget-def="UX3QuickSearchWidget" data-widget-id="48175bb0-0f70-46e6-bb89-7e2781fdb8e4">
#             <div class="quick-search-wrapper">
#              <a aria-label="Search" class="quick-search__item" href="#" title="search">
#               <i aria-hidden="true" class="icon-search">
#               </i>
#               <span class="quick-search__item__arrow">
#               </span>
#              </a>
#              <div class="quick-search quickSearchFormContainer" data-linkto-page="true">
#               <div class="main-search-field-wrapper">
#                <div class="tab clearfix">
#                 <input class="fakeQSInput quickSearchFilter" placeholder="Search" tabindex="13" type="search" value=""/>
#                 <label class="sr-only" for="search-within">
#                  Search within
#                 </label>
#                 <select class="search-within" id="search-within" name="search-within" tabindex="10">
#                  <option value="#pane-67065c09-4a88-49cd-934c-ac707951d35c0">
#                   This Journal
#                  </option>
#                  <option value="#pane-67065c09-4a88-49cd-934c-ac707951d35c1">
#                   Anywhere
#                  </option>
#                 </select>
#                 <ul class="rlist tab__content" role="tablist">
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c0-con" class="tab__pane quick-search-pane__anywhere active" id="pane-67065c09-4a88-49cd-934c-ac707951d35c0" role="tab">
#                   <form action="/action/doSearch" method="get" name="thisJournalQuickSearch" title="Quick Search">
#                    <div class="input-group option-0">
#                     <label class="hiddenLabel" for="searchField0">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField0" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <input name="SeriesKey" type="hidden" value="15222586"/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222586" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222586#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c1-con" class="tab__pane quick-search-pane__anywhere" id="pane-67065c09-4a88-49cd-934c-ac707951d35c1" role="tab">
#                   <form action="https://onlinelibrary.wiley.com/action/doSearch" method="get" name="defaultQuickSearch" title="Quick Search">
#                    <div class="input-group option-1">
#                     <label class="hiddenLabel" for="searchField1">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField1" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="cart-indicator__wrapper" data-widget-def="ux3-layout-widget" data-widget-id="5ef13ed1-f4ac-4b62-a426-07ec9576a586">
#             <div class="pull-left">
#              <div class="cart-indicator__wrapper" data-widget-def="eCommerceCartIndicatorWidget" data-widget-id="4a9f7c04-a273-4a25-91fb-8e7bd9970288">
#              </div>
#             </div>
#             <div class="pull-right">
#              <div class="login-bar-container" data-widget-def="literatumNavigationLoginBar" data-widget-id="d384ca92-7137-45d6-b3c2-78c9c0a98c2b">
#               <div class="loginBar login-open">
#                <a aria-label="Log in or Register" class="show-login" href="/action/showLogin?uri=%2Ftoc%2F15222586%2F2021%2F54%2F1&amp;aria-label=Log+in+or+Register" role="button" uri="/toc/15222586/2021/54/1">
#                 <span class="icon-profile_empty">
#                 </span>
#                 <span class="sign-in-label">
#                  Login / Register
#                 </span>
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </header>
#     </div>
#     <h1 class="hidden">
#      Journal list menu
#     </h1>
#     <div class="pages-nav--sticky pages-nav hidden-lg fixed-element">
#      <div class="pages-nav--res">
#       <div class="container">
#        <ul class="rlist--inline pull-left">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="journal-list" href="#">
#           <i aria-hidden="true" class="icon-toc">
#           </i>
#           <span>
#            Journal
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="journal-list" id="journal-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-1, #menu-item-undefined-2, #menu-item-main-menu-1-1, #menu-item-main-menu-1-2, #menu-item--1, #menu-item--2, .journal-featured" data-toggle="transplant" data-transplant="self">
#           </div>
#           <!-- PERICLES-7683
#               <a href="#" title="More from this journal" class="dropdown__toggle"><span>More from this journal</span></a>
#
#                 <div data-target=".journal-resources" data-remove="false" data-toggle="transplant" data-direction="from" data-transplant="self" class="transplant showit"></div>
# -->
#          </div>
#         </li>
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="articles-list" href="#">
#           <i class="article-img-icon">
#            <img src="/pb-assets/hub-assets/pericles/articles_1-1499257321163.png"/>
#           </i>
#           <span>
#            Articles
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="articles-list" id="articles-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-3, #menu-item-undefined-4, #menu-item-main-menu-1-3, #menu-item-main-menu-1-4, #menu-item--3" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#        <ul class="rlist--inline pull-right">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="actions-list" href="#">
#           <span>
#            Actions
#           </span>
#           <i aria-hidden="true" class="icon-chevron-down">
#           </i>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="actions-list" id="actions-list">
#           <h2 class="side-section-header hiddenLabel--lg">
#            Tools
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target=".journal-actions-container li:nth-child(1), .journal-actions-container li:nth-child(2), .journal-actions-container li:nth-child(3), .journal-actions-container li:nth-child(4), .journal-actions-container li:nth-child(5), #subscribeLink" data-toggle="transplant" data-transplant="self">
#           </div>
#           <h2 class="side-section-header hiddenLabel--lg">
#            Follow journal
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#alert-link, #facebook-link, #twitter-link, #linkedin-link, #most-recent-link, #most-read-link, #most-cited-link" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="pageBody body-text" data-widget-def="pageBody" data-widget-id="72100436-7a82-49fc-933b-c6c9d8c42914">
#      <main id="main-content" tabindex="-1">
#       <!--begin pagefulltext-->
#       <div class="page-body pagefulltext">
#        <div data-pb-dropzone="main">
#         <div class="js--fixed-switch" data-widget-def="ux3-layout-widget" data-widget-id="6da55ccb-5daf-4c91-b961-05eee9e6f293">
#          <div>
#           <div class="secondary-bg-color banner-wrapper" data-widget-def="literatumAd" data-widget-id="0220a30b-90c0-4b51-8637-141edf12f86a">
#            <div class="pb-ad">
#             <aside role="complementary">
#              <div class="advert advert-leaderboard" id="advert-leaderboard">
#               <script>
#                googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#               </script>
#               <!-- No JavaScript support is a call to an image -->
#               <noscript>
#                <a href="/action/clickThrough?id=1013&amp;url=https%3A%2F%2Fpubads.g.doubleclick.net%2Fgampad%2Fjump%3Fiu%3D%24googlePublisherCategory%26amp%3Bsz%3D728x90%26amp%3Btile%3D1%26amp%3Bc%3D%24random&amp;loc=%2Ftoc%2F15222586%2F2021%2F54%2F1&amp;pubId=75078625&amp;placeholderId=1015&amp;productId=101018" target="_blank">
#                 <img src="https://pubads.g.doubleclick.net/gampad/ad?iu=$googlePublisherCategory&amp;sz=728x90&amp;tile=1&amp;c=$random"/>
#                </a>
#               </noscript>
#              </div>
#             </aside>
#            </div>
#           </div>
#           <style type="text/css">
#            li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#           </style>
#           <section class="journal-page-header card" data-widget-def="ux3-layout-widget" data-widget-id="9e8ee65a-2e18-4c00-9474-5ac10e16ecfe">
#            <div class="container">
#             <div class="row">
#              <div class="journal-info-container col-md-8">
#               <a href="/journal/15222586" title="Journal of Magnetic Resonance Imaging homepage">
#                <h1 id="journal-banner-text" style="margin: 0; font-size: 0">
#                 Journal of Magnetic Resonance Imaging
#                </h1>
#                <img alt="Journal of Magnetic Resonance Imaging" class="journal-banner-image" id="journal-banner-image" src="/pb-assets/journal-banners/15222586-1590394653627.jpg" style="margin-bottom: 15px; display: none"/>
#               </a>
#               <script>
#                var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222586-1590394653627.jpg";
#               </script>
#              </div>
#              <div class="hidden-xs hidden-sm hidden-md col-md-4">
#              </div>
#             </div>
#            </div>
#           </section>
#           <div class="stickybar pages-nav hidden-xs hidden-sm hidden-md scrollable-element" data-widget-def="menuWidget" data-widget-id="998218b4-f988-4a0c-8c4f-b2d3875e1770">
#            <div class="stickybar__wrapper">
#             <div class="main-nav">
#              <a data-toggle="nav" href="#undefined" title="menu drawer">
#               <i aria-hidden="true" class="icon-menu2">
#               </i>
#               <i aria-hidden="true" class="icon-close_thin">
#               </i>
#              </a>
#              <nav aria-label="Journal navigation" class="drawer__nav container gutterless hidden-sm hidden-xs" data-ctrl-res="never" role="navigation">
#               <h2 class="is-accessible">
#                Navigation Bar
#               </h2>
#               <section>
#                <h3 class="is-accessible">
#                 Menu
#                </h3>
#                <a class="menu-header hidden-md hidden-lg" href="/">
#                 Home
#                </a>
#                <ul class="menubar rlist--inline" id="menubar" role="menubar">
#                 <li class="menu-item" data-menu-label="Home" id="menu-item-undefined-0" role="presentation">
#                  <a class="sub-menu-item" href="/journal/15222586" role="menuitem" tabindex="0">
#                   <span>
#                    Home
#                   </span>
#                  </a>
#                 </li>
#                 <li class="dropdown menu-parent" data-menu-label="About" id="menu-item-undefined-1" role="presentation">
#                  <a aria-expanded="false" aria-haspopup="true" class="dropdown__toggle" data-target="About-1-dropdown" data-toggle="dropdown" href="#" id="About-1" role="menuitem" tabindex="-1">
#                   <span>
#                    About
#                   </span>
#                   <i aria-hidden="true" class="icon-arrow_r pull-right hidden-md hidden-lg">
#                   </i>
#                   <i aria-hidden="true" class="icon-section_arrow_d pull-right hidden-sm hidden-xs">
#                   </i>
#                  </a>
#                  <ul aria-labelledby="About-1" class="rlist dropdown__menu" id="About-1-dropdown" role="menu">
#                   <li class="menu-item" data-menu-label="Overview" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222586/homepage/productinformation.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Overview
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Contact" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222586/homepage/contact.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Contact
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Editorial Board" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222586/homepage/editorialboard.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Editorial Board
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Advertise" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222586/homepage/advertise.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Advertise
# ...
#                 Terms of Use
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/cookies">
#                 Cookies
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/accessibility">
#                 Accessibility
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Help &amp; Support
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://hub.wiley.com/community/support/onlinelibrary">
#                 Contact Us
#                </a>
#               </li>
#               <li>
#                <a href="https://www.wiley.com/customer-success/wiley-online-library-training-hub">
#                 Training and Support
#                </a>
#               </li>
#               <li>
#                <a href="/dmca-notification-policy">
#                 DMCA &amp; Reporting Piracy
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Opportunities
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://onlinelibrary.wiley.com/agents">
#                 Subscription Agents
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/advertisers">
#                 Advertisers &amp; Corporate Partners
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Connect with Wiley
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://www.wiley.com/network">
#                 The Wiley Network
#                </a>
#               </li>
#               <li>
#                <a href="https://newsroom.wiley.com/">
#                 Wiley Press Room
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="copyright-container" data-widget-def="ux3-layout-widget" data-widget-id="86584e25-e4db-4118-9550-9b4f5341a4ac">
#          <div class="container">
#           <div class="row">
#            <div class=" col-md-12">
#             <div class="copyright" data-widget-def="UX3HTMLWidget" data-widget-id="bfbf6c5d-a650-4662-828f-5275fada9120">
#              <div class="copyright pull-left">
#               Copyright © 1999-2021
#               <a href="https://www.wiley.com">
#                John Wiley &amp; Sons, Inc
#               </a>
#               . All rights reserved
#              </div>
#             </div>
#             <div class="footer-logo pull-right">
#              <a aria-label="Wiley" href="https://www.wiley.com" title="Wiley Home Page">
#               <img alt="Wiley Home Page" src="/pb-assets/tmp-images/footer-logo-wiley-1510029248417.png"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#     <div aria-labelledby="loginPopupHead" class="popup login-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="Cancel Login" class="close" href="#" role="button">
#        <i class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#       </div>
#       <div class="modal__body">
#        <div class="ssoLogin">
#        </div>
#        <h2 id="loginPopupHead">
#         Log in to Wiley Online Library
#        </h2>
#        <div class="login-form">
#         <form action="/action/doLogin?societyURLCode=" class="bordered" method="post">
#          <input name="id" type="hidden" value="67065c09-4a88-49cd-934c-ac707951d35c"/>
#          <input name="popup" type="hidden" value="true"/>
#          <input name="loginUri" type="hidden" value="/toc/15222586/2021/54/1"/>
#          <input name="redirectUri" type="hidden" value="/toc/15222586/2021/54/1"/>
#          <input name="loginUri" type="hidden" value="/toc/15222586/2021/54/1"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="username">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="login" id="username" name="login" placeholder="Enter your email" required="true" size="15" spellcheck="false" type="text" value=""/>
#           <div class="actions">
#           </div>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="password">
#             Password
#            </label>
#           </div>
#           <input autocapitalize="off" autocomplete="off" autocorrect="off" class="password" id="password" name="password" placeholder="Enter your password" required="true" spellcheck="false" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="actions">
#           <a class="link show-request-reset-password" href="/action/requestResetPassword">
#            Forgot password?
#           </a>
#          </div>
#          <div class="loginExtraBeans-dropZone" data-pb-dropzone="loginExtraBeans">
#          </div>
#          <div class="align-end">
#           <span class="submit ">
#            <input class="button btn submit primary no-margin-bottom accessSubmit" name="submitButton" type="submit" value="Log In"/>
#           </span>
#          </div>
#         </form>
#         <div class="societySpecificInstructions">
#         </div>
#        </div>
#        <div class="login-container clearfix form-btn">
#         <a class="linkBtn float-left" href="/action/registration">
#          NEW USER
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#         <a class="linkBtn float-right instituation-login" href="/action/ssostart?redirectUri=%2Ftoc%2F15222586%2F2021%2F54%2F1">
#          INSTITUTIONAL LOGIN
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="changePasswordPopupHead" class="popup change-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close cancel" href="#" role="button">
#        <i class="icon-close_thin">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="changePasswordPopupHead">
#         Change Password
#        </h2>
#       </div>
#       <div class="modal__body">
#        <div class="form">
#         <form action="/action/changePassword" method="post">
#          <div class="message error">
#          </div>
#          <input name="submit" type="hidden" value="submit"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-old">
#             Old Password
#            </label>
#           </div>
#           <input autocomplete="off" class="old" id="a589574e-bb98-4c6e-8fed-67365ff05357-old" name="old" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-new">
#             New Password
#            </label>
#           </div>
#           <input autocomplete="off" class="pass-hint new" id="a589574e-bb98-4c6e-8fed-67365ff05357-new" name="new" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#           <div class="password-strength-indicator" data-max="32" data-min="10" data-strength="3">
#            <span class="text too-short">
#             Too Short
#            </span>
#            <span class="text weak">
#             Weak
#            </span>
#            <span class="text medium">
#             Medium
#            </span>
#            <span class="text strong">
#             Strong
#            </span>
#            <span class="text very-strong">
#             Very Strong
#            </span>
#            <span class="text too-long">
#             Too Long
#            </span>
#           </div>
#          </div>
#          <input class="button primary submit" disabled="disabled" type="submit" value="Submit"/>
#         </form>
#         <a class="fakeFormLastElement" href="#">
#         </a>
#        </div>
#        <div class="success-template hidden">
#         <h2>
#          Password Changed Successfully
#         </h2>
#         <p>
#          Your password has been changed
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="createAccountPopupHead" class="popup registration-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close" href="#" role="button">
#        <i class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="logoDropZone" data-pb-dropzone="logoDropZone">
#        </div>
#        <h2 id="createAccountPopupHead">
#         Create a new account
#        </h2>
#       </div>
#       <div class="modal__body">
#        <form action="/action/registration" class="registration-form" method="post">
#         <input name="redirectUri" type="hidden" value="/toc/15222586/2021/54/1"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="4e647394-f751-4441-baa4-df426bca4b6e.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="4e647394-f751-4441-baa4-df426bca4b6e.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="submit">
#          <input class="button submit primary" type="submit" value="Register"/>
#         </div>
#        </form>
#        <div class="center">
#         <a class="show-login" href="/action/showLogin">
#          Returning user
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="resetPasswordPopupHead" class="popup top-drawer request-reset-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <div class="modal__header">
#        <a aria-label="close dialog" class="cancel close" href="#" role="button">
#         <i class="icon-close_thin">
#         </i>
#        </a>
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="resetPasswordPopupHead">
#         Forgot your password?
#        </h2>
#        <p class="sub">
#         Enter your email address below.
#        </p>
#       </div>
#       <div class="modal__body">
#        <div class="error">
#        </div>
#        <form action="/action/requestResetPassword" class="request-reset-password-form" method="post">
#         <input name="requestResetPassword" type="hidden" value="true"/>
#         <div class="input-group">
#          <div class="input-group">
#           <div class="label">
#            <label for="email">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="email" id="email" name="email" placeholder="Enter your email" size="15" spellcheck="false" type="text" value=""/>
#          </div>
#         </div>
#         <div class="password-recaptcha-ajax">
#         </div>
#         <div class="form-btn">
#          <input class="button btn primary submit" disabled="disabled" name="submit" type="submit" value="RESET PASSWORD"/>
#         </div>
#        </form>
#        <div class="message error">
#        </div>
#        <div class="success-template hidden">
#         <p>
#          Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div>
#      <div class="pb-dropzone" data-pb-dropzone="col-0" title="col-0">
#      </div>
#     </div>
#     <div aria-labelledby="requestUsernamePopupHead" class="popup top-drawer request-username-drawer username-popup hidden" role="dialog" tabindex="-1">
#      <a aria-label="close dialog" class="close" href="#" role="button">
#       <i class="icon-close_thin">
#       </i>
#      </a>
#      <div class="content">
#       <h2 id="requestUsernamePopupHead">
#        Request Username
#       </h2>
#       <div class="form">
#        <p>
#         Can't sign in? Forgot your username?
#        </p>
#        <p class="sub">
#         Enter your email address below and we will send you your username
#        </p>
#        <div class="message error">
#        </div>
#        <form action="/action/requestUsername" method="post">
#         <input name="requestUsername" type="hidden" value="requestUsername"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="username-recaptcha-ajax">
#         </div>
#         <input class="button primary submit" disabled="disabled" name="submit" type="submit" value="Submit"/>
#         <div class="center">
#          <a class="cancel" href="#">
#           Close
#          </a>
#         </div>
#        </form>
#       </div>
#       <div class="success-template hidden note">
#        <p>
#         If the address matches an existing account you will receive an email with instructions to retrieve your username
#        </p>
#       </div>
#      </div>
#     </div>
#     <!-- Belongs at the bottom of the page -->
#     <script type="text/javascript">
#      if(window._satellite) {
# _satellite.pageBottom();
# }
#     </script>
#     <!-- Temporarily styling and we need to remove them after LIT-405827 fixed as part of lit-2020 -->
#     <style>
#      .tfa-form-container .verification-hint {
#         text-align: center;
#         padding-top: 20px;
#         padding-bottom: 20px;
#         font-size: 13px;
#     }
#
#     .tfa-form-container .verification-hint .verification-hint__link {
#         font-weight: 500;
#         display: inline-block;
#         text-decoration: none;
#     }
#     </style>
#     <!-- This HTML widget is temporary, and should be replaced with styles in the next major upgrade. (LIT-406218)  -->
#     <style>
#      .tfa-form-container #tfa-options {
#     	display: none;
#     }
#
#     .tfa-form-container .three-digits {
#     	overflow-wrap: break-word;
#     }
#     </style>
#    </div>
#   </div>
#   <script src="/products/pericles/releasedAssets/js/build.lazyload.bundle-074ab646dd4d1ae50da9.js">
#   </script>
#   <script src="/products/pericles/releasedAssets/js/main.bundle-deb9e5aad7c3df90a0ee.js">
#   </script>
#   <script src="/wro/kbrm~product.js" type="text/javascript">
#   </script>
#   <script>
#    var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();
#   </script>
#   <script data-cf-beacon='{"rayId":"67a0ec0c5fe106bd","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.7.0","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#  </body>
# </html>

# %%
# Get the title
title = soupJMRI.title
print(title)
# Out:
# <title> Journal of Magnetic Resonance Imaging: Vol 54, No 1</title>

# %%
# Print out the text
text = soupJMRI.get_text()
print(soup.text)

# Another way to extract text
# str(all_links[103]).split("<h2>")[1].replace("</h2></a>", "")
# Out:
# var $DoubleClickZone = "j-magres-imaging_jmri";var $DoubleClickSite =  "wly.radiol.imag_000105";digitalData = {"site":{"ip":"152.78.0.24","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2021-08-05","server":"web117"},"identities":[{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"InstitutionUser","uuid":"58cbd8e6-3c5d-4fc0-ac26-57c4792d2c4b","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALWB000204"}]},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"InstitutionUser","uuid":"bfa4ccf8-8126-488a-b090-da278aa7b4d9","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOG00017"}]},{"type":"BasicGroup","uuid":"6a17ff38-0daf-4f0a-b4eb-b42c69d5c12f","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000007783"}]},{"type":"BasicGroup","uuid":"9cb21bff-5e36-40b2-9183-08a76524dc18","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL57933332"}]},{"type":"InstitutionUser","uuid":"a7606ea9-e934-4307-a3d4-c30ec2175d59","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOB00014"}]},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"RegionUser","uuid":"3147507a-46c1-4f33-a077-4feac12c6b71"},{"type":"SmartGroupUser","uuid":"77da7ca2-c9f3-4f94-9737-922e1d15b7d9"},{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"BasicGroup","uuid":"32489ba7-57d6-43ed-b717-a0de5ed5ca0e"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"InstitutionUser","uuid":"1b19994e-f6cd-4a6e-b151-a166eb757a02","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALEM00084"}]},{"type":"InstitutionUser","uuid":"838af7aa-2073-4eca-9e95-df167c7953bb","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"SOUTHA450S"}]},{"type":"InstitutionUser","uuid":"a454dd84-0b2c-4d7b-804b-20fd42da68c7","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"P#JISC"}]},{"type":"BasicGroup","uuid":"f6bf73a6-fd29-4303-8301-24bd8a179b03"},{"type":"BasicGroup","uuid":"8b5697d0-0580-43b3-83ea-a258c8085ad5","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004148"}]},{"type":"InstitutionUser","uuid":"2196ade6-df1b-4d0d-b877-7d8cca58ee79","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"PARENTNESLI"}]},{"type":"BasicGroup","uuid":"8d568359-32d1-4757-be79-b72d00d11429"},{"type":"InstitutionUser","uuid":"9b131268-5322-48d8-a32c-bf8de866dc72","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"OBTXTBULK"}]},{"type":"BasicGroup","uuid":"a9298b81-eb3e-4dfb-82a5-86f98d156f4d","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004150"}]},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"InstitutionUser","uuid":"c2c7b09d-2b4d-4ce1-b401-b744073e0ebc","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000165532"}]},{"type":"BasicGroup","uuid":"f0737c70-8d27-48b0-8b44-af576d0063e8","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000068532"}]},{"type":"SmartGroupUser","uuid":"261f34be-39f9-4f9e-8feb-500f73213904"},{"type":"InstitutionUser","uuid":"ca0c2bfa-0ec9-4312-aa4b-4c51702429d4","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL0000647"}]},{"type":"ReferrerUser","uuid":"b3da44b5-3aad-4291-8eca-73ea8ea97a07"},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"20d013f5-e22b-4df0-ba93-d6d925db9e32"},{"type":"RegionUser","uuid":"82409588-c43f-4337-a6a8-3272d1b7e20e"},{"type":"SmartGroupUser","uuid":"b2dbfe27-ecae-4bb6-bb0d-d75e5caa3762"},{"type":"BasicGroup","uuid":"bd2fcf7d-fa23-4396-9340-9ee81267838e"}],"publication":{"group":{"doi":"10.1002/jmri.v54.1","access" ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Journal of Magnetic Resonance Imaging: Vol 54, No 1
#
# @font-face {
#     font-family: 'Open Sans Subset';
#     font-display: swap;
#     src: local('Muli Regular'), local('Muli-Regular'),
#     url(data:application/font-woff;charset=utf-8;base64,...) format('woff');
# }
#
#
#
#
#
#
#
#
#
#
#
# /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#
#
#
#
#
#
#
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#
#
#
# 	var gs_channels = 'default';
#
#
#
#
# 	var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#
#
# 	var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#
#
# 	googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/jmri.v54.1')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#
#
#
# 	try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#
#
#
# (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#
#
#
#
#
#
#
#
#         function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf('?') !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#
#
#
#         (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaaT8V5l-ZVYFarDpNsSx';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#
#
#     var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Journal of Magnetic Resonance Imaging: Vol 54, No 1";
#
#
#
#
#
# Skip to Main Content
#
#
#
#
#
#
#
#
#
#
#
#
# Working off-campus? Learn about our remote access options
#
#
#
#
#
#
#
# University of Southampton
#
#
#
#
#
#
#
#
#
# University of Southampton
#
#
#
# Search withinThis JournalAnywhereSearch term  Advanced Search  Citation SearchSearch term  Advanced Search  Citation Search
#
#
#
#
#
#
#
#
#
#
# Login / Register
#
#
#
#
#
#
#
#
#
#
#  Journal list menu
#
#
#
#
# Journal
#
#
#
#
#
# Articles
#
#
#
#
#
#
# Actions
#
# Tools
#
# Follow journal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
# li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#
#
#
# Journal of Magnetic Resonance Imaging
#
#
#
# var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222586-1590394653627.jpg";
#
#
#
#
# Navigation BarMenuHomeHomeAboutOverviewContactEditorial BoardAdvertisePermissionsContributeAuthor GuidelinesOpen AccessSubmit a ManuscriptFor RefereesBrowseAccepted ArticlesEarly ViewCurrent IssueAll IssuesCover GalleryVirtual Issues
#
#
# Follow journal
#
# Alert
#
#
#
#
#
# RSS Feeds
#
#
# Most recent (RSS)
#
# Most cited (RSS)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# IssueVolume 54,  Issue 1Pages: spcone, 1-328July 2021
#
# Previous Issue|Next Issue
#
#
#
# GO TO SECTION
#
#
#
#
#
#
#
#
#
# Export Citation(s)
# Export CitationsFormatPlain TextRIS (ProCite, Reference Manager)EndNoteBibTexMedlarsRefWorksType of importCitation file or direct importIndirect import or copy/pasteCancelNext< Go backCitation HelpExport
#
#
#
#
# Cover Image
#
#
# Free Access
#
#
#
#
#                   free
#
#
# Can 3D Pseudo-Continuous Territorial Arterial Spin Labeling Effectively Diagnose Patients With Recanalization of Unilateral Middle Cerebral Artery Stenosis?
#
#  Xinyu Wang MMed,
#  Weiqiang Dou PhD,
#  Dong Dong MD,
#  Xinyi Wang MMed,
#  Xueyu Chen MMed,
#  Kunjian Chen MMed,
#  Huimin Mao MMed,
#  Yu Guo MMed,
#  Chao Zhang MMed,
#
#
# Pages: spcone
# First Published: 11 June 2021
#
#
#
# A typical patient with R-MCA undergoing stenting before (top row) and after (bottom row) surgery. A 65-year-old male with severe R-MCA stenosis. (a) DSA showed that after stenting, the R-MCA stenosis was significantly alleviated, the blood flow was recanalized, and the distal branches were well visualized. (b) DWI showed no obvious high signal before and after the operation. (c) Preoperative 3D pcASL showed that low perfusion area was visible in M6, and postoperative low perfusion had returned to normal. (d) and (e) Preoperative tASL showed that the perfusion in M3, M5, and M6 areas was lower than that of the contralateral side, and the postoperative hypoperfusion area had returned to normal by Wang et al (175–183).
#
#
#
#
#
# Abstract
# PDFRequest permissions
#
#
#
#
#
# Issue Information
#
#
# Free Access
#
#
#
#
#                   free
#
#
# Issue Information
# Pages: 1-10
# First Published: 11 June 2021
#
#
#
# First Page
# PDFRequest permissions
#
#
#
#
#
# Commentary
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Societal and Research Population Biases
#
#  Mark E Schweitzer MD,
#
#
# Pages: 11
# First Published: 13 May 2021
#
#
#
#
#                     Full text
#
# PDFRequest permissions
#
#
#
#
#
# Review Articles
#
#
# Open Access
#
#
#
#
#                   oa
#
#
# MRI-Based Quantitative Osteoporosis Imaging at the Spine and Femur
#
#  Nico Sollmann MD, PhD,
#  Maximilian T. Löffler MD, MSc,
#  Sophia Kronthaler MSc,
#  Christof Böhm MSc,
#  Michael Dieckmeyer MD,
#  Stefan Ruschke PhD,
#  Jan S. Kirschke MD,
#  Julio Carballido-Gamio PhD,
#  Dimitrios C. Karampinos PhD,
#  Roland Krug PhD,
#  Thomas Baum MD,
#
#
# Pages: 12-35
# First Published: 25 June 2020
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Diffusion Imaging in the Post HCP Era
#
#  Steen Moeller PhD,
#  Pramod Pisharady Kumar PhD,
#  Jesper Andersson PhD,
#  Mehmet Akcakaya PhD,
#  Noam Harel PhD,
#  Ruoyun(Emily) Ma PhD,
#  Xiaoping Wu PhD,
#  Essa Yacoub PhD,
#  Christophe Lenglet PhD,
#  Kamil Ugurbil PhD,
#
#
# Pages: 36-57
# First Published: 20 June 2020
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Open Access
#
#
#
#
#                   oa
#
#
# Frontiers of Sodium MRI Revisited: From Cartilage to Brain Imaging
#
#  Olgica Zaric PhD,
#  Vladimir Juras PhD,
#  Pavol Szomolanyi PhD,
#  Markus Schreiner MD,
#  Marcus Raudner MD,
#  Chiara Giraudo PhD,
#  Siegfried Trattnig MD,
#
#
# Pages: 58-75
# First Published: 26 August 2020
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Head and Neck
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Association of Hypertension With Both Occurrence and Outcome of Symptomatic Patients With Mild Intracranial Atherosclerotic Stenosis: A Prospective Higher Resolution Magnetic Resonance Imaging Study
#
#  Zhang Shi MD,
#  Ming Zhao MD,
#  Jing Li MD,
#  Zakaria Meddings BSc,
#  Yibing Shi MD,
#  Tao Jiang MD,
#  Qi Liu MD,
#  Benqiang Deng MD,
#  Jianping Lu MD,
#  Zhongzhao Teng PhD,
#
#
# Pages: 76-88
# First Published: 10 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “The Occurrence and Outcome of Mild Intracranial Atherosclerotic Stenosis: A Prospective High-Resolution MRI Study”
#
#  Min-Ying Su PhD,
#
#
# Pages: 89-90
# First Published: 26 February 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Head and Neck
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Intravoxel Incoherent Motion Magnetic Resonance Imaging for Prediction of Induction Chemotherapy Response in Locally Advanced Hypopharyngeal Carcinoma: Comparison With Model-Free Dynamic Contrast-Enhanced Magnetic Resonance Imaging
#
#  Baoliang Guo MD,
#  Fusheng Ouyang MD,
#  Lizhu Ouyang MD,
#  Xiyi Huang MD,
#  Tiandi Guo MD,
#  Shaojia Lin MD,
#  Ziwei Liu MD,
#  Rong Zhang MD,
#  Shao-min Yang MD,
#  Haixiong Chen PhD,
#  Qiu-gen Hu PhD,
#
#
# Pages: 91-100
# First Published: 11 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “Intra-voxel incoherent motion (IVIM) MRI for prediction of induction chemotherapy response in locally advanced hypopharyngeal carcinoma: comparison with model-free dynamic contrast-enhanced MRI”
#
#  Noriyuki Fujima MD, PhD,
#
#
# Pages: 101-102
# First Published: 28 March 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Pelvis
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Performance of Prostate Imaging Reporting and Data System Version 2.1 for Diagnosis of Prostate Cancer: A Systematic Review and Meta-Analysis
#
#  Kye Jin Park MD,
#  Sang Hyun Choi MD, PhD,
#  Mi-hyun Kim MD, PhD,
#  Jeong Kon Kim MD, PhD,
#  In Gab Jeong MD, PhD,
#
#
# Pages: 103-112
# First Published: 11 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Abdomen
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Quantification of 1.5 T T1 and T2* Relaxation Times of Fetal Tissues in Uncomplicated Pregnancies
#
#
#  Simran Sethi BSc,
#  Stephanie A. Giza BSc,
#  Estee Goldberg MESc,
#  Mary-Ellen E.T. Empey MSc, CRGS,
#  Sandrine de Ribaupierre MSc, MD,
#  Genevieve D.M. Eastabrook MD,
#  Barbra de Vrijer MD,
#  Charles A. McKenzie PhD,
#
#
# Pages: 113-121
# First Published: 15 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Automated Analysis of Multiparametric Magnetic Resonance Imaging/Magnetic Resonance Elastography Exams for Prediction of Nonalcoholic Steatohepatitis
#
#  Bogdan Dzyubak PhD,
#  Jiahui Li MD,
#  Jie Chen MD,
#  Kristin C. Mara MS,
#  Terry M. Therneau PhD,
#  Sudhakar K. Venkatesh MD,
#  Richard L. Ehman MD,
#  Alina M. Allen MD,
#  Meng Yin PhD,
#
#
# Pages: 122-131
# First Published: 15 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “Automated Analysis of Multiparametric MRI/MRE Exams for Prediction of NASH”
#
#  Michael R. Torkzad MD, PhD,
#
#
# Pages: 132-133
# First Published: 09 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Abdomen
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Deep Learning With 3D Convolutional Neural Network for Noninvasive Prediction of Microvascular Invasion in Hepatocellular Carcinoma
#
#  Yongxin Zhang PhD,
#  Xiaofei Lv PhD,
#  Jiliang Qiu PhD,
#  Bin Zhang PhD,
#  Lu Zhang PhD,
#  Jin Fang PhD,
#  Minmin Li MD,
#  Luyan Chen MD,
#  Fei Wang PhD,
#  Shuyi Liu PhD,
#  Shuixing Zhang MD, PhD,
#
#
# Pages: 134-143
# First Published: 08 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial on “Deep Learning with 3D Convolutional Neural Network for Noninvasive Prediction of Microvascular Invasion in Hepatocellular Carcinoma”
#
#  Christian B. van der Pol MD, FRCPC,
#
#
# Pages: 144-145
# First Published: 08 February 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Musculoskeletal
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Bone Marrow Fat Measured by a Chemical Shift-Encoded Sequence (IDEAL-IQ) in Patients With and Without Metabolic Syndrome
#
#  Qiang Ma MD,
#  Xiaoyue Cheng MD,
#  Xinmeng Hou MD,
#  Zhenghan Yang MD, PhD,
#  Daqing Ma MD,
#  Zhenchang Wang MD,
#
#
# Pages: 146-153
# First Published: 16 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “Bone marrow fat measured by a chemical shift-encoded sequence (IDEAL-IQ) in patients with and without metabolic syndrome”
#
#  Guillaume Koch MD, MSc,
#
#
# Pages: 154
# First Published: 23 April 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Musculoskeletal
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Joint-adjacent Adipose Tissue by MRI is Associated With Prevalence and Progression of Knee Degenerative Changes: Data from the Osteoarthritis Initiative
#
#  Jannis Bodden MD,
#  Ahmet H. Ok,
#  Gabby B. Joseph PhD,
#  Michael C. Nevitt PhD, MPH,
#  Charles E. McCulloch PhD,
#  Nancy E. Lane BS, MD,
#  Thomas M. Link MD, PhD,
#
#
# Pages: 155-165
# First Published: 28 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Vascular
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Plaque Morphologic Quantification Reliability of 3D Whole-Brain Vessel Wall Imaging in Patients With Intracranial Atherosclerotic Disease: A Comparison With Conventional 3D Targeted Vessel Wall Imaging
#
#  Na Zhang PhD,
#  Xinfeng Liu MS,
#  Jiayu Xiao MD,
#  Shlee S. Song MD,
#  Zhaoyang Fan PhD,
#
#
# Pages: 166-174
# First Published: 15 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Can 3D Pseudo-Continuous Territorial Arterial Spin Labeling Effectively Diagnose Patients With Recanalization of Unilateral Middle Cerebral Artery Stenosis?
#
#  Xinyu Wang MMed,
#  Weiqiang Dou PhD,
#  Dong Dong MD,
#  Xinyi Wang MMed,
#  Xueyu Chen MMed,
#  Kunjian Chen MMed,
#  Huimin Mao MMed,
#  Yu Guo MMed,
#  Chao Zhang MMed,
#
#
# Pages: 175-183
# First Published: 21 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “Can 3D Pseudo-Continuous Territorial Arterial Spin Labeling Diagnose Unilateral Middle Cerebral Artery Stenosis?”
#
#  Joao Filipe Fernandes MS Eng,
#
#
# Pages: 184-185
# First Published: 11 May 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Neuro
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Perinidal Angiogenesis Is a Predictor for Neurovascular Uncoupling in the Periphery of Brain Arteriovenous Malformations: A Task-Based and Resting-State fMRI Study
#
#  Maogui Li MD,
#  Qingyuan Liu MD,
#  Rui Guo MD,
#  Shuzhe Yang MD,
#  Pengjun Jiang MD,
#  Xin Chen MD,
#  Jun Wu MD,
#  Yong Cao MD,
#  Shuo Wang MD,
#
#
# Pages: 186-196
# First Published: 21 December 2020
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Automated machine learning to predict the co-occurrence of isocitrate dehydrogenase mutations and O6-methylguanine-DNA methyltransferase promoter methylation in patients with gliomas
#
#
#  Simin Zhang PhD,
#  Huaiqiang Sun PhD,
#  Xiaorui Su PhD,
#  Xibiao Yang MM,
#  Weina Wang PhD,
#  Xinyue Wan MM,
#  Qiaoyue Tan MM,
#  Ni Chen MD, PhD,
#  Qiang Yue MD, PhD,
#  Qiyong Gong MD, PhD,
#
#
# Pages: 197-205
# First Published: 03 January 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Role of the spinal canal compliance in regulating posture-related cerebrospinal fluid hydrodynamics in humans
#
#  Noam Alperin PhD,
#  Ritambhar Burman BE,
#  Sang H. Lee MS,
#
#
# Pages: 206-214
# First Published: 25 January 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Alteration of single-subject gray matter networks in major depressed patients with suicidality
#
#  Huiru Li MD,
#  Jing Yang MS,
#  Li Yin MD,
#  Huawei Zhang MD,
#  Feifei Zhang MD,
#  Ziqi Chen MD,
#  Zhiyun Jia MD, PhD,
#  Qiyong Gong MD, PhD,
#
#
# Pages: 215-224
# First Published: 31 December 2020
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “Alteration of single-subject gray matter networks in major depressed patients with suicidality”
#
#  Erkan Gökçe MD,
#
#
# Pages: 225-226
# First Published: 09 February 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Neuro
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Noninvasive Assessment of O(6)-Methylguanine-DNA Methyltransferase Promoter Methylation Status in World Health Organization Grade II–IV Glioma Using Histogram Analysis of Inflow-Based Vascular-Space-Occupancy Combined with Structural Magnetic Resonance Imaging
#
#  Wenle He MD,
#  Xiaodan Li MD,
#  Jun Hua PhD,
#  Shukun Liao MD,
#  Liuji Guo MD,
#  Xiang Xiao MD,
#  Xiaomin Liu MD,
#  Jun Zhou MD,
#  Wensheng Wang MD,
#  Yikai Xu MD,
#  Yuankui Wu MD,
#
#
# Pages: 227-236
# First Published: 16 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “Noninvasive Assessment of MGMT Promoter Methylation Status in World Health Organization Grade II-IV Glioma Using Histogram Analysis of Inflow-Based Vascular-Space Occupancy Combined with Structural MR Imaging”
#
#  Letterio S. Politi MD,
#  Federico Pessina MD,
#  Matteo Simonelli MD,
#  Pierina Navarria MD,
#
#
# Pages: 237-238
# First Published: 12 March 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Neuro
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Dynamic Changes in Functional Network Connectivity Involving Amyotrophic Lateral Sclerosis and Its Correlation With Disease Severity
#
#  Hua-Jun Chen MD,
#  Zhang-Yu Zou MD,
#  Xiao-Hong Zhang MD,
#  Jia-Yan Shi MD,
#  Nao-Xin Huang MD,
#  Yan-Juan Lin MD,
#
#
# Pages: 239-248
# First Published: 08 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “Dynamic Changes in Functional Network Connectivity Involving Amyotrophic Lateral Sclerosis and Its Correlation to Disease Severity”
#
#  Sikandar Shaikh DMRD, DNB, MNAMS, EDiR, FICR,
#
#
# Pages: 249-250
# First Published: 06 February 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Breast
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Functional Tumor Volume by Fast Dynamic Contrast-Enhanced MRI for Predicting Neoadjuvant Systemic Therapy Response in Triple-Negative Breast Cancer
#
#  Benjamin C. Musall MS,
#  Abeer H. Abdelhafez MD, PhD,
#  Beatriz E. Adrada MD,
#  Rosalind P. Candelaria MD,
#  Rania M.M. Mohamed MD,
#  Medine Boge MD,
#  Huong Le-Petross MD,
#  Elsa Arribas MD,
#  Deanna L. Lane MD,
#  David A. Spak MD,
#  Jessica W.T. Leung MD,
#  Ken-Pin Hwang PhD,
#  Jong Bum Son PhD,
#  Nabil A. Elshafeey MD,
#  Hagar S. Mahmoud MD,
#  Peng Wei PhD,
#  Jia Sun PhD,
#  Shu Zhang PhD,
#  Jason B. White PhD,
#  Elizabeth E. Ravenberg PhD,
#  Jennifer K. Litton MD,
#  Senthil Damodaran MD, PhD,
#  Alastair M. Thompson MD,
#  Stacy L. Moulder MD,
#  Wei T. Yang MBBS,
#  Mark D. Pagel PhD,
#  Gaiane M. Rauch MD, PhD,
#  Jingfei Ma PhD,
#
#
# Pages: 251-260
# First Published: 15 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “Functional Tumor Volume by Fast Dynamic Contrast-Enhanced MRI for Predicting Neoadjuvant Systemic Therapy Response in Triple-Negative Breast Cancer”
#
#  Federico D. Pineda PhD,
#
#
# Pages: 261-262
# First Published: 11 May 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Pediatrics
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Three-Dimensional Volumetric Magnetic Resonance Imaging Detects Early Alterations of the Brain Growth in Fetuses With Congenital Heart Disease
#
#  Jing-Ya Ren MD,
#  Ming Zhu MD,
#  Su-Zhen Dong MD, PhD,
#
#
# Pages: 263-272
# First Published: 08 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “3D Volumetric MRI Detects Early Alterations of the Brain Growth in Fetuses with Congenital Heart Disease”
#
#  Monika Bekiesinska-Figatowska MD, PhD,
#
#
# Pages: 273-274
# First Published: 05 February 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Cardiac
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Cine MRI detects elevated left heart pressure in pulmonary hypertension
#
#  Kai Lin MD, MS,
#  Roberto Sarnari MD,
#  Ashitha Pathrose MD,
#  Daniel Gordon BS,
#  Julie Blaisdell MS,
#  Michael Markl PhD,
#  James C. Carr MD,
#
#
# Pages: 275-283
# First Published: 09 January 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Noninvasive oxygenation assessment after acute myocardial infarction with breathing maneuvers-induced oxygenation-sensitive magnetic resonance imaging
#
#  Ke Shi MD,
#  Meng-Xi Yang MD,
#  Chun-Chao Xia MS,
#  Wan-Lin Peng MS,
#  Kun Zhang MS,
#  Zhen-Lin Li MS,
#  Ying-Kun Guo MD, PhD,
#  Zhi-Gang Yang MD, PhD,
#
#
# Pages: 284-289
# First Published: 12 January 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Full Access
#
#
#
#
#                      full
#
#
# Texture Analysis of Native T1 Images as a Novel Method for Noninvasive Assessment of Uremic Cardiomyopathy
#
#  Hang Zhou MD,
#  Dong-Aolei An MD,
#  Zhaohui Ni PhD,
#  Jianrong Xu PhD,
#  Wei Fang PhD,
#  Renhua Lu PhD,
#  Liang Ying PhD,
#  Jiaying Huang ND,
#  Qiuying Yao BS,
#  Dawei Li PhD,
#  Binghua Chen PhD,
#  Jianxiao Shen PhD,
#  Haijiao Jin MD,
#  Yuehan Wei MD,
#  Jiani Hu PhD,
#  Lara M. Fahmy PhD,
#  Luke Wesemann MD,
#  Shouliang Qi PhD,
#  Lian-Ming Wu PhD,
#  Shan Mou PhD,
#
#
# Pages: 290-300
# First Published: 18 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial on “Texture Analysis of Native T1 Images as a Novel Method for Non-Invasive Assessment of Myocardial Fibrosis in Dialysis Patients”
#
#  Steve W. Leung MD,
#
#
# Pages: 301-302
# First Published: 26 February 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Cardiac
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Improved Quantification of Myocardium Scar in Late Gadolinium Enhancement Images: Deep Learning Based Image Fusion Approach
#
#  Ahmed S. Fahmy PhD,
#  Ethan J. Rowin MD,
#  Raymond H. Chan MD,
#  Warren J. Manning MD,
#  Martin S. Maron MD,
#  Reza Nezafat PhD,
#
#
# Pages: 303-312
# First Published: 17 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “Improved Quantification of Myocardium Scar in Late Gadolinium Enhancement Images: Deep Learning Based Image Fusion Approach”
#
#  Kenichiro Suwa MD, PhD,
#
#
# Pages: 313-314
# First Published: 29 March 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Original Research
#
# Safety
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Maintaining Image Quality While Reducing Acoustic Noise and Switched Gradient Field Exposure During Lumbar MRI
#
#  Anton Glans MMSc,
#  Jonna Wilén PhD,
#  Lenita Lindgren PhD,
#
#
# Pages: 315-325
# First Published: 09 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Editorial for “Maintaining Image Quality While Reducing Acoustic Noise and Switched Gradient Field Exposure During Lumbar Magnetic Resonance Imaging”
#
#  Kazuhiro Tsuchiya MD, PhD,
#
#
# Pages: 326-327
# First Published: 08 February 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Letter to the Editor
#
#
# Full Access
#
#
#
#
#                   full
#
#
# Feeling the price tag of magnetic resonance imaging claustrophobia
#
#  Adnan M. Sadiq MD,
#  Daniel E. Mariki MSc,
#  Cleopah M. Gundah MSc,
#  Emmanuel V. Assey MD,
#  Marco van Zwetselaar MSc,
#  William P. Howlett MD, PhD,
#  Marieke C. J. Dekker MD, PhD,
#
#
# Pages: 328
# First Published: 24 January 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
#
# Tools
#
# Submit an Article
# Browse free sample issue
# Get content alerts
#
#
#
#
#
# Subscribe to this journal
#
#
#
#
#
#
#
#                 More from this journal
#
# Professional OpportunitiesISMRM Journal AppsW.S. Moore Award Winning ArticlesOther ResourcesFull Issue PDFs
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-rail-1' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			googletag.cmd.push 		( function () {
# 				googletag.display 	( 'advert-rail-2' );
# 			});
#
#
#
#
#
#
#
#
#
#
#
#
#                 Related Title
#
# IssueVolume 86, Issue 4Pages: C1, 1803-2327October 2021
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     .footer-links {
#         text-align: center;
#     }
#     .footer-links h3 {
#         font-weight: 300;
#     }
#     .footer-links a {
#         font-weight: 600;
#     }
#     @media (min-width: 992px) {
#         .footer-links {
#             text-align: left;
#         }
#     }
#
#
#
#                 Additional links
#
#
#
# About Wiley Online Library
#
# Privacy Policy
# Terms of Use
# Cookies
# Accessibility
#
#
#
#
# Help & Support
#
# Contact Us
# Training and Support
# DMCA & Reporting Piracy
#
#
#
#
# Opportunities
#
# Subscription Agents
# Advertisers & Corporate Partners
#
#
#
#
# Connect with Wiley
#
# The Wiley Network
# Wiley Press Room
#
#
#
#
#
#
#
# Copyright © 1999-2021 John Wiley & Sons, Inc. All rights reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Log in to Wiley Online Library
#
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Password
#
#
#
#
#
#
#                                 Forgot password?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         NEW USER >
#
#
#
#                             INSTITUTIONAL LOGIN >
#
#
#
#
#
#
#
#
#
#
#
#
# Change Password
#
#
#
#
#
#
#
# Old Password
#
#
#
#
#
#
# New Password
#
#
#
#
# Too Short
# Weak
# Medium
# Strong
# Very Strong
# Too Long
#
#
#
#
#
#
# Password Changed Successfully
# Your password has been changed
#
#
#
#
#
#
#
#
#
#
# Create a new account
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#                     Returning user
#
#
#
#
#
#
#
#
#
#
#
#
# Forgot your password?
# Enter your email address below.
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#
# Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#
#
#
#
#
#
#
#
# Request Username
#
# Can't sign in? Forgot your username?
# Enter your email address below and we will send you your username
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Close
#
#
#
# If the address matches an existing account you will receive an email with instructions to retrieve your username
#
#
#
#
#
# if(window._satellite) {
# _satellite.pageBottom();
# }
#
#
#
#     .tfa-form-container .verification-hint {
#         text-align: center;
#         padding-top: 20px;
#         padding-bottom: 20px;
#         font-size: 13px;
#     }
#
#     .tfa-form-container .verification-hint .verification-hint__link {
#         font-weight: 500;
#         display: inline-block;
#         text-decoration: none;
#     }
#
#
#
#     .tfa-form-container #tfa-options {
#     	display: none;
#     }
#
#     .tfa-form-container .three-digits {
#     	overflow-wrap: break-word;
#     }
#
#
#
#
#
# var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();

# %%
all_links = soupJMRI.find_all('a')

# %%
# h3 class corresponds to editorial

all_h3 = soupJMRI.find_all("h3")

i = 0
for h3 in all_h3:
  # print(h3)
  print(h3.get_text())
  i += 1
print(i)
# Out:
# Menu
# Format
# Type of import
# Cover Image
# Issue Information
# Commentary
# Review Articles
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Original Research
# Editorial
# Letter to the Editor
# About Wiley Online Library
# Help & Support
# Opportunities
# Connect with Wiley
# 40

# %% [markdown]
# ### Explore: Add Category

# %%
# h4 class corresponds to category

all_h4 = soupJMRI.find_all("h4")

i = 0
for h4 in all_h4:
  # print(h4)
  print(h4.get_text())
  i += 1
print(i)
# Out:
# Head and Neck
# Head and Neck
# Pelvis
# Abdomen
# Abdomen
# Musculoskeletal
# Musculoskeletal
# Vascular
# Neuro
# Neuro
# Neuro
# Breast
# Pediatrics
# Cardiac
# Cardiac
# Safety
# 16

# %%
# li class: corresponds to "First Published"

all_li = soupJMRI.find_all("li")

i = 0
for li in all_li:
  li_class = li.get_attribute_list("class")
  # print(li_class)
  if li_class == ['ePubDate']:
    print(li.get_text())
    i += 1
  # print(li.get_text())
  # i += 1
print(i)
# Out:
# First Published: 11 June 2021
# First Published: 11 June 2021
# First Published: 13 May 2021
# First Published: 25 June 2020
# First Published: 20 June 2020
# First Published: 26 August 2020
# First Published: 10 March 2021
# First Published: 26 February 2021
# First Published: 11 February 2021
# First Published: 28 March 2021
# First Published: 11 February 2021
# First Published: 15 February 2021
# First Published: 15 February 2021
# First Published: 09 February 2021
# First Published: 08 February 2021
# First Published: 08 February 2021
# First Published: 16 March 2021
# First Published: 23 April 2021
# First Published: 28 February 2021
# First Published: 15 February 2021
# First Published: 21 February 2021
# First Published: 11 May 2021
# First Published: 21 December 2020
# First Published: 03 January 2021
# First Published: 25 January 2021
# First Published: 31 December 2020
# First Published: 09 February 2021
# First Published: 16 February 2021
# First Published: 12 March 2021
# First Published: 08 February 2021
# First Published: 06 February 2021
# First Published: 15 February 2021
# First Published: 11 May 2021
# First Published: 08 February 2021
# First Published: 05 February 2021
# First Published: 09 January 2021
# First Published: 12 January 2021
# First Published: 18 February 2021
# First Published: 26 February 2021
# First Published: 17 February 2021
# First Published: 29 March 2021
# First Published: 09 February 2021
# First Published: 08 February 2021
# First Published: 24 January 2021
# 44

# %%
all_h2 = soupJMRI.find_all("h2")

i = 0
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 3:
    print(h2.get_text())
    i += 1
print(i)

# str_h2 = str(all_h2)

# links = soupJMRI.find_all("a")
# str_links = str(links)
# print(str_h2)

# cleantext = BeautifulSoup(str_h2, "lxml").get_text()
# cleantext = BeautifulSoup(str_links, "lxml").get_text()
# print(cleantext)
# Out:
# Can 3D Pseudo-Continuous Territorial Arterial Spin Labeling Effectively Diagnose Patients With Recanalization of Unilateral Middle Cerebral Artery Stenosis?
# Societal and Research Population Biases
# MRI-Based Quantitative Osteoporosis Imaging at the Spine and Femur
# Diffusion Imaging in the Post HCP Era
# Frontiers of Sodium MRI Revisited: From Cartilage to Brain Imaging
# Association of Hypertension With Both Occurrence and Outcome of Symptomatic Patients With Mild Intracranial Atherosclerotic Stenosis: A Prospective Higher Resolution Magnetic Resonance Imaging Study
# Editorial for “The Occurrence and Outcome of Mild Intracranial Atherosclerotic Stenosis: A Prospective High-Resolution MRI Study”
# Intravoxel Incoherent Motion Magnetic Resonance Imaging for Prediction of Induction Chemotherapy Response in Locally Advanced Hypopharyngeal Carcinoma: Comparison With Model-Free Dynamic Contrast-Enhanced Magnetic Resonance Imaging
# Editorial for “Intra-voxel incoherent motion (IVIM) MRI for prediction of induction chemotherapy response in locally advanced hypopharyngeal carcinoma: comparison with model-free dynamic contrast-enhanced MRI”
# Performance of Prostate Imaging Reporting and Data System Version 2.1 for Diagnosis of Prostate Cancer: A Systematic Review and Meta-Analysis
# Quantification of 1.5 T T1 and T2* Relaxation Times of Fetal Tissues in Uncomplicated Pregnancies
#
# Automated Analysis of Multiparametric Magnetic Resonance Imaging/Magnetic Resonance Elastography Exams for Prediction of Nonalcoholic Steatohepatitis
# Editorial for “Automated Analysis of Multiparametric MRI/MRE Exams for Prediction of NASH”
# Deep Learning With 3D Convolutional Neural Network for Noninvasive Prediction of Microvascular Invasion in Hepatocellular Carcinoma
# Editorial on “Deep Learning with 3D Convolutional Neural Network for Noninvasive Prediction of Microvascular Invasion in Hepatocellular Carcinoma”
# Bone Marrow Fat Measured by a Chemical Shift-Encoded Sequence (IDEAL-IQ) in Patients With and Without Metabolic Syndrome
# Editorial for “Bone marrow fat measured by a chemical shift-encoded sequence (IDEAL-IQ) in patients with and without metabolic syndrome”
# Joint-adjacent Adipose Tissue by MRI is Associated With Prevalence and Progression of Knee Degenerative Changes: Data from the Osteoarthritis Initiative
# Plaque Morphologic Quantification Reliability of 3D Whole-Brain Vessel Wall Imaging in Patients With Intracranial Atherosclerotic Disease: A Comparison With Conventional 3D Targeted Vessel Wall Imaging
# Can 3D Pseudo-Continuous Territorial Arterial Spin Labeling Effectively Diagnose Patients With Recanalization of Unilateral Middle Cerebral Artery Stenosis?
# Editorial for “Can 3D Pseudo-Continuous Territorial Arterial Spin Labeling Diagnose Unilateral Middle Cerebral Artery Stenosis?”
# Perinidal Angiogenesis Is a Predictor for Neurovascular Uncoupling in the Periphery of Brain Arteriovenous Malformations: A Task-Based and Resting-State fMRI Study
# Automated machine learning to predict the co-occurrence of isocitrate dehydrogenase mutations and O6-methylguanine-DNA methyltransferase promoter methylation in patients with gliomas
#
# Role of the spinal canal compliance in regulating posture-related cerebrospinal fluid hydrodynamics in humans
# Alteration of single-subject gray matter networks in major depressed patients with suicidality
# Editorial for “Alteration of single-subject gray matter networks in major depressed patients with suicidality”
# Noninvasive Assessment of O(6)-Methylguanine-DNA Methyltransferase Promoter Methylation Status in World Health Organization Grade II–IV Glioma Using Histogram Analysis of Inflow-Based Vascular-Space-Occupancy Combined with Structural Magnetic Resonance Imaging
# Editorial for “Noninvasive Assessment of MGMT Promoter Methylation Status in World Health Organization Grade II-IV Glioma Using Histogram Analysis of Inflow-Based Vascular-Space Occupancy Combined with Structural MR Imaging”
# Dynamic Changes in Functional Network Connectivity Involving Amyotrophic Lateral Sclerosis and Its Correlation With Disease Severity
# Editorial for “Dynamic Changes in Functional Network Connectivity Involving Amyotrophic Lateral Sclerosis and Its Correlation to Disease Severity”
# Functional Tumor Volume by Fast Dynamic Contrast-Enhanced MRI for Predicting Neoadjuvant Systemic Therapy Response in Triple-Negative Breast Cancer
# Editorial for “Functional Tumor Volume by Fast Dynamic Contrast-Enhanced MRI for Predicting Neoadjuvant Systemic Therapy Response in Triple-Negative Breast Cancer”
# Three-Dimensional Volumetric Magnetic Resonance Imaging Detects Early Alterations of the Brain Growth in Fetuses With Congenital Heart Disease
# Editorial for “3D Volumetric MRI Detects Early Alterations of the Brain Growth in Fetuses with Congenital Heart Disease”
# Cine MRI detects elevated left heart pressure in pulmonary hypertension
# Noninvasive oxygenation assessment after acute myocardial infarction with breathing maneuvers-induced oxygenation-sensitive magnetic resonance imaging
# Texture Analysis of Native T1 Images as a Novel Method for Noninvasive Assessment of Uremic Cardiomyopathy
# Editorial on “Texture Analysis of Native T1 Images as a Novel Method for Non-Invasive Assessment of Myocardial Fibrosis in Dialysis Patients”
# Improved Quantification of Myocardium Scar in Late Gadolinium Enhancement Images: Deep Learning Based Image Fusion Approach
# Editorial for “Improved Quantification of Myocardium Scar in Late Gadolinium Enhancement Images: Deep Learning Based Image Fusion Approach”
# Maintaining Image Quality While Reducing Acoustic Noise and Switched Gradient Field Exposure During Lumbar MRI
# Editorial for “Maintaining Image Quality While Reducing Acoustic Noise and Switched Gradient Field Exposure During Lumbar Magnetic Resonance Imaging”
# Feeling the price tag of magnetic resonance imaging claustrophobia
#
#                 More from this journal
#
# Log in to Wiley Online Library
# Create a new account
# 46

# %% [markdown]
# ### Clean up the title list

# %%
list_h2 = []
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 4:
    cells = h2.get_text()
    list_h2.append(cells)

# Delete the last element: "Log in to Wiley Online Library"
list_h2.pop()

# Insert "Issue Information" as the 2nd element
list_h2.insert(1, "Issue Information")

# JMRI Vol 54 No 2
# list_h2.append("Erratum")
# JMRI Vol 54 No 3
# list_h2.insert(2, "Commentary")
# list_h2.append("Condensation Artifact")
# list_h2.append("Reviewer Acknowledgements")

for l in list_h2:
  print(l)
print(len(list_h2))
# Out:
# Can 3D Pseudo-Continuous Territorial Arterial Spin Labeling Effectively Diagnose Patients With Recanalization of Unilateral Middle Cerebral Artery Stenosis?
# Issue Information
# Societal and Research Population Biases
# MRI-Based Quantitative Osteoporosis Imaging at the Spine and Femur
# Diffusion Imaging in the Post HCP Era
# Frontiers of Sodium MRI Revisited: From Cartilage to Brain Imaging
# Association of Hypertension With Both Occurrence and Outcome of Symptomatic Patients With Mild Intracranial Atherosclerotic Stenosis: A Prospective Higher Resolution Magnetic Resonance Imaging Study
# Editorial for “The Occurrence and Outcome of Mild Intracranial Atherosclerotic Stenosis: A Prospective High-Resolution MRI Study”
# Intravoxel Incoherent Motion Magnetic Resonance Imaging for Prediction of Induction Chemotherapy Response in Locally Advanced Hypopharyngeal Carcinoma: Comparison With Model-Free Dynamic Contrast-Enhanced Magnetic Resonance Imaging
# Editorial for “Intra-voxel incoherent motion (IVIM) MRI for prediction of induction chemotherapy response in locally advanced hypopharyngeal carcinoma: comparison with model-free dynamic contrast-enhanced MRI”
# Performance of Prostate Imaging Reporting and Data System Version 2.1 for Diagnosis of Prostate Cancer: A Systematic Review and Meta-Analysis
# Quantification of 1.5 T T1 and T2* Relaxation Times of Fetal Tissues in Uncomplicated Pregnancies
#
# Automated Analysis of Multiparametric Magnetic Resonance Imaging/Magnetic Resonance Elastography Exams for Prediction of Nonalcoholic Steatohepatitis
# Editorial for “Automated Analysis of Multiparametric MRI/MRE Exams for Prediction of NASH”
# Deep Learning With 3D Convolutional Neural Network for Noninvasive Prediction of Microvascular Invasion in Hepatocellular Carcinoma
# Editorial on “Deep Learning with 3D Convolutional Neural Network for Noninvasive Prediction of Microvascular Invasion in Hepatocellular Carcinoma”
# Bone Marrow Fat Measured by a Chemical Shift-Encoded Sequence (IDEAL-IQ) in Patients With and Without Metabolic Syndrome
# Editorial for “Bone marrow fat measured by a chemical shift-encoded sequence (IDEAL-IQ) in patients with and without metabolic syndrome”
# Joint-adjacent Adipose Tissue by MRI is Associated With Prevalence and Progression of Knee Degenerative Changes: Data from the Osteoarthritis Initiative
# Plaque Morphologic Quantification Reliability of 3D Whole-Brain Vessel Wall Imaging in Patients With Intracranial Atherosclerotic Disease: A Comparison With Conventional 3D Targeted Vessel Wall Imaging
# Can 3D Pseudo-Continuous Territorial Arterial Spin Labeling Effectively Diagnose Patients With Recanalization of Unilateral Middle Cerebral Artery Stenosis?
# Editorial for “Can 3D Pseudo-Continuous Territorial Arterial Spin Labeling Diagnose Unilateral Middle Cerebral Artery Stenosis?”
# Perinidal Angiogenesis Is a Predictor for Neurovascular Uncoupling in the Periphery of Brain Arteriovenous Malformations: A Task-Based and Resting-State fMRI Study
# Automated machine learning to predict the co-occurrence of isocitrate dehydrogenase mutations and O6-methylguanine-DNA methyltransferase promoter methylation in patients with gliomas
#
# Role of the spinal canal compliance in regulating posture-related cerebrospinal fluid hydrodynamics in humans
# Alteration of single-subject gray matter networks in major depressed patients with suicidality
# Editorial for “Alteration of single-subject gray matter networks in major depressed patients with suicidality”
# Noninvasive Assessment of O(6)-Methylguanine-DNA Methyltransferase Promoter Methylation Status in World Health Organization Grade II–IV Glioma Using Histogram Analysis of Inflow-Based Vascular-Space-Occupancy Combined with Structural Magnetic Resonance Imaging
# Editorial for “Noninvasive Assessment of MGMT Promoter Methylation Status in World Health Organization Grade II-IV Glioma Using Histogram Analysis of Inflow-Based Vascular-Space Occupancy Combined with Structural MR Imaging”
# Dynamic Changes in Functional Network Connectivity Involving Amyotrophic Lateral Sclerosis and Its Correlation With Disease Severity
# Editorial for “Dynamic Changes in Functional Network Connectivity Involving Amyotrophic Lateral Sclerosis and Its Correlation to Disease Severity”
# Functional Tumor Volume by Fast Dynamic Contrast-Enhanced MRI for Predicting Neoadjuvant Systemic Therapy Response in Triple-Negative Breast Cancer
# Editorial for “Functional Tumor Volume by Fast Dynamic Contrast-Enhanced MRI for Predicting Neoadjuvant Systemic Therapy Response in Triple-Negative Breast Cancer”
# Three-Dimensional Volumetric Magnetic Resonance Imaging Detects Early Alterations of the Brain Growth in Fetuses With Congenital Heart Disease
# Editorial for “3D Volumetric MRI Detects Early Alterations of the Brain Growth in Fetuses with Congenital Heart Disease”
# Cine MRI detects elevated left heart pressure in pulmonary hypertension
# Noninvasive oxygenation assessment after acute myocardial infarction with breathing maneuvers-induced oxygenation-sensitive magnetic resonance imaging
# Texture Analysis of Native T1 Images as a Novel Method for Noninvasive Assessment of Uremic Cardiomyopathy
# Editorial on “Texture Analysis of Native T1 Images as a Novel Method for Non-Invasive Assessment of Myocardial Fibrosis in Dialysis Patients”
# Improved Quantification of Myocardium Scar in Late Gadolinium Enhancement Images: Deep Learning Based Image Fusion Approach
# Editorial for “Improved Quantification of Myocardium Scar in Late Gadolinium Enhancement Images: Deep Learning Based Image Fusion Approach”
# Maintaining Image Quality While Reducing Acoustic Noise and Switched Gradient Field Exposure During Lumbar MRI
# Editorial for “Maintaining Image Quality While Reducing Acoustic Noise and Switched Gradient Field Exposure During Lumbar Magnetic Resonance Imaging”
# Feeling the price tag of magnetic resonance imaging claustrophobia
# 44

# %%
list_date = []
for li in all_li:
  li_class = li.get_attribute_list("class")
  if li_class == ['ePubDate']:
    cells = li.get_text().split(': ')[1]
    list_date.append(cells)

for l in list_date:
  print(l)
print(len(list_date))
# Out:
# 11 June 2021
# 11 June 2021
# 13 May 2021
# 25 June 2020
# 20 June 2020
# 26 August 2020
# 10 March 2021
# 26 February 2021
# 11 February 2021
# 28 March 2021
# 11 February 2021
# 15 February 2021
# 15 February 2021
# 09 February 2021
# 08 February 2021
# 08 February 2021
# 16 March 2021
# 23 April 2021
# 28 February 2021
# 15 February 2021
# 21 February 2021
# 11 May 2021
# 21 December 2020
# 03 January 2021
# 25 January 2021
# 31 December 2020
# 09 February 2021
# 16 February 2021
# 12 March 2021
# 08 February 2021
# 06 February 2021
# 15 February 2021
# 11 May 2021
# 08 February 2021
# 05 February 2021
# 09 January 2021
# 12 January 2021
# 18 February 2021
# 26 February 2021
# 17 February 2021
# 29 March 2021
# 09 February 2021
# 08 February 2021
# 24 January 2021
# 44

# %%
list_url = []
for link in all_links:
  if 'visitable' in str(link.get("class")): # and '/doi/' in link.get("href"):
    cells = link.get("href").replace('/doi', 'https://doi.org')
    list_url.append(cells)

for l in list_url:
  print(l)
print(len(list_url))
# Out:
# https://doi.org/10.1002/jmri.27227
# https://doi.org/10.1002/jmri.27228
# https://doi.org/10.1002/jmri.27681
# https://doi.org/10.1002/jmri.27260
# https://doi.org/10.1002/jmri.27247
# https://doi.org/10.1002/jmri.27326
# https://doi.org/10.1002/jmri.27516
# https://doi.org/10.1002/jmri.27571
# https://doi.org/10.1002/jmri.27537
# https://doi.org/10.1002/jmri.27621
# https://doi.org/10.1002/jmri.27546
# https://doi.org/10.1002/jmri.27547
# https://doi.org/10.1002/jmri.27549
# https://doi.org/10.1002/jmri.27540
# https://doi.org/10.1002/jmri.27538
# https://doi.org/10.1002/jmri.27533
# https://doi.org/10.1002/jmri.27548
# https://doi.org/10.1002/jmri.27645
# https://doi.org/10.1002/jmri.27574
# https://doi.org/10.1002/jmri.27550
# https://doi.org/10.1002/jmri.27560
# https://doi.org/10.1002/jmri.27660
# https://doi.org/10.1002/jmri.27469
# https://doi.org/10.1002/jmri.27498
# https://doi.org/10.1002/jmri.27505
# https://doi.org/10.1002/jmri.27499
# https://doi.org/10.1002/jmri.27544
# https://doi.org/10.1002/jmri.27514
# https://doi.org/10.1002/jmri.27594
# https://doi.org/10.1002/jmri.27521
# https://doi.org/10.1002/jmri.27518
# https://doi.org/10.1002/jmri.27557
# https://doi.org/10.1002/jmri.27669
# https://doi.org/10.1002/jmri.27526
# https://doi.org/10.1002/jmri.27522
# https://doi.org/10.1002/jmri.27504
# https://doi.org/10.1002/jmri.27509
# https://doi.org/10.1002/jmri.27529
# https://doi.org/10.1002/jmri.27523
# https://doi.org/10.1002/jmri.27555
# https://doi.org/10.1002/jmri.27619
# https://doi.org/10.1002/jmri.27527
# https://doi.org/10.1002/jmri.27517
# https://doi.org/10.1002/jmri.27512
# 44

# %%
# df = pd.DataFrame({'title':list_h2, 'url': list_url})
df = pd.DataFrame({'Journal': title, 'Title': list_h2, 'First Published': list_date, 'DOI': list_url})
df
# Out:
#                                               Journal  ...                                 DOI
# 0    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27227
# 1    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27228
# 2    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27681
# 3    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27260
# 4    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27247
# 5    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27326
# 6    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27516
# 7    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27571
# 8    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27537
# 9    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27621
# 10   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27546
# 11   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27547
# 12   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27549
# 13   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27540
# 14   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27538
# 15   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27533
# 16   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27548
# 17   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27645
# 18   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27574
# 19   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27550
# 20   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27560
# 21   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27660
# 22   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27469
# 23   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27498
# 24   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27505
# 25   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27499
# 26   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27544
# 27   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27514
# 28   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27594
# 29   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27521
# 30   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27518
# 31   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27557
# 32   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27669
# 33   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27526
# 34   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27522
# 35   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27504
# 36   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27509
# 37   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27529
# 38   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27523
# 39   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27555
# 40   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27619
# 41   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27527
# 42   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27517
# 43   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27512
#
# [44 rows x 4 columns]

# %% [markdown]
# ### Finally, save as csv file

# %%
df.to_csv(#path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-3.csv',
          #path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-2.csv',
          path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-1.csv', 
          index=False)
