# %% [markdown]
# # Web Scraping using Python

# %% [markdown]
# ## Target Journal: JMRI
#
# Important volumes to include:
#  - Category
#  - Date first published
#
# Examples:
# - https://onlinelibrary.wiley.com/toc/15222586/2021/54/1
# - https://onlinelibrary.wiley.com/toc/15222586/2021/54/2
# - https://onlinelibrary.wiley.com/toc/15222586/2021/54/3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#To easily display the plots, make sure to include the line %matplotlib inline as shown below.
# %matplotlib inline

import urllib
import requests
import lxml

#To perform web scraping, you should also import the libraries shown below. 
#The urllib.request module is used to open URLs. 
#The Beautiful Soup package is used to extract data from html files. 
#The Beautiful Soup library's name is bs4 which stands for Beautiful Soup, version 4.
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ## Method 1 (default): First, save as a local html file
#  - See: https://zetcode.com/python/beautifulsoup/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# JMRI Vol 54 No 1
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_Vol 54, No 1.html'
# JMRI Vol 54 No 2
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 54, No 2.html'
# Current: JMRI Vol 54 No 3
URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 54, No 3.html'

with open(URL, 'r') as f:

    contents = f.read()

    soup = BeautifulSoup(contents, 'lxml')

# %% [markdown]
# Find the corresponding index, and identify the title info

# %%
def safeOpenParsePage(targetUrl):
    try:
        # tmpurl = urlopen(Request(targetUrl, headers={'User-Agent': 'Chrome/92.0.4515.107'}))
        tmpurl = open(targetUrl, 'r')
        tmpR = tmpurl.read()
        # tmpSoup = BeautifulSoup(tmpR, 'html.parser')
        tmpSoup = BeautifulSoup(tmpR, 'lxml')
        return tmpSoup
    except urllib.error.HTTPError as e:
        print(e)
        return None

soupJMRI = safeOpenParsePage(URL)
if soupJMRI is not None:
      print(soupJMRI.prettify())
# Out:
# <!DOCTYPE html>
# <html class="pb-page" data-request-id="e9a30f61-73f9-40c9-a53e-3f820aea96ab" lang="en">
#  <head data-pb-dropzone="head">
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content=";journal:journal:15222586;issue:issue:doi\:10.1002/jmri.v54.3;ctype:string:Journal Content;website:website:pericles;page:string:Table of Contents;requestedJournal:journal:15222586;wgroup:string:Publication Websites;pageGroup:string:Publication Pages" name="pbContext"/>
#   <script type="text/javascript">
#    var $DoubleClickZone = "j-magres-imaging_jmri";var $DoubleClickSite =  "wly.radiol.imag_000105";
#   </script>
#   <script id="analyticDigitalData">
#    digitalData = {"site":{"ip":"109.175.189.34","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2021-08-11","server":"web122"},"identities":[{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"BasicGroup","uuid":"84aa8781-b32a-4f06-979c-30f3ab78ad73"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"BasicGroup","uuid":"b2f59a00-e5f8-40f1-8e75-8c7dd6bce0ba"},{"type":"BasicGroup","uuid":"f6bf73a6-fd29-4303-8301-24bd8a179b03"},{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"ReferrerUser","uuid":"5a52f27c-b57e-4a2d-8de6-c4f2e0fa8465"},{"type":"BasicGroup","uuid":"8b5697d0-0580-43b3-83ea-a258c8085ad5","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004148"}]},{"type":"BasicGroup","uuid":"a9298b81-eb3e-4dfb-82a5-86f98d156f4d","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004150"}]},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"BasicGroup","uuid":"f0737c70-8d27-48b0-8b44-af576d0063e8","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000068532"}]},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"261f34be-39f9-4f9e-8feb-500f73213904"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"ReferrerUser","uuid":"b3da44b5-3aad-4291-8eca-73ea8ea97a07"},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"20d013f5-e22b-4df0-ba93-d6d925db9e32"},{"type":"BasicGroup","uuid":"6a17ff38-0daf-4f0a-b4eb-b42c69d5c12f","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000007783"}]},{"type":"BasicGroup","uuid":"c62f6a8d-8b0e-4a8c-ace7-645ca96979b6"},{"type":"BasicGroup","uuid":"9cb21bff-5e36-40b2-9183-08a76524dc18","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL57933332"}]},{"type":"RegionUser","uuid":"82409588-c43f-4337-a6a8-3272d1b7e20e"},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"RegionUser","uuid":"3147507a-46c1-4f33-a077-4feac12c6b71"},{"type":"SmartGroupUser","uuid":"b2dbfe27-ecae-4bb6-bb0d-d75e5caa3762"},{"type":"SmartGroupUser","uuid":"77da7ca2-c9f3-4f94-9737-922e1d15b7d9"}],"publication":{"group":{"doi":"10.1002/jmri.v54.3","access":"no","volume":"54","issue":"3","coverDate":"2021-09-01","topics":[{"taxonomyUri":"global-subject-codes","topicLabel":"Radiology \u0026 Imaging","topicUri":"mdp0"},{"taxonomyUri":"global-subject-codes","topicLabel":"Medical \u0026 Health Physics","topicUri":"phc0"},{"taxonomyUri":"global-subject-codes","topicLabel":"MEDICAL SCIENCE","topicUri":"md"},{"taxonomyUri":"global-subject-codes","topicLabel":"MRI","topicUri":"mdp3"},{"taxonomyUri":"global-subject-codes","topicLabel":"Interventional Radiology","topicUri":"mdp4"},{"taxonomyUri":"global-subject-codes","topicLabel":"Informatics","topicUri":"mdp1"},{"taxonomyUri":"global-subject-codes","topicLabel":"PHYSICS","topicUri":"ph"}]},"series":{"title":"Journal of Magnetic Resonance Imaging","doi":"10.1002/(ISSN)1522-2586","access":"no","code":"15222586","issn":"1053-1807","eissn":"1522-2586","topics":[{"taxonomyUri":"gpt-sitename","topicLabel":"wly.radiol.imag_000105","topicUri":"wly.radiol.imag_000105"},{"taxonomyUri":"global-subject-codes","topicLabel":"Radiology \u0026 Imaging","topicUri":"mdp0"},{"taxonomyUri":"global-subject-codes","topicLabel":"Medical \u0026 Health Physics","topicUri":"phc0"},{"taxonomyUri":"global-subject-codes","topicLabel":"MEDICAL SCIENCE","topicUri":"md"},{"taxonomyUri":"global-subject-codes","topicLabel":"MRI","topicUri":"mdp3"},{"taxonomyUri":"global-subject-codes","topicLabel":"Interventional Radiology","topicUri":"mdp4"},{"taxonomyUri":"global-subject-codes","topicLabel":"Informatics","topicUri":"mdp1"},{"taxonomyUri":"global ...
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="noarchive" name="robots"/>
#   <meta name="pb-robots-disabled"/>
#   <meta content=" Journal of Magnetic Resonance Imaging: Vol 54, No 3" property="og:title"/>
#   <meta content="Journal" property="og:type"/>
#   <meta content="https://onlinelibrary.wiley.com/toc/15222586/2021/54/3" property="og:url"/>
#   <meta content="https://onlinelibrary.wiley.com/cover/15222586/54/3" property="og:image"/>
#   <meta content="Wiley Online Library" property="og:site_name"/>
#   <meta content="Click on the title to browse this issue" property="og:description"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="app-id=673861322" name="apple-itunes-app"/>
#   <meta content="10.1002/jmri.v54.3" name="citation_doi"/>
#   <meta content="10.1002/jmri.v54.3" name="dc.identifier"/>
#   <title>
#    Journal of Magnetic Resonance Imaging: Vol 54, No 3
#   </title>
#   <link href="/wro/kbrm~product.css" rel="stylesheet" type="text/css"/>
#   <style>
#    @font-face {
#     font-family: 'Open Sans Subset';
#     font-display: swap;
#     src: local('Muli Regular'), local('Muli-Regular'),
#     url(data:application/font-woff;charset=utf-8;base64,...) format('woff');
# }
#   </style>
#   <link href="/products/pericles/releasedAssets/css/build-7197e5046da8bff2894b.css" rel="stylesheet"/>
#   <link href="/products/pericles/releasedAssets/css/print-7197e5046da8bff2894b.css" media="print" rel="stylesheet"/>
#   <script async="" src="/pb-assets/catchpoint-1549680351760.js">
#   </script>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/pb-assets/hub-assets/pericles/hub-1628068886633.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/iucr-1510734465460.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/readcube-1510565373110.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/dr-overrides-1611780866727.css" rel="stylesheet" type="text/css"/>
#   <!-- link rel="stylesheet" type="text/css" href="/pb-assets/css/temporary-1525702334993.css" -->
#   <style>
#    /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#   </style>
#   <!-- The Adobe DTM script. Must come after the digitalData object -->
#   <script src="//assets.adobedtm.com/6e626c9ec247e474f6b98eb15a79a185cf7e26a5/satelliteLib-c1ac050bbdc647f13a62578e71f0d817f8a6cbb5.js">
#   </script>
#   <!-- Google Search Console verification -->
#   <meta content="ffz4i4DxIJCdGpRXe0XN6KG6o4FYI-nnFW9I_dg8piM" name="google-site-verification"/>
#   <!-- KRUX Implementation-->
#   <script class="kxct" data-id="JMOONjNh" data-timing="async" data-version="1.9" type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#   </script>
#   <!-- KRUX Implementation cont'd -->
#   <script type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#   </script>
#   <!-- Grapeshot Implementation -->
#   <script>
#    var gs_channels = 'default';
#   </script>
#   <script async="" src="//wiley.grapeshot.co.uk/main/channels.cgi?url=https://onlinelibrary.wiley.com/toc/15222586/2021/54/3">
#   </script>
#   <!-- DoubleClick Implementation -->
#   <script type="text/javascript">
#    var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#   </script>
#   <script>
#    var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#   </script>
#   <script>
#    googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/jmri.v54.3')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#   </script>
#   <script src="//validate.onecount.net/js/all.min.js#cff4b10c3a3d5cc9bbb7e2b9292cc66eae1deafa">
#   </script>
#   <script>
#    try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#   </script>
#   <script data-cf-beacon='{"rayId":"65604cf31ed0e4d9","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.1","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script data-cf-beacon='{"rayId":"65cb04cf2c4898e7","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script async="" src="/cdn-cgi/bm/cv/669835187/api.js">
#   </script>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#   </script>
#   <script data-cf-beacon='{"rayId":"65d1a8e0c92cd32a","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <!-- Get whether TNSI is in live or test mode -->
#   <!-- Get the configured TNSI Javascript version number -->
#   <!-- Get the configured TNSI MerchantID -->
#   <!-- Add "TEST" to beginning of merchant ID when running in test mode -->
#   <!-- loading Javascript for using the persistence Service -->
#   <script src="//unpkg.com/@theidentityselector/thiss-ds">
#   </script>
#   <script type="text/javascript">
#    function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf('?') !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#   </script>
#   <script type="text/javascript">
#    (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaa9OZcF8GJJpddk7cYSx';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#   </script>
#   <script>
#    var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Journal of Magnetic Resonance Imaging: Vol 54, No 3";
#   </script>
#   <script async="" src="/cdn-cgi/bm/cv/669835187/api.js">
#   </script>
#  </head>
#  <body class="pb-ui">
#   <div class="skip-links">
#    <ul class="rlist">
#     <li>
#      <a href="#main-content" tabindex="1">
#       Skip to Main Content
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div data-ng-non-bindable="" id="pb-page-content">
#    <div data-pb-dropzone="main" data-pb-dropzone-name="Main">
#     <div class="pageHeader" data-widget-def="pageHeader" data-widget-id="62175478-b98a-43d5-90f2-1f2045ac1a7e">
#      <header class="page-header">
#       <div data-pb-dropzone="main">
#        <div class="admin-message" data-widget-def="ux3-layout-widget" data-widget-id="bb5b5e2c-d3d6-4015-b586-eeade38f59d4">
#         <div class="container">
#          <div class="row">
#           <div>
#            <div class="pb-ad">
#             <div style="background=blue;">
#              <div class="container">
#               <p style="text-align: center;">
#                <b>
#                 Working off-campus?
#                </b>
#                Learn about our
#                <a href="/action/clickThrough?id=101169&amp;url=https%3A%2F%2Fonlinelibrary.wiley.com%2Fresearchers%2Fread%2Faccess-options&amp;loc=%2Ftoc%2F15222586%2F2021%2F54%2F3&amp;pubId=75224161&amp;placeholderId=1029&amp;productId=1011" tabindex="2" target="_blank">
#                 <font color="white">
#                  <u>
#                   remote access options
#                  </u>
#                 </font>
#                </a>
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="container">
#         <div class="row">
#          <div class="contents col-md-12">
#           <div class="pull-left">
#            <div class="logo-container hidden-xs hidden-sm hidden-md" data-widget-def="ux3-general-image" data-widget-id="ff262197-0fb8-4973-aaa2-2fceba4b5a61">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mainLogo" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#             </a>
#            </div>
#            <div class="logo-container-mobile hidden-lg hidden-md hidden-sm" data-widget-def="ux3-general-image" data-widget-id="6b601b23-7301-47c8-8889-242d041241c4">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mobileLogo" src="/pb-assets/hub-assets/pericles/mobilehublogo-1518781861020.png"/>
#             </a>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="header-quicksearch" data-widget-def="UX3QuickSearchWidget" data-widget-id="48175bb0-0f70-46e6-bb89-7e2781fdb8e4">
#             <div class="quick-search-wrapper">
#              <a aria-label="Search" class="quick-search__item" href="#" title="search">
#               <i aria-hidden="true" class="icon-search">
#               </i>
#               <span class="quick-search__item__arrow">
#               </span>
#              </a>
#              <div class="quick-search quickSearchFormContainer" data-linkto-page="true">
#               <div class="main-search-field-wrapper">
#                <div class="tab clearfix">
#                 <input class="fakeQSInput quickSearchFilter" placeholder="Search" tabindex="13" type="search" value=""/>
#                 <label class="sr-only" for="search-within">
#                  Search within
#                 </label>
#                 <select class="search-within" id="search-within" name="search-within" tabindex="10">
#                  <option value="#pane-67065c09-4a88-49cd-934c-ac707951d35c0">
#                   This Journal
#                  </option>
#                  <option value="#pane-67065c09-4a88-49cd-934c-ac707951d35c1">
#                   Anywhere
#                  </option>
#                 </select>
#                 <ul class="rlist tab__content" role="tablist">
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c0-con" class="tab__pane quick-search-pane__anywhere active" id="pane-67065c09-4a88-49cd-934c-ac707951d35c0" role="tab">
#                   <form action="/action/doSearch" method="get" name="thisJournalQuickSearch" title="Quick Search">
#                    <div class="input-group option-0">
#                     <label class="hiddenLabel" for="searchField0">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField0" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <input name="SeriesKey" type="hidden" value="15222586"/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222586" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222586#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c1-con" class="tab__pane quick-search-pane__anywhere" id="pane-67065c09-4a88-49cd-934c-ac707951d35c1" role="tab">
#                   <form action="https://onlinelibrary.wiley.com/action/doSearch" method="get" name="defaultQuickSearch" title="Quick Search">
#                    <div class="input-group option-1">
#                     <label class="hiddenLabel" for="searchField1">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField1" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="cart-indicator__wrapper" data-widget-def="ux3-layout-widget" data-widget-id="5ef13ed1-f4ac-4b62-a426-07ec9576a586">
#             <div class="pull-left">
#              <div class="cart-indicator__wrapper" data-widget-def="eCommerceCartIndicatorWidget" data-widget-id="4a9f7c04-a273-4a25-91fb-8e7bd9970288">
#              </div>
#             </div>
#             <div class="pull-right">
#              <div class="login-bar-container" data-widget-def="literatumNavigationLoginBar" data-widget-id="d384ca92-7137-45d6-b3c2-78c9c0a98c2b">
#               <div class="loginBar login-open">
#                <a aria-label="Log in or Register" class="show-login" href="/action/showLogin?uri=%2Ftoc%2F15222586%2F2021%2F54%2F3&amp;aria-label=Log+in+or+Register" role="button" uri="/toc/15222586/2021/54/3">
#                 <span class="icon-profile_empty">
#                 </span>
#                 <span class="sign-in-label">
#                  Login / Register
#                 </span>
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </header>
#     </div>
#     <h1 class="hidden">
#      Journal list menu
#     </h1>
#     <div class="pages-nav--sticky pages-nav hidden-lg fixed-element">
#      <div class="pages-nav--res">
#       <div class="container">
#        <ul class="rlist--inline pull-left">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="journal-list" href="#">
#           <i aria-hidden="true" class="icon-toc">
#           </i>
#           <span>
#            Journal
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="journal-list" id="journal-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-1, #menu-item-undefined-2, #menu-item-main-menu-1-1, #menu-item-main-menu-1-2, #menu-item--1, #menu-item--2, .journal-featured" data-toggle="transplant" data-transplant="self">
#           </div>
#           <!-- PERICLES-7683
#               <a href="#" title="More from this journal" class="dropdown__toggle"><span>More from this journal</span></a>
#
#                 <div data-target=".journal-resources" data-remove="false" data-toggle="transplant" data-direction="from" data-transplant="self" class="transplant showit"></div>
# -->
#          </div>
#         </li>
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="articles-list" href="#">
#           <i class="article-img-icon">
#            <img src="/pb-assets/hub-assets/pericles/articles_1-1499257321163.png"/>
#           </i>
#           <span>
#            Articles
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="articles-list" id="articles-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-3, #menu-item-undefined-4, #menu-item-main-menu-1-3, #menu-item-main-menu-1-4, #menu-item--3" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#        <ul class="rlist--inline pull-right">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="actions-list" href="#">
#           <span>
#            Actions
#           </span>
#           <i aria-hidden="true" class="icon-chevron-down">
#           </i>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="actions-list" id="actions-list">
#           <h2 class="side-section-header hiddenLabel--lg">
#            Tools
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target=".journal-actions-container li:nth-child(1), .journal-actions-container li:nth-child(2), .journal-actions-container li:nth-child(3), .journal-actions-container li:nth-child(4), .journal-actions-container li:nth-child(5), #subscribeLink" data-toggle="transplant" data-transplant="self">
#           </div>
#           <h2 class="side-section-header hiddenLabel--lg">
#            Follow journal
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#alert-link, #facebook-link, #twitter-link, #linkedin-link, #most-recent-link, #most-read-link, #most-cited-link" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="pageBody body-text" data-widget-def="pageBody" data-widget-id="72100436-7a82-49fc-933b-c6c9d8c42914">
#      <main id="main-content" tabindex="-1">
#       <!--begin pagefulltext-->
#       <div class="page-body pagefulltext">
#        <div data-pb-dropzone="main">
#         <div class="js--fixed-switch" data-widget-def="ux3-layout-widget" data-widget-id="6da55ccb-5daf-4c91-b961-05eee9e6f293">
#          <div>
#           <div class="secondary-bg-color banner-wrapper" data-widget-def="literatumAd" data-widget-id="0220a30b-90c0-4b51-8637-141edf12f86a">
#            <div class="pb-ad">
#             <aside role="complementary">
#              <div class="advert advert-leaderboard" id="advert-leaderboard">
#               <script>
#                googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#               </script>
#               <!-- No JavaScript support is a call to an image -->
#               <noscript>
#                <a href="/action/clickThrough?id=1013&amp;url=https%3A%2F%2Fpubads.g.doubleclick.net%2Fgampad%2Fjump%3Fiu%3D%24googlePublisherCategory%26amp%3Bsz%3D728x90%26amp%3Btile%3D1%26amp%3Bc%3D%24random&amp;loc=%2Ftoc%2F15222586%2F2021%2F54%2F3&amp;pubId=75224161&amp;placeholderId=1015&amp;productId=101018" target="_blank">
#                 <img src="https://pubads.g.doubleclick.net/gampad/ad?iu=$googlePublisherCategory&amp;sz=728x90&amp;tile=1&amp;c=$random"/>
#                </a>
#               </noscript>
#              </div>
#             </aside>
#            </div>
#           </div>
#           <style type="text/css">
#            li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#           </style>
#           <section class="journal-page-header card" data-widget-def="ux3-layout-widget" data-widget-id="9e8ee65a-2e18-4c00-9474-5ac10e16ecfe">
#            <div class="container">
#             <div class="row">
#              <div class="journal-info-container col-md-8">
#               <a href="/journal/15222586" title="Journal of Magnetic Resonance Imaging homepage">
#                <h1 id="journal-banner-text" style="margin: 0; font-size: 0">
#                 Journal of Magnetic Resonance Imaging
#                </h1>
#                <img alt="Journal of Magnetic Resonance Imaging" class="journal-banner-image" id="journal-banner-image" src="/pb-assets/journal-banners/15222586-1590394653627.jpg" style="margin-bottom: 15px; display: none"/>
#               </a>
#               <script>
#                var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222586-1590394653627.jpg";
#               </script>
#              </div>
#              <div class="hidden-xs hidden-sm hidden-md col-md-4">
#              </div>
#             </div>
#            </div>
#           </section>
#           <div class="stickybar pages-nav hidden-xs hidden-sm hidden-md scrollable-element" data-widget-def="menuWidget" data-widget-id="998218b4-f988-4a0c-8c4f-b2d3875e1770">
#            <div class="stickybar__wrapper">
#             <div class="main-nav">
#              <a data-toggle="nav" href="#undefined" title="menu drawer">
#               <i aria-hidden="true" class="icon-menu2">
#               </i>
#               <i aria-hidden="true" class="icon-close_thin">
#               </i>
#              </a>
#              <nav aria-label="Journal navigation" class="drawer__nav container gutterless hidden-sm hidden-xs" data-ctrl-res="never" role="navigation">
#               <h2 class="is-accessible">
#                Navigation Bar
#               </h2>
#               <section>
#                <h3 class="is-accessible">
#                 Menu
#                </h3>
#                <a class="menu-header hidden-md hidden-lg" href="/">
#                 Home
#                </a>
#                <ul class="menubar rlist--inline" id="menubar" role="menubar">
#                 <li class="menu-item" data-menu-label="Home" id="menu-item-undefined-0" role="presentation">
#                  <a class="sub-menu-item" href="/journal/15222586" role="menuitem" tabindex="0">
#                   <span>
#                    Home
#                   </span>
#                  </a>
#                 </li>
#                 <li class="dropdown menu-parent" data-menu-label="About" id="menu-item-undefined-1" role="presentation">
#                  <a aria-expanded="false" aria-haspopup="true" class="dropdown__toggle" data-target="About-1-dropdown" data-toggle="dropdown" href="#" id="About-1" role="menuitem" tabindex="-1">
#                   <span>
#                    About
#                   </span>
#                   <i aria-hidden="true" class="icon-arrow_r pull-right hidden-md hidden-lg">
#                   </i>
#                   <i aria-hidden="true" class="icon-section_arrow_d pull-right hidden-sm hidden-xs">
#                   </i>
#                  </a>
#                  <ul aria-labelledby="About-1" class="rlist dropdown__menu" id="About-1-dropdown" role="menu">
#                   <li class="menu-item" data-menu-label="Overview" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222586/homepage/productinformation.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Overview
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Contact" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222586/homepage/contact.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Contact
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Editorial Board" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222586/homepage/editorialboard.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Editorial Board
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Advertise" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222586/homepage/advertise.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Advertise
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Permissions" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222586/homepage/permissions.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Permissions
#                     </span>
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                 <li class="dropdown menu-parent" data-menu-label="Contribute" id="menu-item-undefined-2" role="presentation">
#                  <a aria-expanded="false" aria-haspopup="true" class="dropdown__toggle" data-target="Contribute-2-dropdown" data-toggle="dropdown" href="#" id="Contribute-2" role="menuitem" tabindex="-1">
#                   <span>
#                    Contribute
#                   </span>
# ...
#                 Accessibility
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Help &amp; Support
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://hub.wiley.com/community/support/onlinelibrary">
#                 Contact Us
#                </a>
#               </li>
#               <li>
#                <a href="https://www.wiley.com/customer-success/wiley-online-library-training-hub">
#                 Training and Support
#                </a>
#               </li>
#               <li>
#                <a href="/dmca-notification-policy">
#                 DMCA &amp; Reporting Piracy
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Opportunities
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://onlinelibrary.wiley.com/agents">
#                 Subscription Agents
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/advertisers">
#                 Advertisers &amp; Corporate Partners
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Connect with Wiley
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://www.wiley.com/network">
#                 The Wiley Network
#                </a>
#               </li>
#               <li>
#                <a href="https://newsroom.wiley.com/">
#                 Wiley Press Room
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="copyright-container" data-widget-def="ux3-layout-widget" data-widget-id="86584e25-e4db-4118-9550-9b4f5341a4ac">
#          <div class="container">
#           <div class="row">
#            <div class=" col-md-12">
#             <div class="copyright" data-widget-def="UX3HTMLWidget" data-widget-id="bfbf6c5d-a650-4662-828f-5275fada9120">
#              <div class="copyright pull-left">
#               Copyright © 1999-2021
#               <a href="https://www.wiley.com">
#                John Wiley &amp; Sons, Inc
#               </a>
#               . All rights reserved
#              </div>
#             </div>
#             <div class="footer-logo pull-right">
#              <a aria-label="Wiley" href="https://www.wiley.com" title="Wiley Home Page">
#               <img alt="Wiley Home Page" src="/pb-assets/tmp-images/footer-logo-wiley-1510029248417.png"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#     <div aria-labelledby="loginPopupHead" class="popup login-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="Cancel Login" class="close" href="#" role="button">
#        <i class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#       </div>
#       <div class="modal__body">
#        <div class="ssoLogin">
#        </div>
#        <h2 id="loginPopupHead">
#         Log in to Wiley Online Library
#        </h2>
#        <div class="login-form">
#         <form action="/action/doLogin?societyURLCode=" class="bordered" method="post">
#          <input name="id" type="hidden" value="67065c09-4a88-49cd-934c-ac707951d35c"/>
#          <input name="popup" type="hidden" value="true"/>
#          <input name="loginUri" type="hidden" value="/toc/15222586/2021/54/3"/>
#          <input name="redirectUri" type="hidden" value="/toc/15222586/2021/54/3"/>
#          <input name="loginUri" type="hidden" value="/toc/15222586/2021/54/3"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="username">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="login" id="username" name="login" placeholder="Enter your email" required="true" size="15" spellcheck="false" type="text" value=""/>
#           <div class="actions">
#           </div>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="password">
#             Password
#            </label>
#           </div>
#           <input autocapitalize="off" autocomplete="off" autocorrect="off" class="password" id="password" name="password" placeholder="Enter your password" required="true" spellcheck="false" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="actions">
#           <a class="link show-request-reset-password" href="/action/requestResetPassword">
#            Forgot password?
#           </a>
#          </div>
#          <div class="loginExtraBeans-dropZone" data-pb-dropzone="loginExtraBeans">
#          </div>
#          <div class="align-end">
#           <span class="submit ">
#            <input class="button btn submit primary no-margin-bottom accessSubmit" name="submitButton" type="submit" value="Log In"/>
#           </span>
#          </div>
#         </form>
#         <div class="societySpecificInstructions">
#         </div>
#        </div>
#        <div class="login-container clearfix form-btn">
#         <a class="linkBtn float-left" href="/action/registration">
#          NEW USER
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#         <a class="linkBtn float-right instituation-login" href="/action/ssostart?redirectUri=%2Ftoc%2F15222586%2F2021%2F54%2F3">
#          INSTITUTIONAL LOGIN
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="changePasswordPopupHead" class="popup change-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close cancel" href="#" role="button">
#        <i class="icon-close_thin">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="changePasswordPopupHead">
#         Change Password
#        </h2>
#       </div>
#       <div class="modal__body">
#        <div class="form">
#         <form action="/action/changePassword" method="post">
#          <div class="message error">
#          </div>
#          <input name="submit" type="hidden" value="submit"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-old">
#             Old Password
#            </label>
#           </div>
#           <input autocomplete="off" class="old" id="a589574e-bb98-4c6e-8fed-67365ff05357-old" name="old" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-new">
#             New Password
#            </label>
#           </div>
#           <input autocomplete="off" class="pass-hint new" id="a589574e-bb98-4c6e-8fed-67365ff05357-new" name="new" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#           <div class="password-strength-indicator" data-max="32" data-min="10" data-strength="3">
#            <span class="text too-short">
#             Too Short
#            </span>
#            <span class="text weak">
#             Weak
#            </span>
#            <span class="text medium">
#             Medium
#            </span>
#            <span class="text strong">
#             Strong
#            </span>
#            <span class="text very-strong">
#             Very Strong
#            </span>
#            <span class="text too-long">
#             Too Long
#            </span>
#           </div>
#          </div>
#          <input class="button primary submit" disabled="disabled" type="submit" value="Submit"/>
#         </form>
#         <a class="fakeFormLastElement" href="#">
#         </a>
#        </div>
#        <div class="success-template hidden">
#         <h2>
#          Password Changed Successfully
#         </h2>
#         <p>
#          Your password has been changed
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="createAccountPopupHead" class="popup registration-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close" href="#" role="button">
#        <i class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="logoDropZone" data-pb-dropzone="logoDropZone">
#        </div>
#        <h2 id="createAccountPopupHead">
#         Create a new account
#        </h2>
#       </div>
#       <div class="modal__body">
#        <form action="/action/registration" class="registration-form" method="post">
#         <input name="redirectUri" type="hidden" value="/toc/15222586/2021/54/3"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="4e647394-f751-4441-baa4-df426bca4b6e.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="4e647394-f751-4441-baa4-df426bca4b6e.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="submit">
#          <input class="button submit primary" type="submit" value="Register"/>
#         </div>
#        </form>
#        <div class="center">
#         <a class="show-login" href="/action/showLogin">
#          Returning user
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="resetPasswordPopupHead" class="popup top-drawer request-reset-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <div class="modal__header">
#        <a aria-label="close dialog" class="cancel close" href="#" role="button">
#         <i class="icon-close_thin">
#         </i>
#        </a>
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="resetPasswordPopupHead">
#         Forgot your password?
#        </h2>
#        <p class="sub">
#         Enter your email address below.
#        </p>
#       </div>
#       <div class="modal__body">
#        <div class="error">
#        </div>
#        <form action="/action/requestResetPassword" class="request-reset-password-form" method="post">
#         <input name="requestResetPassword" type="hidden" value="true"/>
#         <div class="input-group">
#          <div class="input-group">
#           <div class="label">
#            <label for="email">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="email" id="email" name="email" placeholder="Enter your email" size="15" spellcheck="false" type="text" value=""/>
#          </div>
#         </div>
#         <div class="password-recaptcha-ajax">
#         </div>
#         <div class="form-btn">
#          <input class="button btn primary submit" disabled="disabled" name="submit" type="submit" value="RESET PASSWORD"/>
#         </div>
#        </form>
#        <div class="message error">
#        </div>
#        <div class="success-template hidden">
#         <p>
#          Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div>
#      <div class="pb-dropzone" data-pb-dropzone="col-0" title="col-0">
#      </div>
#     </div>
#     <div aria-labelledby="requestUsernamePopupHead" class="popup top-drawer request-username-drawer username-popup hidden" role="dialog" tabindex="-1">
#      <a aria-label="close dialog" class="close" href="#" role="button">
#       <i class="icon-close_thin">
#       </i>
#      </a>
#      <div class="content">
#       <h2 id="requestUsernamePopupHead">
#        Request Username
#       </h2>
#       <div class="form">
#        <p>
#         Can't sign in? Forgot your username?
#        </p>
#        <p class="sub">
#         Enter your email address below and we will send you your username
#        </p>
#        <div class="message error">
#        </div>
#        <form action="/action/requestUsername" method="post">
#         <input name="requestUsername" type="hidden" value="requestUsername"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="username-recaptcha-ajax">
#         </div>
#         <input class="button primary submit" disabled="disabled" name="submit" type="submit" value="Submit"/>
#         <div class="center">
#          <a class="cancel" href="#">
#           Close
#          </a>
#         </div>
#        </form>
#       </div>
#       <div class="success-template hidden note">
#        <p>
#         If the address matches an existing account you will receive an email with instructions to retrieve your username
#        </p>
#       </div>
#      </div>
#     </div>
#     <!-- Belongs at the bottom of the page -->
#     <script type="text/javascript">
#      if(window._satellite) {
# _satellite.pageBottom();
# }
#     </script>
#     <!-- Temporarily styling and we need to remove them after LIT-405827 fixed as part of lit-2020 -->
#     <style>
#      .tfa-form-container .verification-hint {
#         text-align: center;
#         padding-top: 20px;
#         padding-bottom: 20px;
#         font-size: 13px;
#     }
#
#     .tfa-form-container .verification-hint .verification-hint__link {
#         font-weight: 500;
#         display: inline-block;
#         text-decoration: none;
#     }
#     </style>
#     <!-- This HTML widget is temporary, and should be replaced with styles in the next major upgrade. (LIT-406218)  -->
#     <style>
#      .tfa-form-container #tfa-options {
#     	display: none;
#     }
#
#     .tfa-form-container .three-digits {
#     	overflow-wrap: break-word;
#     }
#     </style>
#    </div>
#   </div>
#   <script src="/products/pericles/releasedAssets/js/build.lazyload.bundle-074ab646dd4d1ae50da9.js">
#   </script>
#   <script src="/products/pericles/releasedAssets/js/main.bundle-deb9e5aad7c3df90a0ee.js">
#   </script>
#   <script src="/wro/kbrm~product.js" type="text/javascript">
#   </script>
#   <script>
#    var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();
#   </script>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'67d09450682e0672',m:'1eaa3fa9edd9d1cf0cb92cedd598f0f20e35820a-1628675633-1800-AUwbRdu7lhORT7UMrRPL1T7qvL178yg2z1RT5hjqOocihIt99cEaUDUcFIVcgBTFljru9H/9it1J7nBgUP7bb4draLdB7akoXOl9Q7FjCe73mHl0F92brHRqE8hef5fDs5ZBe6D86R/gOAOXaF+eNQ8=',s:[0x5f718a8c6c,0x111fabdef7],}})();
#   </script>
#   <script data-cf-beacon='{"rayId":"67d09450682e0672","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.8.0","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#  </body>
# </html>

# %%
# Get the title
title = soupJMRI.title
print(title)
# Out:
# <title> Journal of Magnetic Resonance Imaging: Vol 54, No 3</title>

# %%
# Print out the text
text = soupJMRI.get_text()
print(soup.text)

# Another way to extract text
# str(all_links[103]).split("<h2>")[1].replace("</h2></a>", "")
# Out:
# var $DoubleClickZone = "j-magres-imaging_jmri";var $DoubleClickSite =  "wly.radiol.imag_000105";digitalData = {"site":{"ip":"109.175.189.34","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2021-08-11","server":"web122"},"identities":[{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"BasicGroup","uuid":"84aa8781-b32a-4f06-979c-30f3ab78ad73"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"BasicGroup","uuid":"b2f59a00-e5f8-40f1-8e75-8c7dd6bce0ba"},{"type":"BasicGroup","uuid":"f6bf73a6-fd29-4303-8301-24bd8a179b03"},{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"ReferrerUser","uuid":"5a52f27c-b57e-4a2d-8de6-c4f2e0fa8465"},{"type":"BasicGroup","uuid":"8b5697d0-0580-43b3-83ea-a258c8085ad5","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004148"}]},{"type":"BasicGroup","uuid":"a9298b81-eb3e-4dfb-82a5-86f98d156f4d","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004150"}]},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"BasicGroup","uuid":"f0737c70-8d27-48b0-8b44-af576d0063e8","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000068532"}]},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"261f34be-39f9-4f9e-8feb-500f73213904"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"ReferrerUser","uuid":"b3da44b5-3aad-4291-8eca-73ea8ea97a07"},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"20d013f5-e22b-4df0-ba93-d6d925db9e32"},{"type":"BasicGroup","uuid":"6a17ff38-0daf-4f0a-b4eb-b42c69d5c12f","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000007783"}]},{"type":"BasicGroup","uuid":"c62f6a8d-8b0e-4a8c-ace7-645ca96979b6"},{"type":"BasicGroup","uuid":"9cb21bff-5e36-40b2-9183-08a76524dc18","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL57933332"}]},{"type":"RegionUser","uuid":"82409588-c43f-4337-a6a8-3272d1b7e20e"},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"RegionUser","uuid":"3147507a-46c1-4f33-a077-4feac12c6b71"},{"type":"SmartGroupUser","uuid":"b2dbfe27-ecae-4bb6-bb0d-d75e5caa3762"},{"type":"SmartGroupUser","uuid":"77da7ca2-c9f3-4f94-9737-922e1d15b7d9"}],"publication":{"group":{"doi":"10.1002/jmri.v54.3","access":"no","volume":"54","issue":"3","coverDate":"2021-09-01","topics":[{"taxonomyUri":"global-subject-codes","topicLabel":"Radiology \u0026 Imaging","topicUri":"mdp0"},{"taxonomyUri":"global-subject-codes","topicLabel":"Medical \u0026 Health Physics","topicUri":"phc0"},{"taxonomyUri":"global-subject-codes","topicLabel":"MEDICAL SCIENCE","topicUri":"md"},{"taxonomyUri":"global-subject-codes","topicLabel":"MRI","topicUri":"mdp3"},{"taxonomyUri":"global-subject-codes","topicLabel":"Interventional Radiology","topicUri":"mdp4"},{"taxonomyUri":"global-subject-codes","topicLabel":"Informatics","topicUri":"mdp1"},{"taxonomyUri":"global-subject-codes","topicLabel":"PHYSICS","topicUri":"ph"}]},"series":{"title":"Journal of Magnetic Resonance Imaging","doi":"10.1002/(ISSN)1522-2586","access":"no","code":"15222586","issn":"1053-1807","eissn":"1522-2586","topics":[{"taxonomyUri":"gpt-sitename","topicLabel":"wly.radiol.imag_000105","topicUri":"wly.radiol.imag_000105"},{"taxonomyUri":"global-subject-codes","topicLabel":"Radiology \u0026 Imaging","topicUri":"mdp0"},{"taxonomyUri":"global-subject-codes","topicLabel":"Medical \u0026 Health Physics","topicUri":"phc0"},{"taxonomyUri":"global-subject-codes","topicLabel":"MEDICAL SCIENCE","topicUri":"md"},{"taxonomyUri":"global-subject-codes","topicLabel":"MRI","topicUri":"mdp3"},{"taxonomyUri":"global-subject-codes","topicLabel":"Interventional Radiology","topicUri":"mdp4"},{"taxonomyUri ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Journal of Magnetic Resonance Imaging: Vol 54, No 3
#
# @font-face {
#     font-family: 'Open Sans Subset';
#     font-display: swap;
#     src: local('Muli Regular'), local('Muli-Regular'),
#     url(data:application/font-woff;charset=utf-8;base64,...) format('woff');
# }
#
#
#
#
#
#
#
#
#
#
#
# /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#
#
#
#
#
#
#
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#
#
#
# 	var gs_channels = 'default';
#
#
#
#
# 	var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#
#
# 	var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#
#
# 	googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/jmri.v54.3')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#
#
#
# 	try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#
#
#
# (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#
#
#
#
#
#
#
#
#         function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf('?') !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#
#
#
#         (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaa9OZcF8GJJpddk7cYSx';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#
#
#     var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Journal of Magnetic Resonance Imaging: Vol 54, No 3";
#
#
#
#
#
# Skip to Main Content
#
#
#
#
#
#
#
#
#
#
#
#
# Working off-campus? Learn about our remote access options
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search withinThis JournalAnywhereSearch term  Advanced Search  Citation SearchSearch term  Advanced Search  Citation Search
#
#
#
#
#
#
#
#
#
#
# Login / Register
#
#
#
#
#
#
#
#
#
#
#  Journal list menu
#
#
#
#
# Journal
#
#
#
#
#
# Articles
#
#
#
#
#
#
# Actions
#
# Tools
#
# Follow journal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
# li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#
#
#
# Journal of Magnetic Resonance Imaging
#
#
#
# var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222586-1590394653627.jpg";
#
#
#
#
# Navigation BarMenuHomeHomeAboutOverviewContactEditorial BoardAdvertisePermissionsContributeAuthor GuidelinesOpen AccessSubmit a ManuscriptFor RefereesBrowseAccepted ArticlesEarly ViewCurrent IssueAll IssuesCover GalleryVirtual Issues
#
#
# Follow journal
#
# Alert
#
#
#
#
#
# RSS Feeds
#
#
# Most recent (RSS)
#
# Most cited (RSS)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# IssueVolume 54,  Issue 3Pages: spcone, 673-1027, E1-E4September 2021
#
# Previous Issue
#
#
#
# GO TO SECTION
#
#
#
#
#
#
#
#
#
# Export Citation(s)
# Export CitationsFormatPlain TextRIS (ProCite, Reference Manager)EndNoteBibTexMedlarsRefWorksType of importCitation file or direct importIndirect import or copy/pasteCancelNext< Go backCitation HelpExport
#
#
#
#
# Cover Image
#
#
# Free Access
#
#
#
#
#                   free
#
#
# Whole Brain Adiabatic T1rho and Relaxation Along a Fictitious Field Imaging in Healthy Volunteers and Patients With Multiple Sclerosis: Initial Findings
#
#
#  Ivan Jambor MD, PhD,
#  Aida Steiner MD, PhD,
#  Marko Pesola PhD,
#  Timo Liimatainen PhD,
#  Marcus Sucksdorff MD,
#  Eero Rissanen MD, PhD,
#  Laura Airas MD, PhD,
#  Hannu J. Aronen MD, PhD,
#  Harri Merisaari PhD,
#
#
# Pages: spcone
# First Published: 11 August 2021
#
#
#
# Abstract
# PDFRequest permissions
#
#
#
#
#
# Issue Information
#
#
# Free Access
#
#
#
#
#                   free
#
#
# Issue Information
# Pages: 673-683
# First Published: 11 August 2021
#
#
#
# First Page
# PDFRequest permissions
#
#
#
#
#
# Commentary
#
#
#
#
#
#
#                   no
#
#
# Commentary
# Pages: 685
# First Published: 13 July 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Review Article
#
#
# Open Access
#
#
#
#
#                   oa
#
#
# AI-Enhanced Diagnosis of Challenging Lesions in Breast MRI: A Methodology and Application Primer
#
#  Anke Meyer-Base PhD,
#  Lia Morra PhD,
#  Amirhessam Tahmassebi PhD,
#  Marc Lobbes MD,
#  Uwe Meyer-Base PhD,
#  Katja Pinker MD,
#
#
# Pages: 686-702
# First Published: 30 August 2020
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Breast
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Intratumoral and Peritumoral Radiomics Based on Functional Parametric Maps from Breast DCE-MRI for Prediction of HER-2 and Ki-67 Status
#
#  Chunli Li BS,
#  Lirong Song BS,
#  Jiandong Yin PhD,
#
#
# Pages: 703-714
# First Published: 06 May 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Abdomen
#
#
#
#
#
#
#                      no
#
#
# Reduced Field-of-View Diffusion-Weighted Magnetic Resonance Imaging of the Pancreas With Tilted Excitation Plane: A Preliminary Study
#
#  Masahiro Tanabe MD,
#  Mayumi Higashi MD,
#  Thomas Benkert PhD,
#  Hiroshi Imai MHSc,
#  Keisuke Miyoshi MD,
#  Fumi Kameda MD,
#  Shoko Ariyoshi MD,
#  Kenichiro Ihara MD,
#  Katsuyoshi Ito MD,
#
#
# Pages: 715-720
# First Published: 11 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
#                      no
#
#
# Quantitative Susceptibility Mapping Using a Multispectral Autoregressive Moving Average Model to Assess Hepatic Iron Overload
#
#  Aaryani Tipirneni-Sajja PhD,
#  Ralf B. Loeffler PhD,
#  Jane S. Hankins MD,
#  Cara Morin MD, PhD,
#  Claudia M. Hillenbrand PhD,
#
#
# Pages: 721-727
# First Published: 26 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
#                      no
#
#
# Bowel Wall Visualization Using MR Enterography in Relationship to Bowel Lumen Contents and Patient Demographics
#
#  Ting Ting Zhang MD,
#  Wei-Chou Chang MD, PhD,
#  Zhen Jane Wang MD,
#  Derek C. Sun MD,
#  Michael A. Ohliger MD, PhD,
#  Benjamin M. Yeh MD,
#
#
# Pages: 728-736
# First Published: 04 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Bowel Wall Visualization Using MR Enterography in Relationship to Bowel Lumen Contents and Patient Demographics”
#
#  Mohammed Salman Shazeeb PhD,
#
#
# Pages: 737-738
# First Published: 08 May 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Abdomen
#
#
#
#
#
#
#                      no
#
#
# MRI Measures of Murine Liver Fibrosis
#
#  Diana M. Lindquist PhD,
#  Elizabeth M. Fugate RT(MR),
#  Jiang Wang MD,
#  Akanksha Sharma PhD,
#  Chandrashekhar R. Gandhi PhD,
#  Jonathan R. Dillman MD,
#
#
# Pages: 739-749
# First Published: 18 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “MRI measures of murine liver fibrosis”
#
#  Ella Wilczynski MSc,
#
#
# Pages: 750
# First Published: 01 June 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Abdomen
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Intravoxel Incoherent Motion and Dynamic Contrast-Enhanced Magnetic Resonance Imaging to Early Detect Tissue Injury and Microcirculation Alteration in Hepatic Injury Induced by Intestinal Ischemia–Reperfusion in a Rat Model
#
#  Jiaxing Yang MMed,
#  Mingzhu Meng MMed,
#  Changjie Pan MD,
#  Liulan Qian MMed,
#  Yangyang Sun MMed,
#  Haifeng Shi MD,
#  Yong Shen MD,
#  Weiqiang Dou PhD,
#
#
# Pages: 751-760
# First Published: 21 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Using Intravoxel Incoherent Motion and Dynamic Contrast-Enhanced MR Imaging to Early Detect Tissue Injury and Microcirculation Alteration in Hepatic Injury Induced by Intestinal Ischemia Reperfusion in the Rat Model”
#
#  Satoshi Kobayashi MD, PhD,
#
#
# Pages: 761-762
# First Published: 13 April 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Vascular
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Diagnostic Performance of a Lower-dose Contrast-Enhanced 4D Dynamic MR Angiography of the Lower Extremities at 3 T Using Multisegmental Time-Resolved Maximum Intensity Projections
#
#  Paul Raczeck MD,
#  Peter Fries MD,
#  Alexander Massmann MD,
#  Peter Minko MD,
#  Felix Frenzel MD,
#  Tobias Woerner MD,
#  Arno Buecker MD,
#  Guenther K. Schneider MD,
#
#
# Pages: 763-774
# First Published: 07 April 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Diagnostic Performance of a Lower-Dose Contrast Enhanced 4D Dynamic MR Angiography of the Lower Extremities at 3 T Using Multi-Segmental Time Resolved Maximum Intensity Projections”
#
#  Leonardo Roever PhD,
#  Gary Tse PhD,
#  Giuseppe Biondi-Zoccai MD, MStat,
#
#
# Pages: 775-776
# First Published: 06 May 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Cardiac
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Using Deep Learning to Emulate the Use of an External Contrast Agent in Cardiovascular 4D Flow MRI
#
#  Mariana Bustamante PhD,
#  Federica Viola MSc,
#  Carl-Johan Carlhäll MD, PhD,
#  Tino Ebbers PhD,
#
#
# Pages: 777-786
# First Published: 25 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
#                      no
#
#
# Sensitivity of Myocardial Radiomic Features to Imaging Parameters in Cardiac MR Imaging
#
#  Jihye Jang PhD,
#  Hossam El-Rewaidy MSc,
#  Long H. Ngo PhD,
#  Jennifer Mancio MD,
#  Ibolya Csecs MD,
#  Jennifer Rodriguez BSc,
#  Patrick Pierce RT,
#  Beth Goddu RT,
#  Ulf Neisius MD,
#  Warren Manning MD,
#  Reza Nezafat PhD,
#
#
# Pages: 787-794
# First Published: 01 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Reducing Contrast Agent Dose in Cardiovascular MR Angiography with Deep Learning
#
#  Javier Montalt-Tordera MS,
#  Michael Quail MD, PhD,
#  Jennifer A Steeden PhD,
#  Vivek Muthurangu MD, PhD,
#
#
# Pages: 795-805
# First Published: 22 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial For “Reduction of Contrast Agent Dose in Cardiovascular MR Angiography Using Deep Learning”
#
#  Maythem Saeed PhD,
#
#
# Pages: 806-807
# First Published: 26 March 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Cardiac
#
#
#
#
#
#
#                      no
#
#
# Myocardial Deformation Assessed by MR Feature Tracking in Groups of Patients With Ischemic Heart Disease
#
#  Lei Zhao MD,
#  Chen Zhang MD,
#  Jie Tian MD,
#  Mark DeLano MD,
#  Xiaohai Ma MD,
#
#
# Pages: 808-815
# First Published: 04 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Myocardial Deformation Assessed by MR Feature Tracking in Groups of Patients With Ischemic Heart Disease”
#
#  Pierre-André Vuissoz PhD,
#
#
# Pages: 816-817
# First Published: 05 May 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Pediatrics
#
#
#
#
#
#
#                      no
#
#
# Image Quality Assessment of Fetal Brain MRI Using Multi-Instance Deep Learning Methods
#
#  Axel Largent PhD,
#  Kushal Kapse MS,
#  Scott D. Barnett PhD,
#  Josepheen De Asis-Cruz MD, PhD,
#  Matthew Whitehead MD,
#  Jonathan Murnick MD, PhD,
#  Li Zhao PhD,
#  Nicole Andersen BA,
#  Jessica Quistorff MPH,
#  Catherine Lopez MS,
#  Catherine Limperopoulos PhD,
#
#
# Pages: 818-829
# First Published: 23 April 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Image Quality Assessment of Fetal Brain MRI Using Multi-Instance Deep Learning Methods”
#
#  Luguang Chen MSc,
#
#
# Pages: 830-831
# First Published: 01 June 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Musculoskeletal
#
#
#
#
#
#
#                      no
#
#
# Magnetic Resonance T2* Is Increased in Patients With Early-Stage Achilles and Patellar Tendinopathy
#
#
#  Nikolaj M. Malmgaard-Clausen MD,
#  Peter Tran MD, PhD,
#  Rene B. Svensson PhD,
#  Philip Hansen MD, PhD,
#  Janus D. Nybing MSc,
#  Stig Peter Magnusson PT, DMSc,
#  Michael Kjær MD, DMSc,
#
#
# Pages: 832-839
# First Published: 14 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
#                      no
#
#
# Effects of the Competitive Season and Off-Season on Knee Articular Cartilage in Collegiate Basketball Players Using Quantitative MRI: A Multicenter Study
#
#  Elka B. Rubin BA,
#  Valentina Mazzoli PhD,
#  Marianne S. Black PhD,
#  Katherine Young MEd,
#  Arjun D. Desai BS,
#  Matthew F. Koff PhD,
#  Ashwin Sreedhar,
#  Feliks Kogan PhD,
#  Marc R. Safran MD,
#  Dominic J. Vincentini BS,
#  Katelin A. Knox BS,
#  Tomoo Yamada BS,
#  Andrew McCabe BS,
#  Sharmila Majumdar PhD,
#  Hollis G. Potter MD,
#  Garry E. Gold MD,
#
#
# Pages: 840-851
# First Published: 24 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Effects of the Competitive Season and Off Season on Knee Articular Cartilage in Collegiate Basketball Players Using Quantitative MRI: A Multi-Center Study”
#
#  Karl F. R. Neufang Prof. Dr. med.,
#
#
# Pages: 852-853
# First Published: 29 March 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Head and Neck
#
#
#
#
#
#
#                      no
#
#
# Differences in Radiomics Signatures Between Patients with Early and Advanced T-Stage Nasopharyngeal Carcinoma Facilitate Prognostication
#
#  Shuangshuang Wu MS,
#  Haojiang Li MD,
#  Annan Dong MD,
#  Li Tian MD,
#  Guangying Ruan BS,
#  Lizhi Liu MD,
#  Yuanzhi Shao PhD,
#
#
# Pages: 854-865
# First Published: 08 April 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Neuro
#
#
#
#
#
#
#                      no
#
#
# Whole Brain Adiabatic T1rho and Relaxation Along a Fictitious Field Imaging in Healthy Volunteers and Patients With Multiple Sclerosis: Initial Findings
#
#
#  Ivan Jambor MD, PhD,
#  Aida Steiner MD, PhD,
#  Marko Pesola PhD,
#  Timo Liimatainen PhD,
#  Marcus Sucksdorff MD,
#  Eero Rissanen MD, PhD,
#  Laura Airas MD, PhD,
#  Hannu J. Aronen MD, PhD,
#  Harri Merisaari PhD,
#
#
# Pages: 866-879
# First Published: 06 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
#                      no
#
#
# Deep Learning for Automatic Differential Diagnosis of Primary Central Nervous System Lymphoma and Glioblastoma: Multi-Parametric Magnetic Resonance Imaging Based Convolutional Neural Network Model
#
#  Wei Xia PhD,
#  Bin Hu MD,
#  Haiqing Li MD,
#  Wei Shi MS,
#  Ying Tang MD,
#  Yang Yu MD,
#  Chen Geng PhD,
#  Qiuwen Wu MS,
#  Liqin Yang PhD,
#  Zekuan Yu PhD,
#  Daoying Geng MD,
#  Yuxin Li MD,
#
#
# Pages: 880-887
# First Published: 11 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Pseudo-Enhancement in Intracranial Aneurysms on Black-Blood MRI: Effects of Flow Rate, Spatial Resolution, and Additional Flow Suppression
#
#  Mariya S. Pravdivtseva MS,
#  Franziska Gaidzik MS,
#  Philipp Berg PhD,
#  Carson Hoffman MS,
#  Leonardo A. Rivera-Rivera PhD,
#  Rafael Medero PhD,
#  Lindsay Bodart MS,
#  Alejandro Roldan-Alzate PhD,
#  Michael A. Speidel PhD,
#  Kevin M. Johnson PhD,
#  Oliver Wieben PhD,
#  Olav Jansen MD,
#  Jan-Bernd Hövener PhD,
#  Naomi Larsen MD,
#
#
# Pages: 888-901
# First Published: 10 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Pseudo-Enhancement in Intracranial Aneurysms on Black Blood MRI: Effects of Flow Rate, Spatial Resolution, and Additional Flow Suppression”
#
#  Jean-Pierre Laissy MD, PhD,
#
#
# Pages: 902-903
# First Published: 04 April 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Neuro
#
#
#
#
#
#
#                      no
#
#
# MRI Findings of Arachnoiditis, Revisited. Is Classification Possible?
#
#  Maria El Homsi MD,
#  Karem Gharzeddine MD,
#  Jordan Cuevas BS,
#  Julio Arevalo-Perez MD, PhD,
#  Karim Rebeiz MD,
#  Nabil J. Khoury MD, PhD,
#  Hicham Moukaddam MD,
#
#
# Pages: 904-909
# First Published: 28 February 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “MRI Findings of Arachnoiditis, Revisited. Is Classification Needed?”
#
#  Hugh G. Pemberton MSc,
#  Ferran Prados PhD,
#
#
# Pages: 910-911
# First Published: 13 March 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Neuro
#
#
#
#
#
#
#                      no
#
#
# A Prospective, Longitudinal Magnetic Resonance Imaging Evaluation of Cerebrovascular Reactivity and Infarct Development in Patients With Intracranial Stenosis
#
#  Meher R. Juttukonda PhD,
#  Larry T. Davis MD,
#  Sarah K. Lants BS,
#  Spencer L. Waddle BS,
#  Chelsea A. Lee BS,
#  Niral J. Patel MPH,
#  Lori C. Jordan MD, PhD,
#  Manus J. Donahue PhD,
#
#
# Pages: 912-922
# First Published: 24 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Cerebrovascular Reactivity Timing and Stroke Risk in Patients With Intracranial Stenosis”
#
#  Jie Lu MD, PhD,
#
#
# Pages: 923-924
# First Published: 20 April 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Neuro
#
#
#
#
#
#
#                      no
#
#
# Neuroimaging Phenotyping and Assessment of Structural-Metabolic-Electrophysiological Alterations in the Temporal Neocortex of Focal Cortical Dysplasia IIIa
#
#  Jiajie Mo MD,
#  Wei Wei PhD,
#  Zhenyu Liu PhD,
#  Jianguo Zhang MD,
#  Yanshan Ma MD,
#  Lin Sang MD,
#  Wenhan Hu MD,
#  Chao Zhang MD,
#  Yao Wang MD,
#  Xiu Wang MD,
#  Chang Liu MD,
#  Baotian Zhao MD,
#  Dongmei Gao MD,
#  Jie Tian PhD,
#  Kai Zhang MD,
#
#
# Pages: 925-935
# First Published: 23 April 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Neuroimaging Phenotyping and Structural-Metabolic-Epileptogenic Correlations in the Temporal Neocortex of Focal Cortical Dysplasia IIIa”
#
#  Muhammad A. Ayub MBBS,
#  Salil Soman MD, MS,
#
#
# Pages: 936-937
# First Published: 22 April 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Neuro
#
#
#
#
#
#
#                      no
#
#
# Can Hybrid Arterial Spin Labeling-Tagged Zero-Echo-Time Magnetic Resonance Angiography Be an Effective Candidate in the Evaluation of Intracranial Artery Diseases? A Clinical Feasibility Study
#
#  Song'an Shang PhD,
#  Lijuan Wang MS,
#  Jing Ye PhD,
#  Xianfu Luo PhD,
#  Hongying Zhang PhD,
#  Weiqiang Dou PhD,
#  Jingtao Wu PhD,
#  Daixin Li MS,
#
#
# Pages: 938-949
# First Published: 20 May 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Can Hybrid Arterial Spin Labeling-Tagged Zero-Echo-Time Magnetic Resonance Angiography Be an Effective Candidate in the Evaluation of Intracranial Artery Diseases? A Clinical Feasibility Study”
#
#  Tatsuya Kawai MD, PhD,
#
#
# Pages: 950-951
# First Published: 08 May 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Neuro
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Small-World Networks and Their Relationship With Hippocampal Glutamine/Glutamate Concentration in Healthy Adults With Varying Genetic Risk for Alzheimer's Disease
#
#  Hui Zhang PhD,
#  Pui W. Chiu PhD,
#  Isaac Ip PhD,
#  Tianyin Liu PhD,
#  Gloria H.Y. Wong PhD,
#  You-Qiang Song PhD,
#  Savio W.H. Wong PhD,
#  Karl Herrup PhD,
#  Henry K.F. Mak MD,
#
#
# Pages: 952-961
# First Published: 03 May 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Small-World Networks and Their Relationship With Hippocampal Glutamine/Glutamate (Glx) Concentration in Healthy Adults With Varying Genetic Risk for Alzheimer's Disease”
#
#  Maria Eugenia Caligiuri PhD,
#
#
# Pages: 962-963
# First Published: 14 June 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Thoracic
#
#
# Open Access
#
#
#
#
#                      oa
#
#
# Regional Gas Exchange Measured by 129Xe Magnetic Resonance Imaging Before and After Combination Bronchodilators Treatment in Chronic Obstructive Pulmonary Disease
#
#
#  David G. Mummy PhD,
#  Erika M. Coleman BS,
#  Ziyi Wang PhD,
#  Elianna A. Bier MS,
#  Junlan Lu BS,
#  Bastiaan Driehuys PhD,
#  Yuh-Chin Huang MD,
#
#
# Pages: 964-974
# First Published: 07 May 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Pelvis
#
#
#
#
#
#
#                      no
#
#
# Voxel-level Classification of Prostate Cancer on Magnetic Resonance Imaging: Improving Accuracy Using Four-Compartment Restriction Spectrum Imaging
#
#  Christine H. Feng MD,
#  Christopher C. Conlin PhD,
#  Kanha Batra MS,
#  Ana E. Rodríguez-Soto PhD,
#  Roshan Karunamuni PhD,
#  Aaron Simon MD, PhD,
#  Joshua Kuperman PhD,
#  Rebecca Rakow-Penner MD, PhD,
#  Michael E. Hahn MD, PhD,
#  Anders M. Dale PhD,
#  Tyler M. Seibert MD, PhD,
#
#
# Pages: 975-984
# First Published: 31 March 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Voxel-level Classification of Prostate Cancer on MRI: Improving Accuracy Using Four-Compartment Restriction Spectrum Imaging”
#
#  Durgesh K. Dwivedi Ph.D,
#
#
# Pages: 985-986
# First Published: 21 April 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Pelvis
#
#
#
#
#
#
#                      no
#
#
# Machine Learning-Based Integration of Prognostic Magnetic Resonance Imaging Biomarkers for Myometrial Invasion Stratification in Endometrial Cancer
#
#  Alejandro Rodríguez-Ortega PhD,
#  Alberto Alegre MD,
#  Víctor Lago MD, PhD,
#  José Miguel Carot-Sierra PhD,
#  Amadeo Ten-Esteve BME,
#  Guillermina Montoliu MD, PhD,
#  Santiago Domingo MD, PhD,
#  Ángel Alberich-Bayarri PhD,
#  Luis Martí-Bonmatí MD, PhD,
#
#
# Pages: 987-995
# First Published: 01 April 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Machine Learning-Based Integration of Prognostic MR Imaging Biomarkers for Myometrial Invasion Stratification in Endometrial Cancer”
#
#  Jonn Terje Geitung MD, PhD, MHA,
#
#
# Pages: 996
# First Published: 30 May 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Technical
#
#
#
#
#
#
#                      no
#
#
# Modified Diffusion Tensor Image Processing Pipeline for Archived Studies of Patients With Leukoencephalopathy
#
#  Ruitian Song PhD,
#  John O. Glass MS,
#  Wilburn E. Reddick PhD,
#
#
# Pages: 997-1008
# First Published: 15 April 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
#                      no
#
#
# Prospective Evaluation of Repeatability and Robustness of Radiomic Descriptors in Healthy Brain Tissue Regions In Vivo Across Systematic Variations in T2-Weighted Magnetic Resonance Imaging Acquisition Parameters
#
#  Brendan Eck PhD,
#  Prathyush V. Chirra MS,
#  Avani Muchhala,
#  Sophia Hall,
#  Kaustav Bera MBBS,
#  Pallavi Tiwari PhD,
#  Anant Madabhushi PhD,
#  Nicole Seiberlich PhD,
#  Satish E. Viswanath PhD,
#
#
# Pages: 1009-1021
# First Published: 16 April 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Editorial
#
#
#
#
#
#
#                   no
#
#
# Editorial for “Prospective Evaluation of Repeatability and Reproducibility of Radiomic Descriptors in Healthy Brain Tissue Regions in Vivo Across Systematic Variations in T2-Weighted MRI Acquisition Parameters”
#
#  Anahita Fathi Kazerooni PhD,
#
#
# Pages: 1022-1023
# First Published: 03 May 2021
#
#
#
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
# Case Report
#
# Technical
#
#
#
#
#
#
#                      no
#
#
# Condensation Artifact
#
#  Xiaohong Joe Zhou PhD,
#  Michael P. Flannery BS,
#  Hagai Ganin BS,
#  M. Muge Karaman PhD,
#
#
# Pages: 1024-1027
# First Published: 23 April 2021
#
#
#
# Abstract
#
#                     Full text
#
# PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# Reviewer Appreciation
#
#
#
#
#
#
#                   no
#
#
# Reviewer Acknowledgements
# Pages: E1-E4
# First Published: 11 August 2021
#
#
#
# First Page
#
#                     Full text
#
# PDFRequest permissions
#
#
#
#
#
#
#
#
#
#
# Tools
#
# Submit an Article
# Browse free sample issue
# Get content alerts
#
#
#
#
#
# Subscribe to this journal
#
#
#
#
#
#
#
#                 More from this journal
#
# Professional OpportunitiesISMRM Journal AppsW.S. Moore Award Winning ArticlesOther ResourcesFull Issue PDFs
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-rail-1' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			googletag.cmd.push 		( function () {
# 				googletag.display 	( 'advert-rail-2' );
# 			});
#
#
#
#
#
#
#
#
#
#
#
#
#                 Related Title
#
# IssueVolume 86, Issue 4Pages: C1, 1803-2327October 2021
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     .footer-links {
#         text-align: center;
#     }
#     .footer-links h3 {
#         font-weight: 300;
#     }
#     .footer-links a {
#         font-weight: 600;
#     }
#     @media (min-width: 992px) {
#         .footer-links {
#             text-align: left;
#         }
#     }
#
#
#
#                 Additional links
#
#
#
# About Wiley Online Library
#
# Privacy Policy
# Terms of Use
# Cookies
# Accessibility
#
#
#
#
# Help & Support
#
# Contact Us
# Training and Support
# DMCA & Reporting Piracy
#
#
#
#
# Opportunities
#
# Subscription Agents
# Advertisers & Corporate Partners
#
#
#
#
# Connect with Wiley
#
# The Wiley Network
# Wiley Press Room
#
#
#
#
#
#
#
# Copyright © 1999-2021 John Wiley & Sons, Inc. All rights reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Log in to Wiley Online Library
#
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Password
#
#
#
#
#
#
#                                 Forgot password?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         NEW USER >
#
#
#
#                             INSTITUTIONAL LOGIN >
#
#
#
#
#
#
#
#
#
#
#
#
# Change Password
#
#
#
#
#
#
#
# Old Password
#
#
#
#
#
#
# New Password
#
#
#
#
# Too Short
# Weak
# Medium
# Strong
# Very Strong
# Too Long
#
#
#
#
#
#
# Password Changed Successfully
# Your password has been changed
#
#
#
#
#
#
#
#
#
#
# Create a new account
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#                     Returning user
#
#
#
#
#
#
#
#
#
#
#
#
# Forgot your password?
# Enter your email address below.
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#
# Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#
#
#
#
#
#
#
#
# Request Username
#
# Can't sign in? Forgot your username?
# Enter your email address below and we will send you your username
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Close
#
#
#
# If the address matches an existing account you will receive an email with instructions to retrieve your username
#
#
#
#
#
# if(window._satellite) {
# _satellite.pageBottom();
# }
#
#
#
#     .tfa-form-container .verification-hint {
#         text-align: center;
#         padding-top: 20px;
#         padding-bottom: 20px;
#         font-size: 13px;
#     }
#
#     .tfa-form-container .verification-hint .verification-hint__link {
#         font-weight: 500;
#         display: inline-block;
#         text-decoration: none;
#     }
#
#
#
#     .tfa-form-container #tfa-options {
#     	display: none;
#     }
#
#     .tfa-form-container .three-digits {
#     	overflow-wrap: break-word;
#     }
#
#
#
#
#
# var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();
# (function(){window['__CF$cv$params']={r:'67d09450682e0672',m:'1eaa3fa9edd9d1cf0cb92cedd598f0f20e35820a-1628675633-1800-AUwbRdu7lhORT7UMrRPL1T7qvL178yg2z1RT5hjqOocihIt99cEaUDUcFIVcgBTFljru9H/9it1J7nBgUP7bb4draLdB7akoXOl9Q7FjCe73mHl0F92brHRqE8hef5fDs5ZBe6D86R/gOAOXaF+eNQ8=',s:[0x5f718a8c6c,0x111fabdef7],}})();

# %%
all_links = soupJMRI.find_all('a')

# %% [markdown]
# ### Explore Category

# %%
# h3 class corresponds to editorial

all_h3 = soupJMRI.find_all("h3")

i = 0
for h3 in all_h3:
  # print(h3)
  print(h3.get_text())
  i += 1
print(i)
# Out:
# Menu
# Format
# Type of import
# Cover Image
# Issue Information
# Commentary
# Review Article
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Case Report
# Reviewer Appreciation
# About Wiley Online Library
# Help & Support
# Opportunities
# Connect with Wiley
# 47

# %% [markdown]
# ### Explore Original Research Subcategory

# %%
# h4 class corresponds to category

all_h4 = soupJMRI.find_all("h4")

i = 0
for h4 in all_h4:
  # print(h4)
  print(h4.get_text())
  i += 1
print(i)
# Out:
# Breast
# Abdomen
# Abdomen
# Abdomen
# Vascular
# Cardiac
# Cardiac
# Pediatrics
# Musculoskeletal
# Head and Neck
# Neuro
# Neuro
# Neuro
# Neuro
# Neuro
# Neuro
# Thoracic
# Pelvis
# Pelvis
# Technical
# Technical
# 21

# %%
all_h2 = soupJMRI.find_all("h2")

i = 0
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 3:
    print(h2.get_text())
    i += 1
print(i)

# str_h2 = str(all_h2)

# links = soupJMRI.find_all("a")
# str_links = str(links)
# print(str_h2)

# cleantext = BeautifulSoup(str_h2, "lxml").get_text()
# cleantext = BeautifulSoup(str_links, "lxml").get_text()
# print(cleantext)
# Out:
# Whole Brain Adiabatic T1rho and Relaxation Along a Fictitious Field Imaging in Healthy Volunteers and Patients With Multiple Sclerosis: Initial Findings
#
# AI-Enhanced Diagnosis of Challenging Lesions in Breast MRI: A Methodology and Application Primer
# Intratumoral and Peritumoral Radiomics Based on Functional Parametric Maps from Breast DCE-MRI for Prediction of HER-2 and Ki-67 Status
# Reduced Field-of-View Diffusion-Weighted Magnetic Resonance Imaging of the Pancreas With Tilted Excitation Plane: A Preliminary Study
# Quantitative Susceptibility Mapping Using a Multispectral Autoregressive Moving Average Model to Assess Hepatic Iron Overload
# Bowel Wall Visualization Using MR Enterography in Relationship to Bowel Lumen Contents and Patient Demographics
# Editorial for “Bowel Wall Visualization Using MR Enterography in Relationship to Bowel Lumen Contents and Patient Demographics”
# MRI Measures of Murine Liver Fibrosis
# Editorial for “MRI measures of murine liver fibrosis”
# Intravoxel Incoherent Motion and Dynamic Contrast-Enhanced Magnetic Resonance Imaging to Early Detect Tissue Injury and Microcirculation Alteration in Hepatic Injury Induced by Intestinal Ischemia–Reperfusion in a Rat Model
# Editorial for “Using Intravoxel Incoherent Motion and Dynamic Contrast-Enhanced MR Imaging to Early Detect Tissue Injury and Microcirculation Alteration in Hepatic Injury Induced by Intestinal Ischemia Reperfusion in the Rat Model”
# Diagnostic Performance of a Lower-dose Contrast-Enhanced 4D Dynamic MR Angiography of the Lower Extremities at 3 T Using Multisegmental Time-Resolved Maximum Intensity Projections
# Editorial for “Diagnostic Performance of a Lower-Dose Contrast Enhanced 4D Dynamic MR Angiography of the Lower Extremities at 3 T Using Multi-Segmental Time Resolved Maximum Intensity Projections”
# Using Deep Learning to Emulate the Use of an External Contrast Agent in Cardiovascular 4D Flow MRI
# Sensitivity of Myocardial Radiomic Features to Imaging Parameters in Cardiac MR Imaging
# Reducing Contrast Agent Dose in Cardiovascular MR Angiography with Deep Learning
# Editorial For “Reduction of Contrast Agent Dose in Cardiovascular MR Angiography Using Deep Learning”
# Myocardial Deformation Assessed by MR Feature Tracking in Groups of Patients With Ischemic Heart Disease
# Editorial for “Myocardial Deformation Assessed by MR Feature Tracking in Groups of Patients With Ischemic Heart Disease”
# Image Quality Assessment of Fetal Brain MRI Using Multi-Instance Deep Learning Methods
# Editorial for “Image Quality Assessment of Fetal Brain MRI Using Multi-Instance Deep Learning Methods”
# Magnetic Resonance T2* Is Increased in Patients With Early-Stage Achilles and Patellar Tendinopathy
#
# Effects of the Competitive Season and Off-Season on Knee Articular Cartilage in Collegiate Basketball Players Using Quantitative MRI: A Multicenter Study
# Editorial for “Effects of the Competitive Season and Off Season on Knee Articular Cartilage in Collegiate Basketball Players Using Quantitative MRI: A Multi-Center Study”
# Differences in Radiomics Signatures Between Patients with Early and Advanced T-Stage Nasopharyngeal Carcinoma Facilitate Prognostication
# Whole Brain Adiabatic T1rho and Relaxation Along a Fictitious Field Imaging in Healthy Volunteers and Patients With Multiple Sclerosis: Initial Findings
#
# Deep Learning for Automatic Differential Diagnosis of Primary Central Nervous System Lymphoma and Glioblastoma: Multi-Parametric Magnetic Resonance Imaging Based Convolutional Neural Network Model
# Pseudo-Enhancement in Intracranial Aneurysms on Black-Blood MRI: Effects of Flow Rate, Spatial Resolution, and Additional Flow Suppression
# Editorial for “Pseudo-Enhancement in Intracranial Aneurysms on Black Blood MRI: Effects of Flow Rate, Spatial Resolution, and Additional Flow Suppression”
# MRI Findings of Arachnoiditis, Revisited. Is Classification Possible?
# Editorial for “MRI Findings of Arachnoiditis, Revisited. Is Classification Needed?”
# A Prospective, Longitudinal Magnetic Resonance Imaging Evaluation of Cerebrovascular Reactivity and Infarct Development in Patients With Intracranial Stenosis
# Editorial for “Cerebrovascular Reactivity Timing and Stroke Risk in Patients With Intracranial Stenosis”
# Neuroimaging Phenotyping and Assessment of Structural-Metabolic-Electrophysiological Alterations in the Temporal Neocortex of Focal Cortical Dysplasia IIIa
# Editorial for “Neuroimaging Phenotyping and Structural-Metabolic-Epileptogenic Correlations in the Temporal Neocortex of Focal Cortical Dysplasia IIIa”
# Can Hybrid Arterial Spin Labeling-Tagged Zero-Echo-Time Magnetic Resonance Angiography Be an Effective Candidate in the Evaluation of Intracranial Artery Diseases? A Clinical Feasibility Study
# Editorial for “Can Hybrid Arterial Spin Labeling-Tagged Zero-Echo-Time Magnetic Resonance Angiography Be an Effective Candidate in the Evaluation of Intracranial Artery Diseases? A Clinical Feasibility Study”
# Small-World Networks and Their Relationship With Hippocampal Glutamine/Glutamate Concentration in Healthy Adults With Varying Genetic Risk for Alzheimer's Disease
# Editorial for “Small-World Networks and Their Relationship With Hippocampal Glutamine/Glutamate (Glx) Concentration in Healthy Adults With Varying Genetic Risk for Alzheimer's Disease”
# Regional Gas Exchange Measured by 129Xe Magnetic Resonance Imaging Before and After Combination Bronchodilators Treatment in Chronic Obstructive Pulmonary Disease
#
# Voxel-level Classification of Prostate Cancer on Magnetic Resonance Imaging: Improving Accuracy Using Four-Compartment Restriction Spectrum Imaging
# Editorial for “Voxel-level Classification of Prostate Cancer on MRI: Improving Accuracy Using Four-Compartment Restriction Spectrum Imaging”
# Machine Learning-Based Integration of Prognostic Magnetic Resonance Imaging Biomarkers for Myometrial Invasion Stratification in Endometrial Cancer
# Editorial for “Machine Learning-Based Integration of Prognostic MR Imaging Biomarkers for Myometrial Invasion Stratification in Endometrial Cancer”
# Modified Diffusion Tensor Image Processing Pipeline for Archived Studies of Patients With Leukoencephalopathy
# Prospective Evaluation of Repeatability and Robustness of Radiomic Descriptors in Healthy Brain Tissue Regions In Vivo Across Systematic Variations in T2-Weighted Magnetic Resonance Imaging Acquisition Parameters
# Editorial for “Prospective Evaluation of Repeatability and Reproducibility of Radiomic Descriptors in Healthy Brain Tissue Regions in Vivo Across Systematic Variations in T2-Weighted MRI Acquisition Parameters”
#
#                 More from this journal
#
# Log in to Wiley Online Library
# Create a new account
# 50

# %% [markdown]
# ### Clean up the title list

# %%
list_h2 = []
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 4:
    cells = h2.get_text()
    list_h2.append(cells)

# Delete the last element: "Log in to Wiley Online Library"
list_h2.pop()

# Insert "Issue Information" as the 2nd element
list_h2.insert(1, "Issue Information")

# JMRI Vol 54 No 2
# list_h2.append("Erratum")

# JMRI Vol 54 No 3
list_h2.insert(2, "Commentary")
list_h2.append("Condensation Artifact")
list_h2.append("Reviewer Acknowledgements")

for l in list_h2:
  print(l)
print(len(list_h2))
# Out:
# Whole Brain Adiabatic T1rho and Relaxation Along a Fictitious Field Imaging in Healthy Volunteers and Patients With Multiple Sclerosis: Initial Findings
#
# Issue Information
# Commentary
# AI-Enhanced Diagnosis of Challenging Lesions in Breast MRI: A Methodology and Application Primer
# Intratumoral and Peritumoral Radiomics Based on Functional Parametric Maps from Breast DCE-MRI for Prediction of HER-2 and Ki-67 Status
# Reduced Field-of-View Diffusion-Weighted Magnetic Resonance Imaging of the Pancreas With Tilted Excitation Plane: A Preliminary Study
# Quantitative Susceptibility Mapping Using a Multispectral Autoregressive Moving Average Model to Assess Hepatic Iron Overload
# Bowel Wall Visualization Using MR Enterography in Relationship to Bowel Lumen Contents and Patient Demographics
# Editorial for “Bowel Wall Visualization Using MR Enterography in Relationship to Bowel Lumen Contents and Patient Demographics”
# MRI Measures of Murine Liver Fibrosis
# Editorial for “MRI measures of murine liver fibrosis”
# Intravoxel Incoherent Motion and Dynamic Contrast-Enhanced Magnetic Resonance Imaging to Early Detect Tissue Injury and Microcirculation Alteration in Hepatic Injury Induced by Intestinal Ischemia–Reperfusion in a Rat Model
# Editorial for “Using Intravoxel Incoherent Motion and Dynamic Contrast-Enhanced MR Imaging to Early Detect Tissue Injury and Microcirculation Alteration in Hepatic Injury Induced by Intestinal Ischemia Reperfusion in the Rat Model”
# Diagnostic Performance of a Lower-dose Contrast-Enhanced 4D Dynamic MR Angiography of the Lower Extremities at 3 T Using Multisegmental Time-Resolved Maximum Intensity Projections
# Editorial for “Diagnostic Performance of a Lower-Dose Contrast Enhanced 4D Dynamic MR Angiography of the Lower Extremities at 3 T Using Multi-Segmental Time Resolved Maximum Intensity Projections”
# Using Deep Learning to Emulate the Use of an External Contrast Agent in Cardiovascular 4D Flow MRI
# Sensitivity of Myocardial Radiomic Features to Imaging Parameters in Cardiac MR Imaging
# Reducing Contrast Agent Dose in Cardiovascular MR Angiography with Deep Learning
# Editorial For “Reduction of Contrast Agent Dose in Cardiovascular MR Angiography Using Deep Learning”
# Myocardial Deformation Assessed by MR Feature Tracking in Groups of Patients With Ischemic Heart Disease
# Editorial for “Myocardial Deformation Assessed by MR Feature Tracking in Groups of Patients With Ischemic Heart Disease”
# Image Quality Assessment of Fetal Brain MRI Using Multi-Instance Deep Learning Methods
# Editorial for “Image Quality Assessment of Fetal Brain MRI Using Multi-Instance Deep Learning Methods”
# Magnetic Resonance T2* Is Increased in Patients With Early-Stage Achilles and Patellar Tendinopathy
#
# Effects of the Competitive Season and Off-Season on Knee Articular Cartilage in Collegiate Basketball Players Using Quantitative MRI: A Multicenter Study
# Editorial for “Effects of the Competitive Season and Off Season on Knee Articular Cartilage in Collegiate Basketball Players Using Quantitative MRI: A Multi-Center Study”
# Differences in Radiomics Signatures Between Patients with Early and Advanced T-Stage Nasopharyngeal Carcinoma Facilitate Prognostication
# Whole Brain Adiabatic T1rho and Relaxation Along a Fictitious Field Imaging in Healthy Volunteers and Patients With Multiple Sclerosis: Initial Findings
#
# Deep Learning for Automatic Differential Diagnosis of Primary Central Nervous System Lymphoma and Glioblastoma: Multi-Parametric Magnetic Resonance Imaging Based Convolutional Neural Network Model
# Pseudo-Enhancement in Intracranial Aneurysms on Black-Blood MRI: Effects of Flow Rate, Spatial Resolution, and Additional Flow Suppression
# Editorial for “Pseudo-Enhancement in Intracranial Aneurysms on Black Blood MRI: Effects of Flow Rate, Spatial Resolution, and Additional Flow Suppression”
# MRI Findings of Arachnoiditis, Revisited. Is Classification Possible?
# Editorial for “MRI Findings of Arachnoiditis, Revisited. Is Classification Needed?”
# A Prospective, Longitudinal Magnetic Resonance Imaging Evaluation of Cerebrovascular Reactivity and Infarct Development in Patients With Intracranial Stenosis
# Editorial for “Cerebrovascular Reactivity Timing and Stroke Risk in Patients With Intracranial Stenosis”
# Neuroimaging Phenotyping and Assessment of Structural-Metabolic-Electrophysiological Alterations in the Temporal Neocortex of Focal Cortical Dysplasia IIIa
# Editorial for “Neuroimaging Phenotyping and Structural-Metabolic-Epileptogenic Correlations in the Temporal Neocortex of Focal Cortical Dysplasia IIIa”
# Can Hybrid Arterial Spin Labeling-Tagged Zero-Echo-Time Magnetic Resonance Angiography Be an Effective Candidate in the Evaluation of Intracranial Artery Diseases? A Clinical Feasibility Study
# Editorial for “Can Hybrid Arterial Spin Labeling-Tagged Zero-Echo-Time Magnetic Resonance Angiography Be an Effective Candidate in the Evaluation of Intracranial Artery Diseases? A Clinical Feasibility Study”
# Small-World Networks and Their Relationship With Hippocampal Glutamine/Glutamate Concentration in Healthy Adults With Varying Genetic Risk for Alzheimer's Disease
# Editorial for “Small-World Networks and Their Relationship With Hippocampal Glutamine/Glutamate (Glx) Concentration in Healthy Adults With Varying Genetic Risk for Alzheimer's Disease”
# Regional Gas Exchange Measured by 129Xe Magnetic Resonance Imaging Before and After Combination Bronchodilators Treatment in Chronic Obstructive Pulmonary Disease
#
# Voxel-level Classification of Prostate Cancer on Magnetic Resonance Imaging: Improving Accuracy Using Four-Compartment Restriction Spectrum Imaging
# Editorial for “Voxel-level Classification of Prostate Cancer on MRI: Improving Accuracy Using Four-Compartment Restriction Spectrum Imaging”
# Machine Learning-Based Integration of Prognostic Magnetic Resonance Imaging Biomarkers for Myometrial Invasion Stratification in Endometrial Cancer
# Editorial for “Machine Learning-Based Integration of Prognostic MR Imaging Biomarkers for Myometrial Invasion Stratification in Endometrial Cancer”
# Modified Diffusion Tensor Image Processing Pipeline for Archived Studies of Patients With Leukoencephalopathy
# Prospective Evaluation of Repeatability and Robustness of Radiomic Descriptors in Healthy Brain Tissue Regions In Vivo Across Systematic Variations in T2-Weighted Magnetic Resonance Imaging Acquisition Parameters
# Editorial for “Prospective Evaluation of Repeatability and Reproducibility of Radiomic Descriptors in Healthy Brain Tissue Regions in Vivo Across Systematic Variations in T2-Weighted MRI Acquisition Parameters”
# Condensation Artifact
# Reviewer Acknowledgements
# 51

# %% [markdown]
# ### Add dates first published

# %%
# li class: corresponds to "First Published"

all_li = soupJMRI.find_all("li")

# i = 0
# for li in all_li:
  # li_class = li.get_attribute_list("class")
  # print(li_class)
  # if li_class == ['ePubDate']:
    # print(li.get_text())
    # i += 1
  # print(li.get_text())
  # i += 1
# print(i)

list_date = []
for li in all_li:
  li_class = li.get_attribute_list("class")
  if li_class == ['ePubDate']:
    cells = li.get_text().split(': ')[1]
    list_date.append(cells)

for l in list_date:
  print(l)
print(len(list_date))
# Out:
# 11 August 2021
# 11 August 2021
# 13 July 2021
# 30 August 2020
# 06 May 2021
# 11 March 2021
# 26 February 2021
# 04 March 2021
# 08 May 2021
# 18 March 2021
# 01 June 2021
# 21 March 2021
# 13 April 2021
# 07 April 2021
# 06 May 2021
# 25 February 2021
# 01 March 2021
# 22 February 2021
# 26 March 2021
# 04 March 2021
# 05 May 2021
# 23 April 2021
# 01 June 2021
# 14 March 2021
# 24 March 2021
# 29 March 2021
# 08 April 2021
# 06 March 2021
# 11 March 2021
# 10 March 2021
# 04 April 2021
# 28 February 2021
# 13 March 2021
# 24 March 2021
# 20 April 2021
# 23 April 2021
# 22 April 2021
# 20 May 2021
# 08 May 2021
# 03 May 2021
# 14 June 2021
# 07 May 2021
# 31 March 2021
# 21 April 2021
# 01 April 2021
# 30 May 2021
# 15 April 2021
# 16 April 2021
# 03 May 2021
# 23 April 2021
# 11 August 2021
# 51

# %%
list_url = []
for link in all_links:
  if 'visitable' in str(link.get("class")): # and '/doi/' in link.get("href"):
    cells = link.get("href").replace('/doi', 'https://doi.org')
    list_url.append(cells)

for l in list_url:
  print(l)
print(len(list_url))
# Out:
# https://doi.org/10.1002/jmri.27231
# https://doi.org/10.1002/jmri.27232
# https://doi.org/10.1002/jmri.27830
# https://doi.org/10.1002/jmri.27332
# https://doi.org/10.1002/jmri.27651
# https://doi.org/10.1002/jmri.27590
# https://doi.org/10.1002/jmri.27584
# https://doi.org/10.1002/jmri.27589
# https://doi.org/10.1002/jmri.27668
# https://doi.org/10.1002/jmri.27601
# https://doi.org/10.1002/jmri.27698
# https://doi.org/10.1002/jmri.27604
# https://doi.org/10.1002/jmri.27642
# https://doi.org/10.1002/jmri.27631
# https://doi.org/10.1002/jmri.27663
# https://doi.org/10.1002/jmri.27578
# https://doi.org/10.1002/jmri.27581
# https://doi.org/10.1002/jmri.27573
# https://doi.org/10.1002/jmri.27618
# https://doi.org/10.1002/jmri.27588
# https://doi.org/10.1002/jmri.27666
# https://doi.org/10.1002/jmri.27649
# https://doi.org/10.1002/jmri.27759
# https://doi.org/10.1002/jmri.27600
# https://doi.org/10.1002/jmri.27610
# https://doi.org/10.1002/jmri.27624
# https://doi.org/10.1002/jmri.27633
# https://doi.org/10.1002/jmri.27586
# https://doi.org/10.1002/jmri.27592
# https://doi.org/10.1002/jmri.27587
# https://doi.org/10.1002/jmri.27627
# https://doi.org/10.1002/jmri.27583
# https://doi.org/10.1002/jmri.27597
# https://doi.org/10.1002/jmri.27605
# https://doi.org/10.1002/jmri.27647
# https://doi.org/10.1002/jmri.27615
# https://doi.org/10.1002/jmri.27644
# https://doi.org/10.1002/jmri.27629
# https://doi.org/10.1002/jmri.27671
# https://doi.org/10.1002/jmri.27632
# https://doi.org/10.1002/jmri.27773
# https://doi.org/10.1002/jmri.27662
# https://doi.org/10.1002/jmri.27623
# https://doi.org/10.1002/jmri.27646
# https://doi.org/10.1002/jmri.27625
# https://doi.org/10.1002/jmri.27750
# https://doi.org/10.1002/jmri.27636
# https://doi.org/10.1002/jmri.27635
# https://doi.org/10.1002/jmri.27652
# https://doi.org/10.1002/jmri.27634
# https://doi.org/10.1002/jmri.27838
# 51

# %%
# df = pd.DataFrame({'title':list_h2, 'url': list_url})
df = pd.DataFrame({'Journal': title, 
                   #'Category': list_category, 
                   'Title': list_h2, 
                   'First Published': list_date, 
                   'DOI': list_url})
df
# Out:
#                                               Journal  ...                                 DOI
# 0    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27231
# 1    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27232
# 2    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27830
# 3    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27332
# 4    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27651
# 5    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27590
# 6    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27584
# 7    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27589
# 8    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27668
# 9    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27601
# 10   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27698
# 11   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27604
# 12   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27642
# 13   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27631
# 14   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27663
# 15   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27578
# 16   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27581
# 17   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27573
# 18   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27618
# 19   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27588
# 20   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27666
# 21   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27649
# 22   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27759
# 23   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27600
# 24   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27610
# 25   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27624
# 26   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27633
# 27   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27586
# 28   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27592
# 29   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27587
# 30   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27627
# 31   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27583
# 32   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27597
# 33   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27605
# 34   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27647
# 35   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27615
# 36   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27644
# 37   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27629
# 38   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27671
# 39   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27632
# 40   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27773
# 41   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27662
# 42   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27623
# 43   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27646
# 44   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27625
# 45   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27750
# 46   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27636
# 47   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27635
# 48   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27652
# 49   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27634
# 50   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27838
#
# [51 rows x 4 columns]

# %% [markdown]
# ### Manually create the list of category based on Issue Information
#  - See [here](https://stackoverflow.com/questions/4654414/python-append-item-to-list-n-times) for extending elements in a list for X times

# %%
list_category = ['Cover Image', 'Issue Information', 'Commentary']

### Vol 54 No 1 ###
# list_category.extend(['Review Articles'] * 3)
# list_category.extend(['Original Research: Head and Neck', 'Editorial'] * 2)
# list_category.extend(['Original Research: Pelvis'] * 1)
# list_category.extend(['Original Research: Abdomen'] * 1)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 2)
# list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 1)
# list_category.extend(['Original Research: Musculoskeletal'] * 1)
# list_category.extend(['Original Research: Vascular'] * 1)
# list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)
# list_category.extend(['Original Research: Neuro'] * 3)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 3)
# list_category.extend(['Original Research: Breast', 'Editorial'] * 1)
# list_category.extend(['Original Research: Pediatrics', 'Editorial'] * 1)
# list_category.extend(['Original Research: Cardiac'] * 2)
# list_category.extend(['Original Research: Cardiac', 'Editorial'] * 2)
# list_category.extend(['Original Research: Safety', 'Editorial'] * 1)
# list_category.extend(['Letter to the Editor'] * 1)

### Vol 54 No 2 ###
# list_category.extend(['CME Article'] * 1)
# list_category.extend(['Review Articles'] * 3)
# list_category.extend(['Original Research: Whole Body', 'Editorial'] * 1)
# list_category.extend(['Original Research: Cardiac'] * 4)
# list_category.extend(['Original Research: Pelvis', 'Editorial'] * 2)
# list_category.extend(['Original Research: Technical', 'Editorial'] * 1)
# list_category.extend(['Original Research: Musculoskeletal'] * 2)
# list_category.extend(['Original Research: Abdomen'] * 3)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 1)
# list_category.extend(['Original Research: Neuro'] * 2)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 4)
# list_category.extend(['Original Research: Thoracic', 'Editorial'] * 1)
# list_category.extend(['Original Research: Breast'] * 1)
# list_category.extend(['Original Research: Vascular'] * 1)
# list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)
# list_category.extend(['Original Research: Case Report'] * 1)
# list_category.extend(['Erratum'] * 1)

### Vol 54 No 3 ###
list_category.extend(['Review Articles'] * 1)
list_category.extend(['Original Research: Breast'] * 1)
list_category.extend(['Original Research: Abdomen'] * 2)
list_category.extend(['Original Research: Abdomen', 'Editorial'] * 3)
list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)
list_category.extend(['Original Research: Cardiac'] * 2)
list_category.extend(['Original Research: Cardiac', 'Editorial'] * 2)
list_category.extend(['Original Research: Pediatrics', 'Editorial'] * 1)
list_category.extend(['Original Research: Musculoskeletal'] * 1)
list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 1)
list_category.extend(['Original Research: Head and Neck'] * 1)
list_category.extend(['Original Research: Neuro'] * 2)
list_category.extend(['Original Research: Neuro', 'Editorial'] * 6)
list_category.extend(['Original Research: Thoracic'] * 1)
list_category.extend(['Original Research: Pelvis', 'Editorial'] * 2)
list_category.extend(['Original Research: Technical'] * 1)
list_category.extend(['Original Research: Technical', 'Editorial'] * 1)
list_category.extend(['Original Research: Case Report: Technical'] * 1)
list_category.extend(['Reviewer Appreciation'] * 1)

i = 0
for l in list_category:
  print(l)
  i += 1
print(i)
# Out:
# Cover Image
# Issue Information
# Commentary
# Review Articles
# Original Research: Breast
# Original Research: Abdomen
# Original Research: Abdomen
# Original Research: Abdomen
# Editorial
# Original Research: Abdomen
# Editorial
# Original Research: Abdomen
# Editorial
# Original Research: Vascular
# Editorial
# Original Research: Cardiac
# Original Research: Cardiac
# Original Research: Cardiac
# Editorial
# Original Research: Cardiac
# Editorial
# Original Research: Pediatrics
# Editorial
# Original Research: Musculoskeletal
# Original Research: Musculoskeletal
# Editorial
# Original Research: Head and Neck
# Original Research: Neuro
# Original Research: Neuro
# Original Research: Neuro
# Editorial
# Original Research: Neuro
# Editorial
# Original Research: Neuro
# Editorial
# Original Research: Neuro
# Editorial
# Original Research: Neuro
# Editorial
# Original Research: Neuro
# Editorial
# Original Research: Thoracic
# Original Research: Pelvis
# Editorial
# Original Research: Pelvis
# Editorial
# Original Research: Technical
# Original Research: Technical
# Editorial
# Original Research: Case Report: Technical
# Reviewer Appreciation
# 51

# %%
df.insert(1, 'Category', list_category)
df
# Out:
#                                               Journal  ...                                 DOI
# 0    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27231
# 1    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27232
# 2    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27830
# 3    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27332
# 4    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27651
# 5    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27590
# 6    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27584
# 7    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27589
# 8    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27668
# 9    Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27601
# 10   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27698
# 11   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27604
# 12   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27642
# 13   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27631
# 14   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27663
# 15   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27578
# 16   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27581
# 17   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27573
# 18   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27618
# 19   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27588
# 20   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27666
# 21   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27649
# 22   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27759
# 23   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27600
# 24   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27610
# 25   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27624
# 26   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27633
# 27   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27586
# 28   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27592
# 29   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27587
# 30   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27627
# 31   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27583
# 32   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27597
# 33   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27605
# 34   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27647
# 35   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27615
# 36   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27644
# 37   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27629
# 38   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27671
# 39   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27632
# 40   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27773
# 41   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27662
# 42   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27623
# 43   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27646
# 44   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27625
# 45   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27750
# 46   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27636
# 47   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27635
# 48   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27652
# 49   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27634
# 50   Journal of Magnetic Resonance Imaging: Vol 54...  ...  https://doi.org/10.1002/jmri.27838
#
# [51 rows x 5 columns]

# %% [markdown]
# ### Finally, save as csv file

# %%
df.to_csv(path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-3.csv',
          # path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-2.csv',
          # path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-vol-54-no-1.csv', 
          index=False)
