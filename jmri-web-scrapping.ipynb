# %% [markdown]
# # Web Scraping using Python

# %% [markdown]
# ## Target Journal: JMRI
# - https://onlinelibrary.wiley.com/toc/15222586/2022/55/5
# - https://onlinelibrary.wiley.com/toc/15222586/2022/55/4
# - https://onlinelibrary.wiley.com/toc/15222586/2022/55/3
# - https://onlinelibrary.wiley.com/toc/15222586/2022/55/2
# - https://onlinelibrary.wiley.com/toc/15222586/2022/55/1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#To easily display the plots, make sure to include the line %matplotlib inline as shown below.
# %matplotlib inline

import urllib
import requests
import lxml

#To perform web scraping, you should also import the libraries shown below. 
#The urllib.request module is used to open URLs. 
#The Beautiful Soup package is used to extract data from html files. 
#The Beautiful Soup library's name is bs4 which stands for Beautiful Soup, version 4.
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ## First, save as a local html file
#  - See: https://zetcode.com/python/beautifulsoup/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Vol 55 No 1
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 55, No 1.html'
# Vol 55 No 2
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 55, No 2.html'
# Vol 55 No 3
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 55, No 3.html'
# Vol 55 No 4
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 55, No 4.html'
# Vol 55 No 5
URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Journal of Magnetic Resonance Imaging_ Vol 55, No 5.html'

with open(URL, 'r') as f:

    contents = f.read()

    soup = BeautifulSoup(contents, 'lxml')

# %% [markdown]
# Find the corresponding index, and identify the title info

# %%
def safeOpenParsePage(targetUrl):
    try:
        # tmpurl = urlopen(Request(targetUrl, headers={'User-Agent': 'Chrome/92.0.4515.107'}))
        tmpurl = open(targetUrl, 'r')
        tmpR = tmpurl.read()
        # tmpSoup = BeautifulSoup(tmpR, 'html.parser')
        tmpSoup = BeautifulSoup(tmpR, 'lxml')
        return tmpSoup
    except urllib.error.HTTPError as e:
        print(e)
        return None

soupJMRI = safeOpenParsePage(URL)
if soupJMRI is not None:
      print(soupJMRI.prettify())
# Out:
# <!DOCTYPE html>
# <html class="pb-page" data-request-id="d1cd10b2-9f5e-4b85-ac63-d8622867835b" lang="en">
#  <head data-pb-dropzone="head">
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content=";journal:journal:15222586;ctype:string:Journal Content;website:website:pericles;page:string:Table of Contents;requestedJournal:journal:15222586;wgroup:string:Publication Websites;pageGroup:string:Publication Pages;issue:issue:doi\:10.1002/jmri.v55.5" name="pbContext"/>
#   <script type="text/javascript">
#    var $DoubleClickZone = "j-magres-imaging_jmri";var $DoubleClickSite =  "wly.radiol.imag_000105";
#   </script>
#   <script id="analyticDigitalData">
#    digitalData = {"site":{"ip":"152.78.0.24","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2022-05-05"},"identities":[{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"ReferrerUser","uuid":"5a2c1d70-1255-4a45-95f3-a3aa3a2771fb"},{"type":"InstitutionUser","uuid":"58cbd8e6-3c5d-4fc0-ac26-57c4792d2c4b","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALWB000204"}]},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"SmartGroupUser","uuid":"cb1790a9-a0b9-40b3-915d-806df593aeeb"},{"type":"InstitutionUser","uuid":"dd40e26c-3e96-4e9f-9382-5d13a2a401f3","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL57933332"}]},{"type":"ReferrerUser","uuid":"6401b279-b825-4f41-a389-04e29feb967f"},{"type":"SmartGroupUser","uuid":"7a2a316d-5a37-4ccd-afdb-737bfb863a48"},{"type":"InstitutionUser","uuid":"f2fe3189-2268-4a38-8067-0ed49b53d909","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004150"}]},{"type":"SmartGroupUser","uuid":"28ca5b1a-41f5-4192-8683-6750cc8248b5"},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"RegionUser","uuid":"3147507a-46c1-4f33-a077-4feac12c6b71"},{"type":"SmartGroupUser","uuid":"1a6297fb-6679-4882-a4c2-fdd124624edf"},{"type":"SmartGroupUser","uuid":"77da7ca2-c9f3-4f94-9737-922e1d15b7d9"},{"type":"SmartGroupUser","uuid":"8032f17e-5050-4fb4-9c40-e1f6875d5c2b"},{"type":"BasicGroup","uuid":"2f6750d5-f13f-4356-939b-048ac1423e64"},{"type":"SmartGroupUser","uuid":"a4187e00-f28e-4754-9a0f-1eb306fb0679"},{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"BasicGroup","uuid":"32489ba7-57d6-43ed-b717-a0de5ed5ca0e"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"InstitutionUser","uuid":"1b19994e-f6cd-4a6e-b151-a166eb757a02","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALEM00084"}]},{"type":"InstitutionUser","uuid":"838af7aa-2073-4eca-9e95-df167c7953bb","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"SOUTHA450S"}]},{"type":"InstitutionUser","uuid":"a454dd84-0b2c-4d7b-804b-20fd42da68c7","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"P#JISC"}]},{"type":"InstitutionUser","uuid":"2196ade6-df1b-4d0d-b877-7d8cca58ee79","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"PARENTNESLI"}]},{"type":"BasicGroup","uuid":"8d568359-32d1-4757-be79-b72d00d11429"},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"InstitutionUser","uuid":"c2c7b09d-2b4d-4ce1-b401-b744073e0ebc","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000165532"}]},{"type":"SmartGroupUser","uuid":"261f34be-39f9-4f9e-8feb-500f73213904"},{"type":"InstitutionUser","uuid":"ca0c2bfa-0ec9-4312-aa4b-4c51702429d4","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL0000647"}]},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"20d013f5-e22b-4df0-ba93-d6d925db9e32"},{"type":"InstitutionUser","uuid":"472490a4-a4aa-404d-b9b6-dbc83f1a8ece","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000068532"}]},{"type":"SmartGroupUser","uuid":"97587ffd-dcb4-4cb5-9986-a8ce611532bd"},{"type":"SmartGroupUser","uuid":"a46a154d-979f-41ba-b459-fd34df5c071f"},{"type":"RegionUser","uuid":"82409588-c43f-4337-a6a8-3272d1b7e20e"},{"type":"SmartGroupUser","uuid":"055a2bdd-861f-4fa7-bd49-9773db7e0e3e"},{"type":"SmartGroupUser","uuid":"b2dbfe27-ecae-4bb6-bb0d-d75e5caa3762"},{"type":"BasicGroup","uuid":"bd2fcf7d-fa23-4396-9340-9ee81267838e"}],"publication":{"group":{"doi":"10.1002/jmri.v55.5","access":"full","volume":"55","issue":"5","coverDate":"2022-05-01","topics":[{"taxonomyUri":"global-subject-codes","topicLabel":"MEDICAL S ...
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="noarchive" name="robots"/>
#   <meta content=" Journal of Magnetic Resonance Imaging: Vol 55, No 5" property="og:title"/>
#   <meta content="Journal" property="og:type"/>
#   <meta content="https://onlinelibrary.wiley.com/toc/15222586/2022/55/5" property="og:url"/>
#   <meta content="https://onlinelibrary.wiley.com/cover/15222586/55/5" property="og:image"/>
#   <meta content="Wiley Online Library" property="og:site_name"/>
#   <meta content="Click on the title to browse this issue" property="og:description"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="app-id=673861322" name="apple-itunes-app"/>
#   <link as="script" href="https://cmp.osano.com/AzZdRbSORDOOzF9W/67a788d8-9344-4c9b-a3c2-89b5073ee231/osano.js" rel="preload"/>
#   <script src="https://cmp.osano.com/AzZdRbSORDOOzF9W/67a788d8-9344-4c9b-a3c2-89b5073ee231/osano.js">
#   </script>
#   <meta content="10.1002/jmri.v55.5" name="citation_doi"/>
#   <meta content="10.1002/jmri.v55.5" name="dc.identifier"/>
#   <title>
#    Journal of Magnetic Resonance Imaging: Vol 55, No 5
#   </title>
#   <link href="/wro/l4hi~article-metrics-phase2.css" rel="stylesheet" type="text/css"/>
#   <link href="/wro/l4hi~product.css" rel="stylesheet" type="text/css"/>
#   <link as="font" crossorigin="anonymous" href="/products/acropolis/pericles/releasedAssets/fonts/icomoon/icomoon.woff?b662edd26150aa4747b9" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/products/acropolis/pericles/releasedAssets/fonts/open-sans/open-sans-v15-latin-regular.woff2?b662edd26150aa4747b9" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="/products/acropolis/pericles/releasedAssets/fonts/source-serif-pro/source-serif-pro-v5-latin-regular.woff2?b662edd26150aa4747b9" rel="preload" type="font/woff2"/>
#   <link href="/products/acropolis/pericles/releasedAssets/css/build-b662edd26150aa4747b9.css" rel="stylesheet"/>
#   <link href="/products/acropolis/pericles/releasedAssets/css/print-b662edd26150aa4747b9.css" media="print" rel="stylesheet"/>
#   <script async="" src="/pb-assets/catchpoint-1549680351760.js">
#   </script>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/pb-assets/hub-assets/pericles/hub-1649851616160.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/iucr-1510734465460.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/readcube-1510565373110.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/dr-overrides-1611780866727.css" rel="stylesheet" type="text/css"/>
#   <!-- link rel="stylesheet" type="text/css" href="/pb-assets/css/temporary-1525702334993.css" -->
#   <style>
#    /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#
# /* PERICLES-14726 */
# section.info-tab-wrapper section.metrics {
#     display: block;
# }
#   </style>
#   <!-- The Adobe DTM script. Must come after the digitalData object -->
#   <script src="//assets.adobedtm.com/6e626c9ec247e474f6b98eb15a79a185cf7e26a5/satelliteLib-c1ac050bbdc647f13a62578e71f0d817f8a6cbb5.js">
#   </script>
#   <!-- Google Search Console verification -->
#   <meta content="ffz4i4DxIJCdGpRXe0XN6KG6o4FYI-nnFW9I_dg8piM" name="google-site-verification"/>
#   <!-- KRUX Implementation-->
#   <script class="kxct" data-id="JMOONjNh" data-timing="async" data-version="1.9" type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#   </script>
#   <!-- KRUX Implementation cont'd -->
#   <script type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#   </script>
#   <!-- Grapeshot Implementation -->
#   <script>
#    var gs_channels = 'default';
#   </script>
#   <script async="" src="//wiley.grapeshot.co.uk/main/channels.cgi?url=https://onlinelibrary.wiley.com/toc/15222586/2022/55/5">
#   </script>
#   <!-- DoubleClick Implementation -->
#   <script type="text/javascript">
#    var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#   </script>
#   <script>
#    var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#   </script>
#   <script>
#    googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/jmri.v55.5')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#   </script>
#   <script src="//validate.onecount.net/js/all.min.js#cff4b10c3a3d5cc9bbb7e2b9292cc66eae1deafa">
#   </script>
#   <script>
#    try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#   </script>
#   <script data-cf-beacon='{"rayId":"65604cf31ed0e4d9","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.1","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script data-cf-beacon='{"rayId":"65cb04cf2c4898e7","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script async="" src="/cdn-cgi/bm/cv/669835187/api.js">
#   </script>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#   </script>
#   <script data-cf-beacon='{"rayId":"65d1a8e0c92cd32a","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"6f51ed128cd69e5c","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194">
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"6fb34bc28b3a752d","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194">
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"703954e8dc3197cf","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194">
#   </script>
#   <link href="https://onlinelibrary.wiley.com/toc/15222586/2022/55/5" rel="canonical"/>
#   <!-- Get whether TNSI is in live or test mode -->
#   <!-- Get the configured TNSI Javascript version number -->
#   <!-- Get the configured TNSI MerchantID -->
#   <!-- Add "TEST" to beginning of merchant ID when running in test mode -->
#   <!-- loading Javascript for using the persistence Service -->
#   <script src="//unpkg.com/@theidentityselector/thiss-ds">
#   </script>
#   <script type="text/javascript">
#    function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#             queryParamsDelimiter: encodeURIComponent('?'),
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf(this.queryParamsDelimiter) !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId, entityTitle) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId, entityTitle: entityTitle, eventGroupKey: 'f2fac0d6-6b41-4ab9-b10c-735828fb2a13'}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID, ssoInstitution.entity.title)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#   </script>
#   <script type="text/javascript">
#    (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaak-_YlSmNL966lX0scy';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#   </script>
#   <script>
#    var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Journal of Magnetic Resonance Imaging: Vol 55, No 5";
#   </script>
#  </head>
#  <body class="pb-ui">
#   <div class="skip-links">
#    <ul class="rlist">
#     <li>
#      <a href="#main-content" tabindex="1">
#       Skip to Main Content
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div data-ng-non-bindable="" id="pb-page-content">
#    <div data-pb-dropzone="main" data-pb-dropzone-name="Main">
#     <div class="pageHeader" data-widget-def="pageHeader" data-widget-id="62175478-b98a-43d5-90f2-1f2045ac1a7e">
#      <header class="page-header">
#       <div data-pb-dropzone="main">
#        <div class="admin-message" data-widget-def="ux3-layout-widget" data-widget-id="bb5b5e2c-d3d6-4015-b586-eeade38f59d4">
#         <div class="container">
#          <div class="row">
#           <div>
#            <div class="pb-ad">
#             <div style="background=blue;">
#              <div class="container">
#               <p style="text-align: center;">
#                <b>
#                 Working off-campus?
#                </b>
#                Learn about our
#                <a href="/action/clickThrough?id=101169&amp;url=https%3A%2F%2Fonlinelibrary.wiley.com%2Fresearchers%2Fread%2Faccess-options&amp;loc=%2Ftoc%2F15222586%2F2022%2F55%2F5&amp;pubId=77354177&amp;placeholderId=1029&amp;productId=1011" tabindex="2" target="_blank">
#                 <font color="white">
#                  <u>
#                   remote access options
#                  </u>
#                 </font>
#                </a>
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="container">
#         <div class="row">
#          <div class="contents col-md-12">
#           <div class="institution-wrapper-mobile hidden-lg hidden-md padded-content" data-widget-def="UX3InstitutionBanner" data-widget-id="4d1f2e23-571a-4b27-8ab7-e7cd8ca15964">
#            <div class="institution">
#             <div class="institution-box no-image">
#              <div class="institution-info-wrapper">
#               <span class="institution__name">
#                University of Southampton
#               </span>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="pull-left">
#            <div class="logo-container hidden-xs hidden-sm hidden-md" data-widget-def="ux3-general-image" data-widget-id="ff262197-0fb8-4973-aaa2-2fceba4b5a61">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mainLogo" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#             </a>
#            </div>
#            <div class="logo-container-mobile hidden-lg hidden-md hidden-sm" data-widget-def="ux3-general-image" data-widget-id="6b601b23-7301-47c8-8889-242d041241c4">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mobileLogo" src="/pb-assets/hub-assets/pericles/mobilehublogo-1518781861020.png"/>
#             </a>
#            </div>
#            <div class="institution-wrapper hidden-xs hidden-sm hidden-md institution--block" data-widget-def="UX3InstitutionBanner" data-widget-id="14d0e2f8-27d3-42d0-a477-72015e14e818">
#             <div class="institution">
#              <div class="institution-box no-image">
#               <div class="institution-info-wrapper">
#                <span class="institution__name">
#                 University of Southampton
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="header-quicksearch" data-widget-def="UX3QuickSearchWidget" data-widget-id="48175bb0-0f70-46e6-bb89-7e2781fdb8e4">
#             <div class="quick-search-wrapper">
#              <a aria-label="Search" class="quick-search__item" href="#" title="search">
#               <i aria-hidden="true" class="icon-search">
#               </i>
#               <span class="quick-search__item__arrow">
#               </span>
#              </a>
#              <div class="quick-search quickSearchFormContainer" data-linkto-page="true">
#               <div class="main-search-field-wrapper">
#                <div class="tab clearfix">
#                 <input class="fakeQSInput quickSearchFilter" placeholder="Search" tabindex="13" type="search" value=""/>
#                 <label class="sr-only" for="search-within">
#                  Search within
#                 </label>
#                 <select class="search-within" id="search-within" name="search-within" tabindex="10">
#                  <option data-url="thisCategory" data-value="15222586" value="#pane-67065c09-4a88-49cd-934c-ac707951d35c0">
#                   This Journal
#                  </option>
#                  <option data-url="https://onlinelibrary.wiley.com" value="#pane-67065c09-4a88-49cd-934c-ac707951d35c1">
#                   Anywhere
#                  </option>
#                 </select>
#                 <ul class="rlist tab__content" role="tablist">
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c0-con" class="tab__pane quick-search-pane__anywhere active" id="pane-67065c09-4a88-49cd-934c-ac707951d35c0" role="tab">
#                   <form action="/action/doSearch" method="get" name="thisJournalQuickSearch" title="Quick Search">
#                    <div class="input-group option-0">
#                     <label class="hiddenLabel" for="searchField0">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField0" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <input name="SeriesKey" type="hidden" value="15222586"/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222586" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222586#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c1-con" class="tab__pane quick-search-pane__anywhere" id="pane-67065c09-4a88-49cd-934c-ac707951d35c1" role="tab">
#                   <form action="https://onlinelibrary.wiley.com/action/doSearch" method="get" name="defaultQuickSearch" title="Quick Search">
#                    <div class="input-group option-1">
#                     <label class="hiddenLabel" for="searchField1">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField1" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="cart-indicator__wrapper" data-widget-def="ux3-layout-widget" data-widget-id="5ef13ed1-f4ac-4b62-a426-07ec9576a586">
#             <div class="pull-left">
#              <div class="cart-indicator__wrapper" data-widget-def="eCommerceCartIndicatorWidget" data-widget-id="4a9f7c04-a273-4a25-91fb-8e7bd9970288">
#               <div class="eCommerceCartIndicatorWidget">
#               </div>
#              </div>
#             </div>
#             <div class="pull-right">
#              <div class="login-bar-container" data-widget-def="literatumNavigationLoginBar" data-widget-id="d384ca92-7137-45d6-b3c2-78c9c0a98c2b">
#               <div class="loginBar login-open">
#                <a aria-label="Log in or Register" class="show-login" href="/action/showLogin?uri=%2Ftoc%2F15222586%2F2022%2F55%2F5&amp;aria-label=Log+in+or+Register" role="button" uri="/toc/15222586/2022/55/5">
#                 <span class="icon-profile_empty">
#                 </span>
#                 <span class="sign-in-label">
#                  Login / Register
#                 </span>
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </header>
#     </div>
#     <h1 class="hidden">
#      Journal list menu
#     </h1>
#     <div class="pages-nav--sticky pages-nav hidden-lg fixed-element">
#      <div class="pages-nav--res">
#       <div class="container">
#        <ul class="rlist--inline pull-left">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="journal-list" href="#">
#           <i aria-hidden="true" class="icon-toc">
#           </i>
#           <span>
#            Journal
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="journal-list" id="journal-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-1, #menu-item-undefined-2, #menu-item-main-menu-1-1, #menu-item-main-menu-1-2, #menu-item--1, #menu-item--2, .journal-featured" data-toggle="transplant" data-transplant="self">
#           </div>
#           <!-- PERICLES-7683
#               <a href="#" title="More from this journal" class="dropdown__toggle"><span>More from this journal</span></a>
#
#                 <div data-target=".journal-resources" data-remove="false" data-toggle="transplant" data-direction="from" data-transplant="self" class="transplant showit"></div>
# -->
#          </div>
#         </li>
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="articles-list" href="#">
#           <i class="article-img-icon">
#            <img src="/pb-assets/hub-assets/pericles/articles_1-1499257321163.png"/>
#           </i>
#           <span>
#            Articles
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="articles-list" id="articles-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-3, #menu-item-undefined-4, #menu-item-main-menu-1-3, #menu-item-main-menu-1-4, #menu-item--3" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#        <ul class="rlist--inline pull-right">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="actions-list" href="#">
#           <span>
#            Actions
#           </span>
#           <i aria-hidden="true" class="icon-chevron-down">
#           </i>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="actions-list" id="actions-list">
#           <h2 class="side-section-header hiddenLabel--lg">
#            Tools
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target=".journal-actions-container li:nth-child(1), .journal-actions-container li:nth-child(2), .journal-actions-container li:nth-child(3), .journal-actions-container li:nth-child(4), .journal-actions-container li:nth-child(5), #subscribeLink" data-toggle="transplant" data-transplant="self">
#           </div>
#           <h2 class="side-section-header hiddenLabel--lg">
#            Follow journal
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#alert-link, #facebook-link, #twitter-link, #linkedin-link, #most-recent-link, #most-read-link, #most-cited-link" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="pageBody body-text" data-widget-def="pageBody" data-widget-id="72100436-7a82-49fc-933b-c6c9d8c42914">
#      <main id="main-content" tabindex="-1">
#       <!--begin pagefulltext-->
#       <div class="page-body pagefulltext">
#        <div data-pb-dropzone="main">
#         <div class="js--fixed-switch" data-widget-def="ux3-layout-widget" data-widget-id="6da55ccb-5daf-4c91-b961-05eee9e6f293">
#          <div>
#           <div class="secondary-bg-color banner-wrapper" data-widget-def="literatumAd" data-widget-id="0220a30b-90c0-4b51-8637-141edf12f86a">
#            <div class="pb-ad">
#             <aside role="complementary">
#              <div class="advert advert-leaderboard" id="advert-leaderboard">
#               <script>
#                googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#               </script>
#               <!-- No JavaScript support is a call to an image -->
#               <noscript>
#                <a href="/action/clickThrough?id=1013&amp;url=https%3A%2F%2Fpubads.g.doubleclick.net%2Fgampad%2Fjump%3Fiu%3D%24googlePublisherCategory%26amp%3Bsz%3D728x90%26amp%3Btile%3D1%26amp%3Bc%3D%24random&amp;loc=%2Ftoc%2F15222586%2F2022%2F55%2F5&amp;pubId=77354177&amp;placeholderId=1015&amp;productId=101018" target="_blank">
#                 <img src="https://pubads.g.doubleclick.net/gampad/ad?iu=$googlePublisherCategory&amp;sz=728x90&amp;tile=1&amp;c=$random"/>
#                </a>
#               </noscript>
#              </div>
#             </aside>
#            </div>
#           </div>
#           <style type="text/css">
#            li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#           </style>
#           <section class="journal-page-header card" data-widget-def="ux3-layout-widget" data-widget-id="9e8ee65a-2e18-4c00-9474-5ac10e16ecfe">
#            <div class="container">
#             <div class="row">
#              <div class="journal-info-container col-md-8">
#               <a href="/journal/15222586" title="Journal of Magnetic Resonance Imaging homepage">
#                <h1 id="journal-banner-text" style="margin: 0; font-size: 0">
#                 Journal of Magnetic Resonance Imaging
#                </h1>
#                <img alt="Journal of Magnetic Resonance Imaging" class="journal-banner-image" id="journal-banner-image" src="/pb-assets/journal-banners/15222586-1590394653627.jpg" style="margin-bottom: 15px; display: none"/>
#               </a>
#               <script>
#                var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222586-1590394653627.jpg";
#               </script>
#              </div>
#              <div class="hidden-xs hidden-sm hidden-md col-md-4">
#              </div>
#             </div>
#            </div>
#           </section>
#           <div class="stickybar pages-nav hidden-xs hidden-sm hidden-md scrollable-element" data-widget-def="menuWidget" data-widget-id="998218b4-f988-4a0c-8c4f-b2d3875e1770">
#            <div class="stickybar__wrapper">
#             <div class="main-nav">
#              <a data-toggle="nav" href="#undefined" title="menu drawer">
#               <i aria-hidden="true" class="icon-menu2">
#               </i>
#               <i aria-hidden="true" class="icon-close_thin">
#               </i>
#              </a>
#              <nav aria-label="Journal navigation" class="drawer__nav container gutterless hidden-sm hidden-xs" data-ctrl-res="never" role="navigation">
#               <h2 class="is-accessible">
#                Navigation Bar
#               </h2>
#               <section>
#                <h3 class="is-accessible">
#                 Menu
#                </h3>
#                <a class="menu-header hidden-md hidden-lg" href="/">
#                 Home
#                </a>
#                <ul class="menubar rlist--inline" id="menubar" role="menubar">
# ...
#                 Accessibility
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/publishing-policies">
#                 Wiley Research DE&amp;I Statement and Publishing Policies
#                </a>
#               </li>
#              </ul>
#             </div>
#             <style>
#              .mange-cookies-btn{
#         background: none;
#         color: inherit;
#         border: none;
#         padding: 0;
#         cursor: pointer;
#         font-weight: 600;
#     }
#     .mange-cookies-btn:hover,
#     .mange-cookies-btn:focus,
#     .mange-cookies-btn:active {
#         text-decoration: none;
#         outline: 0;
#         background-color: transparent;
#     }
#
#     .mange-cookies-btn:focus {
#         outline: 5px auto -webkit-focus-ring-color;
#     }
#
#     .osano-cm-widget {
#         display: none;
#     }
#             </style>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Help &amp; Support
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://hub.wiley.com/community/support/onlinelibrary">
#                 Contact Us
#                </a>
#               </li>
#               <li>
#                <a href="https://www.wiley.com/customer-success/wiley-online-library-training-hub">
#                 Training and Support
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/dmca-notification-policy">
#                 DMCA &amp; Reporting Piracy
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Opportunities
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://onlinelibrary.wiley.com/agents">
#                 Subscription Agents
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/advertisers">
#                 Advertisers &amp; Corporate Partners
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Connect with Wiley
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://www.wiley.com/network">
#                 The Wiley Network
#                </a>
#               </li>
#               <li>
#                <a href="https://newsroom.wiley.com/">
#                 Wiley Press Room
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="copyright-container" data-widget-def="ux3-layout-widget" data-widget-id="86584e25-e4db-4118-9550-9b4f5341a4ac">
#          <div class="container">
#           <div class="row">
#            <div class=" col-md-12">
#             <div class="copyright" data-widget-def="UX3HTMLWidget" data-widget-id="bfbf6c5d-a650-4662-828f-5275fada9120">
#              <div class="copyright pull-left">
#               Copyright © 1999-2022
#               <a href="https://www.wiley.com">
#                John Wiley &amp; Sons, Inc
#               </a>
#               . All rights reserved
#              </div>
#             </div>
#             <div class="footer-logo pull-right">
#              <a aria-label="Wiley" href="https://www.wiley.com" title="Wiley Home Page">
#               <img alt="Wiley Home Page" src="/pb-assets/tmp-images/footer-logo-wiley-1510029248417.png"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#     <div aria-labelledby="loginPopupHead" class="popup login-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="Cancel Login" class="close" href="#" role="button">
#        <i aria-hidden="true" class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#       </div>
#       <div class="modal__body">
#        <div class="ssoLogin">
#        </div>
#        <h2 id="loginPopupHead">
#         Log in to Wiley Online Library
#        </h2>
#        <div class="login-form">
#         <form action="/action/doLogin?societyURLCode=" class="bordered" method="post">
#          <input name="id" type="hidden" value="67065c09-4a88-49cd-934c-ac707951d35c"/>
#          <input name="popup" type="hidden" value="true"/>
#          <input name="loginUri" type="hidden" value="/toc/15222586/2022/55/5"/>
#          <input name="redirectUri" type="hidden" value="/toc/15222586/2022/55/5"/>
#          <input name="loginUri" type="hidden" value="/toc/15222586/2022/55/5"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="username">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="login" id="username" name="login" placeholder="Enter your email" required="true" size="15" spellcheck="false" type="text" value=""/>
#           <div class="actions">
#           </div>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="password">
#             Password
#            </label>
#           </div>
#           <input autocapitalize="off" autocomplete="off" autocorrect="off" class="password" id="password" name="password" placeholder="Enter your password" required="true" spellcheck="false" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="actions">
#           <a class="link show-request-reset-password" href="/action/requestResetPassword">
#            Forgot password?
#           </a>
#          </div>
#          <div class="loginExtraBeans-dropZone" data-pb-dropzone="loginExtraBeans">
#          </div>
#          <div class="align-end">
#           <span class="submit ">
#            <input class="button btn submit primary no-margin-bottom accessSubmit" name="submitButton" type="submit" value="Log In"/>
#           </span>
#          </div>
#         </form>
#         <div class="societySpecificInstructions">
#         </div>
#        </div>
#        <div class="login-container clearfix form-btn">
#         <a class="linkBtn float-left" href="/action/registration">
#          NEW USER
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#         <a class="linkBtn float-right instituation-login" href="/action/ssostart?redirectUri=%2Ftoc%2F15222586%2F2022%2F55%2F5">
#          INSTITUTIONAL LOGIN
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="changePasswordPopupHead" class="popup change-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close cancel" href="#" role="button">
#        <i class="icon-close_thin">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="changePasswordPopupHead">
#         Change Password
#        </h2>
#       </div>
#       <div class="modal__body">
#        <div class="form">
#         <form action="/action/changePassword" method="post">
#          <div class="message error">
#          </div>
#          <input name="submit" type="hidden" value="submit"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-old">
#             Old Password
#            </label>
#           </div>
#           <input autocomplete="off" class="old" id="a589574e-bb98-4c6e-8fed-67365ff05357-old" name="old" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-new">
#             New Password
#            </label>
#           </div>
#           <input autocomplete="off" class="pass-hint new" id="a589574e-bb98-4c6e-8fed-67365ff05357-new" name="new" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#           <div class="password-strength-indicator" data-max="32" data-min="10" data-strength="3">
#            <span class="text too-short">
#             Too Short
#            </span>
#            <span class="text weak">
#             Weak
#            </span>
#            <span class="text medium">
#             Medium
#            </span>
#            <span class="text strong">
#             Strong
#            </span>
#            <span class="text very-strong">
#             Very Strong
#            </span>
#            <span class="text too-long">
#             Too Long
#            </span>
#           </div>
#          </div>
#          <input class="button primary submit" disabled="disabled" type="submit" value="Submit"/>
#         </form>
#         <a class="fakeFormLastElement" href="#">
#         </a>
#        </div>
#        <div class="success-template hidden">
#         <h2>
#          Password Changed Successfully
#         </h2>
#         <p>
#          Your password has been changed
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="createAccountPopupHead" class="popup registration-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close" href="#" role="button">
#        <i class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="logoDropZone" data-pb-dropzone="logoDropZone">
#        </div>
#        <h2 id="createAccountPopupHead">
#         Create a new account
#        </h2>
#       </div>
#       <div class="modal__body">
#        <form action="/action/registration" class="registration-form" method="post">
#         <input name="redirectUri" type="hidden" value="/toc/15222586/2022/55/5"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="4e647394-f751-4441-baa4-df426bca4b6e.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="4e647394-f751-4441-baa4-df426bca4b6e.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="submit">
#          <input class="button submit primary" type="submit" value="Register"/>
#         </div>
#        </form>
#        <div class="center">
#         <a class="show-login" href="/action/showLogin">
#          Returning user
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="resetPasswordPopupHead" class="popup top-drawer request-reset-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <div class="modal__header">
#        <a aria-label="close dialog" class="cancel close" href="#" role="button">
#         <i class="icon-close_thin">
#         </i>
#        </a>
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="resetPasswordPopupHead">
#         Forgot your password?
#        </h2>
#        <p class="sub">
#         Enter your email address below.
#        </p>
#       </div>
#       <div class="modal__body">
#        <div class="error">
#        </div>
#        <form action="/action/requestResetPassword" class="request-reset-password-form" method="post">
#         <input name="requestResetPassword" type="hidden" value="true"/>
#         <div class="input-group">
#          <div class="input-group">
#           <div class="label">
#            <label for="email">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="email" id="email" name="email" placeholder="Enter your email" size="15" spellcheck="false" type="text" value=""/>
#          </div>
#         </div>
#         <div class="password-recaptcha-ajax">
#         </div>
#         <div class="message error">
#         </div>
#         <div class="form-btn">
#          <input class="button btn primary submit" disabled="disabled" name="submit" type="submit" value="RESET PASSWORD"/>
#         </div>
#        </form>
#        <div class="success-template hidden">
#         <p>
#          Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div>
#      <div class="pb-dropzone" data-pb-dropzone="col-0" title="col-0">
#      </div>
#     </div>
#     <div aria-labelledby="requestUsernamePopupHead" class="popup top-drawer request-username-drawer username-popup hidden" role="dialog" tabindex="-1">
#      <a aria-label="close dialog" class="close" href="#" role="button">
#       <i class="icon-close_thin">
#       </i>
#      </a>
#      <div class="content">
#       <h2 id="requestUsernamePopupHead">
#        Request Username
#       </h2>
#       <div class="form">
#        <p>
#         Can't sign in? Forgot your username?
#        </p>
#        <p class="sub">
#         Enter your email address below and we will send you your username
#        </p>
#        <div class="message error">
#        </div>
#        <form action="/action/requestUsername" method="post">
#         <input name="requestUsername" type="hidden" value="requestUsername"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="username-recaptcha-ajax">
#         </div>
#         <input class="button primary submit" disabled="disabled" name="submit" type="submit" value="Submit"/>
#         <div class="center">
#          <a class="cancel" href="#">
#           Close
#          </a>
#         </div>
#        </form>
#       </div>
#       <div class="success-template hidden note">
#        <p>
#         If the address matches an existing account you will receive an email with instructions to retrieve your username
#        </p>
#       </div>
#      </div>
#     </div>
#     <!-- Belongs at the bottom of the page -->
#     <script type="text/javascript">
#      if(window._satellite) {
# _satellite.pageBottom();
# }
#     </script>
#    </div>
#   </div>
#   <script src="/wro/l4hi~article-metrics-phase2.js" type="text/javascript">
#   </script>
#   <script src="/products/acropolis/pericles/releasedAssets/js/build.lazyload.bundle-735f91645072c55da582.js">
#   </script>
#   <script src="/products/acropolis/pericles/releasedAssets/js/main.bundle-fbcd9da45bcb4acd5f9a.js">
#   </script>
#   <script src="/wro/l4hi~product.js" type="text/javascript">
#   </script>
#   <script>
#    var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"7068ac870879e648","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194">
#   </script>
#  </body>
# </html>

# %%
# Get the title
title = soupJMRI.title
print(title)
# Out:
# <title> Journal of Magnetic Resonance Imaging: Vol 55, No 5</title>

# %%
# Print out the text
text = soupJMRI.get_text()
print(soup.text)

# Another way to extract text
# str(all_links[103]).split("<h2>")[1].replace("</h2></a>", "")
# Out:
# var $DoubleClickZone = "j-magres-imaging_jmri";var $DoubleClickSite =  "wly.radiol.imag_000105";digitalData = {"site":{"ip":"152.78.0.24","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2022-05-05"},"identities":[{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"ReferrerUser","uuid":"5a2c1d70-1255-4a45-95f3-a3aa3a2771fb"},{"type":"InstitutionUser","uuid":"58cbd8e6-3c5d-4fc0-ac26-57c4792d2c4b","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALWB000204"}]},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"SmartGroupUser","uuid":"cb1790a9-a0b9-40b3-915d-806df593aeeb"},{"type":"InstitutionUser","uuid":"dd40e26c-3e96-4e9f-9382-5d13a2a401f3","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL57933332"}]},{"type":"ReferrerUser","uuid":"6401b279-b825-4f41-a389-04e29feb967f"},{"type":"SmartGroupUser","uuid":"7a2a316d-5a37-4ccd-afdb-737bfb863a48"},{"type":"InstitutionUser","uuid":"f2fe3189-2268-4a38-8067-0ed49b53d909","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004150"}]},{"type":"SmartGroupUser","uuid":"28ca5b1a-41f5-4192-8683-6750cc8248b5"},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"RegionUser","uuid":"3147507a-46c1-4f33-a077-4feac12c6b71"},{"type":"SmartGroupUser","uuid":"1a6297fb-6679-4882-a4c2-fdd124624edf"},{"type":"SmartGroupUser","uuid":"77da7ca2-c9f3-4f94-9737-922e1d15b7d9"},{"type":"SmartGroupUser","uuid":"8032f17e-5050-4fb4-9c40-e1f6875d5c2b"},{"type":"BasicGroup","uuid":"2f6750d5-f13f-4356-939b-048ac1423e64"},{"type":"SmartGroupUser","uuid":"a4187e00-f28e-4754-9a0f-1eb306fb0679"},{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"BasicGroup","uuid":"32489ba7-57d6-43ed-b717-a0de5ed5ca0e"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"InstitutionUser","uuid":"1b19994e-f6cd-4a6e-b151-a166eb757a02","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALEM00084"}]},{"type":"InstitutionUser","uuid":"838af7aa-2073-4eca-9e95-df167c7953bb","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"SOUTHA450S"}]},{"type":"InstitutionUser","uuid":"a454dd84-0b2c-4d7b-804b-20fd42da68c7","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"P#JISC"}]},{"type":"InstitutionUser","uuid":"2196ade6-df1b-4d0d-b877-7d8cca58ee79","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"PARENTNESLI"}]},{"type":"BasicGroup","uuid":"8d568359-32d1-4757-be79-b72d00d11429"},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"InstitutionUser","uuid":"c2c7b09d-2b4d-4ce1-b401-b744073e0ebc","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000165532"}]},{"type":"SmartGroupUser","uuid":"261f34be-39f9-4f9e-8feb-500f73213904"},{"type":"InstitutionUser","uuid":"ca0c2bfa-0ec9-4312-aa4b-4c51702429d4","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL0000647"}]},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"20d013f5-e22b-4df0-ba93-d6d925db9e32"},{"type":"InstitutionUser","uuid":"472490a4-a4aa-404d-b9b6-dbc83f1a8ece","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000068532"}]},{"type":"SmartGroupUser","uuid":"97587ffd-dcb4-4cb5-9986-a8ce611532bd"},{"type":"SmartGroupUser","uuid":"a46a154d-979f-41ba-b459-fd34df5c071f"},{"type":"RegionUser","uuid":"82409588-c43f-4337-a6a8-3272d1b7e20e"},{"type":"SmartGroupUser","uuid":"055a2bdd-861f-4fa7-bd49-9773db7e0e3e"},{"type":"SmartGroupUser","uuid":"b2dbfe27-ecae-4bb6-bb0d-d75e5caa3762"},{"type":"BasicGroup","uuid":"bd2fcf7d-fa23-4396-9340-9ee81267838e"}],"publication":{"group":{"doi":"10.1002/jmri.v55.5","access":"full","volume":"55","issue":"5","co ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Journal of Magnetic Resonance Imaging: Vol 55, No 5
#
#
#
#
#
#
#
#
#
#
#
#
# /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#
# /* PERICLES-14726 */
# section.info-tab-wrapper section.metrics {
#     display: block;
# }
#
#
#
#
#
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#
#
#
# 	var gs_channels = 'default';
#
#
#
#
# 	var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#
#
# 	var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#
#
# 	googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/jmri.v55.5')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#
#
#
# 	try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#
#
#
# (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#
#
#
#
#
#
#
#
#
#
#
#
#         function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#             queryParamsDelimiter: encodeURIComponent('?'),
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf(this.queryParamsDelimiter) !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId, entityTitle) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId, entityTitle: entityTitle, eventGroupKey: 'f2fac0d6-6b41-4ab9-b10c-735828fb2a13'}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID, ssoInstitution.entity.title)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#
#
#
#         (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaak-_YlSmNL966lX0scy';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#
#
#     var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Journal of Magnetic Resonance Imaging: Vol 55, No 5";
#
#
#
#
# Skip to Main Content
#
#
#
#
#
#
#
#
#
#
#
#
# Working off-campus? Learn about our remote access options
#
#
#
#
#
#
#
# University of Southampton
#
#
#
#
#
#
#
#
#
# University of Southampton
#
#
#
# Search withinThis JournalAnywhereSearch term  Advanced Search  Citation SearchSearch term  Advanced Search  Citation Search
#
#
#
#
#
#
#
#
#
#
#
#
# Login / Register
#
#
#
#
#
#
#
#
#
#
#  Journal list menu
#
#
#
#
# Journal
#
#
#
#
#
# Articles
#
#
#
#
#
#
# Actions
#
# Tools
#
# Follow journal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
# li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#
#
#
# Journal of Magnetic Resonance Imaging
#
#
#
# var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222586-1590394653627.jpg";
#
#
#
#
# Navigation BarMenuHomeHomeAboutOverviewContactEditorial BoardOA AdvantagesAdvertisePermissionsContributeAuthor GuidelinesOpen AccessSubmit a Manuscript For Referees BrowseAccepted ArticlesEarly ViewCurrent IssueAll IssuesCover GalleryVirtual Issues
#
#
# Follow journal
#
# Alert
#
#
#
#
#
# RSS Feeds
#
#
# Most recent (RSS)
#
# Most cited (RSS)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# IssueVolume 55,  Issue 5Pages: spcone, 1273-1585May 2022
#
# Previous Issue
#
#
#
# GO TO SECTION
#
#
#
#
#
#
#
#
# Export Citation(s)
# Export CitationsFormatPlain TextRIS (ProCite, Reference Manager)EndNoteBibTexMedlarsRefWorksType of importCitation file or direct importIndirect import or copy/pasteCancelNext< Go backCitation HelpExport
#
#
# Cover Image
#
# Free Access
#
#
# free
#
# A Comparative Study of Amide Proton Transfer Weighted Imaging and Intravoxel Incoherent Motion MRI Techniques Versus (18) F-FDG PET to Distinguish Solitary Pulmonary Lesions and Their Subtypes
#
#  Ting Fang MS,
#  Nan Meng MD,
#  Pengyang Feng MS,
#  Zhun Huang MS,
#  Ziqiang Li MS,
#  Fangfang Fu MD,
#  Jianmin Yuan PhD,
#  Yang Yang PhD,
#  Hui Liu PhD,
#  Neil Roberts PhD,
#  Meiyun Wang MD,
#
#
# Pages: spcone
# First Published: 15 April 2022
#
#
#
# (A–H) A 64-year-old male patient, with adenocarcinoma (AC) in the left lung, (A) is D pseudocolored map with D = 1.08 × 10−3 mm2/second, (B) is F pseudocolored map with F = 22.5%, (C) is D* pseudocolored map with D* = 18.36 × 10−5 mm2/second, (D) is T2W image with fat saturation pre-pulse, (E) is hematoxylin and eosin (H&E) staining image which confirms this SPLs to be AC, (F ) is the fusion image of the SUV map and the attenuation correction map with SUVmax = 14.29, (G) is the B0 map, (H) is the mtrasym map with mtrasym (3.5 ppm) (%) = 7.3%. D = diffusion coefficient; F = perfusion fraction; D* = pseudo diffusion coefficient; SPLs = solitary pulmonary lesions; AC = adenocarcinoma; SUVmax = maximum value of standard uptake value; MTRAsym = magnetization transfer ratio asymmetry. by Ting Fang et al. (1376–1390)
#
#
#
#
#
#
# AbstractPDFRequest permissions
#
#
#
#
# Issue Information
#
# Free Access
#
#
# free
#
# Issue Information
# Pages: 1273-1282
# First Published: 15 April 2022
#
#
#
# First PagePDFRequest permissions
#
#
#
#
# Review Articles
#
# Neuro
#
# Full Access
#
#
# full
#
# Magnetic Resonance Iron Imaging in Amyotrophic Lateral Sclerosis
#
#  Anjan Bhattarai MEng,
#  Gary F. Egan PhD,
#  Paul Talman PhD,
#  Phyllis Chua PhD,
#  Zhaolin Chen PhD,
#
#
# Pages: 1283-1300
# First Published: 15 February 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Cardiac
#
# Full Access
#
#
# full
#
# Four-Dimensional Flow Magnetic Resonance Imaging in the Assessment of Blood Flow in the Heart and Great Vessels: A Systematic Review
#
#  Ciara M. Doyle MSc,
#  Jenny Orr MBChB,
#  John P. Greenwood PhD,
#  Sven Plein PhD,
#  Charalampos Tsoumpas PhD,
#  Malenka M. Bissell PhD,
#
#
# Pages: 1301-1321
# First Published: 20 August 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Safety
#
# Free Access
#
#
# free
#
# Magnetic Resonance Imaging During a Pandemic: Recommendations by the ISMRM Safety Committee
#
#  Jeremy D. Collins MD,
#  Howard Rowley MD,
#  Tim Leiner MD,
#  Scott Reeder MD, PhD,
#  Maureen Hood PhD,
#  Ilona Dekkers MD, PhD,
#  Khin Tha MD,
#  Vikas Gulani MD, PhD,
#  Emre Kopanoglu PhD,
#  for the ISMRM MR Safety Committee ,
#
#
# Pages: 1322-1339
# First Published: 20 December 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Technical
#
# Open Access
#
#
# oa
#
# Compressed Sensing in Sodium Magnetic Resonance Imaging: Techniques, Applications, and Future Prospects
#
#  Qingping Chen MSc,
#  N. Jon Shah PhD,
#  Wieland A. Worthoff PhD,
#
#
# Pages: 1340-1356
# First Published: 17 December 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Musculoskeletal
#
# Full Access
#
#
# full
#
# An Update in Imaging Evaluation of Histopathological Grade of Soft Tissue Sarcomas Using Structural and Quantitative Imaging and Radiomics
#
#  Shaobo Fang MD,
#  Yanyu Yang MD,
#  Nan Xu MD,
#  Yun Tu MD,
#  Zhenzhen Yin MD,
#  Yu Zhang PhD,
#  Yajie Liu MS,
#  Zhiqing Duan MD,
#  Wenyu Liu MD,
#  Shaowu Wang PhD,
#
#
# Pages: 1357-1375
# First Published: 12 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Research Articles
#
# Chest
#
# Full Access
#
#
# full
#
# A Comparative Study of Amide Proton Transfer Weighted Imaging and Intravoxel Incoherent Motion MRI Techniques Versus (18) F-FDG PET to Distinguish Solitary Pulmonary Lesions and Their Subtypes
#
#  Ting Fang MS,
#  Nan Meng MD,
#  Pengyang Feng MS,
#  Zhun Huang MS,
#  Ziqiang Li MS,
#  Fangfang Fu MD,
#  Jianmin Yuan PhD,
#  Yang Yang PhD,
#  Hui Liu PhD,
#  Neil Roberts PhD,
#  Meiyun Wang MD,
#
#
# Pages: 1376-1390
# First Published: 01 November 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “A Comparative Study of Amide Proton Transfer Weighted Imaging (APTw) and Intravoxel Incoherent Motion (IVIM) MRI Techniques and (18) F-FDG PET to Distinguish Solitary Pulmonary Lesions and Their Subtypes”
#
#  Danilo T. Wada MD, MPS,
#  Marcel Koenigkam-Santos MD, PhD,
#
#
# Pages: 1391-1392
# First Published: 10 November 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Abdomen
#
# Full Access
#
#
# full
#
# Perfusion Analysis of Kidney Injury in Rats With Cirrhosis Induced by Common Bile Duct Ligation Using Arterial Spin Labeling MRI
#
#  Yongquan Yu MD,
#  Shuangshuang Xie MD,
#  Kaiqi Wang PhD,
#  Fuzhi Zhang MS,
#  Chao Jiang MS,
#  Caixin Qiu MS,
#  Jinxia Zhu PhD,
#  Wen Shen MD,
#
#
# Pages: 1393-1404
# First Published: 09 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Perfusion Analysis of Kidney Injury in Rats With Cirrhosis Induced by Common Bile Duct Ligation Using Arterial Spin Labeling MRI”
#
#  Shengwen Deng MB, PhD,
#  Eric R. Muir PhD,
#
#
# Pages: 1405-1406
# First Published: 01 October 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Abdomen
#
# Full Access
#
#
# full
#
# Hepatic Iron Quantification Using a Free-Breathing 3D Radial Gradient Echo Technique and Validation With a 2D Biopsy-Calibrated R2* Relaxometry Method
#
#  Shawyon Chase Rohani BS,
#  Cara E. Morin MD, PhD,
#  Xiaodong Zhong PhD,
#  Stephan Kannengiesser PhD,
#  Utsav Shrestha MS,
#  Chris Goode BS,
#  Joseph Holtrop PhD,
#  Ayaz Khan PhD,
#  Ralf B. Loeffler PhD,
#  Jane S. Hankins MD, MS,
#  Claudia M. Hillenbrand PhD,
#  Aaryani Tipirneni-Sajja PhD,
#
#
# Pages: 1407-1416
# First Published: 20 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Hepatic Iron Quantification Using a Free-Breathing 3D Radial Gradient Echo Technique and Validation with a 2D Biopsy-Calibrated R2* Relaxometry Method”
#
#  Diana M. Lindquist PhD,
#  Jonathan R. Dillman MD,
#  Jean A. Tkach PhD,
#
#
# Pages: 1417-1418
# First Published: 14 September 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Abdomen
#
# Full Access
#
#
# full
#
# Effects of B1+ Heterogeneity on Spin Echo-Based Liver Iron Estimates
#
#  Eamon K. Doyle PhD,
#  Samuel Thornton,
#  Nilesh R. Ghugre PhD,
#  Thomas D. Coates MD,
#  Krishna S. Nayak PhD,
#  John C. Wood MD, PhD,
#
#
# Pages: 1419-1425
# First Published: 23 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Effects of B1 Heterogeneity on Spin Echo-Based Liver Iron Estimates”
#
#  Scott B. Reeder MD, PhD,
#
#
# Pages: 1426-1427
# First Published: 16 September 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Vascular
#
# Open Access
#
#
# oa
#
# A General Model to Calculate the Spin–Lattice Relaxation Rate (R1) of Blood, Accounting for Hematocrit, Oxygen Saturation, Oxygen Partial Pressure, and Magnetic Field Strength Under Hyperoxic Conditions
#
#  Emma Bluemke BS,
#  Eleanor Stride PhD,
#  Daniel P. Bulte PhD,
#
#
# Pages: 1428-1439
# First Published: 01 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Perfusion and Permeability MRI Predicts Future Cavernous Angioma Hemorrhage and Growth
#
#  Je Yeong Sone BA,
#  Nicholas Hobson MSc,
#  Abhinav Srinath BA,
#  Sharbel G. Romanos BA,
#  Ying Li MD,
#  Julián Carrión-Penagos MD,
#  Abdallah Shkoukani MD,
#  Agnieszka Stadnik MSc,
#  Kristina Piedad RN, BSN,
#  Rhonda Lightle BS,
#  Thomas Moore BS,
#  Dorothy DeBiasse BS,
#  Dehua Bi MSc,
#  Robert Shenkar PhD,
#  Timothy Carroll PhD,
#  Yuan Ji PhD,
#  Romuald Girard PhD,
#  Issam A. Awad MD,
#
#
# Pages: 1440-1449
# First Published: 24 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Perfusion and Permeability Magnetic Resonance Imaging (MRI) Predicts Future Cavernous Angioma Hemorrhage and Growth”
#
#  David Hasan MD, MSc, FAANS, FAHA,
#
#
# Pages: 1450-1451
# First Published: 29 September 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Cardiac
#
# Open Access
#
#
# oa
#
# Right/Left Ventricular Blood Pool T2 Ratio as an Innovative Cardiac MRI Screening Tool for the Identification of Left-to-Right Shunts in Patients With Right Ventricular Disease
#
#  Tilman Emrich MD,
#  Veronica Bordonaro MD,
#  U. Joseph Schoepf MD,
#  Aniela Petrescu MD,
#  Gabrielle Young BS,
#  Moritz Halfmann MD,
#  Theresia Schoeler,
#  Josua Decker MD,
#  Ibukun Abidoye MD,
#  Anna Lena Emrich MD,
#  Karl-Friedrich Kreitner MD,
#  Kai Helge Schmidt MD,
#  Akos Varga-Szemes MD, PhD,
#  Aurelio Secinaro MD,
#
#
# Pages: 1452-1458
# First Published: 10 August 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for: “Right/Left Ventricular Blood Pool T2 Ratio as an Innovative Cardiac MRI Screening Tool for the Identification of Left-to-Right Shunts in Patients with Right Ventricular Disease”
#
#  Hideo Arai RT,
#  Masateru Kawakubo PhD,
#  Toshiaki Kadokami MD, PhD,
#
#
# Pages: 1459-1460
# First Published: 06 August 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Cardiac
#
# Full Access
#
#
# full
#
# Impact of BMI on Left Atrial Strain and Abnormal Atrioventricular Interaction in Patients With Type 2 Diabetes Mellitus: A Cardiac Magnetic Resonance Feature Tracking Study
#
#  Meng-ting Shen MD,
#  Ying-kun Guo MD,
#  Xi Liu MD,
#  Yan Ren MD,
#  Li Jiang MD,
#  Lin-jun Xie MS,
#  Yue Gao MD,
#  Yi Zhang MD,
#  Ming-yan Deng MS,
#  Yuan Li MD,
#  Zhi-gang Yang PhD,
#
#
# Pages: 1461-1475
# First Published: 22 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Impact of BMI on Left Atrial Strain and Abnormal Atrioventricular Interaction in Patients With Type 2 Diabetes Mellitus: A Cardiac Magnetic Resonance Feature Tracking Study”
#
#  Mareike Gastl MD,
#  Florian Bönner MD,
#
#
# Pages: 1476-1477
# First Published: 06 November 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Cardiac
#
# Full Access
#
#
# full
#
# Diverse Right Ventricular Remodeling Evaluated by MRI and Prognosis in Eisenmenger Syndrome With Different Shunt Locations
#
#  Chao Gong MD,
#  Shuai He BMSci,
#  Xiaoling Chen BMSci,
#  Lili Wang BMSci,
#  Jiajuan Guo BMSci,
#  Juan He BMSci,
#  Lidan Yin BMSci,
#  Chen Chen MD,
#  Yuchi Han PhD,
#  Yucheng Chen MD,
#
#
# Pages: 1478-1488
# First Published: 21 June 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Diverse Right Ventricular Remodelling Evaluated by Cardiac Magnetic Resonance Imaging and Prognosis in Eisenmenger Syndrome with Different Shunt Locations”
#
#  Sara L. Hungerford MBBS,
#  Nicole K. Bart MBBS, PhD,
#
#
# Pages: 1489-1490
# First Published: 23 June 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Head and Neck
#
# Full Access
#
#
# full
#
# Radiomic Features on Multiparametric MRI for Preoperative Evaluation of Pituitary Macroadenomas Consistency: Preliminary Findings
#
#  Tao Wan PhD,
#  Chunxue Wu MD,
#  Ming Meng MD,
#  Tao Liu PhD,
#  Chuzhong Li MD,
#  Jun Ma MD,
#  Zengchang Qin PhD,
#
#
# Pages: 1491-1503
# First Published: 22 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# A Comparison of 3 T and 7 T MRI for the Clinical Evaluation of Uveal Melanoma
#
#  Michael C.Y. Tang MD,
#  Myriam G. Jaarsma-Coes MSc,
#  Teresa A. Ferreira MD,
#  Lorna Zwirs - Grech Fonk MD,
#  Marina Marinkovic MD,
#  Gregorius P.M. Luyten MD, PhD,
#  Jan-Willem M. Beenakker PhD,
#
#
# Pages: 1504-1515
# First Published: 15 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “A Comparison of 3T and 7T MRI for the Clinical Evaluation of Uveal Melanoma”
#
#  Aurélien Bustin PhD,
#
#
# Pages: 1516-1517
# First Published: 03 October 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Breast
#
# Full Access
#
#
# full
#
# Transfer Learning Strategy Based on Unsupervised Learning and Ensemble Learning for Breast Cancer Molecular Subtype Prediction Using Dynamic Contrast-Enhanced MRI
#
#  Rong Sun PhD,
#  Xuewen Hou PhD,
#  Xiujuan Li MD, PhD,
#  Yuanzhong Xie MD, PhD,
#  Shengdong Nie PhD,
#
#
# Pages: 1518-1534
# First Published: 20 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Transfer Learning Strategy Based on Unsupervised Learning and Ensemble Learning for Breast Cancer Molecular Subtype Prediction Using Dynamic Contrast Enhanced MRI”
#
#  Jonn-Terje Geitung MD, PhD, MHA,
#
#
# Pages: 1535
# First Published: 14 October 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Musculoskeletal
#
# Full Access
#
#
# full
#
# Q-Dixon and GRAPPATINI T2 Mapping Parameters: A Whole Spinal Assessment of the Relationship Between Osteoporosis and Intervertebral Disc Degeneration
#
#  Xiangwen Li MD,
#  Yuxue Xie MD,
#  Rong Lu MD,
#  Yuyang Zhang MD,
#  Qing Li MD,
#  Tobias Kober MD,
#  Tom Hilbert MD,
#  Hongyue Tao MD,
#  Shuang Chen PhD,
#
#
# Pages: 1536-1546
# First Published: 19 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Q-Dixon and GRAPPATINI T2 Mapping Parameters: A Whole Spinal Assessment of the Relationships Between Osteoporosis and Intervertebral Disc Degeneration”
#
#  Jessica Marie Bugeja BE (Electrical and Biomedical Engineering) (Hons),
#
#
# Pages: 1547-1548
# First Published: 14 October 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Editorial for “Device for Assessing Knee Joint Dynamics During MR Imaging”
#
#  Christopher J. Hanrahan MD, PhD,
#
#
# Pages: 1549-1550
# First Published: 29 November 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Neuro
#
# Full Access
#
#
# full
#
# Imaging Blood–Brain Barrier Permeability Through MRI in Pediatric Sickle Cell Disease: A Feasibility Study
#
#  Zixuan Lin PhD,
#  Eboni Lance MD, PhD,
#  Tiffany McIntyre BS,
#  Yang Li PhD,
#  Peiying Liu PhD,
#  Chantelle Lim BS,
#  Hongli Fan BS,
#  Aylin Tekes MD,
#  Alicia Cannon PhD,
#  James F. Casella MD,
#  Hanzhang Lu PhD,
#
#
# Pages: 1551-1558
# First Published: 22 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Improved Assessment of Longitudinal Spinal Cord Atrophy in Multiple Sclerosis Using a Registration-Based Approach: Relevance for Clinical Studies
#
#  Paola Valsasina MSc,
#  Mark A. Horsfield PhD,
#  Alessandro Meani MSc,
#  Claudio Gobbi MD,
#  Antonio Gallo MD,
#  Maria A. Rocca MD,
#  Massimo Filippi MD, FEAN, FAAN,
#
#
# Pages: 1559-1568
# First Published: 28 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Improved Assessment of Longitudinal Spinal Cord Atrophy in Multiple Sclerosis Using a Registration-Based Approach: Relevance for Clinical Studies”
#
#  Barbara Bellenberg PhD,
#  Carsten Lukas MD,
#
#
# Pages: 1569-1570
# First Published: 15 October 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# Research Articles
#
# Neuro
#
# Full Access
#
#
# full
#
# Optimal Diffusion Gradient Encoding Scheme for Diffusion Tensor Imaging Based on Golden Ratio
#
#  Liangyou Liu MS,
#  Zhaotong Li PhD,
#  Zeru Zhang MS,
#  Yifan Xia PhD,
#  Sha Li MS,
#  Song Gao PhD,
#
#
# Pages: 1571-1581
# First Published: 30 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
# Editorial
#
# Full Access
#
#
# full
#
# Editorial for “Optimal Diffusion Gradient Encoding Scheme for Diffusion Tensor Imaging Based on Golden Ratio”
#
#  Giuseppe Cruciata MD,
#
#
# Pages: 1582-1583
# First Published: 01 October 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Editorial for “Cross-Scanner Harmonization of Neuromelanin-Sensitive MRI for Multisite Studies”
#
#  Lara Wieland Dipl.-Psych,
#  Florian Schlagenhauf MD,
#
#
# Pages: 1584-1585
# First Published: 18 September 2021
#
#
#
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
#
# Tools
#
# Submit an Article
# Browse free sample issue
# Get content alerts
#
#
#
#
#
# Subscribe to this journal
#
#
#
#
#
#
#
#                 More from this journal
#
# Professional OpportunitiesISMRM Journal AppsW.S. Moore Award Winning ArticlesOther ResourcesFull Issue PDFs
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-rail-1' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			googletag.cmd.push 		( function () {
# 				googletag.display 	( 'advert-rail-2' );
# 			});
#
#
#
#
#
#
#
#
#
#
#
#
#                 Related Title
#
# IssueVolume 88, Issue 1Pages: C1, 1-500July 2022
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     .footer-links {
#         text-align: center;
#     }
#     .footer-links h3 {
#         font-weight: 300;
#     }
#     .footer-links a {
#         font-weight: 600;
#     }
#     @media (min-width: 992px) {
#         .footer-links {
#             text-align: left;
#         }
#     }
#
#
#
#                 Additional links
#
#
#
# About Wiley Online Library
#
# Privacy Policy
# Terms of Use
# About Cookies
# Manage Cookies
# Accessibility
# Wiley Research DE&I Statement and Publishing Policies
#
#
#
#     .mange-cookies-btn{
#         background: none;
#         color: inherit;
#         border: none;
#         padding: 0;
#         cursor: pointer;
#         font-weight: 600;
#     }
#     .mange-cookies-btn:hover,
#     .mange-cookies-btn:focus,
#     .mange-cookies-btn:active {
#         text-decoration: none;
#         outline: 0;
#         background-color: transparent;
#     }
#
#     .mange-cookies-btn:focus {
#         outline: 5px auto -webkit-focus-ring-color;
#     }
#
#     .osano-cm-widget {
#         display: none;
#     }
#
#
#
# Help & Support
#
# Contact Us
# Training and Support
# DMCA & Reporting Piracy
#
#
#
#
# Opportunities
#
# Subscription Agents
# Advertisers & Corporate Partners
#
#
#
#
# Connect with Wiley
#
# The Wiley Network
# Wiley Press Room
#
#
#
#
#
#
#
# Copyright © 1999-2022 John Wiley & Sons, Inc. All rights reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Log in to Wiley Online Library
#
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Password
#
#
#
#
#
#
#                                 Forgot password?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         NEW USER >
#
#
#
#                             INSTITUTIONAL LOGIN >
#
#
#
#
#
#
#
#
#
#
#
#
# Change Password
#
#
#
#
#
#
#
# Old Password
#
#
#
#
#
#
# New Password
#
#
#
#
# Too Short
# Weak
# Medium
# Strong
# Very Strong
# Too Long
#
#
#
#
#
#
# Password Changed Successfully
# Your password has been changed
#
#
#
#
#
#
#
#
#
#
# Create a new account
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#                     Returning user
#
#
#
#
#
#
#
#
#
#
#
#
# Forgot your password?
# Enter your email address below.
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#
# Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#
#
#
#
#
#
#
#
# Request Username
#
# Can't sign in? Forgot your username?
# Enter your email address below and we will send you your username
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Close
#
#
#
# If the address matches an existing account you will receive an email with instructions to retrieve your username
#
#
#
#
#
# if(window._satellite) {
# _satellite.pageBottom();
# }
#
#
#
#
#
#
# var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();

# %%
all_links = soupJMRI.find_all('a')

# %% [markdown]
# ### Explore Category

# %%
# h3 class corresponds to editorial

all_h3 = soupJMRI.find_all("h3")

i = 0
for h3 in all_h3:
  # print(h3)
  print(h3.get_text())
  i += 1
print(i)
# Out:
# Menu
# Format
# Type of import
# Cover Image
# Issue Information
# Review Articles
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# Research Articles
# Editorial
# About Wiley Online Library
# Help & Support
# Opportunities
# Connect with Wiley
# 36

# %% [markdown]
# ### Explore Original Research Subcategory

# %%
# h4 class corresponds to category

all_h4 = soupJMRI.find_all("h4")

i = 0
for h4 in all_h4:
  # print(h4)
  print(h4.get_text())
  i += 1
print(i)
# Out:
# Neuro
# Cardiac
# Safety
# Technical
# Musculoskeletal
# Chest
# Abdomen
# Abdomen
# Abdomen
# Vascular
# Cardiac
# Cardiac
# Cardiac
# Head and Neck
# Breast
# Musculoskeletal
# Neuro
# Neuro
# 18

# %%
all_h2 = soupJMRI.find_all("h2")

i = 0
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 3:
    print(h2.get_text())
    i += 1
print(i)

# str_h2 = str(all_h2)

# links = soupJMRI.find_all("a")
# str_links = str(links)
# print(str_h2)

# cleantext = BeautifulSoup(str_h2, "lxml").get_text()
# cleantext = BeautifulSoup(str_links, "lxml").get_text()
# print(cleantext)
# Out:
# A Comparative Study of Amide Proton Transfer Weighted Imaging and Intravoxel Incoherent Motion MRI Techniques Versus (18) F-FDG PET to Distinguish Solitary Pulmonary Lesions and Their Subtypes
# Magnetic Resonance Iron Imaging in Amyotrophic Lateral Sclerosis
# Four-Dimensional Flow Magnetic Resonance Imaging in the Assessment of Blood Flow in the Heart and Great Vessels: A Systematic Review
# Magnetic Resonance Imaging During a Pandemic: Recommendations by the ISMRM Safety Committee
# Compressed Sensing in Sodium Magnetic Resonance Imaging: Techniques, Applications, and Future Prospects
# An Update in Imaging Evaluation of Histopathological Grade of Soft Tissue Sarcomas Using Structural and Quantitative Imaging and Radiomics
# A Comparative Study of Amide Proton Transfer Weighted Imaging and Intravoxel Incoherent Motion MRI Techniques Versus (18) F-FDG PET to Distinguish Solitary Pulmonary Lesions and Their Subtypes
# Editorial for “A Comparative Study of Amide Proton Transfer Weighted Imaging (APTw) and Intravoxel Incoherent Motion (IVIM) MRI Techniques and (18) F-FDG PET to Distinguish Solitary Pulmonary Lesions and Their Subtypes”
# Perfusion Analysis of Kidney Injury in Rats With Cirrhosis Induced by Common Bile Duct Ligation Using Arterial Spin Labeling MRI
# Editorial for “Perfusion Analysis of Kidney Injury in Rats With Cirrhosis Induced by Common Bile Duct Ligation Using Arterial Spin Labeling MRI”
# Hepatic Iron Quantification Using a Free-Breathing 3D Radial Gradient Echo Technique and Validation With a 2D Biopsy-Calibrated R2* Relaxometry Method
# Editorial for “Hepatic Iron Quantification Using a Free-Breathing 3D Radial Gradient Echo Technique and Validation with a 2D Biopsy-Calibrated R2* Relaxometry Method”
# Effects of B1+ Heterogeneity on Spin Echo-Based Liver Iron Estimates
# Editorial for “Effects of B1 Heterogeneity on Spin Echo-Based Liver Iron Estimates”
# A General Model to Calculate the Spin–Lattice Relaxation Rate (R1) of Blood, Accounting for Hematocrit, Oxygen Saturation, Oxygen Partial Pressure, and Magnetic Field Strength Under Hyperoxic Conditions
# Perfusion and Permeability MRI Predicts Future Cavernous Angioma Hemorrhage and Growth
# Editorial for “Perfusion and Permeability Magnetic Resonance Imaging (MRI) Predicts Future Cavernous Angioma Hemorrhage and Growth”
# Right/Left Ventricular Blood Pool T2 Ratio as an Innovative Cardiac MRI Screening Tool for the Identification of Left-to-Right Shunts in Patients With Right Ventricular Disease
# Editorial for: “Right/Left Ventricular Blood Pool T2 Ratio as an Innovative Cardiac MRI Screening Tool for the Identification of Left-to-Right Shunts in Patients with Right Ventricular Disease”
# Impact of BMI on Left Atrial Strain and Abnormal Atrioventricular Interaction in Patients With Type 2 Diabetes Mellitus: A Cardiac Magnetic Resonance Feature Tracking Study
# Editorial for “Impact of BMI on Left Atrial Strain and Abnormal Atrioventricular Interaction in Patients With Type 2 Diabetes Mellitus: A Cardiac Magnetic Resonance Feature Tracking Study”
# Diverse Right Ventricular Remodeling Evaluated by MRI and Prognosis in Eisenmenger Syndrome With Different Shunt Locations
# Editorial for “Diverse Right Ventricular Remodelling Evaluated by Cardiac Magnetic Resonance Imaging and Prognosis in Eisenmenger Syndrome with Different Shunt Locations”
# Radiomic Features on Multiparametric MRI for Preoperative Evaluation of Pituitary Macroadenomas Consistency: Preliminary Findings
# A Comparison of 3 T and 7 T MRI for the Clinical Evaluation of Uveal Melanoma
# Editorial for “A Comparison of 3T and 7T MRI for the Clinical Evaluation of Uveal Melanoma”
# Transfer Learning Strategy Based on Unsupervised Learning and Ensemble Learning for Breast Cancer Molecular Subtype Prediction Using Dynamic Contrast-Enhanced MRI
# Editorial for “Transfer Learning Strategy Based on Unsupervised Learning and Ensemble Learning for Breast Cancer Molecular Subtype Prediction Using Dynamic Contrast Enhanced MRI”
# Q-Dixon and GRAPPATINI T2 Mapping Parameters: A Whole Spinal Assessment of the Relationship Between Osteoporosis and Intervertebral Disc Degeneration
# Editorial for “Q-Dixon and GRAPPATINI T2 Mapping Parameters: A Whole Spinal Assessment of the Relationships Between Osteoporosis and Intervertebral Disc Degeneration”
# Editorial for “Device for Assessing Knee Joint Dynamics During MR Imaging”
# Imaging Blood–Brain Barrier Permeability Through MRI in Pediatric Sickle Cell Disease: A Feasibility Study
# Improved Assessment of Longitudinal Spinal Cord Atrophy in Multiple Sclerosis Using a Registration-Based Approach: Relevance for Clinical Studies
# Editorial for “Improved Assessment of Longitudinal Spinal Cord Atrophy in Multiple Sclerosis Using a Registration-Based Approach: Relevance for Clinical Studies”
# Optimal Diffusion Gradient Encoding Scheme for Diffusion Tensor Imaging Based on Golden Ratio
# Editorial for “Optimal Diffusion Gradient Encoding Scheme for Diffusion Tensor Imaging Based on Golden Ratio”
# Editorial for “Cross-Scanner Harmonization of Neuromelanin-Sensitive MRI for Multisite Studies”
#
#                 More from this journal
#
# Log in to Wiley Online Library
# Create a new account
# 40

# %% [markdown]
# ## Next, clean up the title list

# %%
list_h2 = []
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 3:
    cells = h2.get_text()
    list_h2.append(cells)

# Delete the last element: "Log in to Wiley Online Library"
list_h2.pop()

# Insert "Issue Information" as the 2nd element
list_h2.insert(1, "Issue Information")

# JMRI Vol 54 No 2
# list_h2.append("Erratum")

# JMRI Vol 54 No 3
# list_h2.insert(2, "Commentary")
# list_h2.append("Condensation Artifact")
# list_h2.append("Reviewer Acknowledgements")

# JMRI Vol 54 No 6
# list_h2.insert(2, "ISMRM Young Investigator Award Winners")

# JMRI Vol 55 No 1 Pop out a few more
list_h2 = list_h2[:-2]

for l in list_h2:
  print(l)
print(len(list_h2))
# Out:
# A Comparative Study of Amide Proton Transfer Weighted Imaging and Intravoxel Incoherent Motion MRI Techniques Versus (18) F-FDG PET to Distinguish Solitary Pulmonary Lesions and Their Subtypes
# Issue Information
# Magnetic Resonance Iron Imaging in Amyotrophic Lateral Sclerosis
# Four-Dimensional Flow Magnetic Resonance Imaging in the Assessment of Blood Flow in the Heart and Great Vessels: A Systematic Review
# Magnetic Resonance Imaging During a Pandemic: Recommendations by the ISMRM Safety Committee
# Compressed Sensing in Sodium Magnetic Resonance Imaging: Techniques, Applications, and Future Prospects
# An Update in Imaging Evaluation of Histopathological Grade of Soft Tissue Sarcomas Using Structural and Quantitative Imaging and Radiomics
# A Comparative Study of Amide Proton Transfer Weighted Imaging and Intravoxel Incoherent Motion MRI Techniques Versus (18) F-FDG PET to Distinguish Solitary Pulmonary Lesions and Their Subtypes
# Editorial for “A Comparative Study of Amide Proton Transfer Weighted Imaging (APTw) and Intravoxel Incoherent Motion (IVIM) MRI Techniques and (18) F-FDG PET to Distinguish Solitary Pulmonary Lesions and Their Subtypes”
# Perfusion Analysis of Kidney Injury in Rats With Cirrhosis Induced by Common Bile Duct Ligation Using Arterial Spin Labeling MRI
# Editorial for “Perfusion Analysis of Kidney Injury in Rats With Cirrhosis Induced by Common Bile Duct Ligation Using Arterial Spin Labeling MRI”
# Hepatic Iron Quantification Using a Free-Breathing 3D Radial Gradient Echo Technique and Validation With a 2D Biopsy-Calibrated R2* Relaxometry Method
# Editorial for “Hepatic Iron Quantification Using a Free-Breathing 3D Radial Gradient Echo Technique and Validation with a 2D Biopsy-Calibrated R2* Relaxometry Method”
# Effects of B1+ Heterogeneity on Spin Echo-Based Liver Iron Estimates
# Editorial for “Effects of B1 Heterogeneity on Spin Echo-Based Liver Iron Estimates”
# A General Model to Calculate the Spin–Lattice Relaxation Rate (R1) of Blood, Accounting for Hematocrit, Oxygen Saturation, Oxygen Partial Pressure, and Magnetic Field Strength Under Hyperoxic Conditions
# Perfusion and Permeability MRI Predicts Future Cavernous Angioma Hemorrhage and Growth
# Editorial for “Perfusion and Permeability Magnetic Resonance Imaging (MRI) Predicts Future Cavernous Angioma Hemorrhage and Growth”
# Right/Left Ventricular Blood Pool T2 Ratio as an Innovative Cardiac MRI Screening Tool for the Identification of Left-to-Right Shunts in Patients With Right Ventricular Disease
# Editorial for: “Right/Left Ventricular Blood Pool T2 Ratio as an Innovative Cardiac MRI Screening Tool for the Identification of Left-to-Right Shunts in Patients with Right Ventricular Disease”
# Impact of BMI on Left Atrial Strain and Abnormal Atrioventricular Interaction in Patients With Type 2 Diabetes Mellitus: A Cardiac Magnetic Resonance Feature Tracking Study
# Editorial for “Impact of BMI on Left Atrial Strain and Abnormal Atrioventricular Interaction in Patients With Type 2 Diabetes Mellitus: A Cardiac Magnetic Resonance Feature Tracking Study”
# Diverse Right Ventricular Remodeling Evaluated by MRI and Prognosis in Eisenmenger Syndrome With Different Shunt Locations
# Editorial for “Diverse Right Ventricular Remodelling Evaluated by Cardiac Magnetic Resonance Imaging and Prognosis in Eisenmenger Syndrome with Different Shunt Locations”
# Radiomic Features on Multiparametric MRI for Preoperative Evaluation of Pituitary Macroadenomas Consistency: Preliminary Findings
# A Comparison of 3 T and 7 T MRI for the Clinical Evaluation of Uveal Melanoma
# Editorial for “A Comparison of 3T and 7T MRI for the Clinical Evaluation of Uveal Melanoma”
# Transfer Learning Strategy Based on Unsupervised Learning and Ensemble Learning for Breast Cancer Molecular Subtype Prediction Using Dynamic Contrast-Enhanced MRI
# Editorial for “Transfer Learning Strategy Based on Unsupervised Learning and Ensemble Learning for Breast Cancer Molecular Subtype Prediction Using Dynamic Contrast Enhanced MRI”
# Q-Dixon and GRAPPATINI T2 Mapping Parameters: A Whole Spinal Assessment of the Relationship Between Osteoporosis and Intervertebral Disc Degeneration
# Editorial for “Q-Dixon and GRAPPATINI T2 Mapping Parameters: A Whole Spinal Assessment of the Relationships Between Osteoporosis and Intervertebral Disc Degeneration”
# Editorial for “Device for Assessing Knee Joint Dynamics During MR Imaging”
# Imaging Blood–Brain Barrier Permeability Through MRI in Pediatric Sickle Cell Disease: A Feasibility Study
# Improved Assessment of Longitudinal Spinal Cord Atrophy in Multiple Sclerosis Using a Registration-Based Approach: Relevance for Clinical Studies
# Editorial for “Improved Assessment of Longitudinal Spinal Cord Atrophy in Multiple Sclerosis Using a Registration-Based Approach: Relevance for Clinical Studies”
# Optimal Diffusion Gradient Encoding Scheme for Diffusion Tensor Imaging Based on Golden Ratio
# Editorial for “Optimal Diffusion Gradient Encoding Scheme for Diffusion Tensor Imaging Based on Golden Ratio”
# Editorial for “Cross-Scanner Harmonization of Neuromelanin-Sensitive MRI for Multisite Studies”
# 38

# %% [markdown]
# ### Add dates first published

# %%
# li class: corresponds to "First Published"

all_li = soupJMRI.find_all("li")

# i = 0
# for li in all_li:
  # li_class = li.get_attribute_list("class")
  # print(li_class)
  # if li_class == ['ePubDate']:
    # print(li.get_text())
    # i += 1
  # print(li.get_text())
  # i += 1
# print(i)

list_date = []
for li in all_li:
  li_class = li.get_attribute_list("class")
  if li_class == ['ePubDate']:
    cells = li.get_text().split(': ')[1]
    list_date.append(cells)

for l in list_date:
  print(l)
print(len(list_date))
# Out:
# 15 April 2022
# 15 April 2022
# 15 February 2021
# 20 August 2021
# 20 December 2021
# 17 December 2021
# 12 October 2021
# 01 November 2021
# 10 November 2021
# 09 September 2021
# 01 October 2021
# 20 September 2021
# 14 September 2021
# 23 September 2021
# 16 September 2021
# 01 October 2021
# 24 September 2021
# 29 September 2021
# 10 August 2021
# 06 August 2021
# 22 September 2021
# 06 November 2021
# 21 June 2021
# 23 June 2021
# 22 September 2021
# 15 October 2021
# 03 October 2021
# 20 October 2021
# 14 October 2021
# 19 October 2021
# 14 October 2021
# 29 November 2021
# 22 October 2021
# 28 September 2021
# 15 October 2021
# 30 September 2021
# 01 October 2021
# 18 September 2021
# 38

# %%
list_url = []
for link in all_links:
  if 'visitable' in str(link.get("class")): # and '/doi/' in link.get("href"):
    cells = link.get("href").replace('/doi', 'https://doi.org')
    list_url.append(cells)

for l in list_url:
  print(l)
print(len(list_url))
# Out:
# https://doi.org/10.1002/jmri.27712
# https://doi.org/10.1002/jmri.27713
# https://doi.org/10.1002/jmri.27530
# https://doi.org/10.1002/jmri.27874
# https://doi.org/10.1002/jmri.28006
# https://doi.org/10.1002/jmri.28029
# https://doi.org/10.1002/jmri.27954
# https://doi.org/10.1002/jmri.27977
# https://doi.org/10.1002/jmri.27987
# https://doi.org/10.1002/jmri.27917
# https://doi.org/10.1002/jmri.27947
# https://doi.org/10.1002/jmri.27921
# https://doi.org/10.1002/jmri.27904
# https://doi.org/10.1002/jmri.27928
# https://doi.org/10.1002/jmri.27667
# https://doi.org/10.1002/jmri.27938
# https://doi.org/10.1002/jmri.27935
# https://doi.org/10.1002/jmri.27944
# https://doi.org/10.1002/jmri.27881
# https://doi.org/10.1002/jmri.27880
# https://doi.org/10.1002/jmri.27931
# https://doi.org/10.1002/jmri.27973
# https://doi.org/10.1002/jmri.27791
# https://doi.org/10.1002/jmri.27799
# https://doi.org/10.1002/jmri.27930
# https://doi.org/10.1002/jmri.27939
# https://doi.org/10.1002/jmri.27941
# https://doi.org/10.1002/jmri.27955
# https://doi.org/10.1002/jmri.27957
# https://doi.org/10.1002/jmri.27959
# https://doi.org/10.1002/jmri.27960
# https://doi.org/10.1002/jmri.27998
# https://doi.org/10.1002/jmri.27965
# https://doi.org/10.1002/jmri.27937
# https://doi.org/10.1002/jmri.27958
# https://doi.org/10.1002/jmri.27943
# https://doi.org/10.1002/jmri.27946
# https://doi.org/10.1002/jmri.27924
# 38

# %%
# df = pd.DataFrame({'title':list_h2, 'url': list_url})
df = pd.DataFrame({'Journal': title, 
                   #'Category': list_category, 
                   'Title': list_h2, 
                   'First Published': list_date, 
                   'DOI': list_url})
df
# Out:
#                                               Journal  \
# 0    Journal of Magnetic Resonance Imaging: Vol 55...
# 1    Journal of Magnetic Resonance Imaging: Vol 55...
# 2    Journal of Magnetic Resonance Imaging: Vol 55...
# 3    Journal of Magnetic Resonance Imaging: Vol 55...
# 4    Journal of Magnetic Resonance Imaging: Vol 55...
# 5    Journal of Magnetic Resonance Imaging: Vol 55...
# 6    Journal of Magnetic Resonance Imaging: Vol 55...
# 7    Journal of Magnetic Resonance Imaging: Vol 55...
# 8    Journal of Magnetic Resonance Imaging: Vol 55...
# 9    Journal of Magnetic Resonance Imaging: Vol 55...
# 10   Journal of Magnetic Resonance Imaging: Vol 55...
# 11   Journal of Magnetic Resonance Imaging: Vol 55...
# 12   Journal of Magnetic Resonance Imaging: Vol 55...
# 13   Journal of Magnetic Resonance Imaging: Vol 55...
# 14   Journal of Magnetic Resonance Imaging: Vol 55...
# 15   Journal of Magnetic Resonance Imaging: Vol 55...
# 16   Journal of Magnetic Resonance Imaging: Vol 55...
# 17   Journal of Magnetic Resonance Imaging: Vol 55...
# 18   Journal of Magnetic Resonance Imaging: Vol 55...
# 19   Journal of Magnetic Resonance Imaging: Vol 55...
# 20   Journal of Magnetic Resonance Imaging: Vol 55...
# 21   Journal of Magnetic Resonance Imaging: Vol 55...
# 22   Journal of Magnetic Resonance Imaging: Vol 55...
# 23   Journal of Magnetic Resonance Imaging: Vol 55...
# 24   Journal of Magnetic Resonance Imaging: Vol 55...
# 25   Journal of Magnetic Resonance Imaging: Vol 55...
# 26   Journal of Magnetic Resonance Imaging: Vol 55...
# 27   Journal of Magnetic Resonance Imaging: Vol 55...
# 28   Journal of Magnetic Resonance Imaging: Vol 55...
# 29   Journal of Magnetic Resonance Imaging: Vol 55...
# 30   Journal of Magnetic Resonance Imaging: Vol 55...
# 31   Journal of Magnetic Resonance Imaging: Vol 55...
# 32   Journal of Magnetic Resonance Imaging: Vol 55...
# 33   Journal of Magnetic Resonance Imaging: Vol 55...
# 34   Journal of Magnetic Resonance Imaging: Vol 55...
# 35   Journal of Magnetic Resonance Imaging: Vol 55...
# 36   Journal of Magnetic Resonance Imaging: Vol 55...
# 37   Journal of Magnetic Resonance Imaging: Vol 55...
#
#                                                 Title    First Published  \
# 0   A Comparative Study of Amide Proton Transfer W...      15 April 2022
# 1                                   Issue Information      15 April 2022
# 2   Magnetic Resonance Iron Imaging in Amyotrophic...   15 February 2021
# 3   Four-Dimensional Flow Magnetic Resonance Imagi...     20 August 2021
# 4   Magnetic Resonance Imaging During a Pandemic: ...   20 December 2021
# 5   Compressed Sensing in Sodium Magnetic Resonanc...   17 December 2021
# 6   An Update in Imaging Evaluation of Histopathol...    12 October 2021
# 7   A Comparative Study of Amide Proton Transfer W...   01 November 2021
# 8   Editorial for “A Comparative Study of Amide Pr...   10 November 2021
# 9   Perfusion Analysis of Kidney Injury in Rats Wi...  09 September 2021
# 10  Editorial for “Perfusion Analysis of Kidney In...    01 October 2021
# 11  Hepatic Iron Quantification Using a Free-Breat...  20 September 2021
# 12  Editorial for “Hepatic Iron Quantification Usi...  14 September 2021
# 13  Effects of B1+ Heterogeneity on Spin Echo-Base...  23 September 2021
# 14  Editorial for “Effects of B1 Heterogeneity on ...  16 September 2021
# 15  A General Model to Calculate the Spin–Lattice ...    01 October 2021
# 16  Perfusion and Permeability MRI Predicts Future...  24 September 2021
# 17  Editorial for “Perfusion and Permeability Magn...  29 September 2021
# 18  Right/Left Ventricular Blood Pool T2 Ratio as ...     10 August 2021
# 19  Editorial for: “Right/Left Ventricular Blood P...     06 August 2021
# 20  Impact of BMI on Left Atrial Strain and Abnorm...  22 September 2021
# 21  Editorial for “Impact of BMI on Left Atrial St...   06 November 2021
# 22  Diverse Right Ventricular Remodeling Evaluated...       21 June 2021
# 23  Editorial for “Diverse Right Ventricular Remod...       23 June 2021
# 24  Radiomic Features on Multiparametric MRI for P...  22 September 2021
# 25  A Comparison of 3 T and 7 T MRI for the Clinic...    15 October 2021
# 26  Editorial for “A Comparison of 3T and 7T MRI f...    03 October 2021
# 27  Transfer Learning Strategy Based on Unsupervis...    20 October 2021
# 28  Editorial for “Transfer Learning Strategy Base...    14 October 2021
# 29  Q-Dixon and GRAPPATINI T2 Mapping Parameters: ...    19 October 2021
# 30  Editorial for “Q-Dixon and GRAPPATINI T2 Mappi...    14 October 2021
# 31  Editorial for “Device for Assessing Knee Joint...   29 November 2021
# 32  Imaging Blood–Brain Barrier Permeability Throu...    22 October 2021
# 33  Improved Assessment of Longitudinal Spinal Cor...  28 September 2021
# 34  Editorial for “Improved Assessment of Longitud...    15 October 2021
# 35  Optimal Diffusion Gradient Encoding Scheme for...  30 September 2021
# 36  Editorial for “Optimal Diffusion Gradient Enco...    01 October 2021
# 37  Editorial for “Cross-Scanner Harmonization of ...  18 September 2021
#
#                                    DOI
# 0   https://doi.org/10.1002/jmri.27712
# 1   https://doi.org/10.1002/jmri.27713
# 2   https://doi.org/10.1002/jmri.27530
# 3   https://doi.org/10.1002/jmri.27874
# 4   https://doi.org/10.1002/jmri.28006
# 5   https://doi.org/10.1002/jmri.28029
# 6   https://doi.org/10.1002/jmri.27954
# 7   https://doi.org/10.1002/jmri.27977
# 8   https://doi.org/10.1002/jmri.27987
# 9   https://doi.org/10.1002/jmri.27917
# 10  https://doi.org/10.1002/jmri.27947
# 11  https://doi.org/10.1002/jmri.27921
# 12  https://doi.org/10.1002/jmri.27904
# 13  https://doi.org/10.1002/jmri.27928
# 14  https://doi.org/10.1002/jmri.27667
# 15  https://doi.org/10.1002/jmri.27938
# 16  https://doi.org/10.1002/jmri.27935
# 17  https://doi.org/10.1002/jmri.27944
# 18  https://doi.org/10.1002/jmri.27881
# 19  https://doi.org/10.1002/jmri.27880
# 20  https://doi.org/10.1002/jmri.27931
# 21  https://doi.org/10.1002/jmri.27973
# 22  https://doi.org/10.1002/jmri.27791
# 23  https://doi.org/10.1002/jmri.27799
# 24  https://doi.org/10.1002/jmri.27930
# 25  https://doi.org/10.1002/jmri.27939
# 26  https://doi.org/10.1002/jmri.27941
# 27  https://doi.org/10.1002/jmri.27955
# 28  https://doi.org/10.1002/jmri.27957
# 29  https://doi.org/10.1002/jmri.27959
# 30  https://doi.org/10.1002/jmri.27960
# 31  https://doi.org/10.1002/jmri.27998
# 32  https://doi.org/10.1002/jmri.27965
# 33  https://doi.org/10.1002/jmri.27937
# 34  https://doi.org/10.1002/jmri.27958
# 35  https://doi.org/10.1002/jmri.27943
# 36  https://doi.org/10.1002/jmri.27946
# 37  https://doi.org/10.1002/jmri.27924

# %% [markdown]
# ## Third, manually create the list of category based on Issue Information
#  - See [here](https://stackoverflow.com/questions/4654414/python-append-item-to-list-n-times) for extending elements in a list for X times

# %%
# list_category = ['Cover Image', 'Issue Information', 'Commentary']

### Vol 55 No 1 ###
# list_category = ['Cover Image', 'Issue Information']
# list_category.extend(['JMRI-ISMRM Recommendation'] * 1)
# list_category.extend(['Review Articles'] * 5)
# list_category.extend(['Original Research: Abdomen'] * 2)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 1)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 4)
# list_category.extend(['Original Research: Cardiac', 'Editorial'] * 3)
# list_category.extend(['Original Research: Musculoskeletal'] * 1)
# list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 1)
# list_category.extend(['Original Research: Vascular'] * 1)
# list_category.extend(['Original Research: Pelvis'] * 2)
# list_category.extend(['Original Research: Pelvis', 'Editorial'] * 1)
# list_category.extend(['Original Research: Technical'] * 1)
# list_category.extend(['Original Research: Technical', 'Editorial'] * 1)

### Vol 55 No 2 ###
# list_category = ['Cover Image', 'Issue Information']
# list_category.extend(['JMRI-ISMRM Recommendation'] * 2)
# list_category.extend(['Review Articles'] * 5)
# list_category.extend(['Original Research: Head and Neck'] * 1)
# list_category.extend(['Original Research: Neuro'] * 3)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 1)
# list_category.extend(['Original Research: Pelvis', 'Editorial'] * 2)
# list_category.extend(['Original Research: Abdomen'] * 2)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 2)
# list_category.extend(['Original Research: Pediatrics', 'Editorial'] * 1)
# list_category.extend(['Original Research: Cardiac', 'Editorial'] * 3)
# list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 2)
# list_category.extend(['Letter to the Editor'] * 1)

### Vol 55 No 3 ###
# list_category = ['Cover Image', 'Issue Information']
# list_category.extend(['CME Article'] * 1)
# list_category.extend(['Review Articles'] * 5)
# list_category.extend(['Original Research: Breast', 'Editorial'] * 1)
# list_category.extend(['Original Research: Abdomen'] * 3)
# list_category.extend(['Original Research: Abdomen', 'Editorial'] * 1)
# list_category.extend(['Original Research: Technical'] * 1)
# list_category.extend(['Original Research: Cardiac'] * 1)
# list_category.extend(['Original Research: Cardiac', 'Editorial'] * 2)
# list_category.extend(['Original Research: Musculoskeletal'] * 1)
# list_category.extend(['Original Research: Neuro'] * 1)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 2)
# list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)

### Vol 55 No 4 ###
# list_category = ['Cover Image', 'Issue Information']
# list_category.extend(['CME Article'] * 1)
# list_category.extend(['Review Articles'] * 5)
# list_category.extend(['Original Research: Head and Neck', 'Editorial'] * 2)
# list_category.extend(['Original Research: Cardiac'] * 1)
# list_category.extend(['Original Research: Cardiac', 'Editorial'] * 1)
# list_category.extend(['Original Research: Whole Body'] * 1)
# list_category.extend(['Original Research: Neuro'] * 2)
# list_category.extend(['Original Research: Neuro', 'Editorial'] * 3)
# list_category.extend(['Original Research: Chest', 'Editorial'] * 1)
# list_category.extend(['Original Research: Musculoskeletal'] * 1)
# list_category.extend(['Original Research: Abdomen'] * 4)
# list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)

### Vol 55 No 5 ###
list_category = ['Cover Image', 'Issue Information']
list_category.extend(['Review Articles'] * 5)
list_category.extend(['Original Research: Chest', 'Editorial'] * 1)
list_category.extend(['Original Research: Abdomen'] * 2)
list_category.extend(['Original Research: Abdomen', 'Editorial'] * 2)
list_category.extend(['Original Research: Vascular'] * 1)
list_category.extend(['Original Research: Vascular', 'Editorial'] * 1)
list_category.extend(['Original Research: Cardiac', 'Editorial'] * 3)
list_category.extend(['Original Research: Head and Neck'] * 1)
list_category.extend(['Original Research: Head and Neck', 'Editorial'] * 1)
list_category.extend(['Original Research: Breast', 'Editorial'] * 1)
list_category.extend(['Original Research: Musculoskeletal', 'Editorial'] * 1)
list_category.extend(['Editorial'] * 1)
list_category.extend(['Original Research: Neuro'] * 1)
list_category.extend(['Original Research: Neuro', 'Editorial'] * 2)
list_category.extend(['Editorial'] * 1)

i = 0
for l in list_category:
  print(l)
  i += 1
print(i)
# Out:
# Cover Image
# Issue Information
# Review Articles
# Review Articles
# Review Articles
# Review Articles
# Review Articles
# Original Research: Chest
# Editorial
# Original Research: Abdomen
# Original Research: Abdomen
# Original Research: Abdomen
# Editorial
# Original Research: Abdomen
# Editorial
# Original Research: Vascular
# Original Research: Vascular
# Editorial
# Original Research: Cardiac
# Editorial
# Original Research: Cardiac
# Editorial
# Original Research: Cardiac
# Editorial
# Original Research: Head and Neck
# Original Research: Head and Neck
# Editorial
# Original Research: Breast
# Editorial
# Original Research: Musculoskeletal
# Editorial
# Editorial
# Original Research: Neuro
# Original Research: Neuro
# Editorial
# Original Research: Neuro
# Editorial
# Editorial
# 38

# %%
df.insert(1, 'Category', list_category)
df
# Out:
#                                               Journal  \
# 0    Journal of Magnetic Resonance Imaging: Vol 55...
# 1    Journal of Magnetic Resonance Imaging: Vol 55...
# 2    Journal of Magnetic Resonance Imaging: Vol 55...
# 3    Journal of Magnetic Resonance Imaging: Vol 55...
# 4    Journal of Magnetic Resonance Imaging: Vol 55...
# 5    Journal of Magnetic Resonance Imaging: Vol 55...
# 6    Journal of Magnetic Resonance Imaging: Vol 55...
# 7    Journal of Magnetic Resonance Imaging: Vol 55...
# 8    Journal of Magnetic Resonance Imaging: Vol 55...
# 9    Journal of Magnetic Resonance Imaging: Vol 55...
# 10   Journal of Magnetic Resonance Imaging: Vol 55...
# 11   Journal of Magnetic Resonance Imaging: Vol 55...
# 12   Journal of Magnetic Resonance Imaging: Vol 55...
# 13   Journal of Magnetic Resonance Imaging: Vol 55...
# 14   Journal of Magnetic Resonance Imaging: Vol 55...
# 15   Journal of Magnetic Resonance Imaging: Vol 55...
# 16   Journal of Magnetic Resonance Imaging: Vol 55...
# 17   Journal of Magnetic Resonance Imaging: Vol 55...
# 18   Journal of Magnetic Resonance Imaging: Vol 55...
# 19   Journal of Magnetic Resonance Imaging: Vol 55...
# 20   Journal of Magnetic Resonance Imaging: Vol 55...
# 21   Journal of Magnetic Resonance Imaging: Vol 55...
# 22   Journal of Magnetic Resonance Imaging: Vol 55...
# 23   Journal of Magnetic Resonance Imaging: Vol 55...
# 24   Journal of Magnetic Resonance Imaging: Vol 55...
# 25   Journal of Magnetic Resonance Imaging: Vol 55...
# 26   Journal of Magnetic Resonance Imaging: Vol 55...
# 27   Journal of Magnetic Resonance Imaging: Vol 55...
# 28   Journal of Magnetic Resonance Imaging: Vol 55...
# 29   Journal of Magnetic Resonance Imaging: Vol 55...
# 30   Journal of Magnetic Resonance Imaging: Vol 55...
# 31   Journal of Magnetic Resonance Imaging: Vol 55...
# 32   Journal of Magnetic Resonance Imaging: Vol 55...
# 33   Journal of Magnetic Resonance Imaging: Vol 55...
# 34   Journal of Magnetic Resonance Imaging: Vol 55...
# 35   Journal of Magnetic Resonance Imaging: Vol 55...
# 36   Journal of Magnetic Resonance Imaging: Vol 55...
# 37   Journal of Magnetic Resonance Imaging: Vol 55...
#
#                               Category  \
# 0                          Cover Image
# 1                    Issue Information
# 2                      Review Articles
# 3                      Review Articles
# 4                      Review Articles
# 5                      Review Articles
# 6                      Review Articles
# 7             Original Research: Chest
# 8                            Editorial
# 9           Original Research: Abdomen
# 10          Original Research: Abdomen
# 11          Original Research: Abdomen
# 12                           Editorial
# 13          Original Research: Abdomen
# 14                           Editorial
# 15         Original Research: Vascular
# 16         Original Research: Vascular
# 17                           Editorial
# 18          Original Research: Cardiac
# 19                           Editorial
# 20          Original Research: Cardiac
# 21                           Editorial
# 22          Original Research: Cardiac
# 23                           Editorial
# 24    Original Research: Head and Neck
# 25    Original Research: Head and Neck
# 26                           Editorial
# 27           Original Research: Breast
# 28                           Editorial
# 29  Original Research: Musculoskeletal
# 30                           Editorial
# 31                           Editorial
# 32            Original Research: Neuro
# 33            Original Research: Neuro
# 34                           Editorial
# 35            Original Research: Neuro
# 36                           Editorial
# 37                           Editorial
#
#                                                 Title    First Published  \
# 0   A Comparative Study of Amide Proton Transfer W...      15 April 2022
# 1                                   Issue Information      15 April 2022
# 2   Magnetic Resonance Iron Imaging in Amyotrophic...   15 February 2021
# 3   Four-Dimensional Flow Magnetic Resonance Imagi...     20 August 2021
# 4   Magnetic Resonance Imaging During a Pandemic: ...   20 December 2021
# 5   Compressed Sensing in Sodium Magnetic Resonanc...   17 December 2021
# 6   An Update in Imaging Evaluation of Histopathol...    12 October 2021
# 7   A Comparative Study of Amide Proton Transfer W...   01 November 2021
# 8   Editorial for “A Comparative Study of Amide Pr...   10 November 2021
# 9   Perfusion Analysis of Kidney Injury in Rats Wi...  09 September 2021
# 10  Editorial for “Perfusion Analysis of Kidney In...    01 October 2021
# 11  Hepatic Iron Quantification Using a Free-Breat...  20 September 2021
# 12  Editorial for “Hepatic Iron Quantification Usi...  14 September 2021
# 13  Effects of B1+ Heterogeneity on Spin Echo-Base...  23 September 2021
# 14  Editorial for “Effects of B1 Heterogeneity on ...  16 September 2021
# 15  A General Model to Calculate the Spin–Lattice ...    01 October 2021
# 16  Perfusion and Permeability MRI Predicts Future...  24 September 2021
# 17  Editorial for “Perfusion and Permeability Magn...  29 September 2021
# 18  Right/Left Ventricular Blood Pool T2 Ratio as ...     10 August 2021
# 19  Editorial for: “Right/Left Ventricular Blood P...     06 August 2021
# 20  Impact of BMI on Left Atrial Strain and Abnorm...  22 September 2021
# 21  Editorial for “Impact of BMI on Left Atrial St...   06 November 2021
# 22  Diverse Right Ventricular Remodeling Evaluated...       21 June 2021
# 23  Editorial for “Diverse Right Ventricular Remod...       23 June 2021
# 24  Radiomic Features on Multiparametric MRI for P...  22 September 2021
# 25  A Comparison of 3 T and 7 T MRI for the Clinic...    15 October 2021
# 26  Editorial for “A Comparison of 3T and 7T MRI f...    03 October 2021
# 27  Transfer Learning Strategy Based on Unsupervis...    20 October 2021
# 28  Editorial for “Transfer Learning Strategy Base...    14 October 2021
# 29  Q-Dixon and GRAPPATINI T2 Mapping Parameters: ...    19 October 2021
# 30  Editorial for “Q-Dixon and GRAPPATINI T2 Mappi...    14 October 2021
# 31  Editorial for “Device for Assessing Knee Joint...   29 November 2021
# 32  Imaging Blood–Brain Barrier Permeability Throu...    22 October 2021
# 33  Improved Assessment of Longitudinal Spinal Cor...  28 September 2021
# 34  Editorial for “Improved Assessment of Longitud...    15 October 2021
# 35  Optimal Diffusion Gradient Encoding Scheme for...  30 September 2021
# 36  Editorial for “Optimal Diffusion Gradient Enco...    01 October 2021
# 37  Editorial for “Cross-Scanner Harmonization of ...  18 September 2021
#
#                                    DOI
# 0   https://doi.org/10.1002/jmri.27712
# 1   https://doi.org/10.1002/jmri.27713
# 2   https://doi.org/10.1002/jmri.27530
# 3   https://doi.org/10.1002/jmri.27874
# 4   https://doi.org/10.1002/jmri.28006
# 5   https://doi.org/10.1002/jmri.28029
# 6   https://doi.org/10.1002/jmri.27954
# 7   https://doi.org/10.1002/jmri.27977
# 8   https://doi.org/10.1002/jmri.27987
# 9   https://doi.org/10.1002/jmri.27917
# 10  https://doi.org/10.1002/jmri.27947
# 11  https://doi.org/10.1002/jmri.27921
# 12  https://doi.org/10.1002/jmri.27904
# 13  https://doi.org/10.1002/jmri.27928
# 14  https://doi.org/10.1002/jmri.27667
# 15  https://doi.org/10.1002/jmri.27938
# 16  https://doi.org/10.1002/jmri.27935
# 17  https://doi.org/10.1002/jmri.27944
# 18  https://doi.org/10.1002/jmri.27881
# 19  https://doi.org/10.1002/jmri.27880
# 20  https://doi.org/10.1002/jmri.27931
# 21  https://doi.org/10.1002/jmri.27973
# 22  https://doi.org/10.1002/jmri.27791
# 23  https://doi.org/10.1002/jmri.27799
# 24  https://doi.org/10.1002/jmri.27930
# 25  https://doi.org/10.1002/jmri.27939
# 26  https://doi.org/10.1002/jmri.27941
# 27  https://doi.org/10.1002/jmri.27955
# 28  https://doi.org/10.1002/jmri.27957
# 29  https://doi.org/10.1002/jmri.27959
# 30  https://doi.org/10.1002/jmri.27960
# 31  https://doi.org/10.1002/jmri.27998
# 32  https://doi.org/10.1002/jmri.27965
# 33  https://doi.org/10.1002/jmri.27937
# 34  https://doi.org/10.1002/jmri.27958
# 35  https://doi.org/10.1002/jmri.27943
# 36  https://doi.org/10.1002/jmri.27946
# 37  https://doi.org/10.1002/jmri.27924

# %% [markdown]
# ## Save as csv

# %%
df.to_csv(path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri/jmri-vol-55-no-5.csv',
          # path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri/jmri-vol-55-no-4.csv',
          #path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri/jmri-vol-55-no-3.csv',
          #path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri/jmri-vol-55-no-2.csv',
          #path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri/jmri-vol-55-no-1.csv',
          index=False)

# %% [markdown]
# ## Save as xlsx file
#  - See [here](https://xlsxwriter.readthedocs.io/working_with_pandas.html) for instruction

# %%
# !pip install xlsxwriter
import xlsxwriter

# (Comment out after saving first sheet) Create an ExcelWriter object
# writer = pd.ExcelWriter('/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-all-summary.xlsx', engine='xlsxwriter')

# %%
df.to_excel(excel_writer=writer,
            # sheet_name='jmri-vol-54-no-1',
            # sheet_name='jmri-vol-54-no-2',
            sheet_name='jmri-vol-54-no-3',
            index=False)

# %%
# (Uncomment at the end) Close the Pandas Excel writer and output the Excel file.
writer.save()
