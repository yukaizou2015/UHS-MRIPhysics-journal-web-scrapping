# %% [markdown]
# # Web Scraping using Python

# %% [markdown]
# ## Target Journal: MRM
#
# - https://onlinelibrary.wiley.com/toc/15222594/2021/86/4
# - https://onlinelibrary.wiley.com/toc/15222594/2021/86/3
# - https://onlinelibrary.wiley.com/toc/15222594/2021/86/2
# - https://onlinelibrary.wiley.com/toc/15222594/2021/86/1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#To easily display the plots, make sure to include the line %matplotlib inline as shown below.
# %matplotlib inline

import urllib
import requests
import lxml

#To perform web scraping, you should also import the libraries shown below. 
#The urllib.request module is used to open URLs. 
#The Beautiful Soup package is used to extract data from html files. 
#The Beautiful Soup library's name is bs4 which stands for Beautiful Soup, version 4.
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ## First, save as a local html file
#  - See: https://zetcode.com/python/beautifulsoup/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# MRM Vol 86 No 2
URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Magnetic Resonance in Medicine_ Vol 86, No 2.html'
# MRM Vol 86 No 4
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Magnetic Resonance in Medicine_ Vol 86, No 4.html'

with open(URL, 'r') as f:

    contents = f.read()

    soup = BeautifulSoup(contents, 'lxml')

# %% [markdown]
# Find the corresponding index, and identify the title info

# %%
def safeOpenParsePage(targetUrl):
    try:
        # tmpurl = urlopen(Request(targetUrl, headers={'User-Agent': 'Chrome/92.0.4515.107'}))
        tmpurl = open(targetUrl, 'r')
        tmpR = tmpurl.read()
        # tmpSoup = BeautifulSoup(tmpR, 'html.parser')
        tmpSoup = BeautifulSoup(tmpR, 'lxml')
        return tmpSoup
    except urllib.error.HTTPError as e:
        print(e)
        return None

soupMRM = safeOpenParsePage(URL)
if soupMRM is not None:
      print(soupMRM.prettify())
# Out:
# <!DOCTYPE html>
# <html class="pb-page" data-request-id="60e18eb4-26e3-4638-9f3a-ccad28e4f47d" lang="en">
#  <head data-pb-dropzone="head">
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content=";journal:journal:15222594;ctype:string:Journal Content;website:website:pericles;requestedJournal:journal:15222594;page:string:Table of Contents;wgroup:string:Publication Websites;issue:issue:doi\:10.1002/mrm.v86.2;pageGroup:string:Publication Pages" name="pbContext"/>
#   <script type="text/javascript">
#    var $DoubleClickZone = "magres-med_mrm";var $DoubleClickSite =  "wly.radiol.imag_000105";
#   </script>
#   <script id="analyticDigitalData">
#    digitalData = {}
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="noarchive" name="robots"/>
#   <meta content=" Magnetic Resonance in Medicine: Vol 86, No 2" property="og:title"/>
#   <meta content="Journal" property="og:type"/>
#   <meta content="https://onlinelibrary.wiley.com/toc/15222594/2021/86/2" property="og:url"/>
#   <meta content="https://onlinelibrary.wiley.com/cover/15222594/86/2" property="og:image"/>
#   <meta content="Wiley Online Library" property="og:site_name"/>
#   <meta content="Click on the title to browse this issue" property="og:description"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="app-id=673865417" name="apple-itunes-app"/>
#   <meta content="10.1002/mrm.v86.2" name="citation_doi"/>
#   <meta content="10.1002/mrm.v86.2" name="dc.identifier"/>
#   <title>
#    Magnetic Resonance in Medicine: Vol 86, No 2
#   </title>
#   <link href="/wro/kkrk~product.css" rel="stylesheet" type="text/css"/>
#   <style>
#    @font-face {
#     font-family: 'Open Sans Subset';
#     font-display: swap;
#     src: local('Muli Regular'), local('Muli-Regular'),
#     url(data:application/font-woff;charset=utf-8;base64,...) format('woff');
# }
#   </style>
#   <link href="/products/acropolis/pericles/releasedAssets/css/build-792a8b1af6e6bb721709.css" rel="stylesheet"/>
#   <link href="/products/acropolis/pericles/releasedAssets/css/print-792a8b1af6e6bb721709.css" media="print" rel="stylesheet"/>
#   <script async="" src="/pb-assets/catchpoint-1549680351760.js">
#   </script>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/pb-assets/hub-assets/pericles/hub-1628068886633.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/iucr-1510734465460.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/readcube-1510565373110.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/dr-overrides-1611780866727.css" rel="stylesheet" type="text/css"/>
#   <!-- link rel="stylesheet" type="text/css" href="/pb-assets/css/temporary-1525702334993.css" -->
#   <style>
#    /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#   </style>
#   <!-- The Adobe DTM script. Must come after the digitalData object -->
#   <script src="//assets.adobedtm.com/6e626c9ec247e474f6b98eb15a79a185cf7e26a5/satelliteLib-c1ac050bbdc647f13a62578e71f0d817f8a6cbb5.js">
#   </script>
#   <!-- Google Search Console verification -->
#   <meta content="ffz4i4DxIJCdGpRXe0XN6KG6o4FYI-nnFW9I_dg8piM" name="google-site-verification"/>
#   <!-- KRUX Implementation-->
#   <script class="kxct" data-id="JMOONjNh" data-timing="async" data-version="1.9" type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#   </script>
#   <!-- KRUX Implementation cont'd -->
#   <script type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#   </script>
#   <!-- Grapeshot Implementation -->
#   <script>
#    var gs_channels = 'default';
#   </script>
#   <script async="" src="//wiley.grapeshot.co.uk/main/channels.cgi?url=https://onlinelibrary.wiley.com/toc/15222594/2021/86/2">
#   </script>
#   <!-- DoubleClick Implementation -->
#   <script type="text/javascript">
#    var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#   </script>
#   <script>
#    var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#   </script>
#   <script>
#    googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/mrm.v86.2')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#   </script>
#   <script src="//validate.onecount.net/js/all.min.js#cff4b10c3a3d5cc9bbb7e2b9292cc66eae1deafa">
#   </script>
#   <script>
#    try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#   </script>
#   <script data-cf-beacon='{"rayId":"65604cf31ed0e4d9","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.1","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script data-cf-beacon='{"rayId":"65cb04cf2c4898e7","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script async="" src="/cdn-cgi/bm/cv/669835187/api.js">
#   </script>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#   </script>
#   <script data-cf-beacon='{"rayId":"65d1a8e0c92cd32a","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <link href="https://onlinelibrary.wiley.com/toc/15222594/2021/86/2" rel="canonical"/>
#   <!-- Get whether TNSI is in live or test mode -->
#   <!-- Get the configured TNSI Javascript version number -->
#   <!-- Get the configured TNSI MerchantID -->
#   <!-- Add "TEST" to beginning of merchant ID when running in test mode -->
#   <!-- loading Javascript for using the persistence Service -->
#   <script src="//unpkg.com/@theidentityselector/thiss-ds">
#   </script>
#   <script type="text/javascript">
#    function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf('?') !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId, entityTitle) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId, entityTitle: entityTitle, eventGroupKey: '04c7ce53-a4da-44cd-8522-dd5e30603c27'}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID, ssoInstitution.entity.title)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#   </script>
#   <script type="text/javascript">
#    (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaafcMozskKmV4AmBkxVx';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#   </script>
#   <script>
#    var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Magnetic Resonance in Medicine: Vol 86, No 2";
#   </script>
#  </head>
#  <body class="pb-ui">
#   <div class="skip-links">
#    <ul class="rlist">
#     <li>
#      <a href="#main-content" tabindex="1">
#       Skip to Main Content
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div data-ng-non-bindable="" id="pb-page-content">
#    <div data-pb-dropzone="main" data-pb-dropzone-name="Main">
#     <div class="pageHeader" data-widget-def="pageHeader" data-widget-id="62175478-b98a-43d5-90f2-1f2045ac1a7e">
#      <header class="page-header">
#       <div data-pb-dropzone="main">
#        <div class="admin-message" data-widget-def="ux3-layout-widget" data-widget-id="bb5b5e2c-d3d6-4015-b586-eeade38f59d4">
#         <div class="container">
#          <div class="row">
#           <div>
#            <div class="pb-ad">
#             <div style="background=blue;">
#              <div class="container">
#               <p style="text-align: center;">
#                We are upgrading Wiley Online Library over the weekend of September 11th–12th.
#                <br/>
#                All content will continue to be available, but some functionality may not work as expected. We apologize for any inconvenience this may cause.
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="container">
#         <div class="row">
#          <div class="contents col-md-12">
#           <div class="pull-left">
#            <div class="logo-container hidden-xs hidden-sm hidden-md" data-widget-def="ux3-general-image" data-widget-id="ff262197-0fb8-4973-aaa2-2fceba4b5a61">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mainLogo" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#             </a>
#            </div>
#            <div class="logo-container-mobile hidden-lg hidden-md hidden-sm" data-widget-def="ux3-general-image" data-widget-id="6b601b23-7301-47c8-8889-242d041241c4">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mobileLogo" src="/pb-assets/hub-assets/pericles/mobilehublogo-1518781861020.png"/>
#             </a>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="header-quicksearch" data-widget-def="UX3QuickSearchWidget" data-widget-id="48175bb0-0f70-46e6-bb89-7e2781fdb8e4">
#             <div class="quick-search-wrapper">
#              <a aria-label="Search" class="quick-search__item" href="#" title="search">
#               <i aria-hidden="true" class="icon-search">
#               </i>
#               <span class="quick-search__item__arrow">
#               </span>
#              </a>
#              <div class="quick-search quickSearchFormContainer" data-linkto-page="true">
#               <div class="main-search-field-wrapper">
#                <div class="tab clearfix">
#                 <input class="fakeQSInput quickSearchFilter" placeholder="Search" tabindex="13" type="search" value=""/>
#                 <label class="sr-only" for="search-within">
#                  Search within
#                 </label>
#                 <select class="search-within" id="search-within" name="search-within" tabindex="10">
#                  <option data-url="thisCategory" data-value="15222594" value="#pane-67065c09-4a88-49cd-934c-ac707951d35c0">
#                   This Journal
#                  </option>
#                  <option data-url="https://onlinelibrary.wiley.com" value="#pane-67065c09-4a88-49cd-934c-ac707951d35c1">
#                   Anywhere
#                  </option>
#                 </select>
#                 <ul class="rlist tab__content" role="tablist">
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c0-con" class="tab__pane quick-search-pane__anywhere active" id="pane-67065c09-4a88-49cd-934c-ac707951d35c0" role="tab">
#                   <form action="/action/doSearch" method="get" name="thisJournalQuickSearch" title="Quick Search">
#                    <div class="input-group option-0">
#                     <label class="hiddenLabel" for="searchField0">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField0" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <input name="SeriesKey" type="hidden" value="15222594"/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222594" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222594#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c1-con" class="tab__pane quick-search-pane__anywhere" id="pane-67065c09-4a88-49cd-934c-ac707951d35c1" role="tab">
#                   <form action="https://onlinelibrary.wiley.com/action/doSearch" method="get" name="defaultQuickSearch" title="Quick Search">
#                    <div class="input-group option-1">
#                     <label class="hiddenLabel" for="searchField1">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField1" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="cart-indicator__wrapper" data-widget-def="ux3-layout-widget" data-widget-id="5ef13ed1-f4ac-4b62-a426-07ec9576a586">
#             <div class="pull-left">
#              <div class="cart-indicator__wrapper" data-widget-def="eCommerceCartIndicatorWidget" data-widget-id="4a9f7c04-a273-4a25-91fb-8e7bd9970288">
#               <div class="eCommerceCartIndicatorWidget">
#               </div>
#              </div>
#             </div>
#             <div class="pull-right">
#              <div class="login-bar-container" data-widget-def="literatumNavigationLoginBar" data-widget-id="d384ca92-7137-45d6-b3c2-78c9c0a98c2b">
#               <div class="loginBar login-open">
#                <a aria-label="Log in or Register" class="show-login" href="/action/showLogin?uri=%2Ftoc%2F15222594%2F2021%2F86%2F2&amp;aria-label=Log+in+or+Register" role="button" uri="/toc/15222594/2021/86/2">
#                 <span class="icon-profile_empty">
#                 </span>
#                 <span class="sign-in-label">
#                  Login / Register
#                 </span>
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </header>
#     </div>
#     <h1 class="hidden">
#      Journal list menu
#     </h1>
#     <div class="pages-nav--sticky pages-nav hidden-lg fixed-element">
#      <div class="pages-nav--res">
#       <div class="container">
#        <ul class="rlist--inline pull-left">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="journal-list" href="#">
#           <i aria-hidden="true" class="icon-toc">
#           </i>
#           <span>
#            Journal
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="journal-list" id="journal-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-1, #menu-item-undefined-2, #menu-item-main-menu-1-1, #menu-item-main-menu-1-2, #menu-item--1, #menu-item--2, .journal-featured" data-toggle="transplant" data-transplant="self">
#           </div>
#           <!-- PERICLES-7683
#               <a href="#" title="More from this journal" class="dropdown__toggle"><span>More from this journal</span></a>
#
#                 <div data-target=".journal-resources" data-remove="false" data-toggle="transplant" data-direction="from" data-transplant="self" class="transplant showit"></div>
# -->
#          </div>
#         </li>
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="articles-list" href="#">
#           <i class="article-img-icon">
#            <img src="/pb-assets/hub-assets/pericles/articles_1-1499257321163.png"/>
#           </i>
#           <span>
#            Articles
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="articles-list" id="articles-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-3, #menu-item-undefined-4, #menu-item-main-menu-1-3, #menu-item-main-menu-1-4, #menu-item--3" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#        <ul class="rlist--inline pull-right">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="actions-list" href="#">
#           <span>
#            Actions
#           </span>
#           <i aria-hidden="true" class="icon-chevron-down">
#           </i>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="actions-list" id="actions-list">
#           <h2 class="side-section-header hiddenLabel--lg">
#            Tools
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target=".journal-actions-container li:nth-child(1), .journal-actions-container li:nth-child(2), .journal-actions-container li:nth-child(3), .journal-actions-container li:nth-child(4), .journal-actions-container li:nth-child(5), #subscribeLink" data-toggle="transplant" data-transplant="self">
#           </div>
#           <h2 class="side-section-header hiddenLabel--lg">
#            Follow journal
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#alert-link, #facebook-link, #twitter-link, #linkedin-link, #most-recent-link, #most-read-link, #most-cited-link" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="pageBody body-text" data-widget-def="pageBody" data-widget-id="72100436-7a82-49fc-933b-c6c9d8c42914">
#      <main id="main-content" tabindex="-1">
#       <!--begin pagefulltext-->
#       <div class="page-body pagefulltext">
#        <div data-pb-dropzone="main">
#         <div class="js--fixed-switch" data-widget-def="ux3-layout-widget" data-widget-id="6da55ccb-5daf-4c91-b961-05eee9e6f293">
#          <div>
#           <div class="secondary-bg-color banner-wrapper" data-widget-def="literatumAd" data-widget-id="0220a30b-90c0-4b51-8637-141edf12f86a">
#            <div class="pb-ad">
#             <aside role="complementary">
#              <div class="advert advert-leaderboard" id="advert-leaderboard">
#               <script>
#                googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#               </script>
#               <!-- No JavaScript support is a call to an image -->
#               <noscript>
#                <a href="/action/clickThrough?id=1013&amp;url=https%3A%2F%2Fpubads.g.doubleclick.net%2Fgampad%2Fjump%3Fiu%3D%24googlePublisherCategory%26amp%3Bsz%3D728x90%26amp%3Btile%3D1%26amp%3Bc%3D%24random&amp;loc=%2Ftoc%2F15222594%2F2021%2F86%2F2&amp;pubId=74689719&amp;placeholderId=1015&amp;productId=101018" target="_blank">
#                 <img src="https://pubads.g.doubleclick.net/gampad/ad?iu=$googlePublisherCategory&amp;sz=728x90&amp;tile=1&amp;c=$random"/>
#                </a>
#               </noscript>
#              </div>
#             </aside>
#            </div>
#           </div>
#           <style type="text/css">
#            li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#           </style>
#           <section class="journal-page-header card" data-widget-def="ux3-layout-widget" data-widget-id="9e8ee65a-2e18-4c00-9474-5ac10e16ecfe">
#            <div class="container">
#             <div class="row">
#              <div class="journal-info-container col-md-8">
#               <a href="/journal/15222594" title="Magnetic Resonance in Medicine homepage">
#                <h1 id="journal-banner-text" style="margin: 0; font-size: 0">
#                 Magnetic Resonance in Medicine
#                </h1>
#                <img alt="Magnetic Resonance in Medicine" class="journal-banner-image" id="journal-banner-image" src="/pb-assets/journal-banners/15222594-1589988604920.jpg" style="margin-bottom: 15px; display: none"/>
#               </a>
#               <script>
#                var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222594-1589988604920.jpg";
#               </script>
#              </div>
#              <div class="hidden-xs hidden-sm hidden-md col-md-4">
#              </div>
#             </div>
#            </div>
#           </section>
#           <div class="stickybar pages-nav hidden-xs hidden-sm hidden-md scrollable-element" data-widget-def="menuWidget" data-widget-id="998218b4-f988-4a0c-8c4f-b2d3875e1770">
#            <div class="stickybar__wrapper">
#             <div class="main-nav">
#              <a data-toggle="nav" href="#undefined" title="menu drawer">
#               <i aria-hidden="true" class="icon-menu2">
#               </i>
#               <i aria-hidden="true" class="icon-close_thin">
#               </i>
#              </a>
#              <nav aria-label="Journal navigation" class="drawer__nav container gutterless hidden-sm hidden-xs" data-ctrl-res="never" role="navigation">
#               <h2 class="is-accessible">
#                Navigation Bar
#               </h2>
#               <section>
#                <h3 class="is-accessible">
#                 Menu
#                </h3>
#                <a class="menu-header hidden-md hidden-lg" href="/">
#                 Home
#                </a>
#                <ul class="menubar rlist--inline" id="menubar" role="menubar">
#                 <li class="menu-item" data-menu-label="Home" id="menu-item-undefined-0" role="presentation">
#                  <a class="sub-menu-item" href="/journal/15222594" role="menuitem" tabindex="0">
#                   <span>
#                    Home
#                   </span>
#                  </a>
#                 </li>
#                 <li class="dropdown menu-parent" data-menu-label="About" id="menu-item-undefined-1" role="presentation">
#                  <a aria-expanded="false" aria-haspopup="true" class="dropdown__toggle" data-target="About-1-dropdown" data-toggle="dropdown" href="#" id="About-1" role="menuitem" tabindex="-1">
#                   <span>
#                    About
#                   </span>
#                   <i aria-hidden="true" class="icon-arrow_r pull-right hidden-md hidden-lg">
#                   </i>
#                   <i aria-hidden="true" class="icon-section_arrow_d pull-right hidden-sm hidden-xs">
#                   </i>
#                  </a>
#                  <ul aria-labelledby="About-1" class="rlist dropdown__menu" id="About-1-dropdown" role="menu">
#                   <li class="menu-item" data-menu-label="Overview" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222594/homepage/productinformation.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Overview
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Contact" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222594/homepage/contact.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Contact
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Editorial Board" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222594/homepage/editorialboard.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Editorial Board
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Former Editors" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222594/homepage/formereditors" role="menuitem" tabindex="-1">
#                     <span>
#                      Former Editors
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Advertise" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222594/homepage/advertise.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Advertise
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Permissions" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222594/homepage/permissions.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Permissions
#                     </span>
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                 <li class="dropdown menu-parent" data-menu-label="Contribute" id="menu-item-undefined-2" role="presentation">
#                  <a aria-expanded="false" aria-haspopup="true" class="dropdown__toggle" data-target="Contribute-2-dropdown" data-toggle="dropdown" href="#" id="Contribute-2" role="menuitem" tabindex="-1">
#                   <span>
#                    Contribute
#                   </span>
#                   <i aria-hidden="true" class="icon-arrow_r pull-right hidden-md hidden-lg">
#                   </i>
#                   <i aria-hidden="true" class="icon-section_arrow_d pull-right hidden-sm hidden-xs">
#                   </i>
#                  </a>
#                  <ul aria-labelledby="Contribute-2" class="rlist dropdown__menu" id="Contribute-2-dropdown" role="menu">
#                   <li class="menu-item" data-menu-label="Author Guidelines" role="presentation">
#                    <a class="sub-menu-item" href="/pb-assets/assets/15222594/mrm_v86_i1_guid final-1616172647.pdf" role="menuitem" tabindex="-1" target="_blank">
#                     <span>
#                      Author Guidelines
#                     </span>
#                     <i aria-hidden="true" class="icon-export-icon">
#                     </i>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Style Guide" role="presentation">
#                    <a class="sub-menu-item" href="/pb-assets/assets/15222594/nav/MRMStyleGuideJune2021-1624019003353.pdf" role="menuitem" tabindex="-1" target="_blank">
#                     <span>
#                      Style Guide
#                     </span>
#                     <i aria-hidden="true" class="icon-export-icon">
#                     </i>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Open Access" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222594/homepage/fundedaccess.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Open Access
#                     </span>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="Submit a Manuscript" role="presentation">
#                    <a class="sub-menu-item" href="http://mc.manuscriptcentral.com/mrm" role="menuitem" tabindex="-1" target="_blank">
#                     <span>
#                      Submit a Manuscript
#                     </span>
#                     <i aria-hidden="true" class="icon-export-icon">
#                     </i>
#                    </a>
#                   </li>
#                   <li class="menu-item" data-menu-label="For Referees" role="presentation">
#                    <a class="sub-menu-item" href="http://wileypeerreview.com" role="menuitem" tabindex="-1" target="_blank">
#                     <span>
#                      For Referees
#                     </span>
#                     <i aria-hidden="true" class="icon-export-icon">
#                     </i>
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                 <li class="dropdown menu-parent" data-menu-label="Browse" id="menu-item-undefined-3" role="presentation">
#                  <a aria-expanded="false" aria-haspopup="true" class="dropdown__toggle" data-target="Browse-3-dropdown" data-toggle="dropdown" href="#" id="Browse-3" role="menuitem" tabindex="-1">
#                   <span>
#                    Browse
#                   </span>
#                   <i aria-hidden="true" class="icon-arrow_r pull-right hidden-md hidden-lg">
#                   </i>
#                   <i aria-hidden="true" class="icon-section_arrow_d pull-right hidden-sm hidden-xs">
#                   </i>
#                  </a>
#                  <ul aria-labelledby="Browse-3" class="rlist dropdown__menu" id="Browse-3-dropdown" role="menu">
#                   <li class="menu-item" data-menu-label="Accepted Articles" role="presentation">
#                    <a class="sub-menu-item" href="/toc/15222594/0/ja" role="menuitem" tabindex="-1">
#                     <span>
#                      Accepted Articles
# ...
#             text-align: left;
#         }
#     }
#         </style>
#         <div class="footer-sections" data-widget-def="ux3-layout-widget" data-widget-id="2753bec1-a79d-4403-827b-6c788ddd6db3">
#          <h2 class="sr-only">
#           Additional links
#          </h2>
#          <div class="container">
#           <div class="row">
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               About Wiley Online Library
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://www.wiley.com/privacy">
#                 Privacy Policy
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/terms-and-conditions">
#                 Terms of Use
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/cookies">
#                 Cookies
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/accessibility">
#                 Accessibility
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Help &amp; Support
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://hub.wiley.com/community/support/onlinelibrary">
#                 Contact Us
#                </a>
#               </li>
#               <li>
#                <a href="https://www.wiley.com/customer-success/wiley-online-library-training-hub">
#                 Training and Support
#                </a>
#               </li>
#               <li>
#                <a href="/dmca-notification-policy">
#                 DMCA &amp; Reporting Piracy
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Opportunities
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://onlinelibrary.wiley.com/agents">
#                 Subscription Agents
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/advertisers">
#                 Advertisers &amp; Corporate Partners
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Connect with Wiley
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://www.wiley.com/network">
#                 The Wiley Network
#                </a>
#               </li>
#               <li>
#                <a href="https://newsroom.wiley.com/">
#                 Wiley Press Room
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="copyright-container" data-widget-def="ux3-layout-widget" data-widget-id="86584e25-e4db-4118-9550-9b4f5341a4ac">
#          <div class="container">
#           <div class="row">
#            <div class=" col-md-12">
#             <div class="copyright" data-widget-def="UX3HTMLWidget" data-widget-id="bfbf6c5d-a650-4662-828f-5275fada9120">
#              <div class="copyright pull-left">
#               Copyright © 1999-2021
#               <a href="https://www.wiley.com">
#                John Wiley &amp; Sons, Inc
#               </a>
#               . All rights reserved
#              </div>
#             </div>
#             <div class="footer-logo pull-right">
#              <a aria-label="Wiley" href="https://www.wiley.com" title="Wiley Home Page">
#               <img alt="Wiley Home Page" src="/pb-assets/tmp-images/footer-logo-wiley-1510029248417.png"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#     <div aria-labelledby="loginPopupHead" class="popup login-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="Cancel Login" class="close" href="#" role="button">
#        <i aria-hidden="true" class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#       </div>
#       <div class="modal__body">
#        <div class="ssoLogin">
#        </div>
#        <h2 id="loginPopupHead">
#         Log in to Wiley Online Library
#        </h2>
#        <div class="login-form">
#         <form action="/action/doLogin?societyURLCode=" class="bordered" method="post">
#          <input name="id" type="hidden" value="67065c09-4a88-49cd-934c-ac707951d35c"/>
#          <input name="popup" type="hidden" value="true"/>
#          <input name="loginUri" type="hidden" value="/toc/15222594/2021/86/2"/>
#          <input name="redirectUri" type="hidden" value="/toc/15222594/2021/86/2"/>
#          <input name="loginUri" type="hidden" value="/toc/15222594/2021/86/2"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="username">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="login" id="username" name="login" placeholder="Enter your email" required="true" size="15" spellcheck="false" type="text" value=""/>
#           <div class="actions">
#           </div>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="password">
#             Password
#            </label>
#           </div>
#           <input autocapitalize="off" autocomplete="off" autocorrect="off" class="password" id="password" name="password" placeholder="Enter your password" required="true" spellcheck="false" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="actions">
#           <a class="link show-request-reset-password" href="/action/requestResetPassword">
#            Forgot password?
#           </a>
#          </div>
#          <div class="loginExtraBeans-dropZone" data-pb-dropzone="loginExtraBeans">
#          </div>
#          <div class="align-end">
#           <span class="submit ">
#            <input class="button btn submit primary no-margin-bottom accessSubmit" name="submitButton" type="submit" value="Log In"/>
#           </span>
#          </div>
#         </form>
#         <div class="societySpecificInstructions">
#         </div>
#        </div>
#        <div class="login-container clearfix form-btn">
#         <a class="linkBtn float-left" href="/action/registration">
#          NEW USER
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#         <a class="linkBtn float-right instituation-login" href="/action/ssostart?redirectUri=%2Ftoc%2F15222594%2F2021%2F86%2F2">
#          INSTITUTIONAL LOGIN
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="changePasswordPopupHead" class="popup change-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close cancel" href="#" role="button">
#        <i class="icon-close_thin">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="changePasswordPopupHead">
#         Change Password
#        </h2>
#       </div>
#       <div class="modal__body">
#        <div class="form">
#         <form action="/action/changePassword" method="post">
#          <div class="message error">
#          </div>
#          <input name="submit" type="hidden" value="submit"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-old">
#             Old Password
#            </label>
#           </div>
#           <input autocomplete="off" class="old" id="a589574e-bb98-4c6e-8fed-67365ff05357-old" name="old" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-new">
#             New Password
#            </label>
#           </div>
#           <input autocomplete="off" class="pass-hint new" id="a589574e-bb98-4c6e-8fed-67365ff05357-new" name="new" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#           <div class="password-strength-indicator" data-max="32" data-min="10" data-strength="3">
#            <span class="text too-short">
#             Too Short
#            </span>
#            <span class="text weak">
#             Weak
#            </span>
#            <span class="text medium">
#             Medium
#            </span>
#            <span class="text strong">
#             Strong
#            </span>
#            <span class="text very-strong">
#             Very Strong
#            </span>
#            <span class="text too-long">
#             Too Long
#            </span>
#           </div>
#          </div>
#          <input class="button primary submit" disabled="disabled" type="submit" value="Submit"/>
#         </form>
#         <a class="fakeFormLastElement" href="#">
#         </a>
#        </div>
#        <div class="success-template hidden">
#         <h2>
#          Password Changed Successfully
#         </h2>
#         <p>
#          Your password has been changed
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="createAccountPopupHead" class="popup registration-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close" href="#" role="button">
#        <i class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="logoDropZone" data-pb-dropzone="logoDropZone">
#        </div>
#        <h2 id="createAccountPopupHead">
#         Create a new account
#        </h2>
#       </div>
#       <div class="modal__body">
#        <form action="/action/registration" class="registration-form" method="post">
#         <input name="redirectUri" type="hidden" value="/toc/15222594/2021/86/2"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="4e647394-f751-4441-baa4-df426bca4b6e.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="4e647394-f751-4441-baa4-df426bca4b6e.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="submit">
#          <input class="button submit primary" type="submit" value="Register"/>
#         </div>
#        </form>
#        <div class="center">
#         <a class="show-login" href="/action/showLogin">
#          Returning user
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="resetPasswordPopupHead" class="popup top-drawer request-reset-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <div class="modal__header">
#        <a aria-label="close dialog" class="cancel close" href="#" role="button">
#         <i class="icon-close_thin">
#         </i>
#        </a>
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="resetPasswordPopupHead">
#         Forgot your password?
#        </h2>
#        <p class="sub">
#         Enter your email address below.
#        </p>
#       </div>
#       <div class="modal__body">
#        <div class="error">
#        </div>
#        <form action="/action/requestResetPassword" class="request-reset-password-form" method="post">
#         <input name="requestResetPassword" type="hidden" value="true"/>
#         <div class="input-group">
#          <div class="input-group">
#           <div class="label">
#            <label for="email">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="email" id="email" name="email" placeholder="Enter your email" size="15" spellcheck="false" type="text" value=""/>
#          </div>
#         </div>
#         <div class="password-recaptcha-ajax">
#         </div>
#         <div class="form-btn">
#          <input class="button btn primary submit" disabled="disabled" name="submit" type="submit" value="RESET PASSWORD"/>
#         </div>
#        </form>
#        <div class="message error">
#        </div>
#        <div class="success-template hidden">
#         <p>
#          Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div>
#      <div class="pb-dropzone" data-pb-dropzone="col-0" title="col-0">
#      </div>
#     </div>
#     <div aria-labelledby="requestUsernamePopupHead" class="popup top-drawer request-username-drawer username-popup hidden" role="dialog" tabindex="-1">
#      <a aria-label="close dialog" class="close" href="#" role="button">
#       <i class="icon-close_thin">
#       </i>
#      </a>
#      <div class="content">
#       <h2 id="requestUsernamePopupHead">
#        Request Username
#       </h2>
#       <div class="form">
#        <p>
#         Can't sign in? Forgot your username?
#        </p>
#        <p class="sub">
#         Enter your email address below and we will send you your username
#        </p>
#        <div class="message error">
#        </div>
#        <form action="/action/requestUsername" method="post">
#         <input name="requestUsername" type="hidden" value="requestUsername"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="username-recaptcha-ajax">
#         </div>
#         <input class="button primary submit" disabled="disabled" name="submit" type="submit" value="Submit"/>
#         <div class="center">
#          <a class="cancel" href="#">
#           Close
#          </a>
#         </div>
#        </form>
#       </div>
#       <div class="success-template hidden note">
#        <p>
#         If the address matches an existing account you will receive an email with instructions to retrieve your username
#        </p>
#       </div>
#      </div>
#     </div>
#     <!-- Belongs at the bottom of the page -->
#     <script type="text/javascript">
#      if(window._satellite) {
# _satellite.pageBottom();
# }
#     </script>
#    </div>
#   </div>
#   <script src="/products/acropolis/pericles/releasedAssets/js/build.lazyload.bundle-7f40ce784dbb604c697b.js">
#   </script>
#   <script src="/products/acropolis/pericles/releasedAssets/js/main.bundle-eb667800e966bc2c8806.js">
#   </script>
#   <script src="/wro/kkrk~product.js" type="text/javascript">
#   </script>
#   <script>
#    var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();
#   </script>
#   <script data-cf-beacon='{"rayId":"68d7d7b3cf2f544b","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.8.1","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#  </body>
# </html>

# %%
# Get the title
title = soupMRM.title
print(title)
# Out:
# <title> Magnetic Resonance in Medicine: Vol 86, No 2</title>

# %%
# Print out the text
text = soupMRM.get_text()
print(soup.text)

# Another way to extract text
# str(all_links[103]).split("<h2>")[1].replace("</h2></a>", "")
# Out:
# var $DoubleClickZone = "magres-med_mrm";var $DoubleClickSite =  "wly.radiol.imag_000105";digitalData = {}
#
#
#
#
#
#
#
#
#
#
#
#
#  Magnetic Resonance in Medicine: Vol 86, No 2
#
# @font-face {
#     font-family: 'Open Sans Subset';
#     font-display: swap;
#     src: local('Muli Regular'), local('Muli-Regular'),
#     url(data:application/font-woff;charset=utf-8;base64,...) format('woff');
# }
#
#
#
#
#
#
#
#
#
#
#
# /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#
#
#
#
#
#
#
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#
#
#
# 	var gs_channels = 'default';
#
#
#
#
# 	var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#
#
# 	var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#
#
# 	googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/mrm.v86.2')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#
#
#
# 	try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#
#
#
# (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#
#
#
#
#
#
#
#
#
#         function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf('?') !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId, entityTitle) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId, entityTitle: entityTitle, eventGroupKey: '04c7ce53-a4da-44cd-8522-dd5e30603c27'}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID, ssoInstitution.entity.title)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#
#
#
#         (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaafcMozskKmV4AmBkxVx';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#
#
#     var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Magnetic Resonance in Medicine: Vol 86, No 2";
#
#
#
#
# Skip to Main Content
#
#
#
#
#
#
#
#
#
#
#
#
# We are upgrading Wiley Online Library over the weekend of September 11th–12th.
#           All content will continue to be available, but some functionality may not work as expected. We apologize for any inconvenience this may cause.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search withinThis JournalAnywhereSearch term  Advanced Search  Citation SearchSearch term  Advanced Search  Citation Search
#
#
#
#
#
#
#
#
#
#
#
#
# Login / Register
#
#
#
#
#
#
#
#
#
#
#  Journal list menu
#
#
#
#
# Journal
#
#
#
#
#
# Articles
#
#
#
#
#
#
# Actions
#
# Tools
#
# Follow journal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
# li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#
#
#
# Magnetic Resonance in Medicine
#
#
#
# var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222594-1589988604920.jpg";
#
#
#
#
# Navigation BarMenuHomeHomeAboutOverviewContactEditorial BoardFormer EditorsAdvertisePermissionsContributeAuthor Guidelines Style Guide Open AccessSubmit a Manuscript For Referees BrowseAccepted ArticlesEarly ViewCurrent IssueAll IssuesEditor's PicksCover GalleryVirtual Issues
#
#
# Follow journal
#
# Alert
# Facebook page
# Twitter channel
#
# Twitter channel
#
# RSS Feeds
#
# Most recent (RSS)
#
# Most cited (RSS)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# IssueVolume 86,  Issue 2Pages: C1, 599-1174August 2021
#
# Previous Issue|Next Issue
#
#
#
# GO TO SECTION
#
#
#
#
#
#
#
#
# Export Citation(s)
# Export CitationsFormatPlain TextRIS (ProCite, Reference Manager)EndNoteBibTexMedlarsRefWorksType of importCitation file or direct importIndirect import or copy/pasteCancelNext< Go backCitation HelpExport
#
#
# COVER IMAGE
#
# Free Access
#
#
# free
#
# Synchrotron X-ray micro-CT as a validation dataset for diffusion MRI in whole mouse brain
# Pages: C1
# First Published: 24 April 2021
#
#
# PDFRequest permissions
#
#
#
#
# ISSUE INFORMATION
#
# Free Access
#
#
# free
#
# Issue Information
# Pages: 599-610
# First Published: 24 April 2021
#
#
#
# First PagePDFRequest permissions
#
#
#
#
# FULL PAPER—SPECTROSCOPIC METHODOLOGY
#
# Open Access
#
#
# oa
#
# Calibration-free regional RF shims for MRS
#
#  Adam Berrington,
#  Michal Považan,
#  Christopher Mirfin,
#  Stephen Bawden,
#  Young Woo Park,
#  Daniel C. Marsh,
#  Richard Bowtell,
#  Penny A. Gowland,
#
#
# Pages: 611-624
# First Published: 21 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# RAPID COMMUNICATIONS—IMAGING METHODOLOGY
#
#
#
#
# unknown
#
# High-resolution sodium imaging using anatomical and sparsity constraints for denoising and recovery of novel features
#
#  Yibo Zhao,
#  Rong Guo,
#  Yudu Li,
#  Keith R. Thulborn,
#  Zhi-Pei Liang,
#
#
# Pages: 625-636
# First Published: 25 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Motion-compensated 3D turbo spin-echo for more robust MR intracranial vessel wall imaging
#
#  Zhehao Hu,
#  Andre van der Kouwe,
#  Fei Han,
#  Jiayu Xiao,
#  Junzhou Chen,
#  Hui Han,
#  Xiaoming Bi,
#  Debiao Li,
#  Zhaoyang Fan,
#
#
# Pages: 637-647
# First Published: 25 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# FULL PAPERS—IMAGING METHODOLOGY
#
#
#
#
# unknown
#
# High spatial resolution spiral first-pass myocardial perfusion imaging with whole-heart coverage at 3 T
#
#  Junyu Wang,
#  Yang Yang,
#  Daniel S. Weller,
#  Ruixi Zhou,
#  Matthew Van Houten,
#  Changyu Sun,
#  Frederick H. Epstein,
#  Craig H. Meyer,
#  Christopher M. Kramer,
#  Michael Salerno,
#
#
# Pages: 648-662
# First Published: 11 March 2021
#
#
# Click here for author-reader discussions
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# All-systolic first-pass myocardial rest perfusion at a long saturation time using simultaneous multi-slice imaging and compressed sensing acceleration
#
#  Giulio Ferrazzi,
#  Sarah McElroy,
#  Radhouene Neji,
#  Karl P. Kunze,
#  Muhummad Sohaib Nazir,
#  Peter Speier,
#  Daniel Stäb,
#  Christoph Forman,
#  Reza Razavi,
#  Amedeo Chiribiri,
#  Sébastien Roujol,
#
#
# Pages: 663-676
# First Published: 10 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Apparent exchange rate imaging: On its applicability and the connection to the real exchange rate
#
#  Dominik Ludwig,
#  Frederik Bernd Laun,
#  Mark Edward Ladd,
#  Peter Bachert,
#  Tristan Anselm Kuder,
#
#
# Pages: 677-692
# First Published: 10 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Imperfect spoiling in variable flip angle T1 mapping at 7T: Quantifying and minimizing impact
#
#  Nadège Corbin,
#  Martina F. Callaghan,
#
#
# Pages: 693-708
# First Published: 01 March 2021
#
#
# Click here for author-reader discussions
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# MRzero - Automated discovery of MRI sequences using supervised learning
#
#  A. Loktyushin,
#  K. Herz,
#  N. Dang,
#  F. Glang,
#  A. Deshmane,
#  S. Weinmüller,
#  A. Doerfler,
#  B. Schölkopf,
#  K. Scheffler,
#  M. Zaiss,
#
#
# Pages: 709-724
# First Published: 23 March 2021
#
#
# Click here for author-reader discussions
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Prospective motion detection and re-acquisition in diffusion MRI using a phase image–based method—Application to brain and tongue imaging
#
#  Xiao Liang,
#  Pan Su,
#  Sunil G. Patil,
#  Nahla M. H. Elsaid,
#  Steven Roys,
#  Maureen Stone,
#  Rao P. Gullapalli,
#  Jerry L. Prince,
#  Jiachen Zhuo,
#
#
# Pages: 725-737
# First Published: 04 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Efficient whole-brain tract-specific T1 mapping at 3T with slice-shuffled inversion-recovery diffusion-weighted imaging
#
#  Ilana R. Leppert,
#  Daniel A. Andrews,
#  Jennifer S. W. Campbell,
#  Daniel J. Park,
#  G. Bruce Pike,
#  Jonathan R. Polimeni,
#  Christine L. Tardif,
#
#
# Pages: 738-753
# First Published: 21 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Time dependence in diffusion MRI predicts tissue outcome in ischemic stroke patients
#
#  Björn Lampinen,
#  Jimmy Lätt,
#  Johan Wasselius,
#  Danielle van Westen,
#  Markus Nilsson,
#
#
# Pages: 754-764
# First Published: 23 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Quasi–steady-state CEST (QUASS CEST) solution improves the accuracy of CEST quantification: QUASS CEST MRI-based omega plot analysis
#
#  Phillip Zhe Sun,
#
#
# Pages: 765-776
# First Published: 10 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Trading off spatio-temporal properties in 3D high-speed fMRI using interleaved stack-of-spirals trajectories
#
#  Bruno Riemenschneider,
#  Burak Akin,
#  Pierre LeVan,
#  Jürgen Hennig,
#
#
# Pages: 777-790
# First Published: 10 March 2021
#
#
# Click here for author-reader discussions
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Distortion-free, high-isotropic-resolution diffusion MRI with gSlider BUDA-EPI and multicoil dynamic B0 shimming
#
#  Congyu Liao,
#  Berkin Bilgic,
#  Qiyuan Tian,
#  Jason P. Stockmann,
#  Xiaozhi Cao,
#  Qiuyun Fan,
#  Siddharth Srinivasan Iyer,
#  Fuyixue Wang,
#  Chanon Ngamsombat,
#  Wei-Ching Lo,
#  Mary Kate Manhard,
#  Susie Y. Huang,
#  Lawrence L. Wald,
#  Kawin Setsompop,
#
#
# Pages: 791-803
# First Published: 10 March 2021
#
#
# Click here for author-reader discussions
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Highly accelerated free-breathing real-time phase contrast cardiovascular MRI via complex-difference deep learning
#
#  Hassan Haji-Valizadeh,
#  Rui Guo,
#  Selcuk Kucukseymen,
#  Amanda Paskavitz,
#  Xiaoying Cai,
#  Jennifer Rodriguez,
#  Patrick Pierce,
#  Beth Goddu,
#  Daniel Kim,
#  Warren Manning,
#  Reza Nezafat,
#
#
# Pages: 804-819
# First Published: 15 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Aliasing layers for processing parallel imaging and EPI ghost artifacts efficiently in convolutional neural networks
#
#  Hidenori Takeshima,
#
#
# Pages: 820-834
# First Published: 14 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# qModeL: A plug-and-play model-based reconstruction for highly accelerated multi-shot diffusion MRI using learned priors
#
#  Merry Mani,
#  Vincent A. Magnotta,
#  Mathews Jacob,
#
#
# Pages: 835-851
# First Published: 24 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Strategies to improve intratrain prospective motion correction for turbo spin-echo sequences with constant flip angles
#
#  Xiang Gao,
#  Patrick Hucker,
#  Jürgen Hennig,
#  Maxim Zaitsev,
#
#
# Pages: 852-865
# First Published: 16 March 2021
#
#
# Click here for author-reader discussions
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# A multi-inversion multi-echo spin and gradient echo echo planar imaging sequence with low image distortion for rapid quantitative parameter mapping and synthetic image contrasts
#
#  Mary Kate Manhard,
#  Jason Stockmann,
#  Congyu Liao,
#  Daniel Park,
#  Sohyun Han,
#  Merlin Fair,
#  Maaike van den Boomen,
#  Jon Polimeni,
#  Berkin Bilgic,
#  Kawin Setsompop,
#
#
# Pages: 866-880
# First Published: 25 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Ultrashort echo time Cones double echo steady state (UTE-Cones-DESS) for rapid morphological imaging of short T2 tissues
#
#  Hyungseok Jang,
#  Yajun Ma,
#  Michael Carl,
#  Saeed Jerban,
#  Eric Y. Chang,
#  Jiang Du,
#
#
# Pages: 881-892
# First Published: 23 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Whole-brain amide CEST imaging at 3T with a steady-state radial MRI acquisition
#
#  Ran Sui,
#  Lin Chen,
#  Yuguo Li,
#  Jianpan Huang,
#  Kannie W. Y. Chan,
#  Xiang Xu,
#  Peter C. M. van Zijl,
#  Jiadi Xu,
#
#
# Pages: 893-906
# First Published: 27 March 2021
#
#
# Click here for author-reader discussions
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# TECHNICAL NOTES—IMAGING METHODOLOGY
#
#
#
#
# unknown
#
# Removal of off-resonance xenon gas artifacts in pulmonary gas-transfer MRI
#
#  Matthew M. Willmering,
#  Zackary I. Cleveland,
#  Laura L. Walkup,
#  Jason C. Woods,
#
#
# Pages: 907-915
# First Published: 04 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Aliasing artifact reduction in spiral real-time MRI
#
#  Ye Tian,
#  Yongwan Lim,
#  Ziwei Zhao,
#  Dani Byrd,
#  Shrikanth Narayanan,
#  Krishna S. Nayak,
#
#
# Pages: 916-925
# First Published: 16 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Motion-insensitive diffusion imaging of the brain using optical tracking and dynamic sequence updates
#
#  Artan Kaso,
#  Thomas Ernst,
#
#
# Pages: 926-934
# First Published: 15 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# PVP-coated Gd-grafted nanodiamonds as a novel and potentially safer contrast agent for in vivo MRI
#
#  Alexander M. Panich,
#  Moti Salti,
#  Ofer Prager,
#  Evyatar Swissa,
#  Yuri V. Kulvelis,
#  Elena B. Yudina,
#  Alexander E. Aleksenskii,
#  Shaul D. Goren,
#  Alexander Ya. Vul',
#  Alexander I. Shames,
#
#
# Pages: 935-942
# First Published: 16 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Preliminary demonstration of in vivo quasi-steady-state CEST postprocessing—Correction of saturation time and relaxation delay for robust quantification of tumor MT and APT effects
#
#  Xiao-Yong Zhang,
#  Yuting Zhai,
#  Ziyi Jin,
#  Cong Li,
#  Phillip Zhe Sun,
#  Yin Wu,
#
#
# Pages: 943-953
# First Published: 15 March 2021
#
#
# Click here for author-reader discussions
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Artifact reduction in free-breathing, free-running myocardial perfusion imaging with interleaved non-selective RF excitations
#
#  Hassan Haji-Valizadeh,
#  Rui Guo,
#  Selcuk Kucukseymen,
#  Xiaoying Cai,
#  Jennifer Rodriguez,
#  Patrick Pierce,
#  Beth Goddu,
#  Warren Manning,
#  Reza Nezafat,
#
#
# Pages: 954-963
# First Published: 25 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Dynamic MRI of the abdomen using parallel non-Cartesian convolutional recurrent neural networks
#
#  Yufei Zhang,
#  Huajun She,
#  Yiping P. Du,
#
#
# Pages: 964-973
# First Published: 21 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# FULL PAPERS—PRECLINICAL AND CLINICAL IMAGING
#
#
#
#
# unknown
#
# Can R2’ mapping evaluate hypoxia in renal ischemia reperfusion injury quantitatively? An experimental study
#
#  Jinggang Zhang,
#  Jie Chen,
#  Qin Chen,
#  Jing Chen,
#  Kai Luo,
#  Liang Pan,
#  Yongcheng Zhang,
#  Weiqiang Dou,
#  Wei Xing,
#
#
# Pages: 974-983
# First Published: 16 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Diffusion-prepared fast spin echo for artifact-free spinal cord imaging
#
#  Seung-Yi Lee,
#  Briana P. Meyer,
#  Shekar N. Kurpad,
#  Matthew D. Budde,
#
#
# Pages: 984-994
# First Published: 15 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Investigating plasma volume expanders as novel macromolecular MRI-CEST contrast agents for tumor contrast-enhanced imaging
#
#  Lorena Consolino,
#  Pietro Irrera,
#  Feriel Romdhane,
#  Annasofia Anemone,
#  Dario Livio Longo,
#
#
# Pages: 995-1007
# First Published: 25 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Simultaneous proteoglycans and hypoxia mapping of chondrosarcoma environment by frequency selective CEST MRI
#
#  Roxane Autissier,
#  Leslie Mazuel,
#  Elise Maubert,
#  Jean-Marie Bonny,
#  Philippe Auzeloux,
#  Sébastien Schmitt,
#  Amidou Traoré,
#  Caroline Peyrode,
#  Elisabeth Miot-Noirault,
#  Guilhem Pagés,
#
#
# Pages: 1008-1018
# First Published: 27 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# TECHNICAL NOTE—PRECLINICAL AND CLINICAL IMAGING
#
#
#
#
# unknown
#
# Calibration of T2 oximetry MRI for subjects with sickle cell disease
#
#  Adam Bush,
#  Chau Vu,
#  Soyoung Choi,
#  Matthew Borzage,
#  Xin Miao,
#  Wenbo Li,
#  Qin Qin,
#  Aart J. Nederveen,
#  Thomas D. Coates,
#  John C. Wood,
#
#
# Pages: 1019-1028
# First Published: 14 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# FULL PAPERS—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
#
#
#
#
# unknown
#
# A simulation study of cell size and volume fraction mapping for tissue with two underlying cell populations using diffusion-weighted MRI
#
#  Shu Xing,
#  Ives R. Levesque,
#
#
# Pages: 1029-1044
# First Published: 28 February 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Parsimonious modeling of skeletal muscle perfusion: Connecting the stretched exponential and fractional Fickian diffusion
#
#  David A. Reiter,
#  Fatemeh Adelnia,
#  Donnie Cameron,
#  Richard G. Spencer,
#  Luigi Ferrucci,
#
#
# Pages: 1045-1057
# First Published: 16 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# TECHNICAL NOTES—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
#
#
#
#
# unknown
#
# Superoxide free radical spin-lattice relaxivity: A quench-assisted MR study
#
#  Martin J. MacKinnon,
#  Bruce A. Berkowitz,
#  Yen-Yu Ian Shih,
#
#
# Pages: 1058-1066
# First Published: 23 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Synchrotron X-ray micro-CT as a validation dataset for diffusion MRI in whole mouse brain
#
#  Scott Trinkle,
#  Sean Foxley,
#  Narayanan Kasthuri,
#  Patrick La Rivière,
#
#
# Pages: 1067-1076
# First Published: 25 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# FULL PAPERS—COMPUTER PROCESSING AND MODELING
#
#
#
#
# unknown
#
# MC2-Net: motion correction network for multi-contrast brain MRI
#
#  Jongyeon Lee,
#  Byungjai Kim,
#  HyunWook Park,
#
#
# Pages: 1077-1092
# First Published: 15 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Analysis of deep complex-valued convolutional neural networks for MRI reconstruction and phase-focused applications
#
#  Elizabeth Cole,
#  Joseph Cheng,
#  John Pauly,
#  Shreyas Vasanawala,
#
#
# Pages: 1093-1109
# First Published: 16 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# A Bayesian approach to diffusional kurtosis imaging
#
#  Eizou Umezawa,
#  Daichi Ishihara,
#  Ryoichi Kato,
#
#
# Pages: 1110-1124
# First Published: 25 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Automated renal segmentation in healthy and chronic kidney disease subjects using a convolutional neural network
#
#  Alexander J. Daniel,
#  Charlotte E. Buchanan,
#  Thomas Allcock,
#  Daniel Scerri,
#  Eleanor F. Cox,
#  Benjamin L. Prestwich,
#  Susan T. Francis,
#
#
# Pages: 1125-1136
# First Published: 23 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# TECHNICAL NOTE—COMPUTER PROCESSING AND MODELING
#
#
#
#
# unknown
#
# A theoretical framework for retrospective  correction to the arterial input function in quantitative myocardial perfusion MRI
#
#  Lexiaozi Fan,
#  Bradley D. Allen,
#  Austin E. Culver,
#  Li-Yueh Hsu,
#  Kyungpyo Hong,
#  Brandon C. Benefield,
#  James C. Carr,
#  Daniel C. Lee,
#  Daniel Kim,
#
#
# Pages: 1137-1144
# First Published: 24 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# FULL PAPER—HARDWARE AND INSTRUMENTATION
#
#
#
#
# unknown
#
# A perfusion phantom for ASL MRI based on impinging jets
#
#  Marianna Gabrielyan,
#  M. Dylan Tisdall,
#  Christoph Kammer,
#  Christopher Higgins,
#  Paulo E. Arratia,
#  John A. Detre,
#
#
# Pages: 1145-1158
# First Published: 27 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# TECHNICAL NOTES—HARDWARE AND INSTRUMENTATION
#
#
#
#
# unknown
#
# Quantitative anatomy mimicking slice phantoms
#
#  Karthik Gopalan,
#  Jonathan I. Tamir,
#  Ana C. Arias,
#  Michael Lustig,
#
#
# Pages: 1159-1166
# First Published: 19 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
# unknown
#
# Improved whole-brain SNR with an integrated high-permittivity material in a head array at 7T
#
#  Karthik Lakshmanan,
#  Giuseppe Carluccio,
#  Jerzy Walczyk,
#  Ryan Brown,
#  Sebastian Rupprecht,
#  Qing X. Yang,
#  Michael T. Lanagan,
#  Christopher M. Collins,
#
#
# Pages: 1167-1174
# First Published: 23 March 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
# Tools
#
# Submit an Article
# Browse free sample issue
# Get content alerts
#
#
#
#
#
# Subscribe to this journal
#
#
#
#
#
#
#
#                 More from this journal
#
# ISMRM Journal AppsEditor's PicksOther ResourcesStyle GuideTop 10 Most Downloaded ArticlesI.I. Rabi Award Winning Articles
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-rail-1' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			googletag.cmd.push 		( function () {
# 				googletag.display 	( 'advert-rail-2' );
# 			});
#
#
#
#
#
#
#
#
#
#
#
#
#                 Related Title
#
# IssueVolume 54, Issue 3Pages: spcone, 673-1027, E1-E4September 2021
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     .footer-links {
#         text-align: center;
#     }
#     .footer-links h3 {
#         font-weight: 300;
#     }
#     .footer-links a {
#         font-weight: 600;
#     }
#     @media (min-width: 992px) {
#         .footer-links {
#             text-align: left;
#         }
#     }
#
#
#
#                 Additional links
#
#
#
# About Wiley Online Library
#
# Privacy Policy
# Terms of Use
# Cookies
# Accessibility
#
#
#
#
# Help & Support
#
# Contact Us
# Training and Support
# DMCA & Reporting Piracy
#
#
#
#
# Opportunities
#
# Subscription Agents
# Advertisers & Corporate Partners
#
#
#
#
# Connect with Wiley
#
# The Wiley Network
# Wiley Press Room
#
#
#
#
#
#
#
# Copyright © 1999-2021 John Wiley & Sons, Inc. All rights reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Log in to Wiley Online Library
#
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Password
#
#
#
#
#
#
#                                 Forgot password?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         NEW USER >
#
#
#
#                             INSTITUTIONAL LOGIN >
#
#
#
#
#
#
#
#
#
#
#
#
# Change Password
#
#
#
#
#
#
#
# Old Password
#
#
#
#
#
#
# New Password
#
#
#
#
# Too Short
# Weak
# Medium
# Strong
# Very Strong
# Too Long
#
#
#
#
#
#
# Password Changed Successfully
# Your password has been changed
#
#
#
#
#
#
#
#
#
#
# Create a new account
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#                     Returning user
#
#
#
#
#
#
#
#
#
#
#
#
# Forgot your password?
# Enter your email address below.
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#
# Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#
#
#
#
#
#
#
#
# Request Username
#
# Can't sign in? Forgot your username?
# Enter your email address below and we will send you your username
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Close
#
#
#
# If the address matches an existing account you will receive an email with instructions to retrieve your username
#
#
#
#
#
# if(window._satellite) {
# _satellite.pageBottom();
# }
#
#
#
#
#
# var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();

# %%
all_links = soupMRM.find_all('a')

# %% [markdown]
# ### Explore Category

# %%
# h3 class corresponds to editorial

all_h3 = soupMRM.find_all("h3")

i = 0
for h3 in all_h3:
  # print(h3)
  print(h3.get_text())
  i += 1
print(i)
# Out:
# Menu
# Format
# Type of import
# COVER IMAGE
# ISSUE INFORMATION
# FULL PAPER—SPECTROSCOPIC METHODOLOGY
# RAPID COMMUNICATIONS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# FULL PAPERS—PRECLINICAL AND CLINICAL IMAGING
# TECHNICAL NOTE—PRECLINICAL AND CLINICAL IMAGING
# FULL PAPERS—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
# TECHNICAL NOTES—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
# FULL PAPERS—COMPUTER PROCESSING AND MODELING
# TECHNICAL NOTE—COMPUTER PROCESSING AND MODELING
# FULL PAPER—HARDWARE AND INSTRUMENTATION
# TECHNICAL NOTES—HARDWARE AND INSTRUMENTATION
# About Wiley Online Library
# Help & Support
# Opportunities
# Connect with Wiley
# 21

# %% [markdown]
# ### Explore Original Research Subcategory

# %%
# h4 class corresponds to category

# all_h4 = soupMRM.find_all("h4")

# i = 0
# for h4 in all_h4:
#   # print(h4)
#   print(h4.get_text())
#   i += 1
# print(i)
# Out:
# 0

# %%
all_h2 = soupMRM.find_all("h2")

i = 0
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 3:
    print(h2.get_text())
    i += 1
print(i)

# str_h2 = str(all_h2)

# links = soupJMRI.find_all("a")
# str_links = str(links)
# print(str_h2)

# cleantext = BeautifulSoup(str_h2, "lxml").get_text()
# cleantext = BeautifulSoup(str_links, "lxml").get_text()
# print(cleantext)
# Out:
# Synchrotron X-ray micro-CT as a validation dataset for diffusion MRI in whole mouse brain
# Calibration-free regional RF shims for MRS
# High-resolution sodium imaging using anatomical and sparsity constraints for denoising and recovery of novel features
# Motion-compensated 3D turbo spin-echo for more robust MR intracranial vessel wall imaging
# High spatial resolution spiral first-pass myocardial perfusion imaging with whole-heart coverage at 3 T
# All-systolic first-pass myocardial rest perfusion at a long saturation time using simultaneous multi-slice imaging and compressed sensing acceleration
# Apparent exchange rate imaging: On its applicability and the connection to the real exchange rate
# Imperfect spoiling in variable flip angle T1 mapping at 7T: Quantifying and minimizing impact
# MRzero - Automated discovery of MRI sequences using supervised learning
# Prospective motion detection and re-acquisition in diffusion MRI using a phase image–based method—Application to brain and tongue imaging
# Efficient whole-brain tract-specific T1 mapping at 3T with slice-shuffled inversion-recovery diffusion-weighted imaging
# Time dependence in diffusion MRI predicts tissue outcome in ischemic stroke patients
# Quasi–steady-state CEST (QUASS CEST) solution improves the accuracy of CEST quantification: QUASS CEST MRI-based omega plot analysis
# Trading off spatio-temporal properties in 3D high-speed fMRI using interleaved stack-of-spirals trajectories
# Distortion-free, high-isotropic-resolution diffusion MRI with gSlider BUDA-EPI and multicoil dynamic B0 shimming
# Highly accelerated free-breathing real-time phase contrast cardiovascular MRI via complex-difference deep learning
# Aliasing layers for processing parallel imaging and EPI ghost artifacts efficiently in convolutional neural networks
# qModeL: A plug-and-play model-based reconstruction for highly accelerated multi-shot diffusion MRI using learned priors
# Strategies to improve intratrain prospective motion correction for turbo spin-echo sequences with constant flip angles
# A multi-inversion multi-echo spin and gradient echo echo planar imaging sequence with low image distortion for rapid quantitative parameter mapping and synthetic image contrasts
# Ultrashort echo time Cones double echo steady state (UTE-Cones-DESS) for rapid morphological imaging of short T2 tissues
# Whole-brain amide CEST imaging at 3T with a steady-state radial MRI acquisition
# Removal of off-resonance xenon gas artifacts in pulmonary gas-transfer MRI
# Aliasing artifact reduction in spiral real-time MRI
# Motion-insensitive diffusion imaging of the brain using optical tracking and dynamic sequence updates
# PVP-coated Gd-grafted nanodiamonds as a novel and potentially safer contrast agent for in vivo MRI
# Preliminary demonstration of in vivo quasi-steady-state CEST postprocessing—Correction of saturation time and relaxation delay for robust quantification of tumor MT and APT effects
# Artifact reduction in free-breathing, free-running myocardial perfusion imaging with interleaved non-selective RF excitations
# Dynamic MRI of the abdomen using parallel non-Cartesian convolutional recurrent neural networks
# Can R2’ mapping evaluate hypoxia in renal ischemia reperfusion injury quantitatively? An experimental study
# Diffusion-prepared fast spin echo for artifact-free spinal cord imaging
# Investigating plasma volume expanders as novel macromolecular MRI-CEST contrast agents for tumor contrast-enhanced imaging
# Simultaneous proteoglycans and hypoxia mapping of chondrosarcoma environment by frequency selective CEST MRI
# Calibration of T2 oximetry MRI for subjects with sickle cell disease
# A simulation study of cell size and volume fraction mapping for tissue with two underlying cell populations using diffusion-weighted MRI
# Parsimonious modeling of skeletal muscle perfusion: Connecting the stretched exponential and fractional Fickian diffusion
# Superoxide free radical spin-lattice relaxivity: A quench-assisted MR study
# Synchrotron X-ray micro-CT as a validation dataset for diffusion MRI in whole mouse brain
# MC2-Net: motion correction network for multi-contrast brain MRI
# Analysis of deep complex-valued convolutional neural networks for MRI reconstruction and phase-focused applications
# A Bayesian approach to diffusional kurtosis imaging
# Automated renal segmentation in healthy and chronic kidney disease subjects using a convolutional neural network
# A theoretical framework for retrospective  correction to the arterial input function in quantitative myocardial perfusion MRI
# A perfusion phantom for ASL MRI based on impinging jets
# Quantitative anatomy mimicking slice phantoms
# Improved whole-brain SNR with an integrated high-permittivity material in a head array at 7T
#
#                 More from this journal
#
# Log in to Wiley Online Library
# Create a new account
# 49

# %% [markdown]
# ## Next, clean up the title list

# %%
list_h2 = []
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 3:
    cells = h2.get_text()
    list_h2.append(cells)

# Delete the last element: "Log in to Wiley Online Library"
list_h2.pop()

# Insert "Issue Information" as the 2nd element
list_h2.insert(1, "Issue Information")

# https://stackoverflow.com/questions/15715912/remove-the-last-n-elements-of-a-list
del list_h2[-2:]

for l in list_h2:
  print(l)
print(len(list_h2))
# Out:
# Synchrotron X-ray micro-CT as a validation dataset for diffusion MRI in whole mouse brain
# Issue Information
# Calibration-free regional RF shims for MRS
# High-resolution sodium imaging using anatomical and sparsity constraints for denoising and recovery of novel features
# Motion-compensated 3D turbo spin-echo for more robust MR intracranial vessel wall imaging
# High spatial resolution spiral first-pass myocardial perfusion imaging with whole-heart coverage at 3 T
# All-systolic first-pass myocardial rest perfusion at a long saturation time using simultaneous multi-slice imaging and compressed sensing acceleration
# Apparent exchange rate imaging: On its applicability and the connection to the real exchange rate
# Imperfect spoiling in variable flip angle T1 mapping at 7T: Quantifying and minimizing impact
# MRzero - Automated discovery of MRI sequences using supervised learning
# Prospective motion detection and re-acquisition in diffusion MRI using a phase image–based method—Application to brain and tongue imaging
# Efficient whole-brain tract-specific T1 mapping at 3T with slice-shuffled inversion-recovery diffusion-weighted imaging
# Time dependence in diffusion MRI predicts tissue outcome in ischemic stroke patients
# Quasi–steady-state CEST (QUASS CEST) solution improves the accuracy of CEST quantification: QUASS CEST MRI-based omega plot analysis
# Trading off spatio-temporal properties in 3D high-speed fMRI using interleaved stack-of-spirals trajectories
# Distortion-free, high-isotropic-resolution diffusion MRI with gSlider BUDA-EPI and multicoil dynamic B0 shimming
# Highly accelerated free-breathing real-time phase contrast cardiovascular MRI via complex-difference deep learning
# Aliasing layers for processing parallel imaging and EPI ghost artifacts efficiently in convolutional neural networks
# qModeL: A plug-and-play model-based reconstruction for highly accelerated multi-shot diffusion MRI using learned priors
# Strategies to improve intratrain prospective motion correction for turbo spin-echo sequences with constant flip angles
# A multi-inversion multi-echo spin and gradient echo echo planar imaging sequence with low image distortion for rapid quantitative parameter mapping and synthetic image contrasts
# Ultrashort echo time Cones double echo steady state (UTE-Cones-DESS) for rapid morphological imaging of short T2 tissues
# Whole-brain amide CEST imaging at 3T with a steady-state radial MRI acquisition
# Removal of off-resonance xenon gas artifacts in pulmonary gas-transfer MRI
# Aliasing artifact reduction in spiral real-time MRI
# Motion-insensitive diffusion imaging of the brain using optical tracking and dynamic sequence updates
# PVP-coated Gd-grafted nanodiamonds as a novel and potentially safer contrast agent for in vivo MRI
# Preliminary demonstration of in vivo quasi-steady-state CEST postprocessing—Correction of saturation time and relaxation delay for robust quantification of tumor MT and APT effects
# Artifact reduction in free-breathing, free-running myocardial perfusion imaging with interleaved non-selective RF excitations
# Dynamic MRI of the abdomen using parallel non-Cartesian convolutional recurrent neural networks
# Can R2’ mapping evaluate hypoxia in renal ischemia reperfusion injury quantitatively? An experimental study
# Diffusion-prepared fast spin echo for artifact-free spinal cord imaging
# Investigating plasma volume expanders as novel macromolecular MRI-CEST contrast agents for tumor contrast-enhanced imaging
# Simultaneous proteoglycans and hypoxia mapping of chondrosarcoma environment by frequency selective CEST MRI
# Calibration of T2 oximetry MRI for subjects with sickle cell disease
# A simulation study of cell size and volume fraction mapping for tissue with two underlying cell populations using diffusion-weighted MRI
# Parsimonious modeling of skeletal muscle perfusion: Connecting the stretched exponential and fractional Fickian diffusion
# Superoxide free radical spin-lattice relaxivity: A quench-assisted MR study
# Synchrotron X-ray micro-CT as a validation dataset for diffusion MRI in whole mouse brain
# MC2-Net: motion correction network for multi-contrast brain MRI
# Analysis of deep complex-valued convolutional neural networks for MRI reconstruction and phase-focused applications
# A Bayesian approach to diffusional kurtosis imaging
# Automated renal segmentation in healthy and chronic kidney disease subjects using a convolutional neural network
# A theoretical framework for retrospective  correction to the arterial input function in quantitative myocardial perfusion MRI
# A perfusion phantom for ASL MRI based on impinging jets
# Quantitative anatomy mimicking slice phantoms
# Improved whole-brain SNR with an integrated high-permittivity material in a head array at 7T
# 47

# %% [markdown]
# ### Add dates first published

# %%
# li class: corresponds to "First Published"

all_li = soupMRM.find_all("li")

# i = 0
# for li in all_li:
  # li_class = li.get_attribute_list("class")
  # print(li_class)
  # if li_class == ['ePubDate']:
    # print(li.get_text())
    # i += 1
  # print(li.get_text())
  # i += 1
# print(i)

list_date = []
for li in all_li:
  li_class = li.get_attribute_list("class")
  if li_class == ['ePubDate']:
    cells = li.get_text().split(': ')[1]
    list_date.append(cells)

for l in list_date:
  print(l)
print(len(list_date))
# Out:
# 24 April 2021
# 24 April 2021
# 21 March 2021
# 25 March 2021
# 25 March 2021
# 11 March 2021
# 10 March 2021
# 10 March 2021
# 01 March 2021
# 23 March 2021
# 04 March 2021
# 21 March 2021
# 23 March 2021
# 10 March 2021
# 10 March 2021
# 10 March 2021
# 15 March 2021
# 14 March 2021
# 24 March 2021
# 16 March 2021
# 25 March 2021
# 23 March 2021
# 27 March 2021
# 04 March 2021
# 16 March 2021
# 15 March 2021
# 16 March 2021
# 15 March 2021
# 25 March 2021
# 21 March 2021
# 16 March 2021
# 15 March 2021
# 25 March 2021
# 27 March 2021
# 14 March 2021
# 28 February 2021
# 16 March 2021
# 23 March 2021
# 25 March 2021
# 15 March 2021
# 16 March 2021
# 25 March 2021
# 23 March 2021
# 24 March 2021
# 27 March 2021
# 19 March 2021
# 23 March 2021
# 47

# %%
list_url = []
for link in all_links:
  if 'visitable' in str(link.get("class")): # and '/doi/' in link.get("href"):
    cells = link.get("href").replace('/doi', 'https://doi.org')
    list_url.append(cells)

for l in list_url:
  print(l)
print(len(list_url))
# Out:
# https://doi.org/10.1002/mrm.28817
# https://doi.org/10.1002/mrm.28371
# https://doi.org/10.1002/mrm.28749
# https://doi.org/10.1002/mrm.28767
# https://doi.org/10.1002/mrm.28777
# https://doi.org/10.1002/mrm.28701
# https://doi.org/10.1002/mrm.28712
# https://doi.org/10.1002/mrm.28714
# https://doi.org/10.1002/mrm.28720
# https://doi.org/10.1002/mrm.28727
# https://doi.org/10.1002/mrm.28729
# https://doi.org/10.1002/mrm.28734
# https://doi.org/10.1002/mrm.28743
# https://doi.org/10.1002/mrm.28744
# https://doi.org/10.1002/mrm.28742
# https://doi.org/10.1002/mrm.28748
# https://doi.org/10.1002/mrm.28750
# https://doi.org/10.1002/mrm.28758
# https://doi.org/10.1002/mrm.28756
# https://doi.org/10.1002/mrm.28763
# https://doi.org/10.1002/mrm.28761
# https://doi.org/10.1002/mrm.28769
# https://doi.org/10.1002/mrm.28770
# https://doi.org/10.1002/mrm.28737
# https://doi.org/10.1002/mrm.28746
# https://doi.org/10.1002/mrm.28747
# https://doi.org/10.1002/mrm.28762
# https://doi.org/10.1002/mrm.28764
# https://doi.org/10.1002/mrm.28765
# https://doi.org/10.1002/mrm.28774
# https://doi.org/10.1002/mrm.28696
# https://doi.org/10.1002/mrm.28751
# https://doi.org/10.1002/mrm.28778
# https://doi.org/10.1002/mrm.28781
# https://doi.org/10.1002/mrm.28757
# https://doi.org/10.1002/mrm.28694
# https://doi.org/10.1002/mrm.28766
# https://doi.org/10.1002/mrm.28722
# https://doi.org/10.1002/mrm.28776
# https://doi.org/10.1002/mrm.28719
# https://doi.org/10.1002/mrm.28733
# https://doi.org/10.1002/mrm.28741
# https://doi.org/10.1002/mrm.28768
# https://doi.org/10.1002/mrm.28760
# https://doi.org/10.1002/mrm.28697
# https://doi.org/10.1002/mrm.28740
# https://doi.org/10.1002/mrm.28780
# 47

# %%
# df = pd.DataFrame({'title':list_h2, 'url': list_url})
df = pd.DataFrame({'Journal': title, 
                   #'Category': list_category, 
                   'Title': list_h2, 
                   'First Published': list_date, 
                   'DOI': list_url})
df
# Out:
#                                           Journal  ...                                DOI
# 0    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28817
# 1    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28371
# 2    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28749
# 3    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28767
# 4    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28777
# 5    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28701
# 6    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28712
# 7    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28714
# 8    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28720
# 9    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28727
# 10   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28729
# 11   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28734
# 12   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28743
# 13   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28744
# 14   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28742
# 15   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28748
# 16   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28750
# 17   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28758
# 18   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28756
# 19   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28763
# 20   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28761
# 21   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28769
# 22   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28770
# 23   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28737
# 24   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28746
# 25   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28747
# 26   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28762
# 27   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28764
# 28   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28765
# 29   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28774
# 30   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28696
# 31   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28751
# 32   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28778
# 33   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28781
# 34   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28757
# 35   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28694
# 36   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28766
# 37   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28722
# 38   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28776
# 39   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28719
# 40   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28733
# 41   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28741
# 42   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28768
# 43   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28760
# 44   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28697
# 45   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28740
# 46   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28780
#
# [47 rows x 4 columns]

# %% [markdown]
# ## Third, manually create the list of category based on Issue Information
#  - See [here](https://stackoverflow.com/questions/4654414/python-append-item-to-list-n-times) for extending elements in a list for X times

# %%
# list_category = ['Cover Image', 'Issue Information', 'Commentary']

### Vol 86 No 2 ###
list_category = ['Cover Image', 'Issue Information']
list_category.extend(['FULL PAPER—SPECTROSCOPIC METHODOLOGY'] * 1)
list_category.extend(['RAPID COMMUNICATIONS—IMAGING METHODOLOGY'] * 2)
list_category.extend(['FULL PAPERS—IMAGING METHODOLOGY'] * 18)
list_category.extend(['TECHNICAL NOTES—IMAGING METHODOLOGY'] * 7)
list_category.extend(['FULL PAPERS—PRECLINICAL AND CLINICAL IMAGING'] * 4)
list_category.extend(['TECHNICAL NOTE—PRECLINICAL AND CLINICAL IMAGING'] * 1)
list_category.extend(['FULL PAPERS—BIOPHYSICS AND BASIC MIOMEDICAL RESEARCH'] * 2)
list_category.extend(['TECHNICAL NOTE—BIOPHYSICS AND BASIC MIOMEDICAL RESEARCH'] * 2)
list_category.extend(['FULL PAPERS—COMPUTER PROCESSING AND MODELING'] * 4)
list_category.extend(['TECHNICAL NOTE—COMPUTER PROCESSING AND MODELING'] * 1)
list_category.extend(['FULL PAPER—HARDWARE AND INSTRUMENTATION'] * 1)
list_category.extend(['TECHNICAL NOTES—HARDWARE AND INSTRUMENTATION'] * 2)

### Vol 86 No 4 ###
# list_category = ['Cover Image', 'Issue Information', 'Orbituary']
# list_category.extend(['RESEARCH ARTICLE—PRECLINICAL AND CLINICAL SPECTROSCOPY'] * 1)
# list_category.extend(['RESEARCH ARTICLES—IMAGING METHODOLOGY'] * 19)
# list_category.extend(['TECHNICAL NOTES—IMAGING METHODOLOGY'] * 2)
# list_category.extend(['RESEARCH ARTICLES—PRECLINICAL AND CLINICAL IMAGING'] * 3)
# list_category.extend(['TECHNICAL NOTE—PRECLINICAL AND CLINICAL IMAGING'] * 1)
# list_category.extend(['TECHNICAL NOTE—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH'] * 1)
# list_category.extend(['RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING'] * 7)
# list_category.extend(['TECHNICAL NOTE—COMPUTER PROCESSING AND MODELING'] * 1)
# list_category.extend(['RESEARCH ARTICLES—HARDWARE AND INSTRUMENTATION'] * 3)
# list_category.extend(['RESEARCH ARTICLE—ESR'] * 1)

i = 0
for l in list_category:
  print(l)
  i += 1
print(i)
# Out:
# Cover Image
# Issue Information
# FULL PAPER—SPECTROSCOPIC METHODOLOGY
# RAPID COMMUNICATIONS—IMAGING METHODOLOGY
# RAPID COMMUNICATIONS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# FULL PAPERS—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# FULL PAPERS—PRECLINICAL AND CLINICAL IMAGING
# FULL PAPERS—PRECLINICAL AND CLINICAL IMAGING
# FULL PAPERS—PRECLINICAL AND CLINICAL IMAGING
# FULL PAPERS—PRECLINICAL AND CLINICAL IMAGING
# TECHNICAL NOTE—PRECLINICAL AND CLINICAL IMAGING
# FULL PAPERS—BIOPHYSICS AND BASIC MIOMEDICAL RESEARCH
# FULL PAPERS—BIOPHYSICS AND BASIC MIOMEDICAL RESEARCH
# TECHNICAL NOTE—BIOPHYSICS AND BASIC MIOMEDICAL RESEARCH
# TECHNICAL NOTE—BIOPHYSICS AND BASIC MIOMEDICAL RESEARCH
# FULL PAPERS—COMPUTER PROCESSING AND MODELING
# FULL PAPERS—COMPUTER PROCESSING AND MODELING
# FULL PAPERS—COMPUTER PROCESSING AND MODELING
# FULL PAPERS—COMPUTER PROCESSING AND MODELING
# TECHNICAL NOTE—COMPUTER PROCESSING AND MODELING
# FULL PAPER—HARDWARE AND INSTRUMENTATION
# TECHNICAL NOTES—HARDWARE AND INSTRUMENTATION
# TECHNICAL NOTES—HARDWARE AND INSTRUMENTATION
# 47

# %%
df.insert(1, 'Category', list_category)
df
# Out:
#                                           Journal  ...                                DOI
# 0    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28817
# 1    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28371
# 2    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28749
# 3    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28767
# 4    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28777
# 5    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28701
# 6    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28712
# 7    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28714
# 8    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28720
# 9    Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28727
# 10   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28729
# 11   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28734
# 12   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28743
# 13   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28744
# 14   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28742
# 15   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28748
# 16   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28750
# 17   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28758
# 18   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28756
# 19   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28763
# 20   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28761
# 21   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28769
# 22   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28770
# 23   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28737
# 24   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28746
# 25   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28747
# 26   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28762
# 27   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28764
# 28   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28765
# 29   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28774
# 30   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28696
# 31   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28751
# 32   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28778
# 33   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28781
# 34   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28757
# 35   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28694
# 36   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28766
# 37   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28722
# 38   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28776
# 39   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28719
# 40   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28733
# 41   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28741
# 42   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28768
# 43   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28760
# 44   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28697
# 45   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28740
# 46   Magnetic Resonance in Medicine: Vol 86, No 2  ...  https://doi.org/10.1002/mrm.28780
#
# [47 rows x 5 columns]

# %% [markdown]
# ## Save as csv

# %%
df.to_csv(path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/mrm-vol-86-no-2.csv',
          # path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/mrm-vol-86-no-4.csv', 
          index=False)

# %% [markdown]
# ## Save as xlsx file
#  - See [here](https://xlsxwriter.readthedocs.io/working_with_pandas.html) for instruction

# %%
# !pip install xlsxwriter
import xlsxwriter

# (Comment out after saving first sheet) Create an ExcelWriter object
# writer = pd.ExcelWriter('/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-all-summary.xlsx', engine='xlsxwriter')

# %%
df.to_excel(excel_writer=writer,
            # sheet_name='jmri-vol-54-no-1',
            # sheet_name='jmri-vol-54-no-2',
            sheet_name='jmri-vol-54-no-3',
            index=False)

# %%
# (Uncomment at the end) Close the Pandas Excel writer and output the Excel file.
writer.save()
