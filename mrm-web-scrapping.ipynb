# %% [markdown]
# # Web Scraping using Python

# %% [markdown]
# ## Target Journal: MRM
#
# - https://onlinelibrary.wiley.com/toc/15222594/2022/87/2
# - https://onlinelibrary.wiley.com/toc/15222594/2022/87/1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#To easily display the plots, make sure to include the line %matplotlib inline as shown below.
# %matplotlib inline

import urllib
import requests
import lxml

#To perform web scraping, you should also import the libraries shown below. 
#The urllib.request module is used to open URLs. 
#The Beautiful Soup package is used to extract data from html files. 
#The Beautiful Soup library's name is bs4 which stands for Beautiful Soup, version 4.
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ## First, save as a local html file
#  - See: https://zetcode.com/python/beautifulsoup/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# MRM Vol 87 No 2
URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Magnetic Resonance in Medicine_ Vol 87, No 2.html'
# MRM Vol 87 No 1
# URL = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/Magnetic Resonance in Medicine_ Vol 87, No 1.html'

with open(URL, 'r') as f:

    contents = f.read()

    soup = BeautifulSoup(contents, 'lxml')

# %% [markdown]
# Find the corresponding index, and identify the title info

# %%
def safeOpenParsePage(targetUrl):
    try:
        # tmpurl = urlopen(Request(targetUrl, headers={'User-Agent': 'Chrome/92.0.4515.107'}))
        tmpurl = open(targetUrl, 'r')
        tmpR = tmpurl.read()
        # tmpSoup = BeautifulSoup(tmpR, 'html.parser')
        tmpSoup = BeautifulSoup(tmpR, 'lxml')
        return tmpSoup
    except urllib.error.HTTPError as e:
        print(e)
        return None

soupMRM = safeOpenParsePage(URL)
if soupMRM is not None:
      print(soupMRM.prettify())
# Out:
# <!DOCTYPE html>
# <html class="pb-page" data-request-id="77439159-6e1b-4bfb-8a48-74ca1c8a7e72" lang="en">
#  <head data-pb-dropzone="head">
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content=";journal:journal:15222594;ctype:string:Journal Content;website:website:pericles;requestedJournal:journal:15222594;page:string:Table of Contents;wgroup:string:Publication Websites;pageGroup:string:Publication Pages;issue:issue:doi\:10.1002/mrm.v87.2" name="pbContext"/>
#   <script type="text/javascript">
#    var $DoubleClickZone = "magres-med_mrm";var $DoubleClickSite =  "wly.radiol.imag_000105";
#   </script>
#   <script id="analyticDigitalData">
#    digitalData = {"site":{"ip":"152.78.0.24","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2022-01-09"},"identities":[{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"ReferrerUser","uuid":"5a2c1d70-1255-4a45-95f3-a3aa3a2771fb"},{"type":"InstitutionUser","uuid":"58cbd8e6-3c5d-4fc0-ac26-57c4792d2c4b","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALWB000204"}]},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"SmartGroupUser","uuid":"cb1790a9-a0b9-40b3-915d-806df593aeeb"},{"type":"ReferrerUser","uuid":"6401b279-b825-4f41-a389-04e29feb967f"},{"type":"InstitutionUser","uuid":"bfa4ccf8-8126-488a-b090-da278aa7b4d9","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOG00017"}]},{"type":"BasicGroup","uuid":"6a17ff38-0daf-4f0a-b4eb-b42c69d5c12f","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000007783"}]},{"type":"BasicGroup","uuid":"9cb21bff-5e36-40b2-9183-08a76524dc18","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL57933332"}]},{"type":"InstitutionUser","uuid":"a7606ea9-e934-4307-a3d4-c30ec2175d59","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOB00014"}]},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"RegionUser","uuid":"3147507a-46c1-4f33-a077-4feac12c6b71"},{"type":"SmartGroupUser","uuid":"1a6297fb-6679-4882-a4c2-fdd124624edf"},{"type":"SmartGroupUser","uuid":"77da7ca2-c9f3-4f94-9737-922e1d15b7d9"},{"type":"SmartGroupUser","uuid":"8032f17e-5050-4fb4-9c40-e1f6875d5c2b"},{"type":"BasicGroup","uuid":"2f6750d5-f13f-4356-939b-048ac1423e64"},{"type":"SmartGroupUser","uuid":"a4187e00-f28e-4754-9a0f-1eb306fb0679"},{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"BasicGroup","uuid":"32489ba7-57d6-43ed-b717-a0de5ed5ca0e"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"InstitutionUser","uuid":"1b19994e-f6cd-4a6e-b151-a166eb757a02","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALEM00084"}]},{"type":"InstitutionUser","uuid":"838af7aa-2073-4eca-9e95-df167c7953bb","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"SOUTHA450S"}]},{"type":"InstitutionUser","uuid":"a454dd84-0b2c-4d7b-804b-20fd42da68c7","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"P#JISC"}]},{"type":"BasicGroup","uuid":"8b5697d0-0580-43b3-83ea-a258c8085ad5","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004148"}]},{"type":"InstitutionUser","uuid":"2196ade6-df1b-4d0d-b877-7d8cca58ee79","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"PARENTNESLI"}]},{"type":"BasicGroup","uuid":"8d568359-32d1-4757-be79-b72d00d11429"},{"type":"BasicGroup","uuid":"a9298b81-eb3e-4dfb-82a5-86f98d156f4d","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004150"}]},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"InstitutionUser","uuid":"c2c7b09d-2b4d-4ce1-b401-b744073e0ebc","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000165532"}]},{"type":"BasicGroup","uuid":"f0737c70-8d27-48b0-8b44-af576d0063e8","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000068532"}]},{"type":"SmartGroupUser","uuid":"261f34be-39f9-4f9e-8feb-500f73213904"},{"type":"InstitutionUser","uuid":"ca0c2bfa-0ec9-4312-aa4b-4c51702429d4","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL0000647"}]},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"20d013f5-e22b-4df0-ba93-d6d925db9e32"},{"type":"RegionUser","uuid":"82409588-c43f-4337-a6a8-3272d1b7e20e"},{"type":"SmartGroupUser","uuid":"055a2bdd-861f-4fa7-bd49-9773db7e0e3e"},{"type":"SmartGroupUser","uuid" ...
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="noarchive" name="robots"/>
#   <meta content=" Magnetic Resonance in Medicine: Vol 87, No 2" property="og:title"/>
#   <meta content="Journal" property="og:type"/>
#   <meta content="https://onlinelibrary.wiley.com/toc/15222594/current" property="og:url"/>
#   <meta content="https://onlinelibrary.wiley.com/cover/15222594/87/2" property="og:image"/>
#   <meta content="Wiley Online Library" property="og:site_name"/>
#   <meta content="Click on the title to browse this issue" property="og:description"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="app-id=673865417" name="apple-itunes-app"/>
#   <link as="script" href="https://cmp.osano.com/AzZdRbSORDOOzF9W/67a788d8-9344-4c9b-a3c2-89b5073ee231/osano.js" rel="preload"/>
#   <script src="https://cmp.osano.com/AzZdRbSORDOOzF9W/67a788d8-9344-4c9b-a3c2-89b5073ee231/osano.js">
#   </script>
#   <meta content="10.1002/mrm.v87.2" name="citation_doi"/>
#   <meta content="10.1002/mrm.v87.2" name="dc.identifier"/>
#   <title>
#    Magnetic Resonance in Medicine: Vol 87, No 2
#   </title>
#   <link href="/wro/kw3w~article-metrics-phase3.css" rel="stylesheet" type="text/css"/>
#   <link href="/wro/kw3w~product.css" rel="stylesheet" type="text/css"/>
#   <link as="font" crossorigin="anonymous" href="/products/acropolis/pericles/releasedAssets/fonts/icomoon/icomoon.woff?67510c72b3d0b403eb21" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/products/acropolis/pericles/releasedAssets/fonts/open-sans/open-sans-v15-latin-regular.woff2?67510c72b3d0b403eb21" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="/products/acropolis/pericles/releasedAssets/fonts/source-serif-pro/source-serif-pro-v5-latin-regular.woff2?67510c72b3d0b403eb21" rel="preload" type="font/woff2"/>
#   <link href="/products/acropolis/pericles/releasedAssets/css/build-67510c72b3d0b403eb21.css" rel="stylesheet"/>
#   <link href="/products/acropolis/pericles/releasedAssets/css/print-67510c72b3d0b403eb21.css" media="print" rel="stylesheet"/>
#   <script async="" src="/pb-assets/catchpoint-1549680351760.js">
#   </script>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/pb-assets/hub-assets/pericles/hub-1628068886633.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/iucr-1510734465460.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/readcube-1510565373110.css" rel="stylesheet" type="text/css"/>
#   <link href="/pb-assets/css/dr-overrides-1611780866727.css" rel="stylesheet" type="text/css"/>
#   <!-- link rel="stylesheet" type="text/css" href="/pb-assets/css/temporary-1525702334993.css" -->
#   <style>
#    /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#   </style>
#   <!-- The Adobe DTM script. Must come after the digitalData object -->
#   <script src="//assets.adobedtm.com/6e626c9ec247e474f6b98eb15a79a185cf7e26a5/satelliteLib-c1ac050bbdc647f13a62578e71f0d817f8a6cbb5.js">
#   </script>
#   <!-- Google Search Console verification -->
#   <meta content="ffz4i4DxIJCdGpRXe0XN6KG6o4FYI-nnFW9I_dg8piM" name="google-site-verification"/>
#   <!-- KRUX Implementation-->
#   <script class="kxct" data-id="JMOONjNh" data-timing="async" data-version="1.9" type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#   </script>
#   <!-- KRUX Implementation cont'd -->
#   <script type="text/javascript">
#    window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#   </script>
#   <!-- Grapeshot Implementation -->
#   <script>
#    var gs_channels = 'default';
#   </script>
#   <script async="" src="//wiley.grapeshot.co.uk/main/channels.cgi?url=https://onlinelibrary.wiley.com/toc/15222594/current">
#   </script>
#   <!-- DoubleClick Implementation -->
#   <script type="text/javascript">
#    var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#   </script>
#   <script>
#    var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#   </script>
#   <script>
#    googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/mrm.v87.2')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#   </script>
#   <script src="//validate.onecount.net/js/all.min.js#cff4b10c3a3d5cc9bbb7e2b9292cc66eae1deafa">
#   </script>
#   <script>
#    try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#   </script>
#   <script data-cf-beacon='{"rayId":"65604cf31ed0e4d9","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.1","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script data-cf-beacon='{"rayId":"65cb04cf2c4898e7","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <script async="" src="/cdn-cgi/bm/cv/669835187/api.js">
#   </script>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#   </script>
#   <script data-cf-beacon='{"rayId":"65d1a8e0c92cd32a","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.5.2","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#   <link href="https://onlinelibrary.wiley.com/toc/15222594/current" rel="canonical"/>
#   <!-- Get whether TNSI is in live or test mode -->
#   <!-- Get the configured TNSI Javascript version number -->
#   <!-- Get the configured TNSI MerchantID -->
#   <!-- Add "TEST" to beginning of merchant ID when running in test mode -->
#   <!-- loading Javascript for using the persistence Service -->
#   <script src="//unpkg.com/@theidentityselector/thiss-ds">
#   </script>
#   <script type="text/javascript">
#    function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf('?') !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId, entityTitle) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId, entityTitle: entityTitle, eventGroupKey: 'bd076971-27f4-4b1d-8cfa-29c5f58ff0f2'}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID, ssoInstitution.entity.title)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#   </script>
#   <script type="text/javascript">
#    (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaaZ9JNVdN5zc5FfKw74x';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#   </script>
#   <script>
#    var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Magnetic Resonance in Medicine: Vol 87, No 2";
#   </script>
#  </head>
#  <body class="pb-ui">
#   <div class="skip-links">
#    <ul class="rlist">
#     <li>
#      <a href="#main-content" tabindex="1">
#       Skip to Main Content
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div data-ng-non-bindable="" id="pb-page-content">
#    <div data-pb-dropzone="main" data-pb-dropzone-name="Main">
#     <div class="pageHeader" data-widget-def="pageHeader" data-widget-id="62175478-b98a-43d5-90f2-1f2045ac1a7e">
#      <header class="page-header">
#       <div data-pb-dropzone="main">
#        <div class="admin-message" data-widget-def="ux3-layout-widget" data-widget-id="bb5b5e2c-d3d6-4015-b586-eeade38f59d4">
#         <div class="container">
#          <div class="row">
#           <div>
#            <div class="pb-ad">
#             <div style="background=blue;">
#              <div class="container">
#               <p style="text-align: center;">
#                <b>
#                 Working off-campus?
#                </b>
#                Learn about our
#                <a href="/action/clickThrough?id=101169&amp;url=https%3A%2F%2Fonlinelibrary.wiley.com%2Fresearchers%2Fread%2Faccess-options&amp;loc=%2Ftoc%2F15222594%2Fcurrent&amp;pubId=76114538&amp;placeholderId=1029&amp;productId=1011" tabindex="2" target="_blank">
#                 <font color="white">
#                  <u>
#                   remote access options
#                  </u>
#                 </font>
#                </a>
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="container">
#         <div class="row">
#          <div class="contents col-md-12">
#           <div class="institution-wrapper-mobile hidden-lg hidden-md padded-content" data-widget-def="UX3InstitutionBanner" data-widget-id="4d1f2e23-571a-4b27-8ab7-e7cd8ca15964">
#            <div class="institution">
#             <div class="institution-box no-image">
#              <div class="institution-info-wrapper">
#               <span class="institution__name">
#                University of Southampton
#               </span>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="pull-left">
#            <div class="logo-container hidden-xs hidden-sm hidden-md" data-widget-def="ux3-general-image" data-widget-id="ff262197-0fb8-4973-aaa2-2fceba4b5a61">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mainLogo" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#             </a>
#            </div>
#            <div class="logo-container-mobile hidden-lg hidden-md hidden-sm" data-widget-def="ux3-general-image" data-widget-id="6b601b23-7301-47c8-8889-242d041241c4">
#             <a href="/" title="Wiley Online Library">
#              <img alt="Wiley Online Library" id="mobileLogo" src="/pb-assets/hub-assets/pericles/mobilehublogo-1518781861020.png"/>
#             </a>
#            </div>
#            <div class="institution-wrapper hidden-xs hidden-sm hidden-md institution--block" data-widget-def="UX3InstitutionBanner" data-widget-id="14d0e2f8-27d3-42d0-a477-72015e14e818">
#             <div class="institution">
#              <div class="institution-box no-image">
#               <div class="institution-info-wrapper">
#                <span class="institution__name">
#                 University of Southampton
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="header-quicksearch" data-widget-def="UX3QuickSearchWidget" data-widget-id="48175bb0-0f70-46e6-bb89-7e2781fdb8e4">
#             <div class="quick-search-wrapper">
#              <a aria-label="Search" class="quick-search__item" href="#" title="search">
#               <i aria-hidden="true" class="icon-search">
#               </i>
#               <span class="quick-search__item__arrow">
#               </span>
#              </a>
#              <div class="quick-search quickSearchFormContainer" data-linkto-page="true">
#               <div class="main-search-field-wrapper">
#                <div class="tab clearfix">
#                 <input class="fakeQSInput quickSearchFilter" placeholder="Search" tabindex="13" type="search" value=""/>
#                 <label class="sr-only" for="search-within">
#                  Search within
#                 </label>
#                 <select class="search-within" id="search-within" name="search-within" tabindex="10">
#                  <option data-url="thisCategory" data-value="15222594" value="#pane-67065c09-4a88-49cd-934c-ac707951d35c0">
#                   This Journal
#                  </option>
#                  <option data-url="https://onlinelibrary.wiley.com" value="#pane-67065c09-4a88-49cd-934c-ac707951d35c1">
#                   Anywhere
#                  </option>
#                 </select>
#                 <ul class="rlist tab__content" role="tablist">
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c0-con" class="tab__pane quick-search-pane__anywhere active" id="pane-67065c09-4a88-49cd-934c-ac707951d35c0" role="tab">
#                   <form action="/action/doSearch" method="get" name="thisJournalQuickSearch" title="Quick Search">
#                    <div class="input-group option-0">
#                     <label class="hiddenLabel" for="searchField0">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField0" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <input name="SeriesKey" type="hidden" value="15222594"/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222594" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced?publication=15222594#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                  <li aria-labelledby="pane-67065c09-4a88-49cd-934c-ac707951d35c1-con" class="tab__pane quick-search-pane__anywhere" id="pane-67065c09-4a88-49cd-934c-ac707951d35c1" role="tab">
#                   <form action="https://onlinelibrary.wiley.com/action/doSearch" method="get" name="defaultQuickSearch" title="Quick Search">
#                    <div class="input-group option-1">
#                     <label class="hiddenLabel" for="searchField1">
#                      Search term
#                     </label>
#                     <input class="autocomplete actualQSInput quickSearchFilter" data-auto-complete-max-chars="32" data-auto-complete-max-words="7" data-contributors-conf="3" data-history-items-conf="3" data-publication-titles-conf="3" data-topics-conf="3" id="searchField1" name="AllField" onfocus="this.value = this.value;" placeholder="Search" tabindex="9" type="search" value=""/>
#                     <div class="search-options-wrapper quickSearchFilter">
#                      <a class="advanced" href="https://onlinelibrary.wiley.com/search/advanced" tabindex="12" title="">
#                       Advanced Search
#                      </a>
#                      <a class="citation" href="https://onlinelibrary.wiley.com/search/advanced#citation" tabindex="12" title="">
#                       Citation Search
#                      </a>
#                     </div>
#                    </div>
#                    <button aria-label="Submit Search" class="btn quick-search__button icon-search" tabindex="11" title="Search" type="submit">
#                    </button>
#                   </form>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="cart-indicator__wrapper" data-widget-def="ux3-layout-widget" data-widget-id="5ef13ed1-f4ac-4b62-a426-07ec9576a586">
#             <div class="pull-left">
#              <div class="cart-indicator__wrapper" data-widget-def="eCommerceCartIndicatorWidget" data-widget-id="4a9f7c04-a273-4a25-91fb-8e7bd9970288">
#               <div class="eCommerceCartIndicatorWidget">
#               </div>
#              </div>
#             </div>
#             <div class="pull-right">
#              <div class="login-bar-container" data-widget-def="literatumNavigationLoginBar" data-widget-id="d384ca92-7137-45d6-b3c2-78c9c0a98c2b">
#               <div class="loginBar login-open">
#                <a aria-label="Log in or Register" class="show-login" href="/action/showLogin?uri=%2Ftoc%2F15222594%2Fcurrent&amp;aria-label=Log+in+or+Register" role="button" uri="/toc/15222594/current">
#                 <span class="icon-profile_empty">
#                 </span>
#                 <span class="sign-in-label">
#                  Login / Register
#                 </span>
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </header>
#     </div>
#     <h1 class="hidden">
#      Journal list menu
#     </h1>
#     <div class="pages-nav--sticky pages-nav hidden-lg fixed-element">
#      <div class="pages-nav--res">
#       <div class="container">
#        <ul class="rlist--inline pull-left">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="journal-list" href="#">
#           <i aria-hidden="true" class="icon-toc">
#           </i>
#           <span>
#            Journal
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="journal-list" id="journal-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-1, #menu-item-undefined-2, #menu-item-main-menu-1-1, #menu-item-main-menu-1-2, #menu-item--1, #menu-item--2, .journal-featured" data-toggle="transplant" data-transplant="self">
#           </div>
#           <!-- PERICLES-7683
#               <a href="#" title="More from this journal" class="dropdown__toggle"><span>More from this journal</span></a>
#
#                 <div data-target=".journal-resources" data-remove="false" data-toggle="transplant" data-direction="from" data-transplant="self" class="transplant showit"></div>
# -->
#          </div>
#         </li>
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="articles-list" href="#">
#           <i class="article-img-icon">
#            <img src="/pb-assets/hub-assets/pericles/articles_1-1499257321163.png"/>
#           </i>
#           <span>
#            Articles
#           </span>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="articles-list" id="articles-list">
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#menu-item-undefined-3, #menu-item-undefined-4, #menu-item-main-menu-1-3, #menu-item-main-menu-1-4, #menu-item--3" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#        <ul class="rlist--inline pull-right">
#         <li>
#          <a data-db-switch="icon-close_thin" data-db-target-for="actions-list" href="#">
#           <span>
#            Actions
#           </span>
#           <i aria-hidden="true" class="icon-chevron-down">
#           </i>
#          </a>
#          <div class="rlist dropBlock__holder" data-db-target-of="actions-list" id="actions-list">
#           <h2 class="side-section-header hiddenLabel--lg">
#            Tools
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target=".journal-actions-container li:nth-child(1), .journal-actions-container li:nth-child(2), .journal-actions-container li:nth-child(3), .journal-actions-container li:nth-child(4), .journal-actions-container li:nth-child(5), #subscribeLink" data-toggle="transplant" data-transplant="self">
#           </div>
#           <h2 class="side-section-header hiddenLabel--lg">
#            Follow journal
#           </h2>
#           <div class="transplant showit" data-direction="from" data-remove="false" data-target="#alert-link, #facebook-link, #twitter-link, #linkedin-link, #most-recent-link, #most-read-link, #most-cited-link" data-toggle="transplant" data-transplant="self">
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="pageBody body-text" data-widget-def="pageBody" data-widget-id="72100436-7a82-49fc-933b-c6c9d8c42914">
#      <main id="main-content" tabindex="-1">
#       <!--begin pagefulltext-->
#       <div class="page-body pagefulltext">
#        <div data-pb-dropzone="main">
#         <div class="js--fixed-switch" data-widget-def="ux3-layout-widget" data-widget-id="6da55ccb-5daf-4c91-b961-05eee9e6f293">
#          <div>
#           <div class="secondary-bg-color banner-wrapper" data-widget-def="literatumAd" data-widget-id="0220a30b-90c0-4b51-8637-141edf12f86a">
#            <div class="pb-ad">
#             <aside role="complementary">
#              <div class="advert advert-leaderboard" id="advert-leaderboard">
#               <script>
#                googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#               </script>
#               <!-- No JavaScript support is a call to an image -->
#               <noscript>
#                <a href="/action/clickThrough?id=1013&amp;url=https%3A%2F%2Fpubads.g.doubleclick.net%2Fgampad%2Fjump%3Fiu%3D%24googlePublisherCategory%26amp%3Bsz%3D728x90%26amp%3Btile%3D1%26amp%3Bc%3D%24random&amp;loc=%2Ftoc%2F15222594%2Fcurrent&amp;pubId=76114538&amp;placeholderId=1015&amp;productId=101018" target="_blank">
#                 <img src="https://pubads.g.doubleclick.net/gampad/ad?iu=$googlePublisherCategory&amp;sz=728x90&amp;tile=1&amp;c=$random"/>
#                </a>
#               </noscript>
#              </div>
#             </aside>
#            </div>
#           </div>
#           <style type="text/css">
#            li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#           </style>
#           <section class="journal-page-header card" data-widget-def="ux3-layout-widget" data-widget-id="9e8ee65a-2e18-4c00-9474-5ac10e16ecfe">
#            <div class="container">
#             <div class="row">
#              <div class="journal-info-container col-md-8">
#               <a href="/journal/15222594" title="Magnetic Resonance in Medicine homepage">
#                <h1 id="journal-banner-text" style="margin: 0; font-size: 0">
#                 Magnetic Resonance in Medicine
#                </h1>
#                <img alt="Magnetic Resonance in Medicine" class="journal-banner-image" id="journal-banner-image" src="/pb-assets/journal-banners/15222594-1589988604920.jpg" style="margin-bottom: 15px; display: none"/>
#               </a>
#               <script>
#                var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222594-1589988604920.jpg";
#               </script>
#              </div>
#              <div class="hidden-xs hidden-sm hidden-md col-md-4">
#              </div>
#             </div>
#            </div>
#           </section>
#           <div class="stickybar pages-nav hidden-xs hidden-sm hidden-md scrollable-element" data-widget-def="menuWidget" data-widget-id="998218b4-f988-4a0c-8c4f-b2d3875e1770">
#            <div class="stickybar__wrapper">
#             <div class="main-nav">
#              <a data-toggle="nav" href="#undefined" title="menu drawer">
#               <i aria-hidden="true" class="icon-menu2">
#               </i>
#               <i aria-hidden="true" class="icon-close_thin">
#               </i>
#              </a>
#              <nav aria-label="Journal navigation" class="drawer__nav container gutterless hidden-sm hidden-xs" data-ctrl-res="never" role="navigation">
#               <h2 class="is-accessible">
#                Navigation Bar
#               </h2>
#               <section>
#                <h3 class="is-accessible">
#                 Menu
#                </h3>
#                <a class="menu-header hidden-md hidden-lg" href="/">
#                 Home
#                </a>
#                <ul class="menubar rlist--inline" id="menubar" role="menubar">
#                 <li class="menu-item" data-menu-label="Home" id="menu-item-undefined-0" role="presentation">
#                  <a class="sub-menu-item" href="/journal/15222594" role="menuitem" tabindex="0">
#                   <span>
#                    Home
#                   </span>
#                  </a>
#                 </li>
#                 <li class="dropdown menu-parent" data-menu-label="About" id="menu-item-undefined-1" role="presentation">
#                  <a aria-expanded="false" aria-haspopup="true" class="dropdown__toggle" data-target="About-1-dropdown" data-toggle="dropdown" href="#" id="About-1" role="menuitem" tabindex="-1">
#                   <span>
#                    About
#                   </span>
#                   <i aria-hidden="true" class="icon-arrow_r pull-right hidden-md hidden-lg">
#                   </i>
#                   <i aria-hidden="true" class="icon-section_arrow_d pull-right hidden-sm hidden-xs">
#                   </i>
#                  </a>
#                  <ul aria-labelledby="About-1" class="rlist dropdown__menu" id="About-1-dropdown" role="menu">
#                   <li class="menu-item" data-menu-label="Overview" role="presentation">
#                    <a class="sub-menu-item" href="/page/journal/15222594/homepage/productinformation.html" role="menuitem" tabindex="-1">
#                     <span>
#                      Overview
#                     </span>
#                    </a>
#                   </li>
# ...
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://www.wiley.com/privacy">
#                 Privacy Policy
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/terms-and-conditions">
#                 Terms of Use
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/cookies">
#                 Cookies
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/accessibility">
#                 Accessibility
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/publishing-policies">
#                 Publishing Policies
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Help &amp; Support
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://hub.wiley.com/community/support/onlinelibrary">
#                 Contact Us
#                </a>
#               </li>
#               <li>
#                <a href="https://www.wiley.com/customer-success/wiley-online-library-training-hub">
#                 Training and Support
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/dmca-notification-policy">
#                 DMCA &amp; Reporting Piracy
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Opportunities
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://onlinelibrary.wiley.com/agents">
#                 Subscription Agents
#                </a>
#               </li>
#               <li>
#                <a href="https://onlinelibrary.wiley.com/advertisers">
#                 Advertisers &amp; Corporate Partners
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class=" col-md-3">
#             <div class="footer-links mb-3">
#              <h3>
#               Connect with Wiley
#              </h3>
#              <ul class="rlist">
#               <li>
#                <a href="https://www.wiley.com/network">
#                 The Wiley Network
#                </a>
#               </li>
#               <li>
#                <a href="https://newsroom.wiley.com/">
#                 Wiley Press Room
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="copyright-container" data-widget-def="ux3-layout-widget" data-widget-id="86584e25-e4db-4118-9550-9b4f5341a4ac">
#          <div class="container">
#           <div class="row">
#            <div class=" col-md-12">
#             <div class="copyright" data-widget-def="UX3HTMLWidget" data-widget-id="bfbf6c5d-a650-4662-828f-5275fada9120">
#              <div class="copyright pull-left">
#               Copyright © 1999-2022
#               <a href="https://www.wiley.com">
#                John Wiley &amp; Sons, Inc
#               </a>
#               . All rights reserved
#              </div>
#             </div>
#             <div class="footer-logo pull-right">
#              <a aria-label="Wiley" href="https://www.wiley.com" title="Wiley Home Page">
#               <img alt="Wiley Home Page" src="/pb-assets/tmp-images/footer-logo-wiley-1510029248417.png"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#     <div aria-labelledby="loginPopupHead" class="popup login-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="Cancel Login" class="close" href="#" role="button">
#        <i aria-hidden="true" class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#       </div>
#       <div class="modal__body">
#        <div class="ssoLogin">
#        </div>
#        <h2 id="loginPopupHead">
#         Log in to Wiley Online Library
#        </h2>
#        <div class="login-form">
#         <form action="/action/doLogin?societyURLCode=" class="bordered" method="post">
#          <input name="id" type="hidden" value="67065c09-4a88-49cd-934c-ac707951d35c"/>
#          <input name="popup" type="hidden" value="true"/>
#          <input name="loginUri" type="hidden" value="/toc/15222594/current"/>
#          <input name="redirectUri" type="hidden" value="/toc/15222594/current"/>
#          <input name="loginUri" type="hidden" value="/toc/15222594/current"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="username">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="login" id="username" name="login" placeholder="Enter your email" required="true" size="15" spellcheck="false" type="text" value=""/>
#           <div class="actions">
#           </div>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="password">
#             Password
#            </label>
#           </div>
#           <input autocapitalize="off" autocomplete="off" autocorrect="off" class="password" id="password" name="password" placeholder="Enter your password" required="true" spellcheck="false" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="actions">
#           <a class="link show-request-reset-password" href="/action/requestResetPassword">
#            Forgot password?
#           </a>
#          </div>
#          <div class="loginExtraBeans-dropZone" data-pb-dropzone="loginExtraBeans">
#          </div>
#          <div class="align-end">
#           <span class="submit ">
#            <input class="button btn submit primary no-margin-bottom accessSubmit" name="submitButton" type="submit" value="Log In"/>
#           </span>
#          </div>
#         </form>
#         <div class="societySpecificInstructions">
#         </div>
#        </div>
#        <div class="login-container clearfix form-btn">
#         <a class="linkBtn float-left" href="/action/registration">
#          NEW USER
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#         <a class="linkBtn float-right instituation-login" href="/action/ssostart?redirectUri=%2Ftoc%2F15222594%2Fcurrent">
#          INSTITUTIONAL LOGIN
#          <span aria-hidden="true">
#           &gt;
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="changePasswordPopupHead" class="popup change-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close cancel" href="#" role="button">
#        <i class="icon-close_thin">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="changePasswordPopupHead">
#         Change Password
#        </h2>
#       </div>
#       <div class="modal__body">
#        <div class="form">
#         <form action="/action/changePassword" method="post">
#          <div class="message error">
#          </div>
#          <input name="submit" type="hidden" value="submit"/>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-old">
#             Old Password
#            </label>
#           </div>
#           <input autocomplete="off" class="old" id="a589574e-bb98-4c6e-8fed-67365ff05357-old" name="old" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#          </div>
#          <div class="input-group">
#           <div class="label">
#            <label for="a589574e-bb98-4c6e-8fed-67365ff05357-new">
#             New Password
#            </label>
#           </div>
#           <input autocomplete="off" class="pass-hint new" id="a589574e-bb98-4c6e-8fed-67365ff05357-new" name="new" type="password" value=""/>
#           <span class="password-eye-icon icon-eye hidden">
#           </span>
#           <div class="password-strength-indicator" data-max="32" data-min="10" data-strength="3">
#            <span class="text too-short">
#             Too Short
#            </span>
#            <span class="text weak">
#             Weak
#            </span>
#            <span class="text medium">
#             Medium
#            </span>
#            <span class="text strong">
#             Strong
#            </span>
#            <span class="text very-strong">
#             Very Strong
#            </span>
#            <span class="text too-long">
#             Too Long
#            </span>
#           </div>
#          </div>
#          <input class="button primary submit" disabled="disabled" type="submit" value="Submit"/>
#         </form>
#         <a class="fakeFormLastElement" href="#">
#         </a>
#        </div>
#        <div class="success-template hidden">
#         <h2>
#          Password Changed Successfully
#         </h2>
#         <p>
#          Your password has been changed
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="createAccountPopupHead" class="popup registration-popup hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <a aria-label="close dialog" class="close" href="#" role="button">
#        <i class="icon-tools_close">
#        </i>
#       </a>
#       <div class="modal__header">
#        <div class="logoDropZone" data-pb-dropzone="logoDropZone">
#        </div>
#        <h2 id="createAccountPopupHead">
#         Create a new account
#        </h2>
#       </div>
#       <div class="modal__body">
#        <form action="/action/registration" class="registration-form" method="post">
#         <input name="redirectUri" type="hidden" value="/toc/15222594/current"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="4e647394-f751-4441-baa4-df426bca4b6e.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="4e647394-f751-4441-baa4-df426bca4b6e.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="submit">
#          <input class="button submit primary" type="submit" value="Register"/>
#         </div>
#        </form>
#        <div class="center">
#         <a class="show-login" href="/action/showLogin">
#          Returning user
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-labelledby="resetPasswordPopupHead" class="popup top-drawer request-reset-password-drawer hidden" role="dialog" tabindex="-1">
#      <div class="content">
#       <div class="modal__header">
#        <a aria-label="close dialog" class="cancel close" href="#" role="button">
#         <i class="icon-close_thin">
#         </i>
#        </a>
#        <div class="header_logo">
#         <img alt="" src="/pb-assets/hub-assets/pericles/logo-header-1526603583437.png"/>
#        </div>
#        <h2 id="resetPasswordPopupHead">
#         Forgot your password?
#        </h2>
#        <p class="sub">
#         Enter your email address below.
#        </p>
#       </div>
#       <div class="modal__body">
#        <div class="error">
#        </div>
#        <form action="/action/requestResetPassword" class="request-reset-password-form" method="post">
#         <input name="requestResetPassword" type="hidden" value="true"/>
#         <div class="input-group">
#          <div class="input-group">
#           <div class="label">
#            <label for="email">
#             Email or Customer ID
#            </label>
#           </div>
#           <input autocapitalize="off" autocorrect="off" class="email" id="email" name="email" placeholder="Enter your email" size="15" spellcheck="false" type="text" value=""/>
#          </div>
#         </div>
#         <div class="password-recaptcha-ajax">
#         </div>
#         <div class="form-btn">
#          <input class="button btn primary submit" disabled="disabled" name="submit" type="submit" value="RESET PASSWORD"/>
#         </div>
#        </form>
#        <div class="message error">
#        </div>
#        <div class="success-template hidden">
#         <p>
#          Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div>
#      <div class="pb-dropzone" data-pb-dropzone="col-0" title="col-0">
#      </div>
#     </div>
#     <div aria-labelledby="requestUsernamePopupHead" class="popup top-drawer request-username-drawer username-popup hidden" role="dialog" tabindex="-1">
#      <a aria-label="close dialog" class="close" href="#" role="button">
#       <i class="icon-close_thin">
#       </i>
#      </a>
#      <div class="content">
#       <h2 id="requestUsernamePopupHead">
#        Request Username
#       </h2>
#       <div class="form">
#        <p>
#         Can't sign in? Forgot your username?
#        </p>
#        <p class="sub">
#         Enter your email address below and we will send you your username
#        </p>
#        <div class="message error">
#        </div>
#        <form action="/action/requestUsername" method="post">
#         <input name="requestUsername" type="hidden" value="requestUsername"/>
#         <div class="input-group">
#          <div class="label">
#           <label for="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email">
#            Email or Customer ID
#           </label>
#          </div>
#          <input class="email" id="ac834f24-aa07-4ad2-9d13-f77c843f21cb.email" name="email" size="15" type="text" value=""/>
#         </div>
#         <div class="username-recaptcha-ajax">
#         </div>
#         <input class="button primary submit" disabled="disabled" name="submit" type="submit" value="Submit"/>
#         <div class="center">
#          <a class="cancel" href="#">
#           Close
#          </a>
#         </div>
#        </form>
#       </div>
#       <div class="success-template hidden note">
#        <p>
#         If the address matches an existing account you will receive an email with instructions to retrieve your username
#        </p>
#       </div>
#      </div>
#     </div>
#     <!-- Belongs at the bottom of the page -->
#     <script type="text/javascript">
#      if(window._satellite) {
# _satellite.pageBottom();
# }
#     </script>
#    </div>
#   </div>
#   <script src="/wro/kw3w~article-metrics-phase2.js" type="text/javascript">
#   </script>
#   <script src="/products/acropolis/pericles/releasedAssets/js/build.lazyload.bundle-8dac7d47aa67e1e1f22b.js">
#   </script>
#   <script src="/products/acropolis/pericles/releasedAssets/js/main.bundle-c2749580d44310b644ab.js">
#   </script>
#   <script src="/wro/kw3w~product.js" type="text/javascript">
#   </script>
#   <script>
#    var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"6cb0c723b8497403","token":"f3dd54df2ac243bab2129483f57546d1","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194">
#   </script>
#  </body>
# </html>

# %%
# Get the title
title = soupMRM.title
print(title)
# Out:
# <title> Magnetic Resonance in Medicine: Vol 87, No 2</title>

# %%
# Print out the text
text = soupMRM.get_text()
print(soup.text)

# Another way to extract text
# str(all_links[103]).split("<h2>")[1].replace("</h2></a>", "")
# Out:
# var $DoubleClickZone = "magres-med_mrm";var $DoubleClickSite =  "wly.radiol.imag_000105";digitalData = {"site":{"ip":"152.78.0.24","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2022-01-09"},"identities":[{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"ReferrerUser","uuid":"5a2c1d70-1255-4a45-95f3-a3aa3a2771fb"},{"type":"InstitutionUser","uuid":"58cbd8e6-3c5d-4fc0-ac26-57c4792d2c4b","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALWB000204"}]},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"SmartGroupUser","uuid":"cb1790a9-a0b9-40b3-915d-806df593aeeb"},{"type":"ReferrerUser","uuid":"6401b279-b825-4f41-a389-04e29feb967f"},{"type":"InstitutionUser","uuid":"bfa4ccf8-8126-488a-b090-da278aa7b4d9","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOG00017"}]},{"type":"BasicGroup","uuid":"6a17ff38-0daf-4f0a-b4eb-b42c69d5c12f","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000007783"}]},{"type":"BasicGroup","uuid":"9cb21bff-5e36-40b2-9183-08a76524dc18","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL57933332"}]},{"type":"InstitutionUser","uuid":"a7606ea9-e934-4307-a3d4-c30ec2175d59","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"ALOB00014"}]},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"RegionUser","uuid":"3147507a-46c1-4f33-a077-4feac12c6b71"},{"type":"SmartGroupUser","uuid":"1a6297fb-6679-4882-a4c2-fdd124624edf"},{"type":"SmartGroupUser","uuid":"77da7ca2-c9f3-4f94-9737-922e1d15b7d9"},{"type":"SmartGroupUser","uuid":"8032f17e-5050-4fb4-9c40-e1f6875d5c2b"},{"type":"BasicGroup","uuid":"2f6750d5-f13f-4356-939b-048ac1423e64"},{"type":"SmartGroupUser","uuid":"a4187e00-f28e-4754-9a0f-1eb306fb0679"},{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"BasicGroup","uuid":"32489ba7-57d6-43ed-b717-a0de5ed5ca0e"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"InstitutionUser","uuid":"1b19994e-f6cd-4a6e-b151-a166eb757a02","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EALEM00084"}]},{"type":"InstitutionUser","uuid":"838af7aa-2073-4eca-9e95-df167c7953bb","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"SOUTHA450S"}]},{"type":"InstitutionUser","uuid":"a454dd84-0b2c-4d7b-804b-20fd42da68c7","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"P#JISC"}]},{"type":"BasicGroup","uuid":"8b5697d0-0580-43b3-83ea-a258c8085ad5","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004148"}]},{"type":"InstitutionUser","uuid":"2196ade6-df1b-4d0d-b877-7d8cca58ee79","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"PARENTNESLI"}]},{"type":"BasicGroup","uuid":"8d568359-32d1-4757-be79-b72d00d11429"},{"type":"BasicGroup","uuid":"a9298b81-eb3e-4dfb-82a5-86f98d156f4d","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"CORE00000004150"}]},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"InstitutionUser","uuid":"c2c7b09d-2b4d-4ce1-b401-b744073e0ebc","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000165532"}]},{"type":"BasicGroup","uuid":"f0737c70-8d27-48b0-8b44-af576d0063e8","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL00000068532"}]},{"type":"SmartGroupUser","uuid":"261f34be-39f9-4f9e-8feb-500f73213904"},{"type":"InstitutionUser","uuid":"ca0c2bfa-0ec9-4312-aa4b-4c51702429d4","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"EAL0000647"}]},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"20d013f5-e22b-4df0-ba93-d6d925db9e32"},{"type":"RegionUser","uuid":"82409588-c43f-4337-a6a8-3272d1b7e20e"},{"type":"SmartGro ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Magnetic Resonance in Medicine: Vol 87, No 2
#
#
#
#
#
#
#
#
#
#
#
#
# /* PERICLES-7186: distorted cover images */
# .journal-info-container .cover-image__image img {
#     min-height: unset;
# }
#
# /* TEMPORARY CSS HACK TO FIX LIT-220590 */
# .icon-icon-Rss::before {
#     content: "\e629";
# }
#
# /* TEMPORARY CSS TO FIX ALIGNMENT OF TOP AD IN RIGHT RAIL */
# .publication-cover-info {
#     margin-bottom: 20px;
# }
#
# .article-row-right > .pb-ad {
#     margin-left: 0;
#     margin-bottom: 10px;
# }
#
# /* TEMPORARY HACK FOR PERICLES-6763 */
# .table-of-content .issue-item h2 {
#     font-size: 16px;
# }
#
# .table-of-content .issue-item h2 a.issue-item__title {
#     display: inline;
# }
#
# /* TEMPORARY CSS FOR PERICLES-7445 */
#
# input.saml__consent__yes {
#     background: #005274;
#     font-size: 12px;
#     font-size: .75rem;
#     padding: 12px 20px;
#     border-radius: 0;
#     margin-top: 20px;
#     margin-right: 10px;
#     width: 100px;
# }
#
# input.saml__consent__yes:hover {
#     background: #003951;
# }
#
# /* PERICLES-2166: Site-wide maintenance message */
#
# .admin-message {
#     background-color: #005274;
#     color: white;
# }
#
# /* TEMPORARY CSS FOR STAY-CONNECTED SOCIAL MEDIA ICONS */
# .stay-connected ul  {
#     list-style: none;
#     margin: 0;
#     padding: 0;
# }
#
# .stay-connected i {
#     margin-right: 10px;
#     font-size: 25px;
#     line-height: 55px;
# }
#
# .stay-connected i.icon-hubs-rg-icon,
# .stay-connected i.icon-hubs-soundcloud-icon {
#     font-size: 41px;
# }
#
# .stay-connected .icon-hubs-pinterest-icon:before {
#     color: white;
# }
#
# .stay-connected .icon-hubs-pinterest-icon {
#     background-color: #BD081C;
#     border: solid #BD081C;
#     border-width: 8px;
# }
#
# /* PERICLES-5833: TEMPORARY CSS TO ADJUST POSITION OF ADS */
# .article-mpu-bottom .pb-ad {
#     margin: 0 0 0 195px;
# }
#
#
# .article-mpu-top .pb-ad {
#     padding-top: 20px;
#     margin: 0 0 -35px 0;
# }
#
# .banner-wrapper .pb-ad {
#     padding: 0;
# }
#
# /* TEMPORARY CSS FOR THE SOCIETY MEMBER LOGIN PAGE */
# .society-member-login .widget__header,
# .society-member-login .show-registration,
# .society-member-login .show-request-reset-password {
#     display: none;
# }
#
# .society-member-login .login-form {
#     margin-top: 20px;
# }
#
# .society-member-login .widget__body .input-group+.input-group {
#     margin-top: 15px;
# }
#
#
# /* TEMPORARY CSS TO HIDE FPI IN TOP CONTENT ACTION WIDGET */
# .top-content .firstPageImage {
# 	display: none;
# }
#
#
# .custom-page-pericles .main-content :target:before {
# 	content: "";
# 	display: block;
# 	height: 140px;
# 	margin: -140px 0 0;
# }
#
# /* PERICLES-4777: TEMPORARY CSS TO HIDE OPTIONS IN THE SIDEBAR ON MRW PAGES */
# .journal-resources li#TableofContents,
# .journal-resources li#Topics,
# .journal-resources li#ArticleTitlesAZ {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR UNWANTED MARGIN BELOW COVER IMAGES ON BOOK SERIES PAGES */
# .remove-margin .cover-image {
# 	margin: 0;
# }
#
# /* TEMPORARY FIX TO MAKE IT POSSIBLE TO EDIT RICH TEXT WIDGETS IN SLIDESHOWS */
# .bs .modal-backdrop {
# 	display: none;
# }
#
# /* TEMPORARY FIX FOR MENU POSITION */
# .hubpage-menu nav {
# 	padding-bottom: 0;
# 	position: relative;
# }
#
# /* TEMPORARY FOR MARGIN AROUND ADS */
# .advert.advert-leaderboard {
# 	margin: 15px 0;
# }
#
# .banner-wrapper {
# 	box-shadow: none;
# }
#
# /* TEMPORARY TO FIX OVERFLOW FOR P IN JOURNAL-NEWS SLIDESHOWS */
# .journal-news .slide-item p {
# 	overflow: unset;
# }
#
# /* EDITOR HIGHLIGHTS CSS */
# div.ancillary-content.relateditem div.content {
# 	height: 10em;
# }
# div.ancillary-content.listitem div.content {
# 	height: 4em;
# }
#
# /* TEMPORARY Fix heading on Topical Index widget for MRWs */
# .topical-index h2 {
#     margin: 15px 0;
#     font-size: 1.75rem;
#     line-height: 28px;
#     color: #1c1d1e;
#     font-family: Source Serif Pro,serif;
#     font-weight: normal;
# }
#
# /* PERICLES-7288 */
# .issue-supplementary-files, .cover-image__virtual-issue {
#     margin-bottom: 15px;
# }
#
# /* PERICLES-8875 */
# .journal-news .slide-item img {
#     float: left;
#     margin-right: 10px;
# }
#
# /* DO NOT REMOVE */
# li[heading="Restore Points"].ng-isolate-scope,
# li[heading="Disable Widgets"].ng-isolate-scope {
#     display: none!important;
# }
#
# .modal-header .widgetOrigin {
#     display: none;
# }
#
# /* PERICLES-10090 */
# .cover-image__image img {
#     max-width: 150px;
#     max-height: 150px;
# }
#
# /* LIT-282003 */
# .journal-info-container span.info_value:after {
#     content: '\003B';
# }
#
# .journal-info-container span.info_value:last-child:after {
#     content: '';
# }
#
# /* LIT-299510 */
# h1.citation__title {
#     font-size: 22px;
#     font-size: 1.375rem;
# }
#
# @media (max-width: 991px) {
#     h1.citation__title {
#         font-size: 18px;
#         font-size: 1.125rem;
#     }
#     h1.citation__title:after {
#         content: "";
#     }
# }
#
# /* LIT-295816 */
# .search__item .item__body .meta__details a.publication_meta_serial:after {
#     content: "";
#     margin: 0;
# }
# .search__item .item__body .meta__details a.publication_meta_volume_issue:before {
#     content: "|";
#     margin-left: 4px;
#     margin-right: 4px;
# }
#
# /* PPV */
# .cart-indicator__wrapper {
#     padding: 0;
# }
#
# /* TrendMD Test */
# #article__content #trendmd-suggestions{
#     margin-top: 40px !important;
#     border-top: 1px solid #ddd;
#
# }
# body #article__content .trendmd-widget-container {
#     margin-top: 20px !important;
# }
#
# body #article__content .trendmd-widget-header__heading{
#     font-size: 20px !important;
#     margin-bottom: 30px !important
# }
# body #article__content .trendmd-widget-list-item__link, body #article__content .trendmd-widget-list-item__meta{
#     font-family:'Open Sans', arial, sans-serif !important;
# }
# body #article__content .trendmd-widget{
# 	font-size:16px !important;
# }
# body #article__content .trendmd-widget-list-item{
# 	margin-bottom:24px !important;
# }
# body #article__content .trendmd-widget-list-item__link{
# 	color: #005293 !important;
# }
# body #article__content .trendmd-widget-list-item__meta{
# 	color: #5d5d5d !important;
# 	font-size:14px !important;
# 	margin-top:3px !important;
# }
# body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 	width: 47% !important;
# }
#
# @media (max-width: 450px) {
# 	body #article__content .trendmd-widget_horizontal .trendmd-widget-section{
# 		width: 95% !important;
# 	}
# }
#
# #pane-pcw-related .trendmd-widget-header__heading{
# 	font-size: 18px !important;
# 	font-family:'Open Sans', arial, sans-serif !important;
# }
# #pane-pcw-related .trendmd-widget-container{
# 	padding:0 20px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__link{
# 	 font-family:'Open Sans', arial, sans-serif !important;
# 	 font-size:14px !important;
# 	 color: #005293 !important;
# 	 display:block;
# 	 margin-bottom: 5px !important;
# }
# #pane-pcw-related .trendmd-widget-list-item__meta{
# 	font-family:'Open Sans', arial, sans-serif !important;
# 	color:#666 !important;
# }
# #pane-pcw-related .trendmd-widget-list-item{
# 	margin-bottom:20px !important;
# }
#
#
#
#
#
#
#
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments )
# 	}).q = []);
#
# 	( function () {
# 		var k , m , s , src;
# 		k = document.createElement ( 'script' );
# 		k.type 	= 'text/javascript';
# 		k.async = true;
# 		src = ( m = location.href.match ( /\bkxsrc=([^&]+)/ )) && decodeURIComponent ( m [ 1 ]);
# 		k.src = /^https?:\/\/([a-z0-9_\-\.]+\.)?krxd\.net(:\d{1,5})?\//i.test ( src ) ? src : src === 'disable' ? '' : ( location.protocol === 'https:'?'https:':'http:' ) + '//cdn.krxd.net/controltag?confid=JMOONjNh';
# 		s = document.getElementsByTagName ( 'script' ) [ 0 ];
# 		s.parentNode.insertBefore ( k , s );
# 	} ());
#
#
#
# 	window.Krux || (( Krux = function () {
# 		Krux.q.push ( arguments );
# 	}).q = []);
#
# 	( function () {
# 		function retrieve ( n ) {
# 			var m , k = 'kx' + n;
# 			if ( window.localStorage ) {
# 				return window.localStorage [ k ] || '';
# 			} else if ( navigator.cookieEnabled ) {
# 				m = document.cookie.match ( k + '=([^;]*)' );
# 				return ( m && unescape ( m [ 1 ])) || '';
# 			} else {
# 				return '';
# 			}
# 		}
#
# 		Krux.user = retrieve ( 'user' );
# 		Krux.segments = retrieve ( 'segs' ) && retrieve ( 'segs' ).split ( ',' ) || [];
# 	}) ();
#
#
#
# 	var gs_channels = 'default';
#
#
#
#
# 	var $WileyGooglePublisherID = 2215;
#
# 	if (!$DoubleClickSite) {
# 		switch("pericles") {
# 	  		case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickSite = "wly.agriculture_000018";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickSite = "wly.aqua.fish_000017";
# 				break;
# 			case "aasldpubs":
#   				var $DoubleClickSite = "wly.gastro.hep_000059";
#   				break;
# 			case "headachejournal":
#   				var $DoubleClickSite = "wly.neurology_000086";
#   				break;
#   			case "wildlife":
# 				var $DoubleClickSite = "wly.zoology_000120";
# 				break;
# 			default:
# 				var $DoubleClickSite = "undefined-site";
# 		};
#   	};
#
# 	if (!$DoubleClickZone) {
# 		switch("pericles") {
# 			case "acsess.onlinelibrary.wiley.com":
# 				var $DoubleClickZone = "Agriculture_ACSESS_Hub";
# 				break;
# 			case "afspubs":
# 				var $DoubleClickZone = "AFS_HUB";
# 				break;
# 			case "aasldpubs":
# 				var $DoubleClickZone = "AASLD-pubs_HUB";
# 				break;
# 			case "headachejournal":
# 				var $DoubleClickZone = "headache_HUB";
# 				break;
# 			case "wildlife":
# 				var $DoubleClickZone = "tws_HUB";
# 				break;
# 			default:
# 				var $DoubleClickZone = "undefined-zone";
# 		};
# 	};
#
# 	var $GooglePublisherCategory = "/" + $WileyGooglePublisherID + "/" + $DoubleClickSite + "/" + $DoubleClickZone;
#
#
# 	var googletag = googletag || {};
#
# 	googletag.cmd = googletag.cmd || [];
#
# 	( function () {
#
# 		var gads = document.createElement ( 'script' ) ,
# 		node = document.getElementsByTagName ( 'script' ) [ 0 ] ;
#
# 		gads.async = true;
# 		gads.src = document.location.protocol + '//www.googletagservices.com/tag/js/gpt.js';
#
# 		node.parentNode.insertBefore ( gads , node );
#
# 	}) ();
#
#
# 	googletag.cmd.push ( function () {
#
# 		var sizes = {
# 			leaderboard : googletag.sizeMapping ()
# 				.addSize ([ 300 , 100 ] , [ 300 , 50 ])
# 				.addSize ([ 740 , 100 ] , [ 728 , 90 ])
# 				.addSize ([ 0 , 0 ] , 'fluid')
# 				.build () ,
# 			rail : googletag.sizeMapping ()
# 				.addSize ([ 0 , 0 ] , [ 300 , 250 ])
# 				.build (),
# 			interstitial : googletag.sizeMapping ()
# 							.addSize ([ 0 , 0 ] , [ 640 , 480 ])
# 							.build ()
#
# 		};
#
#
# 		gptPage = window.digitalData && digitalData.page && digitalData.page.page ? digitalData.page.page : "blank";
# 		gptSubPage = window.digitalData && digitalData.page && digitalData.page.subPage ? digitalData.page.subPage : "blank";
#
#
# 		function gptClean(gptText){
# 			if(typeof(gptText)=="string"){
# 				gptText = gptText.replace(/\&/g,'%26');
#
#
# 				return gptText.replace(/\^|\*|#|\$|\"|\'|\=|\,|\!|\+|\~|\;|\(|\)|\<|\>|\[|\]|\?|\%|\:|\@|\;|\&|\||\{|\}|\\|/g,'');
#
# 			}
# 			return "blank";
# 		}
#
#
# 		googletag.pubads ()
# 			.setTargeting ( 'property' 	, 'value-of-property' 	) 	// Change and duplicate this line for as many additional keywords to send
# 			.setTargeting ( 'doi' , gptClean('10.1002/mrm.v87.2')) // Publication DOI
# 			.setTargeting ( 'gs_cat' 	, gs_channels 		) 	// Grapeshot
# 			.setTargeting ( 'ksg' 		, Krux.segments 	) 	// Krux
# 			.setTargeting ( 'kuid' 		, Krux.user 		) 	// Krux
# 			.setTargeting ( 'pbPage', gptClean(gptPage) )
# 			.setTargeting ( 'pbSubPage', gptClean(gptSubPage) )
# 			.setTargeting ( 'urlpath', gptClean(document.location.pathname));
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-leaderboard' )
# 			.defineSizeMapping ( sizes.leaderboard )
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-1' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-1')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-rail-2' )
# 			.defineSizeMapping ( sizes.rail )
# 			.setTargeting ( 'Position', 'advert-rail-2')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
# 		googletag.defineSlot ( $GooglePublisherCategory, 'fluid', 'advert-video' )
# 			.defineSizeMapping ( sizes.interstitial )
# 			.setTargeting ( 'Position', 'advert-video')
# 			.addService ( googletag.pubads ())
# 			.setCollapseEmptyDiv ( true );
#
#
# 		googletag.pubads ().enableSingleRequest ();
# 		googletag.enableServices ();
# 	});
# 	//]]>
#
#
#
# 	try {
# 		GCN.onecount.setTargeting();
# 	} catch (e) {
# 	}
#
#
#
# (function(){window['__CF$cv$params']={r:'65d1a8e0c92cd32a',m:'67aa9be47daef6356de6609e1160d5d3eaa5ffa2-1623318251-1800-AaebyrEA/0jUMhvUAOk0j/wUR0nsoq6UdvlB2Moolrehflza6iixm14P9MalQ+R8Vryip4agQZ71w0jrBJXqJEfdW+xLLufgGKZPRxJhvd4I3qMsuBop2ACJDvs+WtlCjNmSktt5c/WE8XBjCql0oD4=',s:[0x5aebccbc48,0x5cc5562061],}})();
#
#
#
#
#
#
#
#
#
#         function getParameter(parameterName) {
#             let result = null,
#                 tmp = [];
#             location.search
#                 .substr(1)
#                 .split("&")
#                 .forEach(function (item) {
#                     tmp = item.split("=");
#                     if (tmp[0] === parameterName) result = tmp[1];
#                 });
#             return result;
#         }
#
#         var SeamlessAccessService = {
#             spUrl: "/action/ssostart",
#             returnURL: window.location.href,
#             my_context: 'seamlessaccess.org',
#
#             getWAYFLessUrl: function (entityId) {
#                 let redirectURL = getParameter('redirectUri');
#                 if(redirectURL == null){
#                     redirectURL = encodeURIComponent(this.returnURL);
#                 }
#                 if(redirectURL.indexOf('saml_referrer') < 0){
#                     redirectURL += encodeURIComponent(((redirectURL.indexOf('?') !== -1) ? '&' : '?') + 'saml_referrer');
#                 }
#                 return this.spUrl + "?idp=" + encodeURIComponent(entityId)
#                     + "&redirectUri=" + redirectURL;
#             },
#             retrieveEntity: function () {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 return new Promise(function (resolve, reject) {
#                     ps.entities(self.my_context)
#                         .then(function (res) {
#                             // get the results
#                             var results = res.data;
#                             return resolve(results);
#                         }, function (err) {
#                             // failed
#                             reject('retrieve entity error: ' + err);
#                         });
#                 });
#             },
#             updateEntity: function (entitydata) {
#                 var self = this;
#                 var ps = new thiss.PersistenceService('https://service.seamlessaccess.org/ps/');
#
#                 var jsonObj = {};
#                 try {
#                     //try to parse it, if it is a json string
#                     jsonObj = JSON.parse(entitydata.val());
#                 } catch (e) {
#                     jsonObj = entitydata;
#                 }
#                 return new Promise(function (resolve, reject) {
#                     ps.update(self.my_context, jsonObj)
#                         .then(function (res) {
#                             // Process the results
#                             var ssoInstitutions = res.data;
#                             return resolve(ssoInstitutions);
#                         }, function (err) {
#                             // failed
#                             console.log('failed to update the local storage duo to: ' + err);
#                             reject(err);
#                         });
#                 })
#             },
#             getAccessibleEntityStatus: function (doi, entityId, entityTitle) {
#                 return new Promise(function (resolve) {
#                     $.ajax({
#                         type: 'POST',
#                         url: '/action/seamlessAccess',
#                         accept: {
#                             text: "application/json"
#                         },
#                         data: {doi: doi, entityid: entityId, entityTitle: entityTitle, eventGroupKey: 'bd076971-27f4-4b1d-8cfa-29c5f58ff0f2'}
#
#                     }).done(function (status) {
#                         return resolve(status);
#                     });
#                 });
#             },
#             getEntitiesWithAllInfo: function (doi) {
#                 let self = this,
#                     arrayOfPromises = [];
#                 return new Promise(function (resolve, reject) {
#                     self.retrieveEntity().then(function (res) {
#                         let allSsoInstitutions = res;
#                         for (let i in allSsoInstitutions) {
#                             let ssoInstitution = allSsoInstitutions[i];
#                             arrayOfPromises.push(new Promise(function (resolve) {
#                                 self.getAccessibleEntityStatus(doi, ssoInstitution.entity.entityID, ssoInstitution.entity.title)
#                                     .then(function (entityStatus) {
#                                         resolve({
#                                             entityID: ssoInstitution.entity.entityID,
#                                             entityTitle: ssoInstitution.entity.title,
#                                             entityStatusObj: entityStatus,
#                                             entitySsoUrl: self.getWAYFLessUrl(ssoInstitution.entity.entityID)
#                                         });
#                                     }, function (err) {
#                                         console.log('failed to get the entity status: ' + err);
#                                     });
#                             }));
#                         }
#                         Promise.all(arrayOfPromises)
#                             .then(function (finalResponse) {
#                                 resolve(finalResponse);
#                             });
#
#                     }).catch(function (err) {
#                         reject(err);
#                     })
#                 });
#             }
#         };
#
#         window.addEventListener('load', function () {
#             document.querySelectorAll(".sso-institution").forEach(function (institution) {
#                 var entityId = institution.getAttribute('data-entityid');
#                 var entityName = institution.getAttribute('data-name');
#                 var entitydata = {
#                     entityID: entityId,
#                     title: entityName
#                 };
#                 institution.addEventListener("click", function (e) {
#                     e.preventDefault();
#                     var self = this;
#                     SeamlessAccessService.updateEntity(entitydata).then(function (res) {
#                         console.log(res);
#                         window.location.href = self.href;
#                     }).catch(function (err){
#                         window.location.href = self.href;
#                     });
#                 });
#             });
#         });
#
#
#
#         (function() {
#             function riskifiedBeaconLoad() {
#                 var store_domain = 'https://onlinelibrary.wiley.com';
#                 var session_id = 'aaaZ9JNVdN5zc5FfKw74x';
#                 var url = ('https:' == document.location.protocol ? 'https://' : 'http://')
#                     + "beacon.riskified.com?shop=" + store_domain + "&sid=" + session_id;
#                 var s = document.createElement('script');
#                 s.type = 'text/javascript';
#                 s.async = true;
#                 s.src = url;
#                 var x = document.getElementsByTagName('script')[0];
#                 x.parentNode.insertBefore(s, x);
#             }
#             if (window.attachEvent)
#                 window.attachEvent('onload', riskifiedBeaconLoad)
#             else
#                 window.addEventListener('load', riskifiedBeaconLoad, false);
#         })();
#
#
#     var digitalData = window.digitalData ? window.digitalData : {};
#     digitalData.page.title = " Magnetic Resonance in Medicine: Vol 87, No 2";
#
#
#
#
# Skip to Main Content
#
#
#
#
#
#
#
#
#
#
#
#
# Working off-campus? Learn about our remote access options
#
#
#
#
#
#
#
# University of Southampton
#
#
#
#
#
#
#
#
#
# University of Southampton
#
#
#
# Search withinThis JournalAnywhereSearch term  Advanced Search  Citation SearchSearch term  Advanced Search  Citation Search
#
#
#
#
#
#
#
#
#
#
#
#
# Login / Register
#
#
#
#
#
#
#
#
#
#
#  Journal list menu
#
#
#
#
# Journal
#
#
#
#
#
# Articles
#
#
#
#
#
#
# Actions
#
# Tools
#
# Follow journal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-leaderboard' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
# li.menu-item[data-menu-label="Accepted Articles"] {
#   display: none;
# }
#
#
#
# Magnetic Resonance in Medicine
#
#
#
# var image = new Image();
#
# image.onload = function() {
#    // if the image exists
#     document.getElementById("journal-banner-image").style.display = "block";
# }
#
# image.onerror = function() {
#     // if the image does not exist
#     document.getElementById("journal-banner-text").style.marginBottom = "15px";
#     document.getElementById("journal-banner-text").style.fontSize = "22px";
# }
#
# image.src = "/pb-assets/journal-banners/15222594-1589988604920.jpg";
#
#
#
#
# Navigation BarMenuHomeHomeAboutOverviewContactEditorial BoardFormer EditorsJournal MetricsAdvertisePermissionsContributeAuthor Guidelines Style Guide Open AccessSubmit a Manuscript For Referees BrowseAccepted ArticlesEarly ViewCurrent IssueAll IssuesEditor's PicksCover GalleryVirtual Issues
#
#
# Follow journal
#
# Alert
# Facebook page
# Twitter channel
#
# Twitter channel
#
# RSS Feeds
#
# Most recent (RSS)
#
# Most cited (RSS)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# IssueVolume 87,  Issue 2Pages: C1, 551-1092February 2022
#
# Previous Issue
#
#
#
# GO TO SECTION
#
#
#
#
#
#
#
#
# Export Citation(s)
# Export CitationsFormatPlain TextRIS (ProCite, Reference Manager)EndNoteBibTexMedlarsRefWorksType of importCitation file or direct importIndirect import or copy/pasteCancelNext< Go backCitation HelpExport
#
#
# COVER IMAGE
#
# Free Access
#
#
# free
#
# Three-dimensional quantification of circulation using finite-element methods in four-dimensional flow MR data of the thoracic aorta
# Pages: C1
# First Published: 26 November 2021
#
#
# PDFRequest permissions
#
#
#
#
# ISSUE INFORMATION
#
# Free Access
#
#
# free
#
# Issue Information
# Pages: 551-560
# First Published: 26 November 2021
#
#
#
# First PagePDFRequest permissions
#
#
#
#
# RESEARCH ARTICLES—SPECTROSCOPIC METHODOLOGY
#
# Open Access
#
#
# oa
#
# Absolute choline tissue concentration mapping for prostate cancer localization and characterization using 3D 1H MRSI without water-signal suppression
#
#  Nassim Tayari,
#  Alan J. Wright,
#  Arend Heerschap,
#
#
# Pages: 561-573
# First Published: 23 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Uncertainty in denoising of MRSI using low-rank methods
#
#  William T. Clarke,
#  Mark Chiew,
#
#
# Pages: 574-588
# First Published: 21 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# TECHNICAL NOTE—SPECTROSCOPIC METHODOLOGY
#
# Full Access
#
#
# full
#
# Influence of editing pulse flip angle on J-difference MR spectroscopy
#
#  Sofie Tapper,
#  Steve C. N. Hui,
#  Muhammad G. Saleh,
#  Helge J. Zöllner,
#  Georg Oeltzschner,
#  Jamie Near,
#  Brian J. Soher,
#  Richard A. E. Edden,
#
#
# Pages: 589-596
# First Published: 14 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# RESEARCH ARTICLE—PRECINICAL AND CLINICAL SPECTROSCOPY
#
# Full Access
#
#
# full
#
# Spectroscopy-based multi-parametric quantification in subjects with liver iron overload at 1.5T and 3T
#
#  Gregory Simchick,
#  Ruiyang Zhao,
#  Gavin Hamilton,
#  Scott B. Reeder,
#  Diego Hernando,
#
#
# Pages: 597-613
# First Published: 23 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# RESEARCH ARTICLES—IMAGING METHODOLOGY
#
# Full Access
#
#
# full
#
# External Dynamic InTerference Estimation and Removal (EDITER) for low field MRI
#
#  Sai Abitha Srinivas,
#  Stephen F. Cauley,
#  Jason P. Stockmann,
#  Charlotte R. Sappo,
#  Christopher E. Vaughn,
#  Lawrence L. Wald,
#  William A. Grissom,
#  Clarissa Z. Cooley,
#
#
# Pages: 614-628
# First Published: 04 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Comparison of prospective and retrospective motion correction in 3D-encoded neuroanatomical MRI
#
#  Jakob M. Slipsager,
#  Stefan L. Glimberg,
#  Liselotte Højgaard,
#  Rasmus R. Paulsen,
#  Paul Wighton,
#  M. Dylan Tisdall,
#  Camilo Jaimes,
#  Borjan A. Gagoski,
#  P. Ellen Grant,
#  André van der Kouwe,
#  Oline V. Olesen,
#  Robert Frost,
#
#
# Pages: 629-645
# First Published: 07 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Quantitative evaluation of prospective motion correction in healthy subjects at 7T MRI
#
#  Alessandro Sciarra,
#  Hendrik Mattern,
#  Renat Yakupov,
#  Soumick Chatterjee,
#  Daniel Stucht,
#  Steffen Oeltze-Jafra,
#  Frank Godenschweger,
#  Oliver Speck,
#
#
# Pages: 646-657
# First Published: 31 August 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# MULTI-parametric MR imaging with fLEXible design (MULTIPLEX)
#
#  Yongquan Ye,
#  Jingyuan Lyu,
#  Yichen Hu,
#  Zhongqi Zhang,
#  Jian Xu,
#  Weiguo Zhang,
#
#
# Pages: 658-673
# First Published: 31 August 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# B1-gradient–based MRI using frequency-modulated Rabi-encoded echoes
#
#  Efraín Torres,
#  Taylor Froelich,
#  Paul Wang,
#  Lance DelaBarre,
#  Michael Mullen,
#  Gregory Adriany,
#  Daniel Cosmo Pizetta,
#  Mateus José Martins,
#  Edson Luiz Géa Vidoto,
#  Alberto Tannús,
#  Michael Garwood,
#
#
# Pages: 674-685
# First Published: 09 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# MRI-guided attenuation correction in torso PET/MRI: Assessment of segmentation-, atlas-, and deep learning-based approaches in the presence of outliers
#
#  Hossein Arabi,
#  Habib Zaidi,
#
#
# Pages: 686-701
# First Published: 04 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Quantification of balanced SSFP myocardial perfusion imaging at 1.5 T: Impact of the reference image
#
#  Sarah McElroy,
#  Karl P. Kunze,
#  Xenios Milidonis,
#  Li Huang,
#  Muhummad Sohaib Nazir,
#  Carl Evans,
#  Filippo Bosio,
#  Nabila Mughal,
#  Pier Giorgio Masci,
#  Radhouene Neji,
#  Reza Razavi,
#  Amedeo Chiribiri,
#  Sébastien Roujol,
#
#
# Pages: 702-717
# First Published: 23 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Pilot tone navigation for respiratory and cardiac motion-resolved free-running 5D flow MRI
#
#  Mariana B. L. Falcão,
#  Lorenzo Di Sopra,
#  Liliana Ma,
#  Mario Bacher,
#  Jérôme Yerly,
#  Peter Speier,
#  Tobias Rutz,
#  Milan Prša,
#  Michael Markl,
#  Matthias Stuber,
#  Christopher W. Roy,
#
#
# Pages: 718-732
# First Published: 05 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Magnetization-prepared spoiled gradient-echo snapshot imaging for efficient measurement of R2-R1ρ in knee cartilage
#
#  Misung Han,
#  Radhika Tibrewala,
#  Emma Bahroos,
#  Valentina Pedoia,
#  Sharmila Majumdar,
#
#
# Pages: 733-745
# First Published: 30 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Generalized low-rank nonrigid motion-corrected reconstruction for MR fingerprinting
#
#  Gastao Cruz,
#  Haikun Qi,
#  Olivier Jaubert,
#  Thomas Kuestner,
#  Torben Schneider,
#  Rene Michael Botnar,
#  Claudia Prieto,
#
#
# Pages: 746-763
# First Published: 02 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Scan-specific artifact reduction in k-space (SPARK) neural networks synergize with physics-based reconstruction to accelerate MRI
#
#  Yamin Arefeen,
#  Onur Beker,
#  Jaejin Cho,
#  Heng Yu,
#  Elfar Adalsteinsson,
#  Berkin Bilgic,
#
#
# Pages: 764-780
# First Published: 02 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# TECHNICAL NOTES—IMAGING METHODOLOGY
#
# Full Access
#
#
# full
#
# Rapid simultaneous acquisition of macromolecular tissue volume, susceptibility, and relaxometry maps
#
#  Fang Frank Yu,
#  Susie Yi Huang,
#  Ashwin Kumar,
#  Thomas Witzel,
#  Congyu Liao,
#  Tanguy Duval,
#  Julien Cohen-Adad,
#  Berkin Bilgic,
#
#
# Pages: 781-790
# First Published: 04 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Generating spiral gradient waveforms with a compact frequency spectrum
#
#  James G. Pipe,
#  Daniel D. Borup,
#
#
# Pages: 791-799
# First Published: 14 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Workflow for automatic renal perfusion quantification using ASL-MRI and machine learning
#
#  Isabell K. Bones,
#  Clemens Bos,
#  Chrit Moonen,
#  Jeroen Hendrikse,
#  Marijn van Stralen,
#
#
# Pages: 800-809
# First Published: 20 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Demonstration of fast multi-slice quasi-steady-state chemical exchange saturation transfer (QUASS CEST) human brain imaging at 3T
#
#  Hahnsung Kim,
#  Lisa C. Krishnamurthy,
#  Phillip Zhe Sun,
#
#
# Pages: 810-819
# First Published: 30 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# RESEARCH ARTICLES—PRECLINICAL AND CLINICAL IMAGING
#
# Full Access
#
#
# full
#
# Clinical translational neuroimaging of the antioxidant effect of N-acetylcysteine on neural microstructure
#
#  Sue Y. Yi,
#  Brian R. Barnett,
#  McKenzie J. Poetzel,
#  Nicholas A. Stowe,
#  John-Paul J. Yu,
#
#
# Pages: 820-836
# First Published: 30 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Comparative evaluation of polynomial and Lorentzian lineshape-fitted amine CEST imaging in acute ischemic stroke
#
#  Jing Cui,
#  Aqeela Afzal,
#  Zhongliang Zu,
#
#
# Pages: 837-849
# First Published: 30 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# TECHNICAL NOTE—PRECLINICAL AND CLINICAL IMAGING
#
# Full Access
#
#
# full
#
# Consistent depiction of the acidic ischemic lesion with APT MRI—Dual RF power evaluation of pH-sensitive image in acute stroke
#
#  Phillip Zhe Sun,
#
#
# Pages: 850-858
# First Published: 30 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# RESEARCH ARTICLES—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
#
# Open Access
#
#
# oa
#
# Echo time dependence of biexponential and triexponential intravoxel incoherent motion parameters in the liver
#
#  Tobit Führes,
#  Andreas Julian Riexinger,
#  Martin Loh,
#  Jan Martin,
#  Andreas Wetscherek,
#  Tristan Anselm Kuder,
#  Michael Uder,
#  Bernhard Hensel,
#  Frederik Bernd Laun,
#
#
# Pages: 859-871
# First Published: 28 August 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# The use of variable delay multipulse chemical exchange saturation transfer for separately assessing different CEST pools in the human brain at 7T
#
#  Bárbara Schmitz-Abecassis,
#  Elena Vinogradov,
#  Jannie P. Wijnen,
#  Thijs van Harten,
#  Evita C. Wiegers,
#  Hans Hoogduin,
#  Matthias J. P. van Osch,
#  Ece Ercan,
#
#
# Pages: 872-883
# First Published: 14 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# In vivo T1 and T2 relaxation time maps of brain tissue, skeletal muscle, and lipid measured in healthy volunteers at 50 mT
#
#  Thomas O’Reilly,
#  Andrew G. Webb,
#
#
# Pages: 884-895
# First Published: 14 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# TECHNICAL NOTE—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
#
# Full Access
#
#
# full
#
# The number of glomeruli and pyruvate metabolism is not strongly coupled in the healthy rat kidney
#
#  Sabrina Kahina Bech,
#  Haiyun Qi,
#  Christian Østergaard Mariager,
#  Esben Søvsø Szocska Hansen,
#  Efe Ilicak,
#  Frank G. Zöllner,
#  Christoffer Laustsen,
#
#
# Pages: 896-903
# First Published: 23 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
#
# Full Access
#
#
# full
#
# Self-supervised IVIM DWI parameter estimation with a physics based forward model
#
#  Serge Didenko Vasylechko,
#  Simon K. Warfield,
#  Onur Afacan,
#  Sila Kurugol,
#
#
# Pages: 904-914
# First Published: 22 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# A data-driven T2 relaxation analysis approach for myelin water imaging: Spectrum analysis for multiple exponentials via experimental condition oriented simulation (SAME-ECOS)
#
#  Hanwen Liu,
#  Tigris S. Joseph,
#  Qing-San Xiang,
#  Roger Tam,
#  Piotr Kozlowski,
#  David K. B. Li,
#  Alex L. MacKay,
#  John L. K. Kramer,
#  Cornelia Laule,
#
#
# Pages: 915-931
# First Published: 07 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# Training data distribution significantly impacts the estimation of tissue microstructure with machine learning
#
#  Noemi G. Gyori,
#  Marco Palombo,
#  Christopher A. Clark,
#  Hui Zhang,
#  Daniel C. Alexander,
#
#
# Pages: 932-947
# First Published: 21 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Recovering SWI-filtered phase data using deep learning
#
#  Christian Kames,
#  Jonathan Doucette,
#  Christoph Birkl,
#  Alexander Rauscher,
#
#
# Pages: 948-959
# First Published: 05 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Characterization of B1+ field variation in brain at 3 T using 385 healthy individuals across the lifespan
#
#  Thomas MacLennan,
#  Peter Seres,
#  Julia Rickard,
#  Emily Stolz,
#  Christian Beaulieu,
#  Alan H. Wilman,
#
#
# Pages: 960-971
# First Published: 21 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# A data-driven semantic segmentation model for direct cardiac functional analysis based on undersampled radial MR cine series
#
#  Tobias Wech,
#  Markus Johannes Ankenbrand,
#  Thorsten Alexander Bley,
#  Julius Frederik Heidenreich,
#
#
# Pages: 972-983
# First Published: 05 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Automatic segmentation of peripheral arteries and veins in ferumoxytol-enhanced MR angiography
#
#  Vahid Ghodrati,
#  Yair Rivenson,
#  Ashley Prosper,
#  Kevin de Haan,
#  Fadil Ali,
#  Takegawa Yoshida,
#  Arash Bedayat,
#  Kim-Lien Nguyen,
#  J. Paul Finn,
#  Peng Hu,
#
#
# Pages: 984-998
# First Published: 05 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Partial Fourier reconstruction of complex MR images using complex-valued convolutional neural networks
#
#  Linfang Xiao,
#  Yilong Liu,
#  Zheyuan Yi,
#  Yujiao Zhao,
#  Linshan Xie,
#  Peibei Cao,
#  Alex T. L. Leong,
#  Ed X. Wu,
#
#
# Pages: 999-1014
# First Published: 05 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Rapid calculation of static magnetic field perturbation generated by magnetized objects in arbitrary orientations
#
#  Seok-Jin Yeo,
#  So-Hee Lee,
#  Seung-Kyun Lee,
#
#
# Pages: 1015-1027
# First Published: 07 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# TECHNICAL NOTES—COMPUTER PROCESSING AND MODELING
#
# Open Access
#
#
# oa
#
# Accurate free-water estimation in white matter from fast diffusion MRI acquisitions using the spherical means technique
#
#  Antonio Tristán-Vega,
#  Guillem París,
#  Rodrigo de Luis-García,
#  Santiago Aja-Fernández,
#
#
# Pages: 1028-1035
# First Published: 31 August 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# Three-dimensional quantification of circulation using finite-element methods in four-dimensional flow MR data of the thoracic aorta
#
#  Julio Sotelo,
#  Malenka M. Bissell,
#  Yaxin Jiang,
#  Hernan Mella,
#  Joaquín Mura,
#  Sergio Uribe,
#
#
# Pages: 1036-1045
# First Published: 07 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
# RESEARCH ARTICLES—HARDWARE AND INSTRUMENTATION
#
# Open Access
#
#
# oa
#
# Control of a wireless sensor using the pulse sequence for prospective motion correction in brain MRI
#
#  Adam van Niekerk,
#  Johan Berglund,
#  Tim Sprenger,
#  Ola Norbeck,
#  Enrico Avventi,
#  Henric Rydén,
#  Stefan Skare,
#
#
# Pages: 1046-1061
# First Published: 28 August 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Open Access
#
#
# oa
#
# A silent gradient axis for soundless spatial encoding to enable fast and quiet brain imaging
#
#  Edwin Versteeg,
#  Dennis W. J. Klomp,
#  Jeroen C. W. Siero,
#
#
# Pages: 1062-1073
# First Published: 21 September 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
# Full Access
#
#
# full
#
# A 31-channel integrated “AC/DC” B0 shim and radiofrequency receive array coil for improved 7T MRI
#
#  Jason P. Stockmann,
#  Nicolas S. Arango,
#  Thomas Witzel,
#  Azma Mareyam,
#  Charlotte Sappo,
#  Jiazheng Zhou,
#  Lucas Jenkins,
#  Lincoln Craven-Brightman,
#  Eugene Milshteyn,
#  Mathias Davids,
#  W. Scott Hoge,
#  Monika Sliwiak,
#  Shahin Nasr,
#  Boris Keil,
#  Elfar Adalsteinsson,
#  Bastien Guerin,
#  Jacob K. White,
#  Kawin Setsompop,
#  Jonathan R. Polimeni,
#  Lawrence L. Wald,
#
#
# Pages: 1074-1092
# First Published: 10 October 2021
#
#
#
# Abstract
#
#                     Full text
#                 PDF
# ReferencesRequest permissions
#
#
#
#
#
#
#
#
#
# Tools
#
# Submit an Article
# Browse free sample issue
# Get content alerts
#
#
#
#
#
# Subscribe to this journal
#
#
#
#
#
#
#
#                 More from this journal
#
#
#
# ISMRM Journal Apps
# Editor's Picks
# Other Resources
# Style Guide
# Top 10 Most Downloaded Articles
# I.I. Rabi Award Winning Articles
# Full Issue PDFs
#
#
#
#
#
#
#
# 				googletag.cmd.push 		( function () {
# 					googletag.display 	( 'advert-rail-1' );
# 				});
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			googletag.cmd.push 		( function () {
# 				googletag.display 	( 'advert-rail-2' );
# 			});
#
#
#
#
#
#
#
#
#
#
#
#
#                 Related Title
#
# IssueVolume 55, Issue 1Pages: spcone, 1-312January 2022
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     .footer-links {
#         text-align: center;
#     }
#     .footer-links h3 {
#         font-weight: 300;
#     }
#     .footer-links a {
#         font-weight: 600;
#     }
#     @media (min-width: 992px) {
#         .footer-links {
#             text-align: left;
#         }
#     }
#
#
#
#                 Additional links
#
#
#
# About Wiley Online Library
#
# Privacy Policy
# Terms of Use
# Cookies
# Accessibility
# Publishing Policies
#
#
#
#
# Help & Support
#
# Contact Us
# Training and Support
# DMCA & Reporting Piracy
#
#
#
#
# Opportunities
#
# Subscription Agents
# Advertisers & Corporate Partners
#
#
#
#
# Connect with Wiley
#
# The Wiley Network
# Wiley Press Room
#
#
#
#
#
#
#
# Copyright © 1999-2022 John Wiley & Sons, Inc. All rights reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Log in to Wiley Online Library
#
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Password
#
#
#
#
#
#
#                                 Forgot password?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         NEW USER >
#
#
#
#                             INSTITUTIONAL LOGIN >
#
#
#
#
#
#
#
#
#
#
#
#
# Change Password
#
#
#
#
#
#
#
# Old Password
#
#
#
#
#
#
# New Password
#
#
#
#
# Too Short
# Weak
# Medium
# Strong
# Very Strong
# Too Long
#
#
#
#
#
#
# Password Changed Successfully
# Your password has been changed
#
#
#
#
#
#
#
#
#
#
# Create a new account
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#                     Returning user
#
#
#
#
#
#
#
#
#
#
#
#
# Forgot your password?
# Enter your email address below.
#
#
#
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
#
#
#
# Please check your email for instructions on resetting your password.
#                     If you do not receive an email within 10 minutes, your email address may not be registered,
#                     and you may need to create a new Wiley Online Library account.
#
#
#
#
#
#
#
#
# Request Username
#
# Can't sign in? Forgot your username?
# Enter your email address below and we will send you your username
#
#
#
#
# Email or Customer ID
#
#
#
#
#
#
#
# Close
#
#
#
# If the address matches an existing account you will receive an email with instructions to retrieve your username
#
#
#
#
#
# if(window._satellite) {
# _satellite.pageBottom();
# }
#
#
#
#
#
#
# var _prum=[['id','59e8fecb3847311aab7b23c6'],['mark','firstbyte',(new Date()).getTime()]];(function(){var s=document.getElementsByTagName('script')[0],p=document.createElement('script');p.async='async';p.src='//rum-static.pingdom.net/prum.min.js';s.parentNode.insertBefore(p,s);})();

# %%
all_links = soupMRM.find_all('a')

# %% [markdown]
# ### Explore Category

# %%
# h3 class corresponds to editorial

all_h3 = soupMRM.find_all("h3")

i = 0
for h3 in all_h3:
  # print(h3)
  print(h3.get_text())
  i += 1
print(i)
# Out:
# Menu
# Format
# Type of import
# COVER IMAGE
# ISSUE INFORMATION
# RESEARCH ARTICLES—SPECTROSCOPIC METHODOLOGY
# TECHNICAL NOTE—SPECTROSCOPIC METHODOLOGY
# RESEARCH ARTICLE—PRECINICAL AND CLINICAL SPECTROSCOPY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—PRECLINICAL AND CLINICAL IMAGING
# TECHNICAL NOTE—PRECLINICAL AND CLINICAL IMAGING
# RESEARCH ARTICLES—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
# TECHNICAL NOTE—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
# TECHNICAL NOTES—COMPUTER PROCESSING AND MODELING
# RESEARCH ARTICLES—HARDWARE AND INSTRUMENTATION
# About Wiley Online Library
# Help & Support
# Opportunities
# Connect with Wiley
# 21

# %% [markdown]
# ### Explore Original Research Subcategory

# %%
# h4 class corresponds to category

# all_h4 = soupMRM.find_all("h4")

# i = 0
# for h4 in all_h4:
#   # print(h4)
#   print(h4.get_text())
#   i += 1
# print(i)
# Out:
# 0

# %%
all_h2 = soupMRM.find_all("h2")

i = 0
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 3:
    print(h2.get_text())
    i += 1
print(i)

# str_h2 = str(all_h2)

# links = soupJMRI.find_all("a")
# str_links = str(links)
# print(str_h2)

# cleantext = BeautifulSoup(str_h2, "lxml").get_text()
# cleantext = BeautifulSoup(str_links, "lxml").get_text()
# print(cleantext)
# Out:
# Three-dimensional quantification of circulation using finite-element methods in four-dimensional flow MR data of the thoracic aorta
# Absolute choline tissue concentration mapping for prostate cancer localization and characterization using 3D 1H MRSI without water-signal suppression
# Uncertainty in denoising of MRSI using low-rank methods
# Influence of editing pulse flip angle on J-difference MR spectroscopy
# Spectroscopy-based multi-parametric quantification in subjects with liver iron overload at 1.5T and 3T
# External Dynamic InTerference Estimation and Removal (EDITER) for low field MRI
# Comparison of prospective and retrospective motion correction in 3D-encoded neuroanatomical MRI
# Quantitative evaluation of prospective motion correction in healthy subjects at 7T MRI
# MULTI-parametric MR imaging with fLEXible design (MULTIPLEX)
# B1-gradient–based MRI using frequency-modulated Rabi-encoded echoes
# MRI-guided attenuation correction in torso PET/MRI: Assessment of segmentation-, atlas-, and deep learning-based approaches in the presence of outliers
# Quantification of balanced SSFP myocardial perfusion imaging at 1.5 T: Impact of the reference image
# Pilot tone navigation for respiratory and cardiac motion-resolved free-running 5D flow MRI
# Magnetization-prepared spoiled gradient-echo snapshot imaging for efficient measurement of R2-R1ρ in knee cartilage
# Generalized low-rank nonrigid motion-corrected reconstruction for MR fingerprinting
# Scan-specific artifact reduction in k-space (SPARK) neural networks synergize with physics-based reconstruction to accelerate MRI
# Rapid simultaneous acquisition of macromolecular tissue volume, susceptibility, and relaxometry maps
# Generating spiral gradient waveforms with a compact frequency spectrum
# Workflow for automatic renal perfusion quantification using ASL-MRI and machine learning
# Demonstration of fast multi-slice quasi-steady-state chemical exchange saturation transfer (QUASS CEST) human brain imaging at 3T
# Clinical translational neuroimaging of the antioxidant effect of N-acetylcysteine on neural microstructure
# Comparative evaluation of polynomial and Lorentzian lineshape-fitted amine CEST imaging in acute ischemic stroke
# Consistent depiction of the acidic ischemic lesion with APT MRI—Dual RF power evaluation of pH-sensitive image in acute stroke
# Echo time dependence of biexponential and triexponential intravoxel incoherent motion parameters in the liver
# The use of variable delay multipulse chemical exchange saturation transfer for separately assessing different CEST pools in the human brain at 7T
# In vivo T1 and T2 relaxation time maps of brain tissue, skeletal muscle, and lipid measured in healthy volunteers at 50 mT
# The number of glomeruli and pyruvate metabolism is not strongly coupled in the healthy rat kidney
# Self-supervised IVIM DWI parameter estimation with a physics based forward model
# A data-driven T2 relaxation analysis approach for myelin water imaging: Spectrum analysis for multiple exponentials via experimental condition oriented simulation (SAME-ECOS)
# Training data distribution significantly impacts the estimation of tissue microstructure with machine learning
# Recovering SWI-filtered phase data using deep learning
# Characterization of B1+ field variation in brain at 3 T using 385 healthy individuals across the lifespan
# A data-driven semantic segmentation model for direct cardiac functional analysis based on undersampled radial MR cine series
# Automatic segmentation of peripheral arteries and veins in ferumoxytol-enhanced MR angiography
# Partial Fourier reconstruction of complex MR images using complex-valued convolutional neural networks
# Rapid calculation of static magnetic field perturbation generated by magnetized objects in arbitrary orientations
# Accurate free-water estimation in white matter from fast diffusion MRI acquisitions using the spherical means technique
# Three-dimensional quantification of circulation using finite-element methods in four-dimensional flow MR data of the thoracic aorta
# Control of a wireless sensor using the pulse sequence for prospective motion correction in brain MRI
# A silent gradient axis for soundless spatial encoding to enable fast and quiet brain imaging
# A 31-channel integrated “AC/DC” B0 shim and radiofrequency receive array coil for improved 7T MRI
#
#                 More from this journal
#
# Log in to Wiley Online Library
# Create a new account
# 44

# %% [markdown]
# ## Next, clean up the title list

# %%
list_h2 = []
for h2 in all_h2:
  h2_len = len(h2.get_text().split())
  if h2_len > 3:
    cells = h2.get_text()
    list_h2.append(cells)

# Delete the last element: "Log in to Wiley Online Library"
list_h2.pop()

# Insert "Issue Information" as the 2nd element
list_h2.insert(1, "Issue Information")
# MRM Vol 86 No 3
# list_h2.insert(31, "Maxwell parallel imaging")

# https://stackoverflow.com/questions/15715912/remove-the-last-n-elements-of-a-list
del list_h2[-2:]

for l in list_h2:
  print(l)
print(len(list_h2))
# Out:
# Three-dimensional quantification of circulation using finite-element methods in four-dimensional flow MR data of the thoracic aorta
# Issue Information
# Absolute choline tissue concentration mapping for prostate cancer localization and characterization using 3D 1H MRSI without water-signal suppression
# Uncertainty in denoising of MRSI using low-rank methods
# Influence of editing pulse flip angle on J-difference MR spectroscopy
# Spectroscopy-based multi-parametric quantification in subjects with liver iron overload at 1.5T and 3T
# External Dynamic InTerference Estimation and Removal (EDITER) for low field MRI
# Comparison of prospective and retrospective motion correction in 3D-encoded neuroanatomical MRI
# Quantitative evaluation of prospective motion correction in healthy subjects at 7T MRI
# MULTI-parametric MR imaging with fLEXible design (MULTIPLEX)
# B1-gradient–based MRI using frequency-modulated Rabi-encoded echoes
# MRI-guided attenuation correction in torso PET/MRI: Assessment of segmentation-, atlas-, and deep learning-based approaches in the presence of outliers
# Quantification of balanced SSFP myocardial perfusion imaging at 1.5 T: Impact of the reference image
# Pilot tone navigation for respiratory and cardiac motion-resolved free-running 5D flow MRI
# Magnetization-prepared spoiled gradient-echo snapshot imaging for efficient measurement of R2-R1ρ in knee cartilage
# Generalized low-rank nonrigid motion-corrected reconstruction for MR fingerprinting
# Scan-specific artifact reduction in k-space (SPARK) neural networks synergize with physics-based reconstruction to accelerate MRI
# Rapid simultaneous acquisition of macromolecular tissue volume, susceptibility, and relaxometry maps
# Generating spiral gradient waveforms with a compact frequency spectrum
# Workflow for automatic renal perfusion quantification using ASL-MRI and machine learning
# Demonstration of fast multi-slice quasi-steady-state chemical exchange saturation transfer (QUASS CEST) human brain imaging at 3T
# Clinical translational neuroimaging of the antioxidant effect of N-acetylcysteine on neural microstructure
# Comparative evaluation of polynomial and Lorentzian lineshape-fitted amine CEST imaging in acute ischemic stroke
# Consistent depiction of the acidic ischemic lesion with APT MRI—Dual RF power evaluation of pH-sensitive image in acute stroke
# Echo time dependence of biexponential and triexponential intravoxel incoherent motion parameters in the liver
# The use of variable delay multipulse chemical exchange saturation transfer for separately assessing different CEST pools in the human brain at 7T
# In vivo T1 and T2 relaxation time maps of brain tissue, skeletal muscle, and lipid measured in healthy volunteers at 50 mT
# The number of glomeruli and pyruvate metabolism is not strongly coupled in the healthy rat kidney
# Self-supervised IVIM DWI parameter estimation with a physics based forward model
# A data-driven T2 relaxation analysis approach for myelin water imaging: Spectrum analysis for multiple exponentials via experimental condition oriented simulation (SAME-ECOS)
# Training data distribution significantly impacts the estimation of tissue microstructure with machine learning
# Recovering SWI-filtered phase data using deep learning
# Characterization of B1+ field variation in brain at 3 T using 385 healthy individuals across the lifespan
# A data-driven semantic segmentation model for direct cardiac functional analysis based on undersampled radial MR cine series
# Automatic segmentation of peripheral arteries and veins in ferumoxytol-enhanced MR angiography
# Partial Fourier reconstruction of complex MR images using complex-valued convolutional neural networks
# Rapid calculation of static magnetic field perturbation generated by magnetized objects in arbitrary orientations
# Accurate free-water estimation in white matter from fast diffusion MRI acquisitions using the spherical means technique
# Three-dimensional quantification of circulation using finite-element methods in four-dimensional flow MR data of the thoracic aorta
# Control of a wireless sensor using the pulse sequence for prospective motion correction in brain MRI
# A silent gradient axis for soundless spatial encoding to enable fast and quiet brain imaging
# A 31-channel integrated “AC/DC” B0 shim and radiofrequency receive array coil for improved 7T MRI
# 42

# %% [markdown]
# ### Add dates first published

# %%
# li class: corresponds to "First Published"

all_li = soupMRM.find_all("li")

# i = 0
# for li in all_li:
  # li_class = li.get_attribute_list("class")
  # print(li_class)
  # if li_class == ['ePubDate']:
    # print(li.get_text())
    # i += 1
  # print(li.get_text())
  # i += 1
# print(i)

list_date = []
for li in all_li:
  li_class = li.get_attribute_list("class")
  if li_class == ['ePubDate']:
    cells = li.get_text().split(': ')[1]
    list_date.append(cells)

for l in list_date:
  print(l)
print(len(list_date))
# Out:
# 26 November 2021
# 26 November 2021
# 23 September 2021
# 21 September 2021
# 14 September 2021
# 23 September 2021
# 04 September 2021
# 07 September 2021
# 31 August 2021
# 31 August 2021
# 09 September 2021
# 04 September 2021
# 23 September 2021
# 05 October 2021
# 30 September 2021
# 02 October 2021
# 02 October 2021
# 04 September 2021
# 14 September 2021
# 20 October 2021
# 30 September 2021
# 30 September 2021
# 30 September 2021
# 30 September 2021
# 28 August 2021
# 14 September 2021
# 14 September 2021
# 23 September 2021
# 22 October 2021
# 07 September 2021
# 21 September 2021
# 05 October 2021
# 21 September 2021
# 05 October 2021
# 05 October 2021
# 05 October 2021
# 07 October 2021
# 31 August 2021
# 07 September 2021
# 28 August 2021
# 21 September 2021
# 10 October 2021
# 42

# %%
list_url = []
for link in all_links:
  if 'visitable' in str(link.get("class")): # and '/doi/' in link.get("href"):
    cells = link.get("href").replace('/doi', 'https://doi.org')
    list_url.append(cells)

for l in list_url:
  print(l)
print(len(list_url))
# Out:
# https://doi.org/10.1002/mrm.29102
# https://doi.org/10.1002/mrm.28860
# https://doi.org/10.1002/mrm.29012
# https://doi.org/10.1002/mrm.29018
# https://doi.org/10.1002/mrm.29008
# https://doi.org/10.1002/mrm.29021
# https://doi.org/10.1002/mrm.28992
# https://doi.org/10.1002/mrm.28991
# https://doi.org/10.1002/mrm.28998
# https://doi.org/10.1002/mrm.28999
# https://doi.org/10.1002/mrm.29002
# https://doi.org/10.1002/mrm.29003
# https://doi.org/10.1002/mrm.29019
# https://doi.org/10.1002/mrm.29023
# https://doi.org/10.1002/mrm.29024
# https://doi.org/10.1002/mrm.29027
# https://doi.org/10.1002/mrm.29036
# https://doi.org/10.1002/mrm.28995
# https://doi.org/10.1002/mrm.28993
# https://doi.org/10.1002/mrm.29016
# https://doi.org/10.1002/mrm.29028
# https://doi.org/10.1002/mrm.29035
# https://doi.org/10.1002/mrm.29030
# https://doi.org/10.1002/mrm.29029
# https://doi.org/10.1002/mrm.28996
# https://doi.org/10.1002/mrm.29005
# https://doi.org/10.1002/mrm.29009
# https://doi.org/10.1002/mrm.29025
# https://doi.org/10.1002/mrm.28989
# https://doi.org/10.1002/mrm.29000
# https://doi.org/10.1002/mrm.29014
# https://doi.org/10.1002/mrm.29013
# https://doi.org/10.1002/mrm.29011
# https://doi.org/10.1002/mrm.29017
# https://doi.org/10.1002/mrm.29026
# https://doi.org/10.1002/mrm.29033
# https://doi.org/10.1002/mrm.29037
# https://doi.org/10.1002/mrm.28997
# https://doi.org/10.1002/mrm.29004
# https://doi.org/10.1002/mrm.28994
# https://doi.org/10.1002/mrm.29010
# https://doi.org/10.1002/mrm.29022
# 42

# %%
# df = pd.DataFrame({'title':list_h2, 'url': list_url})
df = pd.DataFrame({'Journal': title, 
                   #'Category': list_category, 
                   'Title': list_h2, 
                   'First Published': list_date, 
                   'DOI': list_url})
df
# Out:
#                                           Journal  ...                                DOI
# 0    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29102
# 1    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28860
# 2    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29012
# 3    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29018
# 4    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29008
# 5    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29021
# 6    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28992
# 7    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28991
# 8    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28998
# 9    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28999
# 10   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29002
# 11   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29003
# 12   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29019
# 13   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29023
# 14   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29024
# 15   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29027
# 16   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29036
# 17   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28995
# 18   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28993
# 19   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29016
# 20   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29028
# 21   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29035
# 22   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29030
# 23   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29029
# 24   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28996
# 25   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29005
# 26   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29009
# 27   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29025
# 28   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28989
# 29   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29000
# 30   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29014
# 31   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29013
# 32   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29011
# 33   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29017
# 34   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29026
# 35   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29033
# 36   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29037
# 37   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28997
# 38   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29004
# 39   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28994
# 40   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29010
# 41   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29022
#
# [42 rows x 4 columns]

# %% [markdown]
# ## Third, manually create the list of category based on Issue Information
#  - See [here](https://stackoverflow.com/questions/4654414/python-append-item-to-list-n-times) for extending elements in a list for X times

# %%
# list_category = ['Cover Image', 'Issue Information', 'Commentary']

### Vol 87 No 1 ###
# list_category = ['Cover Image', 'Issue Information']
# list_category.extend(['GUIDELINES—SPECTROSCOPIC METHODOLOGY'] * 1)
# list_category.extend(['RESEARCH ARTICLE—SPECTROSCOPIC METHODOLOGY'] * 1)
# list_category.extend(['TECHNICAL NOTE—SPECTROSCOPIC METHODOLOGY'] * 1)
# list_category.extend(['RESEARCH ARTICLE—PRECLINICAL AND CLINICAL SPECTROSCOPY'] * 1)
# list_category.extend(['RESEARCH ARTICLES—IMAGING METHODOLOGY'] * 13)
# list_category.extend(['TECHNICAL NOTES—IMAGING METHODOLOGY'] * 4)
# list_category.extend(['RAPID COMMUNICATION—PRECLINICAL AND CLINICAL IMAGING'] * 1)
# list_category.extend(['RESEARCH ARTICLE—PRECLINICAL AND CLINICAL IMAGING'] * 1)
# list_category.extend(['RESEARCH ARTICLES—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH'] * 6)
# list_category.extend(['TECHNICAL NOTE—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH'] * 1)
# list_category.extend(['RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING'] * 5)
# list_category.extend(['TECHNICAL NOTE—COMPUTER PROCESSING AND MODELING'] * 1)
# list_category.extend(['RESEARCH ARTICLES—HARDWARE AND INSTRUMENTATION'] * 3)
# list_category.extend(['TECHNICAL NOTE—HARDWARE AND INSTRUMENTATION'] * 1)

### Vol 87 No 2 ###
list_category = ['Cover Image', 'Issue Information']
list_category.extend(['RESEARCH ARTICLES—SPECTROSCOPIC METHODOLOGY'] * 2)
list_category.extend(['TECHNICAL NOTE—SPECTROSCOPIC METHODOLOGY'] * 1)
list_category.extend(['RESEARCH ARTICLE—PRECLINICAL AND CLINICAL SPECTROSCOPY'] * 1)
list_category.extend(['RESEARCH ARTICLES—IMAGING METHODOLOGY'] * 11)
list_category.extend(['TECHNICAL NOTES—IMAGING METHODOLOGY'] * 4)
list_category.extend(['RESEARCH ARTICLES—PRECLINICAL AND CLINICAL IMAGING'] * 2)
list_category.extend(['TECHNICAL NOTE—PRECLINICAL AND CLINICAL IMAGING'] * 1)
list_category.extend(['RESEARCH ARTICLES—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH'] * 3)
list_category.extend(['TECHNICAL NOTE—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH'] * 1)
list_category.extend(['RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING'] * 9)
list_category.extend(['TECHNICAL NOTES—COMPUTER PROCESSING AND MODELING'] * 2)
list_category.extend(['RESEARCH ARTICLES—HARDWARE AND INSTRUMENTATION'] * 3)

i = 0
for l in list_category:
  print(l)
  i += 1
print(i)
# Out:
# Cover Image
# Issue Information
# RESEARCH ARTICLES—SPECTROSCOPIC METHODOLOGY
# RESEARCH ARTICLES—SPECTROSCOPIC METHODOLOGY
# TECHNICAL NOTE—SPECTROSCOPIC METHODOLOGY
# RESEARCH ARTICLE—PRECLINICAL AND CLINICAL SPECTROSCOPY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# TECHNICAL NOTES—IMAGING METHODOLOGY
# RESEARCH ARTICLES—PRECLINICAL AND CLINICAL IMAGING
# RESEARCH ARTICLES—PRECLINICAL AND CLINICAL IMAGING
# TECHNICAL NOTE—PRECLINICAL AND CLINICAL IMAGING
# RESEARCH ARTICLES—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
# RESEARCH ARTICLES—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
# RESEARCH ARTICLES—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
# TECHNICAL NOTE—BIOPHYSICS AND BASIC BIOMEDICAL RESEARCH
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
# RESEARCH ARTICLES—COMPUTER PROCESSING AND MODELING
# TECHNICAL NOTES—COMPUTER PROCESSING AND MODELING
# TECHNICAL NOTES—COMPUTER PROCESSING AND MODELING
# RESEARCH ARTICLES—HARDWARE AND INSTRUMENTATION
# RESEARCH ARTICLES—HARDWARE AND INSTRUMENTATION
# RESEARCH ARTICLES—HARDWARE AND INSTRUMENTATION
# 42

# %%
df.insert(1, 'Category', list_category)
df
# Out:
#                                           Journal  ...                                DOI
# 0    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29102
# 1    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28860
# 2    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29012
# 3    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29018
# 4    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29008
# 5    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29021
# 6    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28992
# 7    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28991
# 8    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28998
# 9    Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28999
# 10   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29002
# 11   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29003
# 12   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29019
# 13   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29023
# 14   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29024
# 15   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29027
# 16   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29036
# 17   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28995
# 18   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28993
# 19   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29016
# 20   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29028
# 21   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29035
# 22   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29030
# 23   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29029
# 24   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28996
# 25   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29005
# 26   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29009
# 27   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29025
# 28   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28989
# 29   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29000
# 30   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29014
# 31   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29013
# 32   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29011
# 33   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29017
# 34   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29026
# 35   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29033
# 36   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29037
# 37   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28997
# 38   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29004
# 39   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.28994
# 40   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29010
# 41   Magnetic Resonance in Medicine: Vol 87, No 2  ...  https://doi.org/10.1002/mrm.29022
#
# [42 rows x 5 columns]

# %% [markdown]
# ## Save as csv

# %%
df.to_csv(path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/mrm/mrm-vol-87-no-2.csv', 
          #path_or_buf='/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/mrm/mrm-vol-87-no-1.csv', 
          index=False)

# %% [markdown]
# ## (Optional) Save as xlsx file
#  - See [here](https://xlsxwriter.readthedocs.io/working_with_pandas.html) for instruction

# %%
# !pip install xlsxwriter
import xlsxwriter

# (Comment out after saving first sheet) Create an ExcelWriter object
# writer = pd.ExcelWriter('/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/jmri-all-summary.xlsx', engine='xlsxwriter')

# %%
df.to_excel(excel_writer=writer,
            # sheet_name='jmri-vol-54-no-1',
            # sheet_name='jmri-vol-54-no-2',
            sheet_name='jmri-vol-54-no-3',
            index=False)

# %%
# (Uncomment at the end) Close the Pandas Excel writer and output the Excel file.
writer.save()
