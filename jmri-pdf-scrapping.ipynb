# %% [markdown]
# # Web Scraping using Python

# %% [markdown]
# ## Target Journal: JMRI
#
# Relevant webpage on ISMRM:
# - https://www.ismrm.org/membership-journals/journals/
#
# Examples:
# - https://onlinelibrary.wiley.com/toc/15222586/2021/54/1
# - https://onlinelibrary.wiley.com/toc/15222586/2021/54/2
# - https://onlinelibrary.wiley.com/toc/15222586/2021/54/3

# %% [markdown]
# Tutorial: See https://theautomatic.net/2019/05/24/3-ways-to-scrape-tables-from-pdfs-with-python/

# %%
# !pip install tabula-py
import tabula

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pdf_path = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/rawdata/JMRI-Vol-54-No-3-IssueInfo-1.pdf'
out_path = '/content/drive/MyDrive/UHS-MRIPhysics-journal-web-scrapping/processed/output.csv'

# Read pdf into a list of DataFrame
dfs = tabula.read_pdf(pdf_path, pages='all', multiple_tables = True)

# Read remote pdf into a list of DataFrame
# dfs2 = tabula.read_pdf("https://github.com/tabulapdf/tabula-java/raw/master/src/test/resources/technology/tabula/arabic.pdf")

# convert PDF into CSV
tabula.convert_into(pdf_path, out_path, output_format="csv", pages='all')

# convert all PDFs in a directory
# tabula.convert_into_by_batch("input_directory", output_format='csv', pages='all')

# %%
print(dfs)
# Out:
# [   Unnamed: 0  ...  Quantitative Susceptibility Mapping Using a Multispectral Autoregressive Moving
# 0         NaN  ...      Average Model to Assess Hepatic Iron Overload
# 1         NaN  ...  Aaryani Tipirneni Sajja, Ralf B. Loeffler, Jan...
# 2         NaN  ...  Bowel Wall Visualization Using MR Enterography...
# 3         NaN  ...                  Contents and Patient Demographics
# 4         NaN  ...  Ting Ting Zhang, Wei Chou Chang, Zhen Jane Wan...
# 5         NaN  ...                                and Benjamin M. Yeh
# 6   Editorial  ...  Editorial for “Bowel Wall Visualization Using ...
# 7         NaN  ...  to Bowel Lumen Contents and Patient Demographics”
# 8         NaN  ...                        Mohammed Salman Shazeeb PhD
# 9         NaN  ...              MRI Measures of Murine Liver Fibrosis
# 10        NaN  ...  Diana M. Lindquist, Elizabeth M. Fugate, Jiang...
# 11        NaN  ...  Chandrashekhar R. Gandhi, and Jonathan R. Dillman
# ...
